# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/usr/lib/python3/dist-packages', '/home/msubirana/Documents/pivlab/clamp-analyses-crispercas/nbs/03_model_biology/02_archs4/04_crispercas']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xe9\x8e\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c7output/98_final_models/clampfull/canonical/archs4/Z.csv\x94\x8cQoutput/98_final_models/clampfull/canonical/archs4/ora/canonical/enrichment.csv.gz\x94\x8cYdata/archs4/traits/archs4_canonical_prelim89/gls-summary-archs4_canonical_prelim89.tsv.gz\x94\x8cCdata/archs4/drug_diseases_associations/smultixcan-mashr-zscores.pkl\x94\x8cUoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/symbol_ensembl.csv\x94\x8cx/home/msubirana/Documents/pivlab/clamp-analyses-crispercas/nbs/03_model_biology/02_archs4/04_crispercas/02_network.ipynb\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x01z\x94K\x00N\x86\x94\x8c\rcanonical_ora\x94K\x01N\x86\x94\x8c\x03gls\x94K\x02N\x86\x94\x8c\nsmultixcan\x94K\x03N\x86\x94\x8c\x07mapping\x94K\x04N\x86\x94\x8c\x08notebook\x94K\x05N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh!\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\')}\x94\x8c\x05_name\x94h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh\x13h\nh\x15h\x0bh\x17h\x0ch\x19h\rh\x1bh\x0eh\x1dh\x0fub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cVoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/community_edges.csv\x94\x8cVoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/community_genes.csv\x94\x8caoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/trait_supported_gene_edges.csv\x94\x8caoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/inter_lv_shared_gene_edges.csv\x94\x8cYoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/network_lv_summary.csv\x94\x8cdoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/network_lv_significant_traits.csv\x94\x8cfoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures/network_lv_significant_pathways.csv\x94\x8c_output/03_model_biology/02_archs4/04_crispercas/02_network/figures/poster_style_twas_matrix.csv\x94\x8cLoutput/03_model_biology/02_archs4/04_crispercas/02_network/notebook.complete\x94e}\x94(h\x11}\x94(\x8c\x0fcommunity_edges\x94K\x00N\x86\x94\x8c\x0fcommunity_genes\x94K\x01N\x86\x94\x8c\x0btrait_edges\x94K\x02N\x86\x94\x8c\x11shared_gene_edges\x94K\x03N\x86\x94\x8c\nlv_summary\x94K\x04N\x86\x94\x8c\tlv_traits\x94K\x05N\x86\x94\x8c\x0blv_pathways\x94K\x06N\x86\x94\x8c\x0btwas_matrix\x94K\x07N\x86\x94\x8c\x08complete\x94K\x08N\x86\x94uh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh@h5hBh6hDh7hFh8hHh9hJh:hLh;hNh<hPh=ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x11}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh\x81K\x01h\x83K\x01h\x85h~ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\x81/home/msubirana/Documents/pivlab/clamp-analyses-crispercas/nbs/03_model_biology/02_archs4/04_crispercas/02_network.executed.ipynb\x94a}\x94(h\x11}\x94h\x1dK\x00N\x86\x94sh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh\x1dh\x94ub\x8c\x06config\x94}\x94(\x8c\x08datasets\x94}\x94(\x8c\x10Brain_Mathys2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c data/pseudobulk/Brain_Mathys2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c8data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz\x94\x8c\x08features\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz\x94\x8c\x08barcodes\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c-data/pseudobulk/raw/Brain_Mathys2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x08cellName\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0ctruth_v1_col\x94\x8c\tCell_Type\x94\x8c\x11raw_cell_type_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x14projection_label_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0fcohort_manifest\x94\x8c1data/pseudobulk/Brain_Mathys2023/patient_info.csv\x94u\x8c\x0fBrain_Xiong2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1fdata/pseudobulk/Brain_Xiong2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c1data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz\x94\x8c\x08features\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz\x94\x8c\x08barcodes\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c,data/pseudobulk/raw/Brain_Xiong2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x06cellId\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x14hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x08Celltype\x94\x8c\x0ctruth_v1_col\x94\x8c\x0bSubcelltype\x94\x8c\x11raw_cell_type_col\x94\x8c\x08Celltype\x94\x8c\x14projection_label_col\x94\x8c\x08Celltype\x94\x8c\x0fcohort_manifest\x94\x8c0data/pseudobulk/Brain_Xiong2023/patient_info.csv\x94u\x8c\x0fHeart_Datar2026\x94}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c=data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad\x94\x8c\x06matrix\x94\x8c\x01X\x94\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x11raw_cell_type_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x14projection_label_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\tmin_cells\x94M\x90\x01\x8c\x07exclude\x94}\x94\x8c\x19cell_type__ontology_label\x94]\x94\x8c\x04cell\x94as\x8c\x0ctruth_v0_map\x94}\x94(\x8c\tadipocyte\x94\x8c\tAdipocyte\x94\x8c\x1eregular atrial cardiac myocyte\x94\x8c\x08AtrialCM\x94\x8c\x10endocardial cell\x94\x8c\x0bEndocardial\x94\x8c\x18cardiac endothelial cell\x94\x8c\x0bEndothelial\x94\x8c\x1emesothelial cell of epicardium\x94\x8c\nEpicardial\x94\x8c\x1cfibroblast of cardiac tissue\x94\x8c\nFibroblast\x94\x8c$endothelial cell of lymphatic vessel\x94\x8c\x14LymphaticEndothelial\x94\x8c\nlymphocyte\x94\x8c\nLymphocyte\x94\x8c\nmacrophage\x94\x8c\nMacrophage\x94\x8c\tmast cell\x94\x8c\x04Mast\x94\x8c\x0ecardiac neuron\x94\x8c\x08Neuronal\x94\x8c\x08pericyte\x94\x8c\x08Pericyte\x94\x8c&vascular associated smooth muscle cell\x94\x8c\x04VSMC\x94\x8c#regular ventricular cardiac myocyte\x94\x8c\rVentricularCM\x94u\x8c\x14projection_label_map\x94}\x94(h\xfeh\xffj\x00\x01\x00\x00j\x01\x01\x00\x00j\x02\x01\x00\x00j\x03\x01\x00\x00j\x04\x01\x00\x00j\x05\x01\x00\x00j\x06\x01\x00\x00j\x07\x01\x00\x00j\x08\x01\x00\x00j\t\x01\x00\x00j\n\x01\x00\x00j\x0b\x01\x00\x00j\x0c\x01\x00\x00j\r\x01\x00\x00j\x0e\x01\x00\x00j\x0f\x01\x00\x00j\x10\x01\x00\x00j\x11\x01\x00\x00j\x12\x01\x00\x00j\x13\x01\x00\x00j\x14\x01\x00\x00j\x15\x01\x00\x00j\x16\x01\x00\x00j\x17\x01\x00\x00j\x18\x01\x00\x00j\x19\x01\x00\x00uu\x8c\tPBMC_1k1k\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x19data/pseudobulk/PBMC_1k1k\x94\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c0data/pseudobulk/raw/PBMC_1k1k/PBMC_1k1k_raw.h5ad\x94\x8c\x06matrix\x94h\xeb\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c"sample_prefix_hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x11raw_cell_type_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x14projection_label_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x0fcohort_manifest\x94\x8c*data/pseudobulk/PBMC_1k1k/patient_info.csv\x94\x8c\x0ctruth_v0_map\x94}\x94(\x8c\x07CD4 CTL\x94\x8c\x05CD4_T\x94\x8c\tCD4 Naive\x94\x8c\x05CD4_T\x94\x8c\x11CD4 Proliferating\x94\x8c\x05CD4_T\x94\x8c\x07CD4 TCM\x94\x8c\x05CD4_T\x94\x8c\x07CD4 TEM\x94\x8c\x05CD4_T\x94\x8c\x04Treg\x94\x8c\x05CD4_T\x94\x8c\tCD8 Naive\x94\x8c\x05CD8_T\x94\x8c\x11CD8 Proliferating\x94\x8c\x05CD8_T\x94\x8c\x07CD8 TCM\x94\x8c\x05CD8_T\x94\x8c\x07CD8 TEM\x94\x8c\x05CD8_T\x94\x8c\x03gdT\x94\x8c\x04gd_T\x94\x8c\x0eB intermediate\x94\x8c\x06B_cell\x94\x8c\x08B memory\x94\x8c\x06B_cell\x94\x8c\x07B naive\x94\x8c\x06B_cell\x94\x8c\x0bPlasmablast\x94\x8c\x08Plasma_B\x94\x8c\tCD14 Mono\x94\x8c\tCD14_Mono\x94\x8c\tCD16 Mono\x94\x8c\tCD16_Mono\x94\x8c\x04cDC1\x94\x8c\x02DC\x94\x8c\x04cDC2\x94\x8c\x02DC\x94\x8c\x04ASDC\x94\x8c\x02DC\x94\x8c\x02NK\x94\x8c\x02NK\x94\x8c\x10NK Proliferating\x94\x8c\x02NK\x94\x8c\rNK_CD56bright\x94\x8c\x02NK\x94u\x8c\x14projection_label_map\x94}\x94(j4\x01\x00\x00j5\x01\x00\x00j6\x01\x00\x00j7\x01\x00\x00j8\x01\x00\x00j9\x01\x00\x00j:\x01\x00\x00j;\x01\x00\x00j<\x01\x00\x00j=\x01\x00\x00j>\x01\x00\x00j?\x01\x00\x00j@\x01\x00\x00jA\x01\x00\x00jB\x01\x00\x00jC\x01\x00\x00jD\x01\x00\x00jE\x01\x00\x00jF\x01\x00\x00jG\x01\x00\x00jH\x01\x00\x00jI\x01\x00\x00jJ\x01\x00\x00jK\x01\x00\x00jL\x01\x00\x00jM\x01\x00\x00jN\x01\x00\x00jO\x01\x00\x00jP\x01\x00\x00jQ\x01\x00\x00jR\x01\x00\x00jS\x01\x00\x00jT\x01\x00\x00jU\x01\x00\x00jV\x01\x00\x00jW\x01\x00\x00jX\x01\x00\x00jY\x01\x00\x00jZ\x01\x00\x00j[\x01\x00\x00j\\\x01\x00\x00j]\x01\x00\x00j^\x01\x00\x00j_\x01\x00\x00j`\x01\x00\x00ja\x01\x00\x00uu\x8c\x0ePBMC_Perez2022\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1edata/pseudobulk/PBMC_Perez2022\x94\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c:data/pseudobulk/raw/PBMC_Perez2022/PBMC_Perez2022_raw.h5ad\x94\x8c\x06matrix\x94\x8c\x05raw.X\x94\x8c\nsample_col\x94\x8c\x07ind_cov\x94\x8c\x10sample_transform\x94\x8c"sample_prefix_hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\tcell_type\x94\x8c\x11raw_cell_type_col\x94\x8c\tcell_type\x94\x8c\x14projection_label_col\x94\x8c\tcell_type\x94\x8c\x0fcohort_manifest\x94\x8c/data/pseudobulk/PBMC_Perez2022/patient_info.csv\x94\x8c\x0ctruth_v0_map\x94}\x94(\x8c\x06B cell\x94\x8c\x06B_cell\x94\x8c\x0bplasmablast\x94\x8c\x06B_cell\x94\x8c\x12classical monocyte\x94\x8c\x07Myeloid\x94\x8c\x16non-classical monocyte\x94\x8c\x07Myeloid\x94\x8c\x1bconventional dendritic cell\x94\x8c\x07Myeloid\x94\x8c\x1bplasmacytoid dendritic cell\x94\x8c\x07Myeloid\x94\x8c\x0fprogenitor cell\x94\x8c\x07Myeloid\x94\x8c\x13natural killer cell\x94\x8c\x02NK\x94\x8c\x1fCD4-positive, alpha-beta T cell\x94\x8c\x06T_cell\x94\x8c\x1fCD8-positive, alpha-beta T cell\x94\x8c\x06T_cell\x94\x8c\nlymphocyte\x94\x8c\x06T_cell\x94u\x8c\x14projection_label_map\x94}\x94(j}\x01\x00\x00j~\x01\x00\x00j\x7f\x01\x00\x00j\x80\x01\x00\x00j\x81\x01\x00\x00j\x82\x01\x00\x00j\x83\x01\x00\x00j\x84\x01\x00\x00j\x85\x01\x00\x00j\x86\x01\x00\x00j\x87\x01\x00\x00j\x88\x01\x00\x00j\x89\x01\x00\x00j\x8a\x01\x00\x00j\x8b\x01\x00\x00j\x8c\x01\x00\x00j\x8d\x01\x00\x00j\x8e\x01\x00\x00j\x8f\x01\x00\x00j\x90\x01\x00\x00j\x91\x01\x00\x00j\x92\x01\x00\x00uu\x8c\x10Lung_Sikkema2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c/data/pseudobulk/Lung_Sikkema2023/lung_HLCA.h5ad\x94\x8c\x06matrix\x94\x8c\x05raw.X\x94\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0bann_level_2\x94\x8c\x0ctruth_v1_col\x94\x8c\x10ann_finest_level\x94\x8c\x11raw_cell_type_col\x94\x8c\x0bann_level_3\x94\x8c\x14projection_label_col\x94\x8c\x0bann_level_2\x94\x8c\tmin_cells\x94M\x90\x01uu\x8c\x07methods\x94}\x94(\x8c\tCLAMPbase\x94\x8c\x0fCLAMPbase/B.csv\x94\x8c\tCLAMPfull\x94\x8c\x0fCLAMPfull/B.csv\x94\x8c\x05PLIER\x94\x8c\x0bPLIER/B.csv\x94\x8c\x03PCA\x94\x8c\tPCA/B.csv\x94\x8c\x03NMF\x94\x8c\tNMF/B.csv\x94\x8c\x03ICA\x94\x8c\tICA/B.csv\x94\x8c\x08Flashier\x94\x8c\x0eflashier/B.csv\x94\x8c\tMOFA-FLEX\x94\x8c\x15MOFA_FLEX_PRIOR/B.csv\x94\x8c\x05GSSig\x94\x8c\tGSS/B.csv\x94\x8c\x06CoGAPS\x94\x8c\x0cCoGAPS/B.csv\x94u\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c&output/01_model_building/00_pseudobulk\x94\x8c\x07biology\x94\x8c%output/03_model_biology/00_pseudobulk\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94\x8c\x06panels\x94\x8c\x10output/99_panels\x94\x8c\x10panels_notebooks\x94\x8c\rnbs/99_panels\x94u\x8c\nreferences\x94}\x94(\x8c\tgo_bp_url\x94\x8c_https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025\x94\x8c\ngo_bp_file\x94\x8c,data/pathways/GO_Biological_Process_2025.gmt\x94\x8c\x0cgo_bp_sha256\x94\x8c@0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee\x94\x8c\x10cell_marker_file\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x14allen_brain_gmt_file\x94\x8c2data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt\x94\x8c\x0cazimuth_file\x94\x8c\x1edata/pathways/Azimuth_2023.txt\x94\x8c\x14gtex_tissues_pathmat\x94\x8c$data/archs4/GTEx_Tissues_pathMat.rds\x94\x8c\x0ebrain_datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94eu\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x0fmodule_recovery\x94}\x94(\x8c\x11top_gene_fraction\x94G?\x84z\xe1G\xae\x14{\x8c\x13retry_gene_fraction\x94G?\x9e\xb8Q\xeb\x85\x1e\xb8\x8c\rfdr_threshold\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\ttop_terms\x94K\x03u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\ngrouped_cv\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\tgroup_col\x94\x8c\x06sample\x94\x8c\nsplit_seed\x94K*\x8c\x10min_train_lv_cor\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x0ebootstrap_seed\x94K{\x8c\x14bootstrap_replicates\x94M\x10\'u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{u\x8c\tmofa_flex\x94}\x94(\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0ctop_fraction\x94G?\x84z\xe1G\xae\x14{u\x8c\x12cell_type_analysis\x94}\x94\x8c\x10excluded_targets\x94}\x94(\x8c\x10Brain_Mathys2023\x94]\x94\x8c\x03Vas\x94a\x8c\x0fBrain_Xiong2023\x94]\x94\x8c\x03Vas\x94a\x8c\x10Lung_Sikkema2023\x94]\x94(\x8c\x18Hematopoietic stem cells\x94\x8c\x0bMesothelium\x94\x8c\rSmooth muscle\x94eus\x8c\x04gtex\x94}\x94(\x8c\x07raw_url\x94\x8cwhttps://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x06raw_gz\x94\x8cCdata/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x08metadata\x94\x8c=data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt\x94\x8c\x0cxcell_scores\x94\x8c7data/gtex/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt\x94\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c output/01_model_building/01_gtex\x94\x8c\x07biology\x94\x8c\x1foutput/03_model_biology/01_gtex\x94\x8c\x0fmodel_notebooks\x94\x8c\x1dnbs/01_model_building/01_gtex\x94\x8c\x11biology_notebooks\x94\x8c\x1cnbs/03_model_biology/01_gtex\x94u\x8c\x08raw_data\x94}\x94(\x8c\nchunk_size\x94Kd\x8c\x07n_cores\x94K\x01u\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x0fmofa_flex_prior\x94}\x94(\x8c\x0cmin_fraction\x94G?\xd9\x99\x99\x99\x99\x99\x9a\x8c\tmin_count\x94K(\x8c\tmax_count\x94K\xc8\x8c\x14similarity_threshold\x94G?\xe9\x99\x99\x99\x99\x99\x9a\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{\x8c\x0ctimeout_days\x94K\x07u\x8c\x03gss\x94}\x94(\x8c\td_cluster\x94K\x04\x8c\x04seed\x94K{u\x8c\x11kmeans_clustering\x94}\x94(\x8c\x0bmin_samples\x94K2\x8c\x0fari_min_samples\x94K\x01\x8c\nn_clusters\x94K6\x8c\tbase_seed\x94M\x10\'\x8c\x0cn_reps_per_k\x94K2\x8c\x0egene_fractions\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xe8\x00\x00\x00\x00\x00\x00G?\xe0\x00\x00\x00\x00\x00\x00G?\xd0\x00\x00\x00\x00\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aG?\xa9\x99\x99\x99\x99\x99\x9aG?\x84z\xe1G\xae\x14{eu\x8c\rlv_importance\x94}\x94(\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xec\xcc\xcc\xcc\xcc\xcc\xcdu\x8c\x13subtissue_inference\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xeb333333\x8c\x15min_subtissue_samples\x94K\x14\x8c\x0fn_jobs_per_fold\x94K\x08\x8c\x0fanatomical_spec\x94\x8c.workflow/config/gtex_anatomical_subtissues.tsv\x94\x8c\x13permutation_repeats\x94M\xe8\x03\x8c\x11bootstrap_repeats\x94M\xe8\x03\x8c\x0fevaluation_jobs\x94K\x08\x8c\x07tissues\x94]\x94(\x8c\x0eAdipose Tissue\x94\x8c\x05Blood\x94\x8c\x0cBlood Vessel\x94\x8c\x05Brain\x94\x8c\x05Colon\x94\x8c\tEsophagus\x94\x8c\x05Heart\x94\x8c\x06Kidney\x94\x8c\x04Skin\x94euu\x8c\x11runtime_benchmark\x94}\x94(\x8c\x05seeds\x94]\x94(K{M\xc8\x01M\x15\x03e\x8c\x07threads\x94K\x04\x8c\x07methods\x94]\x94(\x8c\tCLAMPfull\x94\x8c\tCLAMPbase\x94\x8c\x05PLIER\x94\x8c\x06CoGAPS\x94\x8c\x08Flashier\x94\x8c\x03NMF\x94\x8c\x03PCA\x94\x8c\x03ICA\x94\x8c\x05GSSig\x94\x8c\tMOFA-FLEX\x94e\x8c\x0boutput_root\x94\x8cAoutput/02_model_performance/00_pseudobulk/00_computational_timing\x94\x8c\x08notebook\x94\x8cDnbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb\x94u\x8c\x16runtime_benchmark_gtex\x94}\x94(\x8c\x07dataset\x94\x8c\x04GTEx\x94\x8c\x05seeds\x94]\x94(K{M\xc8\x01M\x15\x03e\x8c\x07threads\x94K\x04\x8c\x07methods\x94]\x94(\x8c\tCLAMPfull\x94\x8c\tCLAMPbase\x94\x8c\x05PLIER\x94\x8c\x08Flashier\x94\x8c\x03NMF\x94\x8c\x03PCA\x94\x8c\x03ICA\x94\x8c\x05GSSig\x94\x8c\tMOFA-FLEX\x94e\x8c\x10excluded_methods\x94}\x94\x8c\x06CoGAPS\x94X\xec\x01\x00\x00rule cogaps_gtex was run to the end of its hard wall-clock budget (gtex.cogaps.timeout_days = 7) and killed without converging; the evidence is on disk at output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt. CoGAPS therefore has no finite GTEx runtime to report, and re-running it here would only re-derive the same censored value at a cost of 21 days. Reported as a right-censored ">7 days, did not converge", not as a data point.  Same reason it is absent from rule full_models_gtex.\n\x94s\x8c\x0fcogaps_evidence\x94\x8c9output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt\x94\x8c\x0boutput_root\x94\x8c;output/02_model_performance/01_gtex/00_computational_timing\x94\x8c\x08notebook\x94\x8c>nbs/02_model_performance/01_gtex/00_computational_timing.ipynb\x94u\x8c\ndonor_bulk\x94}\x94(\x8c\x08datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94\x8c\x0fHeart_Datar2026\x94\x8c\tPBMC_1k1k\x94\x8c\x0ePBMC_Perez2022\x94\x8c\x10Lung_Sikkema2023\x94e\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c1output/01_model_building/00_pseudobulk/donor_bulk\x94\x8c\x07biology\x94\x8c<output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94u\x8c\x0baggregation\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0csample_cells\x94M`\xea\x8c\x10minimum_per_type\x94K\xfa\x8c\x04seed\x94K{u\x8c\x04umap\x94}\x94(\x8c\ntarget_sum\x94M\x10\'\x8c\x05n_hvg\x94M\xd0\x07\x8c\x05n_pcs\x94K2\x8c\x0bn_neighbors\x94K\x1e\x8c\x08min_dist\x94G?\xd3333333\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x15duplicate_gene_policy\x94\x8c\x03sum\x94uu\x8c\x06archs4\x94}\x94(\x8c\x07raw_url\x94\x8c>https://s3.dev.maayanlab.cloud/archs4/files/human_gene_v2.5.h5\x94\x8c\x06raw_h5\x94\x8c\x1edata/archs4/human_gene_v2.5.h5\x94\x8c\x0cgene_lengths\x94\x8c\x1cdata/archs4/gene_lengths.rds\x94\x8c\x0fensembl_version\x94Kk\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c"output/01_model_building/02_archs4\x94\x8c\x07biology\x94\x8c!output/03_model_biology/02_archs4\x94\x8c\x0fmodel_notebooks\x94\x8c\x1fnbs/01_model_building/02_archs4\x94\x8c\x11biology_notebooks\x94\x8c\x1enbs/03_model_biology/02_archs4\x94u\x8c\x08raw_data\x94}\x94(\x8c\nblock_size\x94Kd\x8c\x07n_cores\x94K\nu\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x1bsingle_cell_probability_max\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x04seed\x94K{u\x8c\x03svd\x94}\x94(\x8c\x07n_cores\x94K\x1e\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x0ck_multiplier\x94K\x02\x8c\nmultiplier\x94Kd\x8c\x08max_iter\x94M\x88\x13\x8c\x04seed\x94K{u\x8c\x05prior\x94}\x94\x8c\x04gmts\x94}\x94(\x8c\x08REACTOME\x94\x8c3data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt\x94\x8c\x04GOCC\x94\x8c-data/pathways/c5.go.cc.v2026.1.Hs.symbols.gmt\x94\x8c\x02C8\x94\x8c+data/pathways/c8.all.v2026.1.Hs.symbols.gmt\x94us\x8c\x08coverage\x94}\x94(\x8c\tprior_gmt\x94\x8c"data/pathways/go_bp.Hs.symbols.gmt\x94\x8c\tdatabases\x94]\x94(\x8c\tcanonical\x94\x8c\ncellmarker\x94e\x8c\nmodel_root\x94\x8c;output/01_model_building/02_archs4/02_coverage_study/models\x94\x8c\x08ora_root\x94\x8c8output/01_model_building/02_archs4/02_coverage_study/ora\x94\x8c\x0bassignments\x94\x8c9output/03_model_biology/02_archs4/00_coverage/assignments\x94\x8c\x05seeds\x94]\x94(K\x01K\x02K\x03e\x8c\trng_seeds\x94]\x94(K{K|K}e\x8c\x06levels\x94}\x94(\x8c\x011\x94\x8c\x1700_bp_coverage_study_01\x94\x8c\x015\x94\x8c\x1701_bp_coverage_study_05\x94\x8c\x0210\x94\x8c\x1702_bp_coverage_study_10\x94\x8c\x0225\x94\x8c\x1703_bp_coverage_study_25\x94\x8c\x0250\x94\x8c\x1704_bp_coverage_study_50\x94\x8c\x0275\x94\x8c\x1705_bp_coverage_study_75\x94\x8c\x03100\x94\x8c\x1806_bp_coverage_study_100\x94u\x8c\ninput_root\x94\x8c4output/01_model_building/02_archs4/02_coverage_study\x94\x8c\nmodel_name\x94\x8c\x0cCLAMPfull_bp\x94\x8c\tresources\x94}\x94(j\x14\x03\x00\x00}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\x80\x16uj\x16\x03\x00\x00}\x94(\x8c\x06mem_mb\x94M\x00\xfa\x8c\x07runtime\x94M\xc0!u\x8c\x0210\x94}\x94(\x8c\x06mem_mb\x94J\x00w\x01\x00\x8c\x07runtime\x94M@8u\x8c\x0225\x94}\x94(\x8c\x06mem_mb\x94J\x00k\x03\x00\x8c\x07runtime\x94M\xc0]u\x8c\x0250\x94}\x94(\x8c\x06mem_mb\x94J\x00\xee\x02\x00\x8c\x07runtime\x94M\xa0\x8cu\x8c\x0275\x94}\x94(\x8c\x06mem_mb\x94J\x00e\x04\x00\x8c\x07runtime\x94M\x80\xbbu\x8c\x03100\x94}\x94(\x8c\x06mem_mb\x94J\x00\xe2\x04\x00\x8c\x07runtime\x94M\xf0\xd2uu\x8c\x0bcomparators\x94}\x94(\x8c\x04gtex\x94}\x94(\x8c\x05label\x94\x8c\x04GTEx\x94\x8c\x07fbm_rds\x94\x8c2output/01_model_building/01_gtex/gtex_fbm_filt.rds\x94\x8c\tgenes_rds\x94\x8c/output/01_model_building/01_gtex/gtex_genes.rds\x94\x8c\x0bsamples_rds\x94\x8c1output/01_model_building/01_gtex/gtex_samples.rds\x94\x8c\x03svd\x94\x8c0output/01_model_building/01_gtex/gtex_svdRes.rds\x94\x8c\x01k\x94\x8c1output/01_model_building/01_gtex/CLAMP_K_gtex.rds\x94\x8c\x04base\x94\x8c.output/01_model_building/01_gtex/CLAMPbase.rds\x94\x8c\x06base_z\x94\x8c0output/01_model_building/01_gtex/CLAMPbase/Z.csv\x94\x8c\x08max_iter\x94M\xf4\x01u\x8c\x08recount2\x94}\x94(\x8c\x05label\x94\x8c\x08recount2\x94\x8c\x07fbm_rds\x94\x8cFoutput/01_model_building/03_recount2/00_recount2/recount2_fbm_filt.rds\x94\x8c\tgenes_rds\x94\x8cCoutput/01_model_building/03_recount2/00_recount2/recount2_genes.rds\x94\x8c\x0bsamples_rds\x94\x8cEoutput/01_model_building/03_recount2/00_recount2/recount2_samples.rds\x94\x8c\x03svd\x94\x8cDoutput/01_model_building/03_recount2/00_recount2/recount2_svdRes.rds\x94jP\x03\x00\x00\x8cEoutput/01_model_building/03_recount2/00_recount2/CLAMP_K_recount2.rds\x94\x8c\x04base\x94\x8c>output/01_model_building/03_recount2/00_recount2/CLAMPbase.rds\x94\x8c\x06base_z\x94\x8c@output/01_model_building/03_recount2/00_recount2/CLAMPbase/Z.csv\x94\x8c\x08max_iter\x94M\xf4\x01uu\x8c\x06colors\x94}\x94(\x8c\x05model\x94}\x94(\x8c\tCLAMPfull\x94\x8c\x07#0072B2\x94\x8c\tCLAMPbase\x94\x8c\x07#777777\x94u\x8c\x07dataset\x94}\x94(\x8c\x06ARCHS4\x94\x8c\x07#0072B2\x94\x8c\x04GTEx\x94\x8c\x07#E69F00\x94\x8c\x08recount2\x94\x8c\x07#009E73\x94uu\x8c\x07routing\x94}\x94(\x8c\x14remote_min_free_cpus\x94K\x02\x8c\x16remote_min_free_mem_mb\x94M\x80>\x8c\x13remote_max_ora_jobs\x94K\x08\x8c\x12local_total_mem_mb\x94J\x00w\x01\x00\x8c\x07retries\x94K\x02\x8c\x11retry_mem_factors\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xf8\x00\x00\x00\x00\x00\x00G@\x00\x00\x00\x00\x00\x00\x00e\x8c\x10retry_mem_cap_mb\x94J\x005\x0c\x00u\x8c\x0ebp_models_root\x94\x8c#output/98_final_models/clampfull/bp\x94\x8c\x11bp_model_datasets\x94]\x94(\x8c\x06archs4\x94\x8c\x04gtex\x94\x8c\x08recount2\x94e\x8c\x0eclampbase_root\x94\x8c output/98_final_models/clampbase\x94\x8c\x0eclampbase_seed\x94}\x94(\x8c\x06archs4\x94K\x01\x8c\x04gtex\x94K\x00\x8c\x08recount2\x94K\x00u\x8c\x10clampbase_source\x94}\x94(\x8c\x06archs4\x94}\x94(\x8c\x05model\x94\x8c5output/98_final_models/clampbase/archs4/CLAMPbase.rds\x94h\x13\x8c-output/98_final_models/clampbase/archs4/Z.csv\x94\x8c\x01b\x94\x8c-output/98_final_models/clampbase/archs4/B.csv\x94u\x8c\x04gtex\x94}\x94(\x8c\x05model\x94\x8c.output/01_model_building/01_gtex/CLAMPbase.rds\x94h\x13\x8c0output/01_model_building/01_gtex/CLAMPbase/Z.csv\x94j\x98\x03\x00\x00\x8c0output/01_model_building/01_gtex/CLAMPbase/B.csv\x94u\x8c\x08recount2\x94}\x94(\x8c\x05model\x94\x8c>output/01_model_building/03_recount2/00_recount2/CLAMPbase.rds\x94h\x13\x8c@output/01_model_building/03_recount2/00_recount2/CLAMPbase/Z.csv\x94j\x98\x03\x00\x00\x8c@output/01_model_building/03_recount2/00_recount2/CLAMPbase/B.csv\x94uuu\x8c\nsaturation\x94}\x94(\x8c\tprior_gmt\x94\x8c"data/pathways/go_bp.Hs.symbols.gmt\x94\x8c\nmodel_root\x94\x8c7output/01_model_building/02_archs4/01_saturation/models\x94\x8c\x08ora_root\x94\x8c4output/01_model_building/02_archs4/01_saturation/ora\x94\x8c\x05seeds\x94]\x94(K\x01K\x02K\x03e\x8c\trng_seeds\x94]\x94(K{K|K}e\x8c\tfractions\x94]\x94(K\x01K\x05K\nK\x19K2KKe\x8c\x08k_values\x94]\x94(KVK\xadM\xb0\x01M`\x03M\x10\x05M\xc0\x06e\x8c\rexclude_cells\x94]\x94]\x94(K\x01M\xc0\x06K\x01ea\x8c\ninput_root\x94\x8c4output/01_model_building/02_archs4/02_coverage_study\x94\x8c\x0cinput_levels\x94}\x94(j\x14\x03\x00\x00\x8c\x1700_bp_coverage_study_01\x94j\x16\x03\x00\x00\x8c\x1701_bp_coverage_study_05\x94\x8c\x0210\x94\x8c\x1702_bp_coverage_study_10\x94\x8c\x0225\x94\x8c\x1703_bp_coverage_study_25\x94\x8c\x0250\x94\x8c\x1704_bp_coverage_study_50\x94\x8c\x0275\x94\x8c\x1705_bp_coverage_study_75\x94u\x8c\ninput_leaf\x94\x8c\'study_coverage_rs{fraction}_seed_{seed}\x94\x8c\tbase_root\x94\x8c0output/01_model_building/02_archs4/01_saturation\x94\x8c\tbase_leaf\x94\x8c.study_saturation_rs{fraction}_k{k}_seed_{seed}\x94\x8c\nmodel_name\x94\x8c\x0cCLAMPfull_bp\x94\x8c\x08max_iter\x94M\x88\x13\x8c\tn_samples\x94}\x94(j\x14\x03\x00\x00M\xdd\x17j\x16\x03\x00\x00Mdv\x8c\x0210\x94M\xe5\xec\x8c\x0225\x94J\x1cU\x02\x00\x8c\x0250\x94J\xcd\xa0\x04\x00\x8c\x0275\x94J\x04\xef\x06\x00u\x8c\tresources\x94}\x94(j\x14\x03\x00\x00}\x94(\x8c\x0286\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94Mh\x01u\x8c\x03173\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94Mh\x01u\x8c\x03432\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94M\xa4\x01u\x8c\x03864\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94M\xa4\x01u\x8c\x041296\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94MX\x02u\x8c\x041728\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94M\x84\x03uuj\x16\x03\x00\x00}\x94(\x8c\x0286\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94M\xa4\x01u\x8c\x03173\x94}\x94(\x8c\x06mem_mb\x94M\xc0]\x8c\x07runtime\x94M\xa4\x01u\x8c\x03432\x94}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\xa4\x01u\x8c\x03864\x94}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\xe0\x01u\x8c\x041296\x94}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\xe0\x01u\x8c\x041728\x94}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\x1c\x02uu\x8c\x0210\x94}\x94(\x8c\x0286\x94}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\xa4\x01u\x8c\x03173\x94}\x94(\x8c\x06mem_mb\x94M@\x9c\x8c\x07runtime\x94M\xa4\x01u\x8c\x03432\x94}\x94(\x8c\x06mem_mb\x94M@\x9c\x8c\x07runtime\x94M\xe0\x01u\x8c\x03864\x94}\x94(\x8c\x06mem_mb\x94M@\x9c\x8c\x07runtime\x94M\x1c\x02u\x8c\x041296\x94}\x94(\x8c\x06mem_mb\x94M\x80\xbb\x8c\x07runtime\x94MX\x02u\x8c\x041728\x94}\x94(\x8c\x06mem_mb\x94M\x80\xbb\x8c\x07runtime\x94M\xd0\x02uu\x8c\x0225\x94}\x94(\x8c\x0286\x94}\x94(\x8c\x06mem_mb\x94M\x00\xfa\x8c\x07runtime\x94M\xa4\x01u\x8c\x03173\x94}\x94(\x8c\x06mem_mb\x94M\x00\xfa\x8c\x07runtime\x94M\xe0\x01u\x8c\x03432\x94}\x94(\x8c\x06mem_mb\x94J@\x19\x01\x00\x8c\x07runtime\x94MX\x02u\x8c\x03864\x94}\x94(\x8c\x06mem_mb\x94J\x808\x01\x00\x8c\x07runtime\x94M\x0c\x03u\x8c\x041296\x94}\x94(\x8c\x06mem_mb\x94J\xc0W\x01\x00\x8c\x07runtime\x94M\xc0\x03u\x8c\x041728\x94}\x94(\x8c\x06mem_mb\x94J\x00w\x01\x00\x8c\x07runtime\x94M\xb0\x04uu\x8c\x0250\x94}\x94(\x8c\x0286\x94}\x94(\x8c\x06mem_mb\x94J@\x96\x01\x00\x8c\x07runtime\x94M\xe0\x01u\x8c\x03173\x94}\x94(\x8c\x06mem_mb\x94J\x80\xb5\x01\x00\x8c\x07runtime\x94M\x1c\x02u\x8c\x03432\x94}\x94(\x8c\x06mem_mb\x94J\xc0\xd4\x01\x00\x8c\x07runtime\x94M\x0c\x03u\x8c\x03864\x94}\x94(\x8c\x06mem_mb\x94J\x802\x02\x00\x8c\x07runtime\x94M\xb0\x04u\x8c\x041296\x94}\x94(\x8c\x06mem_mb\x94J\x00q\x02\x00\x8c\x07runtime\x94M\x18\x06u\x8c\x041728\x94}\x94(\x8c\x06mem_mb\x94J\xc0\xce\x02\x00\x8c\x07runtime\x94M\xbc\x07uu\x8c\x0275\x94}\x94(\x8c\x0286\x94}\x94(\x8c\x06mem_mb\x94J\xc0Q\x02\x00\x8c\x07runtime\x94M\xe0\x01u\x8c\x03173\x94}\x94(\x8c\x06mem_mb\x94J\x00q\x02\x00\x8c\x07runtime\x94MX\x02u\x8c\x03432\x94}\x94(\x8c\x06mem_mb\x94J\x80\xaf\x02\x00\x8c\x07runtime\x94M\xc0\x03u\x8c\x03864\x94}\x94(\x8c\x06mem_mb\x94J@\r\x03\x00\x8c\x07runtime\x94M\x18\x06u\x8c\x041296\x94}\x94(\x8c\x06mem_mb\x94J@\x8a\x03\x00\x8c\x07runtime\x94Mp\x08u\x8c\x041728\x94}\x94(\x8c\x06mem_mb\x94J@\x07\x04\x00\x8c\x07runtime\x94M\xc8\nuuu\x8c\x07routing\x94}\x94(\x8c\x0ctotal_mem_mb\x94J\xb8L\n\x00\x8c\tfit_slots\x94K\n\x8c\tora_slots\x94K\x18\x8c\x0fthreads_per_fit\x94K\x08\x8c\x07retries\x94K\x02\x8c\x11retry_mem_factors\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xf8\x00\x00\x00\x00\x00\x00G@\x00\x00\x00\x00\x00\x00\x00e\x8c\x10retry_mem_cap_mb\x94J\xb8L\n\x00uu\x8c\tcanonical\x94}\x94(\x8c\nmodel_name\x94\x8c\x13CLAMPfull_canonical\x94\x8c\nfinal_root\x94\x8c*output/98_final_models/clampfull/canonical\x94\x8c\tcompendia\x94]\x94(\x8c\x06archs4\x94\x8c\x04gtex\x94\x8c\x08recount2\x94e\x8c\x03ora\x94}\x94\x8c\tdatabases\x94]\x94(\x8c\x02bp\x94\x8c\tcanonical\x94\x8c\x08reactome\x94\x8c\ncellmarker\x94esu\x8c\rdrug_diseases\x94}\x94(\x8c\x08data_dir\x94\x8c\x1edata/drug_disease_associations\x94\x8c\x0espredixcan_dir\x94\x8c*data/phenomexcan/gene_assoc/spredixcan/pkl\x94\x8c\x05prior\x94}\x94(\x8c\x06c2_all\x94\x8c+data/pathways/c2.all.v2026.1.Hs.symbols.gmt\x94\x8c\x08reactome\x94\x8c3data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt\x94\x8c\ncellmarker\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x05sheet\x94\x8c\x05human\x94\x8c\x0bterm_column\x94\x8c\tcell_name\x94\x8c\x0bgene_column\x94\x8c\x06Symbol\x94\x8c\noutput_gmt\x94\x8ceoutput/01_model_building/02_archs4/03_drug_diseases_canonical/prior/canonical_reactome_cellmarker.gmt\x94u\x8c\x0ccompute_root\x94\x8c=output/01_model_building/02_archs4/03_drug_diseases_canonical\x94\x8c\x0breport_root\x94\x8c<output/03_model_biology/02_archs4/02_drug_diseases_canonical\x94\x8c\tn_top_lvs\x94]\x94(K\x05K\nK\x19K2e\x8c\x0bn_top_genes\x94]\x94(K2KdK\xfaM\xf4\x01e\x8c\x12figure_n_top_genes\x94Kd\x8c\x10figure_n_top_lvs\x94K\n\x8c\tbootstrap\x94}\x94(\x8c\x06n_boot\x94M\x10\'\x8c\x04seed\x94K*uu\x8c\ncrispercas\x94}\x94(\x8c\tlipid_deg\x94\x8c%data/archs4/crispr_cas9/lipid_DEG.csv\x94\x8c\x0ccompute_root\x94\x8c/output/03_model_biology/02_archs4/04_crispercas\x94\x8c\x0cnetwork_root\x94\x8cBoutput/03_model_biology/02_archs4/04_crispercas/02_network/figures\x94\x8c\tnotebooks\x94\x8c,nbs/03_model_biology/02_archs4/04_crispercas\x94\x8c\x06n_reps\x94K\n\x8c\x03fdr\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\x15archs4_cell_lines_gmt\x94\x8c#data/pathways/archs4_cell_lines.gmt\x94\x8c\x15archs4_cell_lines_url\x94\x8cVhttps://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=ARCHS4_Cell-lines\x94\x8c\x1aarchs4_cell_lines_max_size\x94M\xb8\x0b\x8c\x0bazimuth_gmt\x94\x8c\x1edata/pathways/Azimuth_2023.txt\x94\x8c\x0bazimuth_url\x94\x8cQhttps://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=Azimuth_2023\x94\x8c\x10azimuth_min_size\x94K\x05\x8c\x10azimuth_max_size\x94M\xb8\x0b\x8c\rcanonical_gls\x94\x8cYdata/archs4/traits/archs4_canonical_prelim89/gls-summary-archs4_canonical_prelim89.tsv.gz\x94\x8c\x12smultixcan_zscores\x94\x8cCdata/archs4/drug_diseases_associations/smultixcan-mashr-zscores.pkl\x94\x8c\rlincs_top_pct\x94G?\x84z\xe1G\xae\x14{\x8c\ndrug_names\x94\x8c6data/drug_disease_associations/indications-verbose.tsv\x94u\x8c\x03ora\x94}\x94(\x8c\tdatabases\x94}\x94(\x8c\x02bp\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c"data/pathways/go_bp.Hs.symbols.gmt\x94\x8c\x05label\x94\x8c\x15GO Biological Process\x94u\x8c\x08reactome\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c3data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt\x94\x8c\x05label\x94\x8c\x08Reactome\x94u\x8c\tcanonical\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c*data/pathways/c2.cp.v2026.1.Hs.symbols.gmt\x94\x8c\x12exclude_term_regex\x94\x8c\n^REACTOME_\x94\x8c\x05label\x94\x8c\x16Canonical non-Reactome\x94u\x8c\ncellmarker\x94}\x94(\x8c\x04type\x94\x8c\x0fcellmarker_xlsx\x94\x8c\x04path\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x05sheet\x94\x8c\x05human\x94\x8c\x0bterm_column\x94\x8c\tcell_name\x94\x8c\x0bgene_column\x94\x8c\x06Symbol\x94\x8c\x05label\x94\x8c\nCellMarker\x94uu\x8c\x07top_pct\x94G?\x84z\xe1G\xae\x14{\x8c\x08min_size\x94K\n\x8c\x08max_size\x94M\xf4\x01\x8c\rpvalue_cutoff\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rqvalue_cutoff\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x03fdr\x94]\x94G?\xa9\x99\x99\x99\x99\x99\x9aa\x8c\tresources\x94}\x94(\x8c\x06mem_mb\x94M@\x1f\x8c\x07runtime\x94K<uu\x8c\x0cfinal_models\x94}\x94(\x8c\tclampbase\x94}\x94(\x8c\x06archs4\x94}\x94(\x8c\x04root\x94\x8c\'output/98_final_models/clampbase/archs4\x94\x8c\x03rds\x94\x8c\rCLAMPbase.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94u\x8c\x04gtex\x94}\x94(\x8c\x04root\x94\x8c%output/98_final_models/clampbase/gtex\x94\x8c\x03rds\x94\x8c\rCLAMPbase.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94u\x8c\x08recount2\x94}\x94(\x8c\x04root\x94\x8c)output/98_final_models/clampbase/recount2\x94\x8c\x03rds\x94\x8c\rCLAMPbase.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94uu\x8c\tclampfull\x94}\x94(\x8c\x02bp\x94}\x94(\x8c\x06archs4\x94}\x94(\x8c\x04root\x94\x8c7output/98_final_models/clampfull/bp/archs4/CLAMPfull_bp\x94\x8c\x03rds\x94\x8c\x10CLAMPfull_bp.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94u\x8c\x04gtex\x94}\x94(\x8c\x04root\x94\x8c5output/98_final_models/clampfull/bp/gtex/CLAMPfull_bp\x94\x8c\x03rds\x94\x8c\x10CLAMPfull_bp.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94u\x8c\x08recount2\x94}\x94(\x8c\x04root\x94\x8c9output/98_final_models/clampfull/bp/recount2/CLAMPfull_bp\x94\x8c\x03rds\x94\x8c\x10CLAMPfull_bp.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94uu\x8c\tcanonical\x94}\x94(\x8c\x06archs4\x94}\x94(\x8c\x04root\x94\x8c1output/98_final_models/clampfull/canonical/archs4\x94\x8c\x03rds\x94\x8c\x17CLAMPfull_canonical.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94\x8c\nprovenance\x94\x8c\x18adoption_validation.json\x94u\x8c\x04gtex\x94}\x94(\x8c\x04root\x94\x8c/output/98_final_models/clampfull/canonical/gtex\x94\x8c\x03rds\x94\x8c\x17CLAMPfull_canonical.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94\x8c\nprovenance\x94\x8c\x18adoption_validation.json\x94u\x8c\x08recount2\x94}\x94(\x8c\x04root\x94\x8c3output/98_final_models/clampfull/canonical/recount2\x94\x8c\x03rds\x94\x8c\x17CLAMPfull_canonical.rds\x94j\x98\x03\x00\x00\x8c\x05B.csv\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94\x8c\nprovenance\x94\x8c\x18adoption_validation.json\x94uuuuu\x8c\x08recount2\x94}\x94(\x8c\x03url\x94\x8c/https://ndownloader.figshare.com/files/10881866\x94\x8c\tplier_rds\x94\x8c=data/recount2/recount2_PLIER_data/recount_data_prep_PLIER.RDS\x94\x8c\x08rpkm_rds\x94\x8c2data/recount2/recount2_PLIER_data/recount_rpkm.RDS\x94\x8c\x05paths\x94}\x94\x8c\nproduction\x94\x8c0output/01_model_building/03_recount2/00_recount2\x94s\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\nblock_size\x94Kd\x8c\x04seed\x94K{u\x8c\x03svd\x94}\x94(\x8c\x07n_cores\x94K\x10\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94\x8c\x04seed\x94K{s\x8c\tresources\x94}\x94(\x8c\x11preprocess_mem_mb\x94J@\r\x03\x00\x8c\nsvd_mem_mb\x94J@\r\x03\x00\x8c\x10clampbase_mem_mb\x94J@\r\x03\x00uu\x8c\x0bprojections\x94}\x94(\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c1output/01_model_building/02_archs4/03_projections\x94\x8c\x07biology\x94\x8c0output/03_model_biology/02_archs4/03_projections\x94\x8c\tnotebooks\x94\x8c-nbs/03_model_biology/02_archs4/03_projections\x94\x8c\x08raw_data\x94\x8c\x10data/projections\x94u\x8c\x0carchs4_model\x94}\x94(\x8c\x04root\x94\x8c1output/98_final_models/clampfull/canonical/archs4\x94\x8c\x03rds\x94\x8c\x17CLAMPfull_canonical.rds\x94h\x13\x8c\x05Z.csv\x94\x8c\x07summary\x94\x8c\x0bsummary.csv\x94\x8c\nprovenance\x94\x8cJoutput/98_final_models/clampfull/canonical/archs4/adoption_validation.json\x94u\x8c\x0blocal_model\x94}\x94(\x8c\x05prior\x94}\x94(\x8c\x04gmts\x94}\x94(\x8c\x05C2ALL\x94\x8c+data/pathways/c2.all.v2026.1.Hs.symbols.gmt\x94\x8c\x08REACTOME\x94\x8c3data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt\x94u\x8c\ncellmarker\x94}\x94(\x8c\x04path\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x05sheet\x94\x8c\x05human\x94\x8c\x0bterm_column\x94\x8c\tcell_name\x94\x8c\x0bgene_column\x94\x8c\x06Symbol\x94uu\x8c\x06k_rule\x94\x8c\x11n_samples_minus_1\x94\x8c\x08max_iter\x94K\xc8\x8c\x04seed\x94K{u\x8c\nthresholds\x94}\x94(\x8c\x06lv_fdr\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\x08lv_logfc\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\x0bpathway_fdr\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\x0bpathway_auc\x94G?\xe6ffffffu\x8c\x03ora\x94}\x94(\x8c\x07top_pct\x94G?\x84z\xe1G\xae\x14{\x8c\x08min_size\x94K\n\x8c\x08max_size\x94M\xf4\x01\x8c\tmin_count\x94K\x03\x8c\rpvalue_cutoff\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rqvalue_cutoff\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x03fdr\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\tlv_subset\x94\x8c\x0bsignificant\x94\x8c\tresources\x94}\x94(\x8c\x06mem_mb\x94M\x80>\x8c\x07runtime\x94M\xd0\x02u\x8c\tdatabases\x94}\x94(\x8c\tcanonical\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c*data/pathways/c2.cp.v2026.1.Hs.symbols.gmt\x94\x8c\x05label\x94\x8c\x11Canonical (C2:CP)\x94u\x8c\x08hallmark\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c*data/pathways/h.all.v2026.1.Hs.symbols.gmt\x94\x8c\x05label\x94\x8c\x08Hallmark\x94u\x8c\ncellmarker\x94}\x94(\x8c\x04type\x94\x8c\x0fcellmarker_xlsx\x94\x8c\x04path\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x05sheet\x94\x8c\x05human\x94\x8c\x0bterm_column\x94\x8c\tcell_name\x94\x8c\x0bgene_column\x94\x8c\x06Symbol\x94\x8c\x05label\x94\x8c\nCellMarker\x94uuu\x8c\nbenchmarks\x94}\x94(\x8c\npseudobulk\x94}\x94(\x8c\nprojection\x94\x8c_output/03_model_biology/02_archs4/03_projections/04_pseudobulk_recovery_archs4/pb_canon_dim.csv\x94N\x8c`output/03_model_biology/02_archs4/03_projections/04_pseudobulk_recovery_archs4/pb_dimcontrol.csv\x94u\x8c\x04gtex\x94}\x94(\x8c\nprojection\x94\x8cVoutput/03_model_biology/02_archs4/03_projections/05_gtex_ari_archs4/gtex_canon_dim.csv\x94N\x8cSoutput/03_model_biology/02_archs4/03_projections/05_gtex_ari_archs4/dim_control.csv\x94uu\x8c\x08datasets\x94}\x94(\x8c\x12cyt_ifna_GSE133218\x94}\x94(\x8c\x05group\x94\x8c\tcytokines\x94\x8c\x05label\x94\x8c#EndoC-betaH1, IFN-alpha time course\x94\x8c\taccession\x94\x8c\tGSE133218\x94\x8c\x04kind\x94\x8c\x0bgeo_gtf_tar\x94\x8c\x07id_type\x94\x8c\x07ensembl\x94\x8c\ngene_level\x94\x88\x8c\x06unpack\x94}\x94\x8c\x03tar\x94\x8c\x11GSE133218_RAW.tar\x94s\x8c\tdownloads\x94]\x94}\x94(\x8c\x04name\x94\x8c\x11GSE133218_RAW.tar\x94\x8c\x03url\x94\x8cShttps://ftp.ncbi.nlm.nih.gov/geo/series/GSE133nnn/GSE133218/suppl/GSE133218_RAW.tar\x94\x8c\x06sha256\x94\x8c@086186d5e15e9c7a8666306cb2da3b019edf84275e7e85b6aef31b12b9683ca9\x94ua\x8c\x11sample_annotation\x94}\x94(\x8c\x06source\x94\x8c\rgtf_filenames\x94\x8c\x02id\x94\x8c\r{gsm}_{group}\x94\x8c\x05rules\x94}\x94(\x8c\x03gsm\x94}\x94\x8c\x07extract\x94\x8c\x11.*/(GSM[0-9]+)_.*\x94s\x8c\tcondition\x94}\x94(\x8c\x07pattern\x94\x8c\x05_Ctl_\x94\x8c\x05match\x94\x8c\x07Control\x94\x8c\x07nomatch\x94\x8c\x04IFNa\x94u\x8c\ttimepoint\x94}\x94\x8c\x07extract\x94\x8c\x0f.*(2h|8h|24h).*\x94s\x8c\x05group\x94}\x94(\x8c\x04join\x94]\x94(\x8c\tcondition\x94\x8c\ttimepoint\x94e\x8c\x03sep\x94\x8c\x01_\x94uuu\x8c\tcontrasts\x94]\x94(}\x94(\x8c\x04name\x94\x8c\x06pooled\x94\x8c\x04type\x94\x8c\x0climma_groups\x94\x8c\x06factor\x94\x8c\tcondition\x94\x8c\x06levels\x94]\x94(\x8c\x07Control\x94\x8c\x04IFNa\x94e\x8c\x08contrast\x94\x8c\x0cIFNa-Control\x94u}\x94(\x8c\x04name\x94\x8c\x05tp_2h\x94\x8c\x04type\x94\x8c\x0climma_groups\x94\x8c\x06factor\x94\x8c\x05group\x94\x8c\x06levels\x94]\x94(\x8c\nControl_2h\x94\x8c\nControl_8h\x94\x8c\x0bControl_24h\x94\x8c\x07IFNa_2h\x94\x8c\x07IFNa_8h\x94\x8c\x08IFNa_24h\x94e\x8c\x08contrast\x94\x8c\x12IFNa_2h-Control_2h\x94u}\x94(\x8c\x04name\x94\x8c\x05tp_8h\x94\x8c\x04type\x94\x8c\x0climma_groups\x94\x8c\x06factor\x94\x8c\x05group\x94\x8c\x06levels\x94]\x94(\x8c\nControl_2h\x94\x8c\nControl_8h\x94\x8c\x0bControl_24h\x94\x8c\x07IFNa_2h\x94\x8c\x07IFNa_8h\x94\x8c\x08IFNa_24h\x94e\x8c\x08contrast\x94\x8c\x12IFNa_8h-Control_8h\x94u}\x94(\x8c\x04name\x94\x8c\x06tp_24h\x94\x8c\x04type\x94\x8c\x0climma_groups\x94\x8c\x06factor\x94\x8c\x05group\x94\x8c\x06levels\x94]\x94(\x8c\nControl_2h\x94\x8c\nControl_8h\x94\x8c\x0bControl_24h\x94\x8c\x07IFNa_2h\x94\x8c\x07IFNa_8h\x94\x8c\x08IFNa_24h\x94e\x8c\x08contrast\x94\x8c\x14IFNa_24h-Control_24h\x94ueu\x8c\x12mono_lps_GSE193336\x94}\x94(\x8c\x05group\x94\x8c\x08monocyte\x94\x8c\x05label\x94\x8c%Monocyte-derived macrophages, +/- LPS\x94\x8c\taccession\x94\x8c\tGSE193336\x94\x8c\x04kind\x94\x8c\ngeo_matrix\x94\x8c\x07id_type\x94\x8c\x07ensembl\x94\x8c\ngene_level\x94\x89\x8c\tdownloads\x94]\x94}\x94(\x8c\x04name\x94\x8c8GSE193336_GEO_Processed_Data_Raw_Count_Macrophage.csv.gz\x94\x8c\x03url\x94\x8czhttps://ftp.ncbi.nlm.nih.gov/geo/series/GSE193nnn/GSE193336/suppl/GSE193336_GEO_Processed_Data_Raw_Count_Macrophage.csv.gz\x94\x8c\x06sha256\x94\x8c@2fe82f9b39abd3e4826c74b9280d20fbd3a175d0110b875a35cb84210c7bb98d\x94ua\x8c\x11sample_annotation\x94}\x94(\x8c\x06source\x94\x8c\x08colnames\x94\x8c\x05rules\x94}\x94(\x8c\tcondition\x94}\x94(\x8c\x07pattern\x94\x8c\x05_LPS$\x94\x8c\x05match\x94\x8c\x03LPS\x94\x8c\x07nomatch\x94\x8c\tUntreated\x94u\x8c\x05donor\x94}\x94\x8c\x07extract\x94\x8c\x13^(donor [0-9]+)_.*$\x94suu\x8c\tcontrasts\x94]\x94}\x94(\x8c\x04name\x94\x8c\x10lps_vs_untreated\x94\x8c\x04type\x94\x8c\nlimma_coef\x94\x8c\x06factor\x94\x8c\tcondition\x94\x8c\treference\x94\x8c\tUntreated\x94\x8c\x05block\x94\x8c\x05donor\x94\x8c\x04coef\x94\x8c\x0cconditionLPS\x94uau\x8c\x12placenta_EMTAB6701\x94}\x94(\x8c\x05group\x94\x8c\x08placenta\x94\x8c\x05label\x94\x8c*Placenta / decidua scRNA-seq (trophoblast)\x94\x8c\taccession\x94\x8c\x0bE-MTAB-6701\x94\x8c\x04kind\x94\x8c\x0cebi_sc_atlas\x94\x8c\x07id_type\x94\x8c\x07ensembl\x94\x8c\ngene_level\x94\x89\x8c\npseudobulk\x94}\x94\x8c\tmin_cells\x94K\x14s\x8c\tdownloads\x94]\x94(}\x94(\x8c\x04name\x94\x8c-E-MTAB-6701.aggregated_filtered_counts.mtx.gz\x94\x8c\x03url\x94\x8c\x82https://ftp.ebi.ac.uk/pub/databases/microarray/data/atlas/sc_experiments/E-MTAB-6701/E-MTAB-6701.aggregated_filtered_counts.mtx.gz\x94\x8c\x06sha256\x94\x8c@1a4705d169178245369fe53dbe5f4ce3af1d6e632cb24669aab7b97365e34fd6\x94u}\x94(\x8c\x04name\x94\x8c2E-MTAB-6701.aggregated_filtered_counts.mtx_cols.gz\x94\x8c\x03url\x94\x8c\x87https://ftp.ebi.ac.uk/pub/databases/microarray/data/atlas/sc_experiments/E-MTAB-6701/E-MTAB-6701.aggregated_filtered_counts.mtx_cols.gz\x94\x8c\x06sha256\x94\x8c@75c19dcd58239e5ae871f24878961317e18fc43f3be8b2a4d53a82e3b5c139e3\x94u}\x94(\x8c\x04name\x94\x8c2E-MTAB-6701.aggregated_filtered_counts.mtx_rows.gz\x94\x8c\x03url\x94\x8c\x87https://ftp.ebi.ac.uk/pub/databases/microarray/data/atlas/sc_experiments/E-MTAB-6701/E-MTAB-6701.aggregated_filtered_counts.mtx_rows.gz\x94\x8c\x06sha256\x94\x8c@52d86d88a0de4d8ed6baa545d0e27c20bac2ddf3ac64d0db85c4b95728ccb670\x94u}\x94(\x8c\x04name\x94\x8c\x1dE-MTAB-6701.cell_metadata.tsv\x94\x8c\x03url\x94\x8crhttps://ftp.ebi.ac.uk/pub/databases/microarray/data/atlas/sc_experiments/E-MTAB-6701/E-MTAB-6701.cell_metadata.tsv\x94\x8c\x06sha256\x94\x8c@6f4860414155858d90a4143f208b8c5e09c159f964dfb9d18a7a61926f145d43\x94ue\x8c\rmetadata_file\x94\x8c\x1dE-MTAB-6701.cell_metadata.tsv\x94\x8c\x10metadata_columns\x94}\x94(\x8c\x02id\x94\x8c\x02id\x94\x8c\x05donor\x94\x8c\nindividual\x94\x8c\x05label\x94\x8c#inferred_cell_type_-_authors_labels\x94u\x8c\x06filter\x94}\x94(\x8c\x06column\x94\x8c\rorganism_part\x94\x8c\x06equals\x94\x8c\x08placenta\x94u\x8c\rcell_type_map\x94]\x94(}\x94(\x8c\x07pattern\x94\x8c extravillous trophoblast|\\(evt\\)\x94\x8c\x05label\x94\x8c\x18Extravillous trophoblast\x94u}\x94(\x8c\x07pattern\x94\x8c\x1bsyncytiotrophoblast|\\(sct\\)\x94\x8c\x05label\x94\x8c\x13Syncytiotrophoblast\x94u}\x94(\x8c\x07pattern\x94\x8c\x1fvillous cytotrophoblast|\\(vct\\)\x94\x8c\x05label\x94\x8c\x17Villous cytotrophoblast\x94u}\x94(\x8c\x07pattern\x94\x8c\x08hofbauer\x94\x8c\x05label\x94\x8c\rHofbauer cell\x94u}\x94(\x8c\x07pattern\x94\x8c\x16fetal fibroblast.*ffb2\x94\x8c\x05label\x94\x8c\x12Fetal fibroblast 2\x94u}\x94(\x8c\x07pattern\x94\x8c\x10fetal fibroblast\x94\x8c\x05label\x94\x8c\x12Fetal fibroblast 1\x94u}\x94(\x8c\x07pattern\x94\x8c\x11fetal endothelial\x94\x8c\x05label\x94\x8c\x11Fetal endothelial\x94u}\x94(\x8c\x07pattern\x94\x8c\x14maternal endothelial\x94\x8c\x05label\x94\x8c\x14Maternal endothelial\x94u}\x94(\x8c\x07pattern\x94\x8c\x18decidual macrophage.*dm1\x94\x8c\x05label\x94\x8c\x15Decidual macrophage 1\x94u}\x94(\x8c\x07pattern\x94\x8c\x18decidual macrophage.*dm2\x94\x8c\x05label\x94\x8c\x15Decidual macrophage 2\x94u}\x94(\x8c\x07pattern\x94\x8c\x18decidual macrophage.*dm3\x94\x8c\x05label\x94\x8c\x15Decidual macrophage 3\x94u}\x94(\x8c\x07pattern\x94\x8c\x14glandular epithelial\x94\x8c\x05label\x94\x8c\x14Glandular epithelial\x94u}\x94(\x8c\x07pattern\x94\x8c\x0bgranulocyte\x94\x8c\x05label\x94\x8c\x0bGranulocyte\x94u}\x94(\x8c\x07pattern\x94\x8c\x08monocyte\x94\x8c\x05label\x94\x8c\x08Monocyte\x94ue\x8c\x0econdition_from\x94}\x94(\x8c\x06column\x94\x8c\tcell_type\x94\x8c\x05rules\x94}\x94\x8c\tcondition\x94}\x94(\x8c\x07pattern\x94\x8c\x0btrophoblast\x94\x8c\x05match\x94\x8c\x0bTrophoblast\x94\x8c\x07nomatch\x94\x8c\x05Other\x94usu\x8c\tcontrasts\x94]\x94}\x94(\x8c\x04name\x94\x8c\x14trophoblast_vs_other\x94\x8c\x04type\x94\x8c\nlimma_coef\x94\x8c\x06factor\x94\x8c\tcondition\x94\x8c\treference\x94\x8c\x05Other\x94\x8c\x05block\x94\x8c\x05donor\x94\x8c\x04coef\x94\x8c\x14conditionTrophoblast\x94uauu\x8c\nmechanisms\x94}\x94(\x8c\x12cyt_ifna_GSE133218\x94}\x94(\x8c\x08ISG_core\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c8Colli et al. IFN-alpha IRF/STAT transcriptional response\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41467-020-16327-0\x94\x8c\x08contrast\x94\x8c\x06pooled\x94\x8c\x08database\x94\x8c\x08hallmark\x94\x8c\x05terms\x94]\x94\x8c"HALLMARK_INTERFERON_ALPHA_RESPONSE\x94au\x8c\x0bMHC_class_I\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c\'Colli et al. MHC-I antigen presentation\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41467-020-16327-0\x94\x8c\x08contrast\x94\x8c\x06pooled\x94\x8c\x05terms\x94]\x94(\x8c\x12ANTIGEN_PROCESSING\x94\x8c\x12CROSS_PRESENTATION\x94\x8c\x0bMHC_CLASS_I\x94\x8c\x0fPEPTIDE_LOADING\x94eu\x8c\rER_stress_UPR\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c\x1fColli et al. ER stress response\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41467-020-16327-0\x94\x8c\x08contrast\x94\x8c\x06pooled\x94\x8c\x05terms\x94]\x94(\x8c"HALLMARK_UNFOLDED_PROTEIN_RESPONSE\x94\x8c\x10UNFOLDED_PROTEIN\x94\x8c\x04IRE1\x94\x8c\x0eATF4_ACTIVATES\x94\x8c\x04ATF6\x94\x8c\x04PERK\x94\x8c\x15ENDOPLASMIC_RETICULUM\x94\x8c\x0cER_CHAPERONE\x94\x8c\x16N_LINKED_GLYCOSYLATION\x94eu\x8c\x19proteasome_ubiquitination\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c1Colli et al. protein modification and degradation\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41467-020-16327-0\x94\x8c\x08contrast\x94\x8c\x06pooled\x94\x8c\x05terms\x94]\x94(\x8c\nPROTEASOME\x94\x8c\tUBIQUITIN\x94\x8c\x0bSUMOYLATION\x94\x8c\x0bNEDDYLATION\x94eu\x8c\x10immune_crosstalk\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c6Colli et al. PD-L1/HLA-E protective immune checkpoints\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41467-020-16327-0\x94\x8c\x08contrast\x94\x8c\x06pooled\x94\x8c\x05terms\x94]\x94(\x8c\x13ALLOGRAFT_REJECTION\x94\x8c\x0eNATURAL_KILLER\x94\x8c\x0fT_CELL_RECEPTOR\x94\x8c\tCYTOTOXIC\x94eu\x8c\x0csplicing_RBP\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c:Colli et al. alternative splicing and RNA-binding proteins\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41467-020-16327-0\x94\x8c\x08contrast\x94\x8c\x06pooled\x94\x8c\x05terms\x94]\x94(\x8c\x05SPLIC\x94\x8c\nDESTABILIZ\x94\x8c\x11NONSENSE_MEDIATED\x94\x8c\x0eMRNA_STABILITY\x94euu\x8c\x12mono_lps_GSE193336\x94}\x94(\x8c\x0eSIRT1_NAD_axis\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c;Li et al. NAD depletion inhibits the SIRT1 metabolic sensor\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41598-022-16005-9\x94\x8c\x05terms\x94]\x94(\x8c\x05SIRT1\x94\x8c\x10NAD_BIOSYNTHESIS\x94\x8c\x0eNAD_METABOLISM\x94\x8c\x07SIRTUIN\x94eu\x8c\x18glycolytic_reprogramming\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cQLi et al. increased glucose transport and glycolysis in inflammatory innate cells\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41598-022-16005-9\x94\x8c\x05terms\x94]\x94(\x8c\nGLYCOLYSIS\x94\x8c\x12GLUCOSE_METABOLISM\x94\x8c\x11GLUCOSE_TRANSPORT\x94\x8c\x04HIF1\x94eu\x8c\x1foxidative_phosphorylation_shift\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c?Li et al. reduced OXPHOS and perturbed mitochondrial metabolism\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41598-022-16005-9\x94\x8c\x05terms\x94]\x94(\x8c\x19OXIDATIVE_PHOSPHORYLATION\x94\x8c\x1eRESPIRATORY_ELECTRON_TRANSPORT\x94\x8c\rMITOCHONDRIAL\x94eu\x8c\x19oxidative_stress_response\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cCLi et al. ROS/oxidative stress during early inflammatory activation\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41598-022-16005-9\x94\x8c\x05terms\x94]\x94(\x8c\x10OXIDATIVE_STRESS\x94\x8c\x0fREACTIVE_OXYGEN\x94\x8c\x05KEAP1\x94\x8c\x06NFE2L2\x94\x8c\x04NRF2\x94eu\x8c\x1cinnate_inflammatory_feedback\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cULi et al. HIF1A and NF-kB feed-forward inflammatory activation after SIRT1 inhibition\x94\x8c\x03doi\x94\x8c\x1a10.1038/s41598-022-16005-9\x94\x8c\x05terms\x94]\x94(\x8c\x05NF_KB\x94\x8c\tTOLL_LIKE\x94\x8c\x04TLR4\x94\x8c\x03TNF\x94\x8c\x0cINFLAMMASOME\x94\x8c\x04HIF1\x94eu\x8c\x13macrophage_identity\x94}\x94(\x8c\x08category\x94\x8c\tcell_type\x94\x8c\x06source\x94\x8c GSE193336 experimental cell type\x94\x8c\x08contrast\x94\x8c\x10lps_vs_untreated\x94\x8c\x05terms\x94]\x94(\x8c\nMACROPHAGE\x94\x8c\x08MONOCYTE\x94\x8c\x07MYELOID\x94euu\x8c\x12placenta_EMTAB6701\x94}\x94(\x8c\x14trophoblast_identity\x94}\x94(\x8c\x08category\x94\x8c\tcell_type\x94\x8c\x06source\x94\x8c\'Vento-Tormo et al. trophoblast lineages\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x08contrast\x94\x8c\x14trophoblast_vs_other\x94\x8c\x05terms\x94]\x94(\x8c\x0bTROPHOBLAST\x94\x8c\x08PLACENTA\x94\x8c\x13SYNCYTIOTROPHOBLAST\x94\x8c\x0fCYTOTROPHOBLAST\x94eu\x8c\x18extravillous_trophoblast\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c=Vento-Tormo et al. EVT invasion and spiral-artery remodelling\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x08contrast\x94\x8c\x14trophoblast_vs_other\x94\x8c\x05terms\x94]\x94(\x8c\x0cEXTRAVILLOUS\x94\x8c\x08INVASION\x94\x8c\x16EPITHELIAL_MESENCHYMAL\x94\x8c\x14EXTRACELLULAR_MATRIX\x94\x8c\x0cANGIOGENESIS\x94eu\x8c%syncytiotrophoblast_endocrine_program\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cGVento-Tormo et al. syncytiotrophoblast endocrine and exchange programme\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x08contrast\x94\x8c\x14trophoblast_vs_other\x94\x8c\x05terms\x94]\x94(\x8c\x08SYNCYTIO\x94\x8c\x0fPEPTIDE_HORMONE\x94\x8c\x0fSTEROID_HORMONE\x94\x8c\x12PLACENTAL_LACTOGEN\x94\x8c\x07HORMONE\x94eu\x8c\x10decidual_stromal\x94}\x94(\x8c\x08category\x94\x8c\tcell_type\x94\x8c\x06source\x94\x8c)Vento-Tormo et al. decidual stromal cells\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x08contrast\x94\x8c\x14trophoblast_vs_other\x94\x8c\x05terms\x94]\x94(\x8c\x07DECIDUA\x94\x8c\x07STROMAL\x94\x8c\x14EXTRACELLULAR_MATRIX\x94eu\x8c"decidual_stromal_matrix_remodeling\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cDVento-Tormo et al. decidual stromal extracellular-matrix remodelling\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x08contrast\x94\x8c\x14trophoblast_vs_other\x94\x8c\x05terms\x94]\x94(\x8c\x07DECIDUA\x94\x8c\x07STROMAL\x94\x8c\x14EXTRACELLULAR_MATRIX\x94\x8c\x08COLLAGEN\x94\x8c\x0cANGIOGENESIS\x94eu\x8c\x0fmaternal_immune\x94}\x94(\x8c\x08category\x94\x8c\tcell_type\x94\x8c\x06source\x94\x8c(Vento-Tormo et al. maternal immune cells\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x08contrast\x94\x8c\x14trophoblast_vs_other\x94\x8c\x05terms\x94]\x94(\x8c\x0eNATURAL_KILLER\x94\x8c\nMACROPHAGE\x94\x8c\x0fT_CELL_RECEPTOR\x94\x8c\x06IMMUNE\x94eu\x8c+maternal_fetal_ligand_receptor_interactions\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cIVento-Tormo et al. dNK-trophoblast HLA-C/E/G receptor-ligand interactions\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x05terms\x94]\x94(\x8c\x0eNATURAL_KILLER\x94\x8c\x03HLA\x94\x8c\x15CELL_CELL_INTERACTION\x94eu\x8c\x1edNK_chemokine_immunomodulation\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8cTVento-Tormo et al. dNK subsets have distinct immunomodulatory and chemokine profiles\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x05terms\x94]\x94(\x8c\tCHEMOKINE\x94\x8c\x04CXCL\x94\x8c\x03CCL\x94\x8c\x0eNATURAL_KILLER\x94eu\x8c\x15dNK_metabolic_priming\x94}\x94(\x8c\x08category\x94\x8c\x13molecular_mechanism\x94\x8c\x06source\x94\x8c4Vento-Tormo et al. dNK1 glycolytic metabolic priming\x94\x8c\x03doi\x94\x8c\x1910.1038/s41586-018-0698-6\x94\x8c\x05terms\x94]\x94(\x8c\nGLYCOLYSIS\x94\x8c\x12GLUCOSE_METABOLISM\x94\x8c\x11GLUCOSE_TRANSPORT\x94euuuuu\x8c\x04rule\x94\x8c%stratagenic_network_crispercas_report\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cg/home/msubirana/Documents/pivlab/clamp-analyses-crispercas/nbs/03_model_biology/02_archs4/04_crispercas\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/msubirana/Documents/pivlab/clamp-analyses-crispercas');
######## snakemake preamble end #########

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`
#
# # CRISPR-Cas9 stratagenic network and TWAS recovery
#
# This notebook contains and executes the plotting code. A *missed gene* is a CRISPR-supported gene that is strongly represented in a trait-associated latent program (LV), but lacks a significant single-gene TWAS association for that same trait. Each coloured ellipse is an LV community; its lower label gives the selected pathway and cell-type context. Stars mark CRISPR-supported recovered genes and circles mark other high-loading LV genes. Solid coloured lines to a trait node require nominal same-trait S-MultiXcan evidence (*p* < 0.05). Thin grey dashed lines within an LV indicate gene pairs co-occurring in a canonical pathway significantly enriched for that LV (ORA adjusted *p* < 0.05). Thicker dashed lines in the trait colour connect the same displayed gene across LV communities for that trait. The TWAS bubbles encode gene-level S-MultiXcan −log₁₀(*p*), capped at 60; bold rows are the CRISPR-supported recovered genes.

# %%
# Render CRISPR-Cas9 stratagenic network, TWAS, and combined figures.

import textwrap
from pathlib import Path
from IPython.display import HTML, display

import matplotlib
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.patches import Ellipse
from scipy.stats import norm

matplotlib.use("Agg")
import matplotlib.pyplot as plt


OUT = Path(snakemake.input["mapping"]).parent
Z = pd.read_csv(snakemake.input["z"], index_col=0)
TW = pd.read_pickle(snakemake.input["smultixcan"])
GLS = pd.read_csv(snakemake.input["gls"], sep="\t")
ORA = pd.read_csv(snakemake.input["canonical_ora"])
ORA = ORA[ORA["p.adjust"] < 0.05]
SYMBOL_MAP = pd.read_csv(snakemake.input["mapping"]).dropna().drop_duplicates("SYMBOL").set_index("SYMBOL")["ENSEMBL"]

GROUPS = [
    ("Alzheimer’s", "#8870AA", [("LV1226", "DGAT2", "AD-"), ("LV389", "PCYT2", "20110_10-"), ("LV627", "DGAT2", "20110_10-")], "Alzheimer’s"),
    ("Diabetes", "#477BA8", [("LV1167", "SOX9", "20002_1220-"), ("LV660", "SOX9", "20002_1222-"), ("LV902", "PTEN", "20107_9-")], "Diabetes"),
    ("High cholesterol", "#378A80", [("LV1226", "DGAT2", "20002_1473-"), ("LV1227", "SOX9", "20002_1473-")], "High cholesterol"),
    ("Coronary diseases", "#C18539", [("LV624", "DGAT2", "I25-"), ("LV294", "PTEN", "20002_1074-")], "Coronary diseases"),
    ("Fat mass", "#C8668C", [("LV1421", "HILPDA", "23120_raw-")], "Fat mass"),
    ("Biliary diseases", "#869746", [("LV588", "DGAT2", "K80-")], "Biliary diseases"),
]

LABELS = {
    "LV1226": "Lipoprotein transport / hepatocyte",
    "LV1227": "Cholesterol homeostasis / hepatocyte",
    "LV389": "Phospholipid synthesis / hepatic cell lines",
    "LV588": "Triglyceride synthesis / mixed cell markers",
    "LV627": "Fatty-acid oxidation / hepatocyte",
    "LV1167": "Insulin–FOXA signaling / hepatocyte",
    "LV660": "Antigen presentation / dendritic cell",
    "LV902": "Unresolved pathway / adipocyte",
    "LV624": "Growth-factor signaling / mixed cell markers",
    "LV294": "Innate immune sensing / immune cells",
    "LV1421": "IL12–p38 signaling / mixed cell markers",
}

GENE_IDS = {
    "APOE": "ENSG00000130203", "APOC1": "ENSG00000130208", "APOC2": "ENSG00000234906",
    "LPL": "ENSG00000175445", "LDLR": "ENSG00000130164", "LIPC": "ENSG00000166035",
    "DGAT2": "ENSG00000062282", "SOX9": "ENSG00000125398", "PCYT2": "ENSG00000185813",
    "PTEN": "ENSG00000171862", "HILPDA": "ENSG00000135245",
}


def twas_pvalue(gene, trait_column):
    ensembl = SYMBOL_MAP.get(gene)
    if pd.isna(ensembl) or ensembl not in TW.index:
        return None
    return float(2 * norm.sf(abs(TW.loc[ensembl, trait_column])))


def render_network(show=False):
    edge_rows, gene_rows, trait_rows, shared_rows, summary_rows = [], [], [], [], []
    fig, axes = plt.subplots(2, 3, figsize=(20, 10.7))
    fig.subplots_adjust(left=.02, right=.99, top=.985, bottom=.025, hspace=.055, wspace=.045)
    for ax, (title, color, modules, phenotype) in zip(axes.flat, GROUPS):
        ax.axis("off")
        ax.set_xlim(0, 11.5)
        positions = {1: [(3.6, 8.5)], 2: [(3.2, 12.0), (4.7, 4.4)], 3: [(4.7, 14.0), (2.6, 8.1), (4.7, 2.2)]}[len(modules)]
        ax.set_ylim(*{1: (4.2, 12.8), 2: (1.0, 15.4), 3: (.1, 16.5)}[len(modules)])
        anchor = (10.35, 8.25)
        displayed = {}
        for (lv, hit, trait_prefix), (cx, cy) in zip(modules, positions):
            radius = 1.28
            top = list(Z[lv].nlargest(185).index)
            enriched = ORA[ORA.LV == lv].sort_values("p.adjust")
            gene_sets = [set(str(value).split("/")) for value in enriched.geneID]
            trait_column = next(column for column in TW.columns if column.startswith(trait_prefix))
            trait_id = trait_prefix.rstrip("-")
            trait_association = GLS[(GLS.lv == lv) & (GLS.phenotype.astype(str) == trait_id)]
            trait_fdr = trait_association.fdr.iloc[0] if len(trait_association) else np.nan
            trait_description = trait_association.phenotype_desc.iloc[0] if len(trait_association) else ""
            supported = [(gene, pvalue) for gene in top if (pvalue := twas_pvalue(gene, trait_column)) is not None and pvalue < .05]
            genes = [hit] + [gene for gene, _ in supported if gene != hit][:4]
            genes += [gene for gene in top if gene not in genes][:5 - len(genes)]
            ax.add_patch(Ellipse((cx, cy), 3.8, 3.6, facecolor=color, alpha=.13, edgecolor="none"))
            coordinates = {gene: (cx + radius * np.cos(np.pi / 2 + 2 * np.pi * i / len(genes)), cy + radius * np.sin(np.pi / 2 + 2 * np.pi * i / len(genes))) for i, gene in enumerate(genes)}
            for i, gene1 in enumerate(genes):
                for gene2 in genes[i + 1:]:
                    pathways = [str(enriched.iloc[index].ID) for index, gene_set in enumerate(gene_sets) if gene1 in gene_set and gene2 in gene_set]
                    if pathways:
                        ax.plot([coordinates[gene1][0], coordinates[gene2][0]], [coordinates[gene1][1], coordinates[gene2][1]], lw=.8, ls="--", color="#6A7886", alpha=.6, zorder=1)
                        edge_rows.append([title, lv, gene1, gene2, ";".join(pathways)])
            for gene, (x, y) in coordinates.items():
                ax.scatter(x, y, s=180 if gene == hit else 95, marker="*" if gene == hit else "o", color=color, edgecolor="#26333D" if gene == hit else "white", lw=1.1 if gene == hit else .5, zorder=3)
                ax.text(cx + (x - cx) * 1.48, cy + (y - cy) * 1.43, gene, ha="center", va="center", fontsize=12, fontstyle="italic", fontweight="bold" if gene == hit else "normal", zorder=4)
                gene_rows.append([title, lv, gene, int(Z[lv].rank(ascending=False, method="min").loc[gene]), gene == hit])
                displayed.setdefault(gene, []).append((lv, (x, y)))
            for gene, pvalue in supported:
                if gene in coordinates:
                    x, y = coordinates[gene]
                    ax.annotate("", xy=(anchor[0] - .95, anchor[1]), xytext=(x, y), arrowprops=dict(arrowstyle="-", color=color, lw=1.05, alpha=.58), zorder=0)
                    trait_rows.append([title, lv, gene, trait_column, pvalue])
            ax.text(cx, cy + 2.10, lv, ha="center", fontsize=13, fontweight="bold", color=color)
            ax.text(cx, cy - 2.18, "\n".join(textwrap.wrap(LABELS[lv], 39)), ha="center", va="top", fontsize=12, fontweight="bold", color="#33424F")
            summary_rows.append({
                "trait_group": title,
                "LV": lv,
                "CRISPR_gene": hit,
                "trait_id": trait_id,
                "trait_description": trait_description,
                "LV_trait_FDR": trait_fdr,
                "pathway_cell_type": LABELS[lv],
                "displayed_genes": "; ".join(genes),
                "displayed_gene_loading_ranks": "; ".join(f"{gene}:{int(Z[lv].rank(ascending=False, method='min').loc[gene])}" for gene in genes),
                "nominal_same_trait_TWAS_genes": "; ".join(gene for gene, _ in supported),
                "nominal_same_trait_TWAS_pvalues": "; ".join(f"{gene}:{pvalue:.3g}" for gene, pvalue in supported),
            })
        for gene, nodes in displayed.items():
            for index, (lv1, xy1) in enumerate(nodes):
                for lv2, xy2 in nodes[index + 1:]:
                    ax.plot([xy1[0], xy2[0]], [xy1[1], xy2[1]], lw=1.5, ls=(0, (4, 3)), color=color, alpha=.9, zorder=2)
                    shared_rows.append([title, gene, lv1, lv2])
        ax.text(*anchor, phenotype, ha="center", va="center", fontsize=13, fontweight="bold", bbox=dict(boxstyle="round,pad=.6", fc=color, ec="none", alpha=.18))
    pd.DataFrame(edge_rows, columns=["trait_group", "LV", "gene1", "gene2", "shared_enriched_pathways"]).to_csv(OUT / "community_edges.csv", index=False)
    pd.DataFrame(gene_rows, columns=["trait_group", "LV", "gene", "rank", "recovered"]).to_csv(OUT / "community_genes.csv", index=False)
    pd.DataFrame(trait_rows, columns=["trait_group", "LV", "gene", "trait_column", "twas_pvalue"]).to_csv(OUT / "trait_supported_gene_edges.csv", index=False)
    pd.DataFrame(shared_rows, columns=["trait_group", "gene", "LV1", "LV2"]).to_csv(OUT / "inter_lv_shared_gene_edges.csv", index=False)
    summary = pd.DataFrame(summary_rows)
    selected_lvs = summary.LV.drop_duplicates().tolist()
    raw_traits = GLS[(GLS.lv.isin(selected_lvs)) & (GLS.fdr < .05)].copy()
    raw_pathways = ORA[ORA.LV.isin(selected_lvs)].copy()
    raw_traits.to_csv(OUT / "network_lv_significant_traits.csv", index=False)
    raw_pathways.to_csv(OUT / "network_lv_significant_pathways.csv", index=False)
    traits_by_lv = raw_traits.groupby("lv").apply(lambda table: "; ".join(f"{row.phenotype_desc} [{row.phenotype}; FDR={row.fdr:.3g}]" for _, row in table.sort_values("fdr").iterrows()))
    pathways_by_lv = raw_pathways.groupby("LV").apply(lambda table: "; ".join(f"{row.Description} [FDR={row['p.adjust']:.3g}]" for _, row in table.sort_values("p.adjust").iterrows()))
    summary["n_significant_traits"] = summary.LV.map(raw_traits.groupby("lv").size()).fillna(0).astype(int)
    summary["significant_traits"] = summary.LV.map(traits_by_lv).fillna("")
    summary["n_significant_canonical_pathways"] = summary.LV.map(raw_pathways.groupby("LV").size()).fillna(0).astype(int)
    summary["significant_canonical_pathways"] = summary.LV.map(pathways_by_lv).fillna("")
    summary["shared_gene_LV_connections"] = summary.apply(lambda row: "; ".join(f"{edge[1]}:{edge[3] if edge[2] == row.LV else edge[2]}" for edge in shared_rows if edge[0] == row.trait_group and row.LV in edge[2:]), axis=1)
    summary.to_csv(OUT / "network_lv_summary.csv", index=False)
    if show:
        return fig, summary
    plt.close(fig)


def render_twas(show=False):
    genes = list(GENE_IDS)
    traits = [("20002_1473-", "High\ncholesterol"), ("6177_1-", "Cholesterol-\nlowering medication"), ("AD-", "Alzheimer’s\n(self-report)"), ("IGAP_Alzheimer", "Alzheimer’s\n(IGAP-based TWAS)"), ("20110_10-", "Maternal\nAD / dementia"), ("20002_1074-", "Self-reported\nangina"), ("23120_raw-", "Right-arm\nfat mass")]
    rows = []
    for gene, ensembl in GENE_IDS.items():
        for column, (prefix, label) in enumerate(traits):
            trait_column = next(value for value in TW.columns if value.startswith(prefix))
            pvalue = float(2 * norm.sf(abs(TW.loc[ensembl, trait_column])))
            rows.append([gene, label, pvalue, min(-np.log10(max(pvalue, 1e-300)), 60), column])
    table = pd.DataFrame(rows, columns=["gene", "trait", "pvalue", "neg_log10_p_capped60", "column"])
    table.to_csv(OUT / "poster_style_twas_matrix.csv", index=False)
    fig, ax = plt.subplots(figsize=(16, 9.5))
    fig.subplots_adjust(left=.13, right=.89, top=.74, bottom=.16)
    cmap = LinearSegmentedColormap.from_list("poster", ["#DCEFEA", "#1B4D43"])
    for _, row in table.iterrows():
        y = len(genes) - 1 - genes.index(row.gene)
        ax.scatter(row.column, y, s=18 + row.neg_log10_p_capped60 / 60 * 850, c=[row.neg_log10_p_capped60], cmap=cmap, vmin=0, vmax=60, edgecolor="#879B95", linewidth=.8, zorder=3)
    ax.set_xticks(range(len(traits)), [label for _, label in traits], fontsize=11)
    ax.xaxis.tick_top()
    ax.tick_params(length=0, pad=12)
    ax.set_yticks(range(len(genes)), genes[::-1], fontstyle="italic", fontsize=13)
    ax.set_xlim(-.6, len(traits) - .4)
    ax.set_ylim(-.6, len(genes) - .4)
    ax.grid(color="#E4E8E7", lw=.8)
    ax.axhline(4.5, color="#AAB6B2", ls="--", lw=1)
    for label in ax.get_yticklabels():
        if label.get_text() in {"DGAT2", "SOX9", "PCYT2", "PTEN", "HILPDA"}:
            label.set_fontweight("bold")
    colorbar = fig.colorbar(plt.cm.ScalarMappable(norm=plt.Normalize(0, 60), cmap=cmap), ax=ax, fraction=.035, pad=.04)
    colorbar.set_label("S-MultiXcan\n−log₁₀(p), capped at 60", fontsize=11)
    if show:
        return fig
    plt.close(fig)


OUT.mkdir(parents=True, exist_ok=True)
plt.rcParams.update({"font.family": "DejaVu Sans", "font.size": 10, "axes.spines.top": False, "axes.spines.right": False, "savefig.facecolor": "white"})
network_figure, lv_information = render_network(show=True)
twas_figure = render_twas(show=True)

def show_table(table):
    html = table.to_html(index=False, escape=True)
    style = """
    <style>
      .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
      table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
      table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
      table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
      table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
      table.full-table tr:nth-child(even) td { background: #f5f5f5; }
    </style>
    """
    display(HTML(style + '<div class="full-table-wrap">' + html.replace('<table border="1" class="dataframe">', '<table class="full-table">') + '</div>'))
# Out:
# /tmp/ipykernel_263578/2794994847.py:137: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   traits_by_lv = raw_traits.groupby("lv").apply(lambda table: "; ".join(f"{row.phenotype_desc} [{row.phenotype}; FDR={row.fdr:.3g}]" for _, row in table.sort_values("fdr").iterrows()))
# /tmp/ipykernel_263578/2794994847.py:138: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %% [markdown]
# ## LV information

# %%
lv_index = lv_information.loc[:, ["trait_group", "LV", "CRISPR_gene"]].drop_duplicates()
show_table(lv_index)
# Out:
#     <style>
#       .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
#       table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
#       table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
#       table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
#       table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
#       table.full-table tr:nth-child(even) td { background: #f5f5f5; }
#     </style>
#     <div class="full-table-wrap"><table class="full-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>trait_group</th>
#       <th>LV</th>
#       <th>CRISPR_gene</th>
#     </tr>
# ...

# %% [markdown]
# ## Significant traits

# %%
significant_traits = pd.read_csv(OUT / "network_lv_significant_traits.csv").rename(columns={"lv": "LV"})
significant_traits = lv_index.merge(significant_traits, on="LV", how="inner")
show_table(significant_traits)
# Out:
#     <style>
#       .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
#       table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
#       table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
#       table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
#       table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
#       table.full-table tr:nth-child(even) td { background: #f5f5f5; }
#     </style>
#     <div class="full-table-wrap"><table class="full-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>trait_group</th>
#       <th>LV</th>
#       <th>CRISPR_gene</th>
# ...

# %% [markdown]
# ## Significant canonical pathways

# %%
significant_pathways = pd.read_csv(OUT / "network_lv_significant_pathways.csv")
significant_pathways = lv_index.merge(significant_pathways, on="LV", how="inner")
show_table(significant_pathways)
# Out:
#     <style>
#       .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
#       table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
#       table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
#       table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
#       table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
#       table.full-table tr:nth-child(even) td { background: #f5f5f5; }
#     </style>
#     <div class="full-table-wrap"><table class="full-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>trait_group</th>
#       <th>LV</th>
#       <th>CRISPR_gene</th>
# ...

# %% [markdown]
# ## Displayed LV genes

# %%
displayed_genes = pd.read_csv(OUT / "community_genes.csv")
show_table(displayed_genes)
# Out:
#     <style>
#       .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
#       table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
#       table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
#       table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
#       table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
#       table.full-table tr:nth-child(even) td { background: #f5f5f5; }
#     </style>
#     <div class="full-table-wrap"><table class="full-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>trait_group</th>
#       <th>LV</th>
#       <th>gene</th>
#       <th>rank</th>
# ...

# %% [markdown]
# ## Same-trait TWAS-supported genes

# %%
trait_supported_genes = pd.read_csv(OUT / "trait_supported_gene_edges.csv")
show_table(trait_supported_genes)
# Out:
#     <style>
#       .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
#       table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
#       table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
#       table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
#       table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
#       table.full-table tr:nth-child(even) td { background: #f5f5f5; }
#     </style>
#     <div class="full-table-wrap"><table class="full-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>trait_group</th>
#       <th>LV</th>
#       <th>gene</th>
#       <th>trait_column</th>
# ...

# %% [markdown]
# ## Shared genes between LV communities

# %%
shared_gene_connections = pd.read_csv(OUT / "inter_lv_shared_gene_edges.csv")
show_table(shared_gene_connections)
# Out:
#     <style>
#       .full-table-wrap { max-height: 650px; overflow-y: auto; border: 1px solid #ccc; background: #ffffff; }
#       table.full-table { border-collapse: collapse; width: 100%; font-size: 13px; background: #ffffff; color: #000000; }
#       table.full-table th { position: sticky; top: 0; background: #eef1f5; color: #000000; padding: 6px 8px; border: 1px solid #ccc; text-align: left; }
#       table.full-table td { padding: 6px 8px; border: 1px solid #e0e0e0; vertical-align: top; white-space: normal; word-wrap: break-word; background: #ffffff; color: #000000; }
#       table.full-table td:first-child, table.full-table th:first-child { white-space: nowrap; font-weight: bold; }
#       table.full-table tr:nth-child(even) td { background: #f5f5f5; }
#     </style>
#     <div class="full-table-wrap"><table class="full-table">
#   <thead>
#     <tr style="text-align: right;">
#       <th>trait_group</th>
#       <th>gene</th>
#       <th>LV1</th>
#       <th>LV2</th>
# ...

# %% [markdown]
# ## Stratagenic network

# %%
from io import BytesIO
from IPython.display import HTML, Image, display

network_png = BytesIO()
network_figure.savefig(network_png, format="png", bbox_inches="tight")
display(Image(data=network_png.getvalue()))

# %% [markdown]
# ## Single-gene TWAS

# %%
twas_png = BytesIO()
twas_figure.savefig(twas_png, format="png", bbox_inches="tight")
display(Image(data=twas_png.getvalue()))

# %%
Path(snakemake.output["complete"]).touch()
