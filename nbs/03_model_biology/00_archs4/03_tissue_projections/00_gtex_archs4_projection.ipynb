# %% [markdown]
# # GTEx projection into ARCHS4 CLAMP Hallmark model

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %% [markdown]
# Projects GTEx v8 RNA-seq TPM data into the ARCHS4 CLAMP Hallmark model using `CLAMP::projectCLAMP`.
# Genes are aligned between datasets; the result (LVs x samples) is saved to CSV for downstream analysis.

# %% [markdown]
# ## Libraries

# %%
library(data.table)
library(dplyr)
library(here)
library(CLAMP)

source(here("config.R"))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses

# %% [markdown]
# ## Output

# %%
output_dir <- here("output", "03_model_biology", "00_archs4", "03_tissue_projections", "00_gtex_archs4_projection")
dir.create(output_dir, showWarnings = FALSE, recursive = TRUE)
projection_path <- file.path(output_dir, "gtex_archs4_projection.csv")
projection_path
# Out:
# [1] "/home/msubirana/Documents/pivlab/clamp-analyses/output/03_model_biology/00_archs4/03_tissue_projections/00_gtex_archs4_projection/gtex_archs4_projection.csv"

# %% [markdown]
# ## Load ARCHS4 CLAMP model

# %%
archs4_model <- readRDS(here("output", "01_model_building", "04_archs4", "06_bp_coverage_rshall", "06_bp_coverage_hall_rs_100", "hall_coverage_rs100_seed_1", "CLAMPfull_hall.rds"))
archs4_genes <- rownames(archs4_model$Z)
cat("ARCHS4 model genes:", length(archs4_genes), "\n")
cat("ARCHS4 model samples:  ", ncol(archs4_model$B), "\n")
# Out:
# ARCHS4 model genes: 18423
# ARCHS4 model samples:   605614

# %% [markdown]
# ## Load and aggregate raw GTEx TPM

# %%
exprs_path  <- file.path(config$GTEx$DATASET_FOLDER, 'GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz')
output_file <- config$GTEx$DATASET_FILE

if (!file.exists(output_file)) {
  dir.create(dirname(output_file), recursive = TRUE, showWarnings = FALSE)
  exprs_data <- read.table(exprs_path, header = TRUE, sep = "\t", skip = 2, check.names = FALSE)
  saveRDS(exprs_data, output_file)
  message("File successfully written to: ", output_file)
} else {
  message("Output file already exists. Skipping.")
}
# Out:
# Output file already exists. Skipping.

# %%
gtex <- readRDS(here(config$GTEx$DATASET_FILE))
gtex <- as.data.table(gtex)
aggregated_gtex <- gtex[, lapply(.SD, sum), by = Description, .SDcols = is.numeric]

genes    <- aggregated_gtex$Description
samples  <- colnames(aggregated_gtex[, -1])
data_mat <- as.matrix(aggregated_gtex[, -1])
rownames(data_mat) <- genes
colnames(data_mat) <- samples

cat("GTEx expression:", nrow(data_mat), "genes x", ncol(data_mat), "samples\n")
# Out:
# GTEx expression: 54592 genes x 17382 samples

# %% [markdown]
# ## Normalize GTEx TPM
#
# Apply `preprocessCLAMP` + `zscoreCLAMP`

# %%
# preprocessCLAMP filters low-mean and low-variance genes; zscoreCLAMP z-scores per gene
prep_gtex <- CLAMP::preprocessCLAMP(Y = data_mat, mean_cutoff = 0.5, var_cutoff = 0.1)
norm_gtex <- CLAMP::zscoreCLAMP(Y_filtered = prep_gtex$Y_filtered,
                                 rowStats   = prep_gtex$rowStats)
genes_norm <- rownames(norm_gtex)
cat("Normalized GTEx:", nrow(norm_gtex), "genes x", ncol(norm_gtex), "samples\n")
# Out:
# Normalized GTEx: 23906 genes x 17382 samples

# %% [markdown]
# ## Align to ARCHS4 gene space

# %%
common_genes <- intersect(archs4_genes, genes_norm)
cat("Overlapping genes:", length(common_genes), "/", length(archs4_genes), "ARCHS4 genes",
    sprintf("(%.1f%%)\n", 100 * length(common_genes) / length(archs4_genes)))

# Subset data to common genes
gtex_aligned <- norm_gtex[common_genes, , drop = FALSE]

# Filter model to significant LVs (AUC > 0.7, FDR < 0.05)
archs4_model_summary <- archs4_model$summary
archs4_model_summary %>%
  dplyr::filter(AUC > 0.7) %>%
  dplyr::filter(FDR < 0.01) %>%
  dplyr::pull(LV) %>%
  unique() -> significant_LVs

cat("Significant LVs:", length(significant_LVs), "\n")

# Subset model Z to common genes AND significant LVs
# (projectCLAMP requires nrow(Z) == nrow(newdata))
archs4_model_sub   <- archs4_model
archs4_model_sub$Z <- as.matrix(archs4_model$Z[common_genes, significant_LVs, drop = FALSE])
# Out:
# Overlapping genes: 15603 / 18423 ARCHS4 genes (84.7%)
# Significant LVs: 363

# %% [markdown]
# ## Project with `CLAMP::projectCLAMP`

# %%
proj <- projectCLAMP(
  CLAMPres = archs4_model_sub,
  newdata  = gtex_aligned,
)

write.csv(as.data.frame(proj), projection_path, row.names = TRUE)
message("Projection saved to: ", projection_path)
# Out:
# Projection saved to: /home/msubirana/Documents/pivlab/clamp-analyses/output/03_model_biology/00_archs4/03_tissue_projections/00_gtex_archs4_projection/gtex_archs4_projection.csv

# %%
proj_check <- read.csv(projection_path, row.names = 1, check.names = FALSE)
cat("Projection dimensions:", nrow(proj_check), "LVs x", ncol(proj_check), "samples\n")
proj_check[1:5, 1:5]
# Out:
# Projection dimensions: 363 LVs x 17382 samples
#      GTEX-1117F-0226-SM-5GZZ7 GTEX-1117F-0426-SM-5EGHI GTEX-1117F-0526-SM-5EGHJ
# LV4   0.038761674             -0.199341806             -0.034117713
# LV5  -0.007485786              0.002434416             -0.004115032
# LV6   0.098469664             -0.005738882              0.045076624
# LV7  -0.044971247             -0.032262567             -0.030164494
# LV11 -0.027979902             -0.018314507             -0.014664205
#      GTEX-1117F-0626-SM-5N9CS GTEX-1117F-0726-SM-5GIEN
# LV4   0.16994381              -0.1631328235
# LV5  -0.00308386               0.0004836395
# LV6   0.07515469               0.0435743233
# LV7  -0.03449374              -0.0237511587
# LV11 -0.01267679              -0.0084495946

# %% [markdown]
# ## Randomized-Z projection (null baseline)
#
# Row-permute Z so gene–pathway associations are broken, preserving the loading value distribution.

# %%
set.seed(42)

rand_projection_path <- file.path(output_dir, "gtex_archs4_randomZ_projection.csv")

Z_real   <- as.matrix(archs4_model_sub$Z)
perm_idx <- sample(nrow(Z_real))
Z_rand   <- Z_real[perm_idx, , drop = FALSE]
rownames(Z_rand) <- rownames(Z_real)

archs4_model_rand   <- archs4_model_sub
archs4_model_rand$Z <- Z_rand

proj_rand <- projectCLAMP(
  CLAMPres = archs4_model_rand,
  newdata  = gtex_aligned
)

write.csv(as.data.frame(proj_rand), rand_projection_path, row.names = TRUE)
message("Randomized-Z projection saved to: ", rand_projection_path)
# Out:
# Randomized-Z projection saved to: /home/msubirana/Documents/pivlab/clamp-analyses/output/archs4/gtex_archs4_randomZ_projection.csv
