# %%
arch4_clamp <- readRDS(here::here('output/archs4/archs4_CLAMP.rds'))

# %%
library(dplyr)

arch4_clamp_summary_sub <- arch4_clamp$summary %>% 
dplyr::filter(AUC > 0.7 & FDR < 0.05) %>%
dplyr::arrange(desc(AUC))

dim(arch4_clamp$summary)
head(arch4_clamp_summary_sub)
dim(arch4_clamp_summary_sub)
# Out:
# [1] 13473     7
#                  pathway
# GTEx_Tissues1311 GTEx_Tissues_Nerve - Tibial Female 60-69 Up
# GTEx_Tissues14   GTEx_Tissues_Thyroid Male 50-59 Up
# GTEx_Tissues131  GTEx_Tissues_Nerve - Tibial Female 60-69 Up
# GTEx_Tissues39   GTEx_Tissues_Thyroid Male 60-69 Up
# GTEx_Tissues304  GTEx_Tissues_Skin - Sun Exposed (Lower Leg) Female 40-49 Up
# GTEx_Tissues67   GTEx_Tissues_Adrenal Gland Female 60-69 Up
#                  LV     AUC       p_value      FDR          npos nneg
# GTEx_Tissues1311 LV535  1.0000000 3.012626e-12 1.040747e-09 14   18294
# GTEx_Tissues14   LV1256 1.0000000 3.719587e-12 1.194082e-09 14   18308
# GTEx_Tissues131  LV507  0.9999961 7.888645e-12 2.083994e-09 14   18301
# GTEx_Tissues39   LV1256 0.9999922 3.722367e-12 1.194082e-09 14   18308
# GTEx_Tissues304  LV946  0.9999864 1.297659e-07 6.937841e-06  8   18353
# GTEx_Tissues67   LV680  0.9999761 1.726886e-14 2.332214e-11 16   18294
# [1] 738   7

# %%
print(arch4_clamp_summary_sub)
# Out:
#                                                                                                            pathway
# GTEx_Tissues1311                                                       GTEx_Tissues_Nerve - Tibial Female 60-69 Up
# GTEx_Tissues14                                                                  GTEx_Tissues_Thyroid Male 50-59 Up
# GTEx_Tissues131                                                        GTEx_Tissues_Nerve - Tibial Female 60-69 Up
# GTEx_Tissues39                                                                  GTEx_Tissues_Thyroid Male 60-69 Up
# GTEx_Tissues304                                        GTEx_Tissues_Skin - Sun Exposed (Lower Leg) Female 40-49 Up
# GTEx_Tissues67                                                          GTEx_Tissues_Adrenal Gland Female 60-69 Up
# GTEx_Tissues13                                                            GTEx_Tissues_Adrenal Gland Male 50-59 Up
# ...
