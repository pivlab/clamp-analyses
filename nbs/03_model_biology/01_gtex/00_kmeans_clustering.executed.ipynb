# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/usr/lib/python3/dist-packages', '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95W>\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cCoutput/03_model_biology/01_gtex/00_kmeans_clustering/kmeans_results\x94\x8cboutput/03_model_biology/01_gtex/00_kmeans_clustering/kmeans_models/gtex_CLAMPfull_kmeans_model.pkl\x94\x8cg/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex/00_kmeans_clustering.ipynb\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x05cache\x94K\x00N\x86\x94\x8c\x05model\x94K\x01N\x86\x94\x8c\x08notebook\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x18\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1e)}\x94\x8c\x05_name\x94h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x10h\nh\x12h\x0bh\x14h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8cAoutput/03_model_biology/01_gtex/00_kmeans_clustering/ari_data.csv\x94\x8cHoutput/03_model_biology/01_gtex/00_kmeans_clustering/ari_comparisons.csv\x94\x8cOoutput/03_model_biology/01_gtex/00_kmeans_clustering/gene_fraction_ari_data.csv\x94\x8cVoutput/03_model_biology/01_gtex/00_kmeans_clustering/gene_fraction_ari_comparisons.csv\x94\x8cFoutput/03_model_biology/01_gtex/00_kmeans_clustering/notebook.complete\x94e}\x94(h\x0e}\x94(\x8c\x08ari_data\x94K\x00N\x86\x94\x8c\x0fari_comparisons\x94K\x01N\x86\x94\x8c\x16gene_fraction_ari_data\x94K\x02N\x86\x94\x8c\x1dgene_fraction_ari_comparisons\x94K\x03N\x86\x94\x8c\x08complete\x94K\x04N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh3h,h5h-h7h.h9h/h;h0ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0e}\x94h\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x0e}\x94h\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bhlK\x01hnK\x01hphiub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cp/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex/00_kmeans_clustering.executed.ipynb\x94a}\x94(h\x0e}\x94h\x14K\x00N\x86\x94sh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x14h\x7fub\x8c\x06config\x94}\x94(\x8c\x08datasets\x94}\x94(\x8c\x10Brain_Mathys2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c data/pseudobulk/Brain_Mathys2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c8data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz\x94\x8c\x08features\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz\x94\x8c\x08barcodes\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c-data/pseudobulk/raw/Brain_Mathys2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x08cellName\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0ctruth_v1_col\x94\x8c\tCell_Type\x94\x8c\x11raw_cell_type_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x14projection_label_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0fcohort_manifest\x94\x8c1data/pseudobulk/Brain_Mathys2023/patient_info.csv\x94u\x8c\x0fBrain_Xiong2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1fdata/pseudobulk/Brain_Xiong2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c1data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz\x94\x8c\x08features\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz\x94\x8c\x08barcodes\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c,data/pseudobulk/raw/Brain_Xiong2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x06cellId\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x14hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x08Celltype\x94\x8c\x0ctruth_v1_col\x94\x8c\x0bSubcelltype\x94\x8c\x11raw_cell_type_col\x94\x8c\x08Celltype\x94\x8c\x14projection_label_col\x94\x8c\x08Celltype\x94\x8c\x0fcohort_manifest\x94\x8c0data/pseudobulk/Brain_Xiong2023/patient_info.csv\x94u\x8c\x0fHeart_Datar2026\x94}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c=data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad\x94\x8c\x06matrix\x94\x8c\x01X\x94\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x11raw_cell_type_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x14projection_label_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\tmin_cells\x94M\x90\x01\x8c\x07exclude\x94}\x94\x8c\x19cell_type__ontology_label\x94]\x94\x8c\x04cell\x94as\x8c\x0ctruth_v0_map\x94}\x94(\x8c\tadipocyte\x94\x8c\tAdipocyte\x94\x8c\x1eregular atrial cardiac myocyte\x94\x8c\x08AtrialCM\x94\x8c\x10endocardial cell\x94\x8c\x0bEndocardial\x94\x8c\x18cardiac endothelial cell\x94\x8c\x0bEndothelial\x94\x8c\x1emesothelial cell of epicardium\x94\x8c\nEpicardial\x94\x8c\x1cfibroblast of cardiac tissue\x94\x8c\nFibroblast\x94\x8c$endothelial cell of lymphatic vessel\x94\x8c\x14LymphaticEndothelial\x94\x8c\nlymphocyte\x94\x8c\nLymphocyte\x94\x8c\nmacrophage\x94\x8c\nMacrophage\x94\x8c\tmast cell\x94\x8c\x04Mast\x94\x8c\x0ecardiac neuron\x94\x8c\x08Neuronal\x94\x8c\x08pericyte\x94\x8c\x08Pericyte\x94\x8c&vascular associated smooth muscle cell\x94\x8c\x04VSMC\x94\x8c#regular ventricular cardiac myocyte\x94\x8c\rVentricularCM\x94u\x8c\x14projection_label_map\x94}\x94(h\xe9h\xeah\xebh\xech\xedh\xeeh\xefh\xf0h\xf1h\xf2h\xf3h\xf4h\xf5h\xf6h\xf7h\xf8h\xf9h\xfah\xfbh\xfch\xfdh\xfeh\xffj\x00\x01\x00\x00j\x01\x01\x00\x00j\x02\x01\x00\x00j\x03\x01\x00\x00j\x04\x01\x00\x00uu\x8c\tPBMC_1k1k\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x19data/pseudobulk/PBMC_1k1k\x94\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c0data/pseudobulk/raw/PBMC_1k1k/PBMC_1k1k_raw.h5ad\x94\x8c\x06matrix\x94h\xd6\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c"sample_prefix_hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x11raw_cell_type_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x14projection_label_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x0fcohort_manifest\x94\x8c*data/pseudobulk/PBMC_1k1k/patient_info.csv\x94\x8c\x0ctruth_v0_map\x94}\x94(\x8c\x07CD4 CTL\x94\x8c\x05CD4_T\x94\x8c\tCD4 Naive\x94\x8c\x05CD4_T\x94\x8c\x11CD4 Proliferating\x94\x8c\x05CD4_T\x94\x8c\x07CD4 TCM\x94\x8c\x05CD4_T\x94\x8c\x07CD4 TEM\x94\x8c\x05CD4_T\x94\x8c\x04Treg\x94\x8c\x05CD4_T\x94\x8c\tCD8 Naive\x94\x8c\x05CD8_T\x94\x8c\x11CD8 Proliferating\x94\x8c\x05CD8_T\x94\x8c\x07CD8 TCM\x94\x8c\x05CD8_T\x94\x8c\x07CD8 TEM\x94\x8c\x05CD8_T\x94\x8c\x03gdT\x94\x8c\x04gd_T\x94\x8c\x0eB intermediate\x94\x8c\x06B_cell\x94\x8c\x08B memory\x94\x8c\x06B_cell\x94\x8c\x07B naive\x94\x8c\x06B_cell\x94\x8c\x0bPlasmablast\x94\x8c\x08Plasma_B\x94\x8c\tCD14 Mono\x94\x8c\tCD14_Mono\x94\x8c\tCD16 Mono\x94\x8c\tCD16_Mono\x94\x8c\x04cDC1\x94\x8c\x02DC\x94\x8c\x04cDC2\x94\x8c\x02DC\x94\x8c\x04ASDC\x94\x8c\x02DC\x94\x8c\x02NK\x94\x8c\x02NK\x94\x8c\x10NK Proliferating\x94\x8c\x02NK\x94\x8c\rNK_CD56bright\x94\x8c\x02NK\x94u\x8c\x14projection_label_map\x94}\x94(j\x1f\x01\x00\x00j \x01\x00\x00j!\x01\x00\x00j"\x01\x00\x00j#\x01\x00\x00j$\x01\x00\x00j%\x01\x00\x00j&\x01\x00\x00j\'\x01\x00\x00j(\x01\x00\x00j)\x01\x00\x00j*\x01\x00\x00j+\x01\x00\x00j,\x01\x00\x00j-\x01\x00\x00j.\x01\x00\x00j/\x01\x00\x00j0\x01\x00\x00j1\x01\x00\x00j2\x01\x00\x00j3\x01\x00\x00j4\x01\x00\x00j5\x01\x00\x00j6\x01\x00\x00j7\x01\x00\x00j8\x01\x00\x00j9\x01\x00\x00j:\x01\x00\x00j;\x01\x00\x00j<\x01\x00\x00j=\x01\x00\x00j>\x01\x00\x00j?\x01\x00\x00j@\x01\x00\x00jA\x01\x00\x00jB\x01\x00\x00jC\x01\x00\x00jD\x01\x00\x00jE\x01\x00\x00jF\x01\x00\x00jG\x01\x00\x00jH\x01\x00\x00jI\x01\x00\x00jJ\x01\x00\x00jK\x01\x00\x00jL\x01\x00\x00uu\x8c\x0ePBMC_Perez2022\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1edata/pseudobulk/PBMC_Perez2022\x94\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c:data/pseudobulk/raw/PBMC_Perez2022/PBMC_Perez2022_raw.h5ad\x94\x8c\x06matrix\x94\x8c\x05raw.X\x94\x8c\nsample_col\x94\x8c\x07ind_cov\x94\x8c\x10sample_transform\x94\x8c"sample_prefix_hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\tcell_type\x94\x8c\x11raw_cell_type_col\x94\x8c\tcell_type\x94\x8c\x14projection_label_col\x94\x8c\tcell_type\x94\x8c\x0fcohort_manifest\x94\x8c/data/pseudobulk/PBMC_Perez2022/patient_info.csv\x94\x8c\x0ctruth_v0_map\x94}\x94(\x8c\x06B cell\x94\x8c\x06B_cell\x94\x8c\x0bplasmablast\x94\x8c\x06B_cell\x94\x8c\x12classical monocyte\x94\x8c\x07Myeloid\x94\x8c\x16non-classical monocyte\x94\x8c\x07Myeloid\x94\x8c\x1bconventional dendritic cell\x94\x8c\x07Myeloid\x94\x8c\x1bplasmacytoid dendritic cell\x94\x8c\x07Myeloid\x94\x8c\x0fprogenitor cell\x94\x8c\x07Myeloid\x94\x8c\x13natural killer cell\x94\x8c\x02NK\x94\x8c\x1fCD4-positive, alpha-beta T cell\x94\x8c\x06T_cell\x94\x8c\x1fCD8-positive, alpha-beta T cell\x94\x8c\x06T_cell\x94\x8c\nlymphocyte\x94\x8c\x06T_cell\x94u\x8c\x14projection_label_map\x94}\x94(jh\x01\x00\x00ji\x01\x00\x00jj\x01\x00\x00jk\x01\x00\x00jl\x01\x00\x00jm\x01\x00\x00jn\x01\x00\x00jo\x01\x00\x00jp\x01\x00\x00jq\x01\x00\x00jr\x01\x00\x00js\x01\x00\x00jt\x01\x00\x00ju\x01\x00\x00jv\x01\x00\x00jw\x01\x00\x00jx\x01\x00\x00jy\x01\x00\x00jz\x01\x00\x00j{\x01\x00\x00j|\x01\x00\x00j}\x01\x00\x00uu\x8c\x10Lung_Sikkema2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c/data/pseudobulk/Lung_Sikkema2023/lung_HLCA.h5ad\x94\x8c\x06matrix\x94\x8c\x05raw.X\x94\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0bann_level_2\x94\x8c\x0ctruth_v1_col\x94\x8c\x10ann_finest_level\x94\x8c\x11raw_cell_type_col\x94\x8c\x0bann_level_3\x94\x8c\x14projection_label_col\x94\x8c\x0bann_level_2\x94\x8c\tmin_cells\x94M\x90\x01uu\x8c\x07methods\x94}\x94(\x8c\tCLAMPbase\x94\x8c\x0fCLAMPbase/B.csv\x94\x8c\tCLAMPfull\x94\x8c\x0fCLAMPfull/B.csv\x94\x8c\x05PLIER\x94\x8c\x0bPLIER/B.csv\x94\x8c\x03PCA\x94\x8c\tPCA/B.csv\x94\x8c\x03NMF\x94\x8c\tNMF/B.csv\x94\x8c\x03ICA\x94\x8c\tICA/B.csv\x94\x8c\x08Flashier\x94\x8c\x0eflashier/B.csv\x94\x8c\tMOFA-FLEX\x94\x8c\x15MOFA_FLEX_PRIOR/B.csv\x94\x8c\x05GSSig\x94\x8c\tGSS/B.csv\x94\x8c\x06CoGAPS\x94\x8c\x0cCoGAPS/B.csv\x94u\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c&output/01_model_building/00_pseudobulk\x94\x8c\x07biology\x94\x8c%output/03_model_biology/00_pseudobulk\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94\x8c\x06panels\x94\x8c\x10output/99_panels\x94\x8c\x10panels_notebooks\x94\x8c\rnbs/99_panels\x94u\x8c\nreferences\x94}\x94(\x8c\tgo_bp_url\x94\x8c_https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025\x94\x8c\ngo_bp_file\x94\x8c,data/pathways/GO_Biological_Process_2025.gmt\x94\x8c\x0cgo_bp_sha256\x94\x8c@0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee\x94\x8c\x10cell_marker_file\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x14allen_brain_gmt_file\x94\x8c2data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt\x94\x8c\x0cazimuth_file\x94\x8c\x1edata/pathways/Azimuth_2023.txt\x94\x8c\x14gtex_tissues_pathmat\x94\x8c$data/archs4/GTEx_Tissues_pathMat.rds\x94\x8c\x0ebrain_datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94eu\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x0fmodule_recovery\x94}\x94(\x8c\x11top_gene_fraction\x94G?\x84z\xe1G\xae\x14{\x8c\x13retry_gene_fraction\x94G?\x9e\xb8Q\xeb\x85\x1e\xb8\x8c\rfdr_threshold\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\ttop_terms\x94K\x03u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\ngrouped_cv\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\tgroup_col\x94\x8c\x06sample\x94\x8c\nsplit_seed\x94K*\x8c\x10min_train_lv_cor\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x0ebootstrap_seed\x94K{\x8c\x14bootstrap_replicates\x94M\x10\'u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{u\x8c\tmofa_flex\x94}\x94(\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0ctop_fraction\x94G?\x84z\xe1G\xae\x14{u\x8c\x12cell_type_analysis\x94}\x94\x8c\x10excluded_targets\x94}\x94(\x8c\x10Brain_Mathys2023\x94]\x94\x8c\x03Vas\x94a\x8c\x0fBrain_Xiong2023\x94]\x94\x8c\x03Vas\x94a\x8c\x10Lung_Sikkema2023\x94]\x94(\x8c\x18Hematopoietic stem cells\x94\x8c\x0bMesothelium\x94\x8c\rSmooth muscle\x94eus\x8c\x04gtex\x94}\x94(\x8c\x07raw_url\x94\x8cwhttps://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x06raw_gz\x94\x8cCdata/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x08metadata\x94\x8c=data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt\x94\x8c\x0cxcell_scores\x94\x8c7data/gtex/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt\x94\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c output/01_model_building/01_gtex\x94\x8c\x07biology\x94\x8c\x1foutput/03_model_biology/01_gtex\x94\x8c\x0fmodel_notebooks\x94\x8c\x1dnbs/01_model_building/01_gtex\x94\x8c\x11biology_notebooks\x94\x8c\x1cnbs/03_model_biology/01_gtex\x94u\x8c\x08raw_data\x94}\x94(\x8c\nchunk_size\x94Kd\x8c\x07n_cores\x94K\x01u\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x0fmofa_flex_prior\x94}\x94(\x8c\x0cmin_fraction\x94G?\xd9\x99\x99\x99\x99\x99\x9a\x8c\tmin_count\x94K(\x8c\tmax_count\x94K\xc8\x8c\x14similarity_threshold\x94G?\xe9\x99\x99\x99\x99\x99\x9a\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{\x8c\x0ctimeout_days\x94K\x07u\x8c\x03gss\x94}\x94(\x8c\td_cluster\x94K\x04\x8c\x04seed\x94K{u\x8c\x11kmeans_clustering\x94}\x94(\x8c\x0bmin_samples\x94K2\x8c\x0fari_min_samples\x94K\x01\x8c\nn_clusters\x94K6\x8c\tbase_seed\x94M\x10\'\x8c\x0cn_reps_per_k\x94K2\x8c\x0egene_fractions\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xe8\x00\x00\x00\x00\x00\x00G?\xe0\x00\x00\x00\x00\x00\x00G?\xd0\x00\x00\x00\x00\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aG?\xa9\x99\x99\x99\x99\x99\x9aG?\x84z\xe1G\xae\x14{eu\x8c\rlv_importance\x94}\x94(\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xec\xcc\xcc\xcc\xcc\xcc\xcdu\x8c\x13subtissue_inference\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xeb333333\x8c\x15min_subtissue_samples\x94K\x14\x8c\x0fn_jobs_per_fold\x94K\x08\x8c\x0fanatomical_spec\x94\x8c.workflow/config/gtex_anatomical_subtissues.tsv\x94\x8c\x13permutation_repeats\x94M\xe8\x03\x8c\x11bootstrap_repeats\x94M\xe8\x03\x8c\x0fevaluation_jobs\x94K\x08\x8c\x07tissues\x94]\x94(\x8c\x0eAdipose Tissue\x94\x8c\x05Blood\x94\x8c\x0cBlood Vessel\x94\x8c\x05Brain\x94\x8c\x05Colon\x94\x8c\tEsophagus\x94\x8c\x05Heart\x94\x8c\x06Kidney\x94\x8c\x04Skin\x94euu\x8c\x11runtime_benchmark\x94}\x94(\x8c\x05seeds\x94]\x94(K{M\xc8\x01M\x15\x03e\x8c\x07threads\x94K\x04\x8c\x07methods\x94]\x94(\x8c\tCLAMPfull\x94\x8c\tCLAMPbase\x94\x8c\x05PLIER\x94\x8c\x06CoGAPS\x94\x8c\x08Flashier\x94\x8c\x03NMF\x94\x8c\x03PCA\x94\x8c\x03ICA\x94\x8c\x05GSSig\x94\x8c\tMOFA-FLEX\x94e\x8c\x0boutput_root\x94\x8cAoutput/02_model_performance/00_pseudobulk/00_computational_timing\x94\x8c\x08notebook\x94\x8cDnbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb\x94u\x8c\x16runtime_benchmark_gtex\x94}\x94(\x8c\x07dataset\x94\x8c\x04GTEx\x94\x8c\x05seeds\x94]\x94(K{M\xc8\x01M\x15\x03e\x8c\x07threads\x94K\x04\x8c\x07methods\x94]\x94(\x8c\tCLAMPfull\x94\x8c\tCLAMPbase\x94\x8c\x05PLIER\x94\x8c\x08Flashier\x94\x8c\x03NMF\x94\x8c\x03PCA\x94\x8c\x03ICA\x94\x8c\x05GSSig\x94\x8c\tMOFA-FLEX\x94e\x8c\x10excluded_methods\x94}\x94\x8c\x06CoGAPS\x94X\x0c\x01\x00\x00rule cogaps_gtex was run to the end of its hard wall-clock budget (gtex.cogaps.timeout_days = 7) and killed without converging; the evidence is on disk at output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt. CoGAPS therefore has no finite GTEx runtime to report\n\x94s\x8c\x0fcogaps_evidence\x94\x8c9output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt\x94\x8c\x0boutput_root\x94\x8c;output/02_model_performance/01_gtex/00_computational_timing\x94\x8c\x08notebook\x94\x8c>nbs/02_model_performance/01_gtex/00_computational_timing.ipynb\x94u\x8c\ndonor_bulk\x94}\x94(\x8c\x08datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94\x8c\x0fHeart_Datar2026\x94\x8c\tPBMC_1k1k\x94\x8c\x0ePBMC_Perez2022\x94\x8c\x10Lung_Sikkema2023\x94e\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c1output/01_model_building/00_pseudobulk/donor_bulk\x94\x8c\x07biology\x94\x8c<output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94u\x8c\x0baggregation\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0csample_cells\x94M`\xea\x8c\x10minimum_per_type\x94K\xfa\x8c\x04seed\x94K{u\x8c\x04umap\x94}\x94(\x8c\ntarget_sum\x94M\x10\'\x8c\x05n_hvg\x94M\xd0\x07\x8c\x05n_pcs\x94K2\x8c\x0bn_neighbors\x94K\x1e\x8c\x08min_dist\x94G?\xd3333333\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x15duplicate_gene_policy\x94\x8c\x03sum\x94uu\x8c\x06archs4\x94}\x94(\x8c\x07raw_url\x94\x8c>https://s3.dev.maayanlab.cloud/archs4/files/human_gene_v2.5.h5\x94\x8c\x06raw_h5\x94\x8c\x1edata/archs4/human_gene_v2.5.h5\x94\x8c\x0cgene_lengths\x94\x8c\x1cdata/archs4/gene_lengths.rds\x94\x8c\x0fensembl_version\x94Kk\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c"output/01_model_building/02_archs4\x94\x8c\x07biology\x94\x8c!output/03_model_biology/02_archs4\x94\x8c\x0fmodel_notebooks\x94\x8c\x1fnbs/01_model_building/02_archs4\x94\x8c\x11biology_notebooks\x94\x8c\x1enbs/03_model_biology/02_archs4\x94u\x8c\x08raw_data\x94}\x94(\x8c\nblock_size\x94Kd\x8c\x07n_cores\x94K\nu\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x1bsingle_cell_probability_max\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x04seed\x94K{u\x8c\x03svd\x94}\x94(\x8c\x07n_cores\x94K\x1e\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x0ck_multiplier\x94K\x02\x8c\nmultiplier\x94Kd\x8c\x08max_iter\x94M\x88\x13\x8c\x04seed\x94K{u\x8c\x05prior\x94}\x94\x8c\x04gmts\x94}\x94(\x8c\x04HALL\x94\x8c*data/pathways/h.all.v2026.1.Hs.symbols.gmt\x94\x8c\x08REACTOME\x94\x8c3data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt\x94\x8c\x04GOCC\x94\x8c-data/pathways/c5.go.cc.v2026.1.Hs.symbols.gmt\x94\x8c\x02C8\x94\x8c+data/pathways/c8.all.v2026.1.Hs.symbols.gmt\x94us\x8c\x0bfinal_model\x94}\x94(\x8c\x03dir\x94\x8c1output/01_model_building/02_archs4/01_final_model\x94\x8c\x05seeds\x94]\x94(K\x01K\x02K\x03e\x8c\x0ereference_seed\x94K\x01\x8c\x04leaf\x94\x8c\nseed{seed}\x94\x8c\nmodel_name\x94\x8c\tCLAMPfull\x94u\x8c\x08coverage\x94}\x94(\x8c\tprior_gmt\x94\x8c"data/pathways/go_bp.Hs.symbols.gmt\x94\x8c\nmodel_root\x94\x8c;output/01_model_building/02_archs4/02_coverage_study/models\x94\x8c\x08ora_root\x94\x8c8output/01_model_building/02_archs4/02_coverage_study/ora\x94\x8c\x0bassignments\x94\x8c9output/03_model_biology/02_archs4/00_coverage/assignments\x94\x8c\x05seeds\x94]\x94(K\x01K\x02K\x03e\x8c\trng_seeds\x94]\x94(K{K|K}e\x8c\x06levels\x94}\x94(\x8c\x011\x94\x8c\x1700_bp_coverage_study_01\x94\x8c\x015\x94\x8c\x1701_bp_coverage_study_05\x94\x8c\x0210\x94\x8c\x1702_bp_coverage_study_10\x94\x8c\x0225\x94\x8c\x1703_bp_coverage_study_25\x94\x8c\x0250\x94\x8c\x1704_bp_coverage_study_50\x94\x8c\x0275\x94\x8c\x1705_bp_coverage_study_75\x94\x8c\x03100\x94\x8c\x1806_bp_coverage_study_100\x94u\x8c\ninput_root\x94\x8c4output/01_model_building/02_archs4/02_coverage_study\x94\x8c\nmodel_name\x94\x8c\x0cCLAMPfull_bp\x94\x8c\tresources\x94}\x94(j\x08\x03\x00\x00}\x94(\x8c\x06mem_mb\x94M\x00}\x8c\x07runtime\x94M\x80\x16uj\n\x03\x00\x00}\x94(\x8c\x06mem_mb\x94M\x00\xfa\x8c\x07runtime\x94M\xc0!u\x8c\x0210\x94}\x94(\x8c\x06mem_mb\x94J\x00w\x01\x00\x8c\x07runtime\x94M@8u\x8c\x0225\x94}\x94(\x8c\x06mem_mb\x94J\x00k\x03\x00\x8c\x07runtime\x94M\xc0]u\x8c\x0250\x94}\x94(\x8c\x06mem_mb\x94J\x00\xee\x02\x00\x8c\x07runtime\x94M\xa0\x8cu\x8c\x0275\x94}\x94(\x8c\x06mem_mb\x94J\x00e\x04\x00\x8c\x07runtime\x94M\x80\xbbu\x8c\x03100\x94}\x94(\x8c\x06mem_mb\x94J\x00\xe2\x04\x00\x8c\x07runtime\x94M\xf0\xd2uu\x8c\x0bcomparators\x94}\x94(\x8c\x04gtex\x94}\x94(\x8c\x05label\x94\x8c\x04GTEx\x94\x8c\x07fbm_rds\x94\x8c2output/01_model_building/01_gtex/gtex_fbm_filt.rds\x94\x8c\tgenes_rds\x94\x8c/output/01_model_building/01_gtex/gtex_genes.rds\x94\x8c\x0bsamples_rds\x94\x8c1output/01_model_building/01_gtex/gtex_samples.rds\x94\x8c\x03svd\x94\x8c0output/01_model_building/01_gtex/gtex_svdRes.rds\x94\x8c\x01k\x94\x8c1output/01_model_building/01_gtex/CLAMP_K_gtex.rds\x94\x8c\x04base\x94\x8c.output/01_model_building/01_gtex/CLAMPbase.rds\x94\x8c\x06base_z\x94\x8c0output/01_model_building/01_gtex/CLAMPbase/Z.csv\x94\x8c\x08max_iter\x94M\xf4\x01u\x8c\x08recount2\x94}\x94(\x8c\x05label\x94\x8c\x08recount2\x94\x8c\x07fbm_rds\x94\x8cFoutput/01_model_building/03_recount2/00_recount2/recount2_fbm_filt.rds\x94\x8c\tgenes_rds\x94\x8cCoutput/01_model_building/03_recount2/00_recount2/recount2_genes.rds\x94\x8c\x0bsamples_rds\x94\x8cEoutput/01_model_building/03_recount2/00_recount2/recount2_samples.rds\x94\x8c\x03svd\x94\x8cDoutput/01_model_building/03_recount2/00_recount2/recount2_svdRes.rds\x94jD\x03\x00\x00\x8cEoutput/01_model_building/03_recount2/00_recount2/CLAMP_K_recount2.rds\x94\x8c\x04base\x94\x8c>output/01_model_building/03_recount2/00_recount2/CLAMPbase.rds\x94\x8c\x06base_z\x94\x8c@output/01_model_building/03_recount2/00_recount2/CLAMPbase/Z.csv\x94\x8c\x08max_iter\x94M\xf4\x01uu\x8c\x06colors\x94}\x94(\x8c\x05model\x94}\x94(\x8c\tCLAMPfull\x94\x8c\x07#0072B2\x94\x8c\tCLAMPbase\x94\x8c\x07#777777\x94u\x8c\x07dataset\x94}\x94(\x8c\x06ARCHS4\x94\x8c\x07#0072B2\x94\x8c\x04GTEx\x94\x8c\x07#E69F00\x94\x8c\x08recount2\x94\x8c\x07#009E73\x94uu\x8c\x07routing\x94}\x94(\x8c\x14remote_min_free_cpus\x94K\x02\x8c\x16remote_min_free_mem_mb\x94M\x80>\x8c\x13remote_max_ora_jobs\x94K\x08\x8c\x12local_total_mem_mb\x94J\x00w\x01\x00\x8c\x07retries\x94K\x02\x8c\x11retry_mem_factors\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xf8\x00\x00\x00\x00\x00\x00G@\x00\x00\x00\x00\x00\x00\x00e\x8c\x10retry_mem_cap_mb\x94J\x005\x0c\x00uu\x8c\x03ora\x94}\x94(\x8c\tdatabases\x94}\x94(\x8c\x08reactome\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c3data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt\x94\x8c\x05label\x94\x8c\x08Reactome\x94u\x8c\tcanonical\x94}\x94(\x8c\x04type\x94\x8c\x03gmt\x94\x8c\x04path\x94\x8c*data/pathways/c2.cp.v2026.1.Hs.symbols.gmt\x94\x8c\x12exclude_term_regex\x94\x8c\n^REACTOME_\x94\x8c\x05label\x94\x8c\x16Canonical non-Reactome\x94u\x8c\ncellmarker\x94}\x94(\x8c\x04type\x94\x8c\x0fcellmarker_xlsx\x94\x8c\x04path\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x05sheet\x94\x8c\x05human\x94\x8c\x0bterm_column\x94\x8c\tcell_name\x94\x8c\x0bgene_column\x94\x8c\x06Symbol\x94\x8c\x05label\x94\x8c\nCellMarker\x94uu\x8c\x07top_pct\x94G?\x84z\xe1G\xae\x14{\x8c\x08min_size\x94K\n\x8c\x08max_size\x94M\xf4\x01\x8c\rpvalue_cutoff\x94G?\xa9\x99\x99\x99\x99\x99\x9a\x8c\rqvalue_cutoff\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x03fdr\x94]\x94G?\xa9\x99\x99\x99\x99\x99\x9aa\x8c\tresources\x94}\x94(\x8c\x06mem_mb\x94M@\x1f\x8c\x07runtime\x94M\x80\x16uuuu\x8c\x04rule\x94\x8c\x1dkmeans_clustering_report_gtex\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cL/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/msubirana/Documents/pivlab/clamp-analyses');
######## snakemake preamble end #########

# %% [markdown]
# # GTEx k-means clustering of gene expression data using different methods

# %% [markdown]
# The clustering ensemble itself is run separately by the `kmeans_clustering_gtex` rule (`scripts/gtex/kmeans_clustering.py`); this notebook loads those cached per-method results and renders the ARI comparison figures. It evaluates how well different dimensionality reduction methods preserve biological tissue structure in GTEx gene expression data, comparing raw RNA-Seq, CLAMP base and CLAMPfull, PCA, ICA, NMF, PLIER, Flashier, MOFA-FLEX, and GenomicSuperSignature by Adjusted Rand Index (ARI) against ground-truth tissue labels.

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %% [markdown]
# ## Libraries

# %%
import pickle
import re
from pathlib import Path

import numpy as np
import pandas as pd
import yaml
from pyprojroot.here import here

# %% [markdown]
# ## Settings

# %%
with open(here("config.yaml"), "r") as f:
    _cfg = yaml.safe_load(f)

MODEL_COLORS = _cfg["MODEL_COLORS"]
RNASEQ_FRACTION_COLORS = _cfg["RNASEQ_FRACTION_COLORS"]

def get_model_color(model_name):
    return MODEL_COLORS.get(model_name, "#333333")

def get_fraction_color(fraction_label):
    return RNASEQ_FRACTION_COLORS.get(str(fraction_label), "#333333")

# %% [markdown]
# # Load cached results

# %%
with open(here("workflow/config/gtex.yaml"), "r") as f:
    GTEX_CONFIG = yaml.safe_load(f)["gtex"]

KMEANS_CACHE_DIR = Path(here(f"{GTEX_CONFIG['paths']['biology']}/00_kmeans_clustering/kmeans_results"))

METHOD_CACHE_KEYS = {
    "CLAMP_base": "gtex_CLAMP_base_kmeans",
    "CLAMP_full": "gtex_CLAMPfull_kmeans",
    "PLIER": "gtex_PLIER_kmeans",
    "GenomicSuperSignature": "gtex_GenomicSuperSignature_kmeans",
    "flashier": "gtex_flashier_kmeans",
    "mofabc": "gtex_mofabc_kmeans",
    "pca": "gtex_pca_kmeans",
    "ica": "gtex_ica_kmeans",
    "nmf": "gtex_nmf_kmeans",
}

for suffix, cache_key in METHOD_CACHE_KEYS.items():
    with open(KMEANS_CACHE_DIR / f"{cache_key}.pkl", "rb") as f:
        results = pickle.load(f)
    globals()[f"best_k_gtex_{suffix}_kmeans_results_df"] = results["best_k_results_df"]

with open(KMEANS_CACHE_DIR / "gtex_rnaseq_topvar_tpm_variance_results.pkl", "rb") as f:
    rnaseq_topvar_results = pickle.load(f)

best_mean_ari = -1
best_run_label = None
for run_label, results in rnaseq_topvar_results.items():
    ari = results["scaled_ari"]
    if ari > best_mean_ari:
        best_mean_ari = ari
        best_run_label = run_label

print(f"Best RNA-Seq configuration: {best_run_label}")
print(f"  Best k: {rnaseq_topvar_results[best_run_label]['best_k']}")
print(f"  Mean ARI: {best_mean_ari:.3f}")

best_k_gtex_rnaseq_kmeans_results_df = rnaseq_topvar_results[best_run_label]["best_k_results_df"]

best_k_rnaseq_results = {}
for run_label, results in rnaseq_topvar_results.items():
    pct = int(run_label.split("_")[1].replace("pct", ""))
    frac = pct / 100.0
    df = results["best_k_results_df"].copy()
    df["frac"] = frac
    best_k_rnaseq_results[run_label] = df
# Out:
# Best RNA-Seq configuration: rnaseq_25pct_topvar
#   Best k: 54
#   Mean ARI: 0.606

# %% [markdown]
# ## kmeans ensemble plot

# %%
import re
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from scipy.stats import mannwhitneyu, wilcoxon

mpl.rcParams.update({
    "figure.dpi": 140,
    "savefig.dpi": 300,
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "Helvetica", "DejaVu Sans"],
    "font.size": 11,
    "axes.labelsize": 12,
    "axes.titlesize": 12,
    "xtick.labelsize": 10.5,
    "ytick.labelsize": 10.5,
    "axes.linewidth": 0.8,
    "xtick.major.width": 0.8,
    "ytick.major.width": 0.8,
    "xtick.major.size": 4,
    "ytick.major.size": 4,
})

candidate_names = [
    "best_k_gtex_CLAMP_base_kmeans_results_df",
    "best_k_gtex_CLAMP_full_kmeans_results_df",
    "best_k_gtex_PLIER_kmeans_results_df",
    "best_k_gtex_rnaseq_kmeans_results_df",
    "best_k_gtex_pca_kmeans_results_df",
    "best_k_gtex_ica_kmeans_results_df",
    "best_k_gtex_nmf_kmeans_results_df",
    "best_k_gtex_mofabc_kmeans_results_df",
    "best_k_gtex_flashier_kmeans_results_df",
    "best_k_gtex_GenomicSuperSignature_kmeans_results_df",
]

datasets = {name: globals().get(name) for name in candidate_names}
datasets = {
    k: v for k, v in datasets.items()
    if v is not None and "ari" in v.columns and len(v) > 0
}

if len(datasets) == 0:
    raise ValueError("No valid datasets found with an 'ari' column.")

def clean_name(name: str) -> str:
    name = re.sub(r"^best_k_gtex_", "", name)
    name = re.sub(r"_kmeans_results_df$", "", name)
    return name

display_name_map = {
    "CLAMP_base": "CLAMPbase",
    "CLAMP_full": "CLAMPfull",
    "PLIER": "PLIER",
    "rnaseq": "RNA-Seq",
    "mofabc": "MOFA-FLEX",
    "flashier": "Flashier",
    "GenomicSuperSignature": "GenomicSuperSignature",
    "pca": "PCA",
    "ica": "ICA",
    "nmf": "NMF",
}

def get_display_name(name: str) -> str:
    cleaned = clean_name(name)
    return display_name_map.get(cleaned, cleaned)

means = {
    name: np.asarray(datasets[name]["ari"], dtype=float).mean()
    for name in datasets
}

PINNED_ORDER = ["CLAMPfull", "PLIER", "CLAMPbase", "NMF"]

def order_key(name):
    display = get_display_name(name)
    if display in PINNED_ORDER:
        return (0, PINNED_ORDER.index(display))
    return (1, -means[name])

ordered_names = sorted(means, key=order_key)

data = [np.asarray(datasets[name]["ari"], dtype=float) for name in ordered_names]
labels = [get_display_name(name) for name in ordered_names]

def bh_adjust(pvals):
    pvals = np.asarray(pvals, dtype=float)
    n = len(pvals)
    order = np.argsort(pvals)
    ranked = pvals[order]
    adj = np.empty(n, dtype=float)
    running = 1.0
    for i in range(n - 1, -1, -1):
        rank = i + 1
        val = ranked[i] * n / rank
        running = min(running, val)
        adj[order[i]] = min(running, 1.0)
    return adj

def mw_p_greater(a, b):
    return wilcoxon(a, b, alternative="greater").pvalue

def mw_p_two_sided(a, b):
    return wilcoxon(a, b, alternative="two-sided").pvalue

def format_q(q):
    if q >= 1e-3:
        return f"{q:.3f}"
    exponent = int(np.floor(np.log10(q)))
    coeff = q / (10 ** exponent)
    return rf"{coeff:.1f}$\times$10$^{{{exponent}}}$"

specific_pairs = [
    ("CLAMPfull", "PLIER"),
    ("CLAMPfull", "CLAMPbase"),
    ("CLAMPfull", "RNA-Seq"),
    ("CLAMPbase", "RNA-Seq"),
    ("CLAMPfull", "NMF"),
    ("CLAMPbase", "PLIER"),
    ("CLAMPbase", "NMF"),
]
available_pairs = [(a, b) for a, b in specific_pairs if a in labels and b in labels]

raw_pvals = [
    mw_p_greater(data[labels.index(a)], data[labels.index(b)])
    for a, b in available_pairs
]
qvals = bh_adjust(raw_pvals)
comparisons_to_draw = [(a, b, q) for (a, b), q in zip(available_pairs, qvals)]

raw_pvals_two_sided = [
    mw_p_two_sided(data[labels.index(a)], data[labels.index(b)])
    for a, b in available_pairs
]
qvals_two_sided = bh_adjust(raw_pvals_two_sided)

fig, ax = plt.subplots(figsize=(8.8, 5.6))
rng = np.random.default_rng(7)

positions = np.arange(1, len(data) + 1)

box = ax.boxplot(
    data,
    positions=positions,
    widths=0.52,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color="black", linewidth=1.4),
    whiskerprops=dict(color="black", linewidth=0.9),
    capprops=dict(color="black", linewidth=0.9),
    boxprops=dict(edgecolor="black", linewidth=0.9),
)

for patch, label in zip(box["boxes"], labels):
    patch.set_facecolor(MODEL_COLORS.get(label, "#BBBBBB"))
    patch.set_alpha(0.80)

for x, vals in zip(positions, data):
    jitter = rng.normal(0, 0.035, size=len(vals))
    ax.scatter(
        np.full(len(vals), x) + jitter,
        vals,
        s=18,
        facecolor="white",
        edgecolor="#2b2b2b",
        linewidth=0.55,
        alpha=0.85,
        zorder=3,
    )

for x, vals in zip(positions, data):
    mean_val = np.mean(vals)
    ymax = np.max(vals)
    ax.scatter(
        x, mean_val,
        s=40,
        marker="D",
        facecolor="white",
        edgecolor="black",
        linewidth=0.9,
        zorder=4,
    )
    ax.text(
        x, ymax + 0.018,
        f"{mean_val:.3f}",
        ha="center",
        va="bottom",
        fontsize=10,
        fontweight="bold",
    )

ax.set_ylabel("Adjusted Rand index (ARI)")
ax.set_xlabel("")
ax.set_xticks(positions)
ax.set_xticklabels(labels, rotation=30, ha="right")
ax.set_xlim(0.45, len(data) + 0.55)
ax.set_ylim(0, 0.82)
ax.yaxis.set_major_locator(MultipleLocator(0.2))

ax.grid(axis="y", color="#D9D9D9", linewidth=0.7)
ax.set_axisbelow(True)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

def draw_bracket(ax, x1, x2, y, h, text):
    ax.plot(
        [x1, x1, x2, x2],
        [y, y + h, y + h, y],
        lw=0.9,
        c="black",
        clip_on=False,
    )
    ax.text(
        (x1 + x2) / 2,
        y + h + 0.008,
        text,
        ha="center",
        va="bottom",
        fontsize=9,
        clip_on=False,
    )

xpos = {lab: pos for lab, pos in zip(labels, positions)}

def assign_bracket_tiers(pairs_with_labels):
    rows = [
        {"a": a, "b": b, "left": l, "right": r, "q": q, "span": r - l}
        for a, b, l, r, q in pairs_with_labels
    ]
    rows.sort(key=lambda d: (d["span"], d["q"]))
    levels_used = []
    for row in rows:
        tier = 0
        while True:
            if tier >= len(levels_used):
                levels_used.append([])
                break
            if not any(not (row["right"] < lo or row["left"] > hi) for lo, hi in levels_used[tier]):
                break
            tier += 1
        row["tier"] = tier
        levels_used[tier].append((row["left"], row["right"]))
    return rows

pairs_with_labels = [
    (a, b, *sorted([xpos[a], xpos[b]]), q) for a, b, q in comparisons_to_draw
]
tier_by_pair = {(r["a"], r["b"]): r["tier"] for r in assign_bracket_tiers(pairs_with_labels)}

Y_BASE, Y_STEP, h = 0.845, 0.065, 0.028

for a, b, q in comparisons_to_draw:
    x1, x2 = sorted([xpos[a], xpos[b]])
    y = Y_BASE + tier_by_pair[(a, b)] * Y_STEP
    draw_bracket(ax, x1, x2, y, h, format_q(q))

fig.subplots_adjust(left=0.11, right=0.98, bottom=0.22, top=0.68)

plt.show()

# %%
ARI_EXPORT_DIR = Path(here("output/03_model_biology/01_gtex/00_kmeans_clustering"))
ARI_EXPORT_DIR.mkdir(parents=True, exist_ok=True)

ari_export_df = pd.DataFrame({
    "method": [lab for lab, vals in zip(labels, data) for _ in vals],
    "ari": [v for vals in data for v in vals],
})
ari_export_df.to_csv(ARI_EXPORT_DIR / "ari_data.csv", index=False)

ari_comparisons_df = pd.DataFrame({
    "a": [a for a, b in available_pairs],
    "b": [b for a, b in available_pairs],
    "p_raw": raw_pvals,
    "q": qvals,
    "p_raw_two_sided": raw_pvals_two_sided,
    "q_two_sided": qvals_two_sided,
})
ari_comparisons_df.to_csv(ARI_EXPORT_DIR / "ari_comparisons.csv", index=False)

print(f"Wrote {len(ari_export_df)} ARI rows across {ari_export_df['method'].nunique()} "
      f"methods and {len(ari_comparisons_df)} comparisons to {ARI_EXPORT_DIR}")
# Out:
# Wrote 500 ARI rows across 10 methods and 7 comparisons to /home/msubirana/Documents/pivlab/clamp-analyses/output/03_model_biology/01_gtex/00_kmeans_clustering

# %%
fraction_order = [1.0, 0.75, 0.50, 0.25, 0.10, 0.05, 0.01]
fraction_labels = ["100%", "75%", "50%", "25%", "10%", "5%", "1%"]

def mw_p_two_sided(a, b):
    return mannwhitneyu(a, b, alternative="two-sided").pvalue

aggregated_data = {}
for frac, label in zip(fraction_order, fraction_labels):
    ari_values = []
    for run_label, df in best_k_rnaseq_results.items():
        if df["frac"].iloc[0] == frac:
            ari_values.extend(df["ari"].tolist())
    aggregated_data[label] = np.array(ari_values)

data = [aggregated_data[label] for label in fraction_labels]

fig, ax = plt.subplots(figsize=(8.8, 5.6))
rng = np.random.default_rng(7)

positions = np.arange(1, len(data) + 1)

box = ax.boxplot(
    data,
    positions=positions,
    widths=0.52,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color="black", linewidth=1.4),
    whiskerprops=dict(color="black", linewidth=0.9),
    capprops=dict(color="black", linewidth=0.9),
    boxprops=dict(edgecolor="black", linewidth=0.9),
)

for patch, label in zip(box["boxes"], fraction_labels):
    patch.set_facecolor(get_fraction_color(label))
    patch.set_alpha(0.80)

for x, vals in zip(positions, data):
    jitter = rng.normal(0, 0.035, size=len(vals))
    ax.scatter(
        np.full(len(vals), x) + jitter,
        vals,
        s=18,
        facecolor="white",
        edgecolor="#2b2b2b",
        linewidth=0.55,
        alpha=0.85,
        zorder=3,
    )

for x, vals in zip(positions, data):
    mean_val = np.mean(vals)
    ymax = np.max(vals)
    ax.scatter(
        x, mean_val,
        s=40,
        marker="D",
        facecolor="white",
        edgecolor="black",
        linewidth=0.9,
        zorder=4,
    )
    ax.text(
        x, ymax + 0.018,
        f"{mean_val:.3f}",
        ha="center",
        va="bottom",
        fontsize=10,
        fontweight="bold",
    )

ax.set_ylabel("Adjusted Rand index (ARI)")
ax.set_xlabel("Percentage of genes used for RNA-Seq")
ax.set_xticks(positions)
ax.set_xticklabels(fraction_labels)
ax.set_xlim(0.45, len(data) + 0.55)

ax.grid(axis="y", color="#D9D9D9", linewidth=0.7)
ax.set_axisbelow(True)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

reference_label = "25%"
pairs = [(reference_label, label) for label in fraction_labels if label != reference_label]
raw_pvals = [mw_p_two_sided(aggregated_data[a], aggregated_data[b]) for a, b in pairs]
qvals = bh_adjust(raw_pvals)
comparisons_to_draw = [(a, b, q) for (a, b), q in zip(pairs, qvals)]

xpos = {label: i + 1 for i, label in enumerate(fraction_labels)}
pairs_with_labels = [
    (a, b, *sorted([xpos[a], xpos[b]]), q) for a, b, q in comparisons_to_draw
]
tier_by_pair = {(r["a"], r["b"]): r["tier"] for r in assign_bracket_tiers(pairs_with_labels)}

data_max = max(vals.max() for vals in data)
Y_BASE, Y_STEP, h = data_max + 0.06, 0.065, 0.028
n_tiers = max(tier_by_pair.values()) + 1
y_max = Y_BASE + (n_tiers - 1) * Y_STEP + h + 0.05

for a, b, q in comparisons_to_draw:
    x1, x2 = sorted([xpos[a], xpos[b]])
    y = Y_BASE + tier_by_pair[(a, b)] * Y_STEP
    draw_bracket(ax, x1, x2, y, h, format_q(q))

ax.set_ylim(0, y_max)
ax.yaxis.set_major_locator(MultipleLocator(0.2))

fig.subplots_adjust(left=0.11, right=0.98, bottom=0.15, top=0.95)

plt.show()

# %%
gene_frac_export_df = pd.DataFrame({
    "fraction": [label for label, vals in zip(fraction_labels, data) for _ in vals],
    "ari": [v for vals in data for v in vals],
})
gene_frac_export_df.to_csv(ARI_EXPORT_DIR / "gene_fraction_ari_data.csv", index=False)

gene_frac_comparisons_df = pd.DataFrame(comparisons_to_draw, columns=["a", "b", "q"])
gene_frac_comparisons_df.to_csv(ARI_EXPORT_DIR / "gene_fraction_ari_comparisons.csv", index=False)

print(f"Wrote {len(gene_frac_export_df)} gene-fraction ARI rows across "
      f"{gene_frac_export_df['fraction'].nunique()} fractions and "
      f"{len(gene_frac_comparisons_df)} comparisons to {ARI_EXPORT_DIR}")
# Out:
# Wrote 350 gene-fraction ARI rows across 7 fractions and 6 comparisons to /home/msubirana/Documents/pivlab/clamp-analyses/output/03_model_biology/01_gtex/00_kmeans_clustering
