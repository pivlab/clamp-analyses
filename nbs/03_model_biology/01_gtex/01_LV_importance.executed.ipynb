# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/usr/lib/python3/dist-packages', '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95($\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cooutput/03_model_biology/01_gtex/01_LV_importance_rf_true_labels/gtex_feature_importance_true_labels_binary_shap\x94\x8cc/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex/01_LV_importance.ipynb\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x08shap_dir\x94K\x00N\x86\x94\x8c\x08notebook\x94K\x01N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x15\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1b)}\x94\x8c\x05_name\x94h\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh\x0fh\nh\x11h\x0bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8cQoutput/03_model_biology/01_gtex/01_LV_importance_rf_true_labels/notebook.complete\x94a}\x94(h\r}\x94\x8c\x08complete\x94K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh,h)ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\r}\x94h\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\r}\x94h\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\r}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh]K\x01h_K\x01hahZub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cl/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex/01_LV_importance.executed.ipynb\x94a}\x94(h\r}\x94h\x11K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh\x11hpub\x8c\x06config\x94}\x94(\x8c\x08datasets\x94}\x94(\x8c\x10Brain_Mathys2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c data/pseudobulk/Brain_Mathys2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c8data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz\x94\x8c\x08features\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz\x94\x8c\x08barcodes\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c-data/pseudobulk/raw/Brain_Mathys2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x08cellName\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0ctruth_v1_col\x94\x8c\tCell_Type\x94\x8c\x11raw_cell_type_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x14projection_label_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0fcohort_manifest\x94\x8c1data/pseudobulk/Brain_Mathys2023/patient_info.csv\x94u\x8c\x0fBrain_Xiong2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1fdata/pseudobulk/Brain_Xiong2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c1data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz\x94\x8c\x08features\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz\x94\x8c\x08barcodes\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c,data/pseudobulk/raw/Brain_Xiong2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x06cellId\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x14hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x08Celltype\x94\x8c\x0ctruth_v1_col\x94\x8c\x0bSubcelltype\x94\x8c\x11raw_cell_type_col\x94\x8c\x08Celltype\x94\x8c\x14projection_label_col\x94\x8c\x08Celltype\x94\x8c\x0fcohort_manifest\x94\x8c0data/pseudobulk/Brain_Xiong2023/patient_info.csv\x94u\x8c\x0fHeart_Datar2026\x94}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c=data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad\x94\x8c\x06matrix\x94\x8c\x01X\x94\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x11raw_cell_type_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x14projection_label_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\tmin_cells\x94M\x90\x01\x8c\x07exclude\x94}\x94\x8c\x19cell_type__ontology_label\x94]\x94\x8c\x04cell\x94as\x8c\x0ctruth_v0_map\x94}\x94(\x8c\tadipocyte\x94\x8c\tAdipocyte\x94\x8c\x1eregular atrial cardiac myocyte\x94\x8c\x08AtrialCM\x94\x8c\x10endocardial cell\x94\x8c\x0bEndocardial\x94\x8c\x18cardiac endothelial cell\x94\x8c\x0bEndothelial\x94\x8c\x1emesothelial cell of epicardium\x94\x8c\nEpicardial\x94\x8c\x1cfibroblast of cardiac tissue\x94\x8c\nFibroblast\x94\x8c$endothelial cell of lymphatic vessel\x94\x8c\x14LymphaticEndothelial\x94\x8c\nlymphocyte\x94\x8c\nLymphocyte\x94\x8c\nmacrophage\x94\x8c\nMacrophage\x94\x8c\tmast cell\x94\x8c\x04Mast\x94\x8c\x0ecardiac neuron\x94\x8c\x08Neuronal\x94\x8c\x08pericyte\x94\x8c\x08Pericyte\x94\x8c&vascular associated smooth muscle cell\x94\x8c\x04VSMC\x94\x8c#regular ventricular cardiac myocyte\x94\x8c\rVentricularCM\x94u\x8c\x14projection_label_map\x94}\x94(h\xdah\xdbh\xdch\xddh\xdeh\xdfh\xe0h\xe1h\xe2h\xe3h\xe4h\xe5h\xe6h\xe7h\xe8h\xe9h\xeah\xebh\xech\xedh\xeeh\xefh\xf0h\xf1h\xf2h\xf3h\xf4h\xf5uu\x8c\tPBMC_1k1k\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x19data/pseudobulk/PBMC_1k1k\x94\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c0data/pseudobulk/raw/PBMC_1k1k/PBMC_1k1k_raw.h5ad\x94\x8c\x06matrix\x94h\xc7\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c"sample_prefix_hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x11raw_cell_type_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x14projection_label_col\x94\x8c\x15predicted.celltype.l2\x94\x8c\x0fcohort_manifest\x94\x8c*data/pseudobulk/PBMC_1k1k/patient_info.csv\x94\x8c\x0ctruth_v0_map\x94}\x94(\x8c\x07CD4 CTL\x94\x8c\x05CD4_T\x94\x8c\tCD4 Naive\x94\x8c\x05CD4_T\x94\x8c\x11CD4 Proliferating\x94\x8c\x05CD4_T\x94\x8c\x07CD4 TCM\x94\x8c\x05CD4_T\x94\x8c\x07CD4 TEM\x94\x8c\
94\x8c_https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025\x94\x8c\ngo_bp_file\x94\x8cPoutput/01_model_building/00_pseudobulk/references/GO_Biological_Process_2025.gmt\x94\x8c\x0cgo_bp_sha256\x94\x8c@0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee\x94\x8c\x10cell_marker_file\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x14allen_brain_gmt_file\x94\x8c2data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt\x94\x8c\x0ebrain_datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94eu\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\ngrouped_cv\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\tgroup_col\x94\x8c\x06sample\x94\x8c\nsplit_seed\x94K*\x8c\x10min_train_lv_cor\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x0ebootstrap_seed\x94K{\x8c\x14bootstrap_replicates\x94M\x10\'u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\ns\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{u\x8c\tmofa_flex\x94}\x94(\x8c\nmax_epochs\x94K\xc8\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0ctop_fraction\x94G?\x84z\xe1G\xae\x14{u\x8c\x04gtex\x94}\x94(\x8c\x07raw_url\x94\x8cwhttps://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x06raw_gz\x94\x8cCdata/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x08metadata\x94\x8c=data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt\x94\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c output/01_model_building/01_gtex\x94\x8c\x07biology\x94\x8c\x1foutput/03_model_biology/01_gtex\x94\x8c\x0fmodel_notebooks\x94\x8c\x1dnbs/01_model_building/01_gtex\x94\x8c\x11biology_notebooks\x94\x8c\x1cnbs/03_model_biology/01_gtex\x94u\x8c\x08raw_data\x94}\x94(\x8c\nchunk_size\x94Kd\x8c\x07n_cores\x94K\x01u\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x0emofa_flex_base\x94}\x94(\x8c\nmax_epochs\x94M\xd0\x07\x8c\nbatch_size\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\x0fmofa_flex_prior\x94}\x94(\x8c\x0fmsigdb_category\x94\x8c\x08c5.go.bp\x94\x8c\x0cmsigdb_dbver\x94\x8c\t2026.1.Hs\x94\x8c\x0cmin_fraction\x94G?\xd9\x99\x99\x99\x99\x99\x9a\x8c\tmin_count\x94K(\x8c\tmax_count\x94K\xc8\x8c\x14similarity_threshold\x94G?\xe9\x99\x99\x99\x99\x99\x9a\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{\x8c\x0ctimeout_days\x94K\x07u\x8c\x03gss\x94}\x94(\x8c\td_cluster\x94K\x04\x8c\x04seed\x94K{u\x8c\x11kmeans_clustering\x94}\x94(\x8c\x0bmin_samples\x94K2\x8c\tbase_seed\x94M\x10\'\x8c\x0cn_reps_per_k\x94K2\x8c\x0egene_fractions\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xe8\x00\x00\x00\x00\x00\x00G?\xe0\x00\x00\x00\x00\x00\x00G?\xd0\x00\x00\x00\x00\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aG?\xa9\x99\x99\x99\x99\x99\x9aG?\x84z\xe1G\xae\x14{eu\x8c\rlv_importance\x94}\x94(\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xec\xcc\xcc\xcc\xcc\xcc\xcdu\x8c\x13subtissue_inference\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xeb333333\x8c\x15min_subtissue_samples\x94K\x14\x8c\x0fn_jobs_per_fold\x94K\x08\x8c\x13permutation_repeats\x94K\xc8\x8c\x07tissues\x94]\x94(\x8c\x0eAdipose Tissue\x94\x8c\x05Blood\x94\x8c\x0cBlood Vessel\x94\x8c\x05Brain\x94\x8c\x05Colon\x94\x8c\tEsophagus\x94\x8c\x05Heart\x94\x8c\x06Kidney\x94\x8c\x04Skin\x94euuu\x8c\x04rule\x94\x8c(lv_importance_rf_true_labels_report_gtex\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cL/home/msubirana/Documents/pivlab/clamp-analyses/nbs/03_model_biology/01_gtex\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/msubirana/Documents/pivlab/clamp-analyses');
######## snakemake preamble end #########

# %% [markdown]
# # GTEx tissue feature importance analysis (true GTEx SMTSD labels + SHAP)

# %% [markdown]
# The nested-CV random-forest and SHAP training behind this notebook is done by the `lv_importance_rf_true_labels_gtex` rule (`scripts/gtex/lv_importance_true_labels.py`). This notebook loads the LV matrix for a correlation sanity check and displays the script's output tables.

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %% [markdown]
# ## Libraries

# %%
import csv
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import rpy2.robjects as ro
import seaborn as sns
from pyprojroot.here import here

# %% [markdown]
# # Settings

# %%
OUTPUT_DIR = here('output/03_model_biology/01_gtex/01_LV_importance_rf_true_labels/gtex_feature_importance_true_labels_binary_shap')

print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Output directory: /home/msubirana/Documents/pivlab/clamp-analyses/output/03_model_biology/01_gtex/01_LV_importance_rf_true_labels/gtex_feature_importance_true_labels_binary_shap

# %% [markdown]
# # Output

# %%
sys.path.insert(0, str(here("scripts/gtex")))
from common import extract_B_matrix, extract_summary_matrix

readRDS = ro.r["readRDS"]

# load .rds files from CLAMP with different priors
gtex_CLAMPfull_rds = readRDS(str(here('output/01_model_building/01_gtex/CLAMPfull.rds')))
gtex_CLAMPfull = extract_B_matrix(gtex_CLAMPfull_rds)

lv_data = gtex_CLAMPfull
lv_data.head()
# Out:
#      GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0426-SM-5EGHI  \
# LV1                 -0.056912                  0.129721
# LV2                 -0.206468                 -0.274762
# LV3                  0.008904                 -0.106256
# LV4                  0.725382                 -0.057938
# LV5                  0.177806                  0.024021
#
#      GTEX-1117F-0526-SM-5EGHJ  GTEX-1117F-0626-SM-5N9CS  \
# LV1                 -0.004010                 -0.149621
# LV2                 -0.133169                 -0.030725
# LV3                  0.151010                 -0.124319
# LV4                  0.162755                 -0.002266
# LV5                  0.061455                 -0.023589
#
#      GTEX-1117F-0726-SM-5GIEN  GTEX-1117F-1326-SM-5EGHH  \
# LV1                  0.186576                 -0.035106
# LV2                 -0.179944                 -0.178214
# LV3                 -0.193248                  0.060406
# LV4                  0.095797                  0.152652
# ...

# %% [markdown]
# # Load data

# %%
path = here('data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt')

gtex_meta = pd.read_csv(
    path,
    sep='\t',
    header=0,
    dtype=str,
    quoting=csv.QUOTE_NONE,
    engine='python',
    comment=None,
    keep_default_na=False,
    on_bad_lines='warn'
)

print(gtex_meta.shape)
gtex_meta.head()
# Out:
# (22951, 63)
#                           SAMPID SMATSSCR SMCENTER SMPTHNTS SMRIN   SMTS  \
# 0       GTEX-1117F-0003-SM-58Q7G                B1                 Blood
# 1       GTEX-1117F-0003-SM-5DWSB                B1                 Blood
# 2       GTEX-1117F-0003-SM-6WBT7                B1                 Blood
# 3  GTEX-1117F-0011-R10a-SM-AHZ7F            B1, A1                 Brain
# 4  GTEX-1117F-0011-R10b-SM-CYKQ8            B1, A1            7.2  Brain
#
#                           SMTSD  SMUBRID SMTSISCH SMTSPAX  ... SME1ANTI  \
# 0                   Whole Blood  0013756     1188          ...
# 1                   Whole Blood  0013756     1188          ...
# 2                   Whole Blood  0013756     1188          ...
# 3  Brain - Frontal Cortex (BA9)  0009834     1193          ...
# 4  Brain - Frontal Cortex (BA9)  0009834     1193          ...
#
#   SMSPLTRD SMBSMMRT SME1SNSE SME1PCTS SMRRNART SME1MPRT SMNUM5CD SMDPMPRT  \
# 0
# 1
# 2
# 3
# 4
#
#   SME2PCTS
# 0
# 1
# 2
# ...

# %%
gtex_CLAMPfull_summary = extract_summary_matrix(gtex_CLAMPfull_rds)
gtex_CLAMPfull_summary["pathway"] = gtex_CLAMPfull_summary["pathway"].str.replace("C2CP_", "", regex=False)

print(gtex_CLAMPfull_summary.shape)
gtex_CLAMPfull_summary.head()
# Out:
# (4352, 7)
#                                                   pathway   LV       AUC  \
# BP254           BP_UV-damage Excision Repair (GO:0070914)  LV1  0.641164
# BP513             BP_cGMP-mediated Signaling (GO:0019934)  LV1  0.314307
# BP1632  BP_Mature B Cell Differentiation Involved in I...  LV1  0.314307
# BP2683            BP_Phosphate Ion Transport (GO:0006817)  LV1  0.314307
# BP3972  BP_Regulation of Bicellular Tight Junction Ass...  LV1  0.497258
#
#          p_value       FDR  npos   nneg
# BP254   0.212562  0.649627     2  21514
# BP513   0.852989  0.946780     2  21514
# BP1632  0.852989  0.946780     2  21514
# BP2683  0.852989  0.946780     2  21514
# BP3972  0.507592  0.832405     3  21514

# %%
# samples x LVs
lv_matrix = lv_data.T

# correlation matrix
corr_matrix = lv_matrix.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0,
            xticklabels=False, yticklabels=False)
plt.show()

# find highly correlated pairs
high_corr_threshold = 0.9
high_corr_pairs = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > high_corr_threshold:
            high_corr_pairs.append((
                corr_matrix.columns[i],
                corr_matrix.columns[j],
                corr_matrix.iloc[i, j]
            ))

print(f"Number of highly correlated pairs (|r| > {high_corr_threshold}): {len(high_corr_pairs)}")
# Out:
# Number of highly correlated pairs (|r| > 0.9): 0

# %% [markdown]
# # Feature importance results (RandomForest binary + SHAP)
#
# Computed by `scripts/gtex/lv_importance_true_labels.py` (rule `lv_importance_rf_true_labels_gtex`) and read here for inspection.

# %%
accuracy_df = pd.read_csv(OUTPUT_DIR / "accuracy_summary.tsv", sep="\t")
shap_results_df = pd.read_csv(OUTPUT_DIR / "all_shap_positive.tsv", sep="\t")
cumulative_df = pd.read_csv(OUTPUT_DIR / "cumulative_importance.tsv", sep="\t")

# %%
accuracy_df.sort_values(by='Mean_CV_Accuracy', ascending=False)
# Out:
#                                        Tissue  N_Positive  N_Negative  \
# 20               Cells - Cultured fibroblasts         504       16825
# 21        Cells - EBV-transformed lymphocytes         174       17155
# 48                                Whole Blood         755       16574
# 44                                     Testis         361       16968
# 36                                   Pancreas         328       17001
# 31                                       Lung         578       16751
# 2                               Adrenal Gland         258       17071
# 42                                     Spleen         241       17088
# 33                          Muscle - Skeletal         803       16526
# 30                                      Liver         226       17103
# 25                         Esophagus - Mucosa         555       16774
# 45                                    Thyroid         653       16676
# ...

# %%
cumulative_df.head(40)
# Out:
#    Feature  Mean_SHAP_Tissue  Cumulative_Percent  Rank                  Tissue
# 0    LV106          0.082977            9.240699     1  Adipose - Subcutaneous
# 1    LV220          0.076919           17.806771     2  Adipose - Subcutaneous
# 2    LV520          0.047061           23.047690     3  Adipose - Subcutaneous
# 3     LV68          0.039898           27.490963     4  Adipose - Subcutaneous
# 4     LV90          0.030876           30.929442     5  Adipose - Subcutaneous
# 5    LV311          0.022756           33.463694     6  Adipose - Subcutaneous
# 6     LV57          0.022328           35.950246     7  Adipose - Subcutaneous
# 7    LV111          0.021904           38.389614     8  Adipose - Subcutaneous
# 8    LV263          0.017854           40.377865     9  Adipose - Subcutaneous
# 9    LV392          0.016508           42.216221    10  Adipose - Subcutaneous
# 10   LV322          0.015567           43.949855    11  Adipose - Subcutaneous
# ...
