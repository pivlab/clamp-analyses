# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('output/01_model_building/00_pseudobulk/Brain_Mathys2023/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/Brain_Xiong2023/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/Heart_Datar2026/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/PBMC_1k1k/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/PBMC_Perez2022/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/CLAMPfull/CLAMPfull.rds', 'output/03_model_biology/00_pseudobulk/00_benchmark/clampfull_lv_assignments.csv', 'output/03_model_biology/00_pseudobulk/00_benchmark/clampfull_lv_ct_corr_full.csv', 'data/pseudobulk/Brain_Mathys2023/truthFrac_v0.csv', 'data/pseudobulk/Brain_Xiong2023/truthFrac_v0.csv', 'output/01_model_building/00_pseudobulk/Heart_Datar2026/pseudobulk/truthFrac_v0.csv', 'data/pseudobulk/PBMC_1k1k/truthFrac_v0.csv', 'data/pseudobulk/PBMC_Perez2022/truthFrac_v0.csv', 'output/01_model_building/00_pseudobulk/Lung_Sikkema2023/pseudobulk/truthFrac_v0.csv', 'data/pathways/Cell_marker_Human.xlsx', 'data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt', 'data/pathways/Azimuth_2023.txt', '/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/03_model_biology/00_pseudobulk/02_disentangle.ipynb', "models" = c('output/01_model_building/00_pseudobulk/Brain_Mathys2023/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/Brain_Xiong2023/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/Heart_Datar2026/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/PBMC_1k1k/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/PBMC_Perez2022/models/CLAMPfull/CLAMPfull.rds', 'output/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/CLAMPfull/CLAMPfull.rds'), "assignments" = 'output/03_model_biology/00_pseudobulk/00_benchmark/clampfull_lv_assignments.csv', "corr" = 'output/03_model_biology/00_pseudobulk/00_benchmark/clampfull_lv_ct_corr_full.csv', "truths" = c('data/pseudobulk/Brain_Mathys2023/truthFrac_v0.csv', 'data/pseudobulk/Brain_Xiong2023/truthFrac_v0.csv', 'output/01_model_building/00_pseudobulk/Heart_Datar2026/pseudobulk/truthFrac_v0.csv', 'data/pseudobulk/PBMC_1k1k/truthFrac_v0.csv', 'data/pseudobulk/PBMC_Perez2022/truthFrac_v0.csv', 'output/01_model_building/00_pseudobulk/Lung_Sikkema2023/pseudobulk/truthFrac_v0.csv'), "cell_marker_file" = 'data/pathways/Cell_marker_Human.xlsx', "allen_brain_gmt_file" = 'data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt', "azimuth_file" = 'data/pathways/Azimuth_2023.txt', "notebook" = '/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/03_model_biology/00_pseudobulk/02_disentangle.ipynb'),
    output = list('output/03_model_biology/00_pseudobulk/02_disentangle/top_lvs_per_celltype.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_specificity_margins.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_assignment_quality.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_assignment_quality_by_dataset.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/module_selected_lvs.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/module_top_pathways.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/marker_enrichment_long.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_marker_effects.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/marker_pathway_recovery.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/module_panel_ready.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/notebook.complete', "top" = 'output/03_model_biology/00_pseudobulk/02_disentangle/top_lvs_per_celltype.csv', "margins" = 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_specificity_margins.csv', "quality" = 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_assignment_quality.csv', "quality_by_dataset" = 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_assignment_quality_by_dataset.csv', "selected" = 'output/03_model_biology/00_pseudobulk/02_disentangle/module_selected_lvs.csv', "pathways" = 'output/03_model_biology/00_pseudobulk/02_disentangle/module_top_pathways.csv', "enrichment" = 'output/03_model_biology/00_pseudobulk/02_disentangle/marker_enrichment_long.csv', "effects" = 'output/03_model_biology/00_pseudobulk/02_disentangle/lv_marker_effects.csv', "recovery" = 'output/03_model_biology/00_pseudobulk/02_disentangle/marker_pathway_recovery.csv', "module_panel_ready" = 'output/03_model_biology/00_pseudobulk/02_disentangle/module_panel_ready.csv', "complete" = 'output/03_model_biology/00_pseudobulk/02_disentangle/notebook.complete'),
    params = list(c('Brain_Mathys2023', 'Brain_Xiong2023', 'Heart_Datar2026', 'PBMC_1k1k', 'PBMC_Perez2022', 'Lung_Sikkema2023'), 'output/01_model_building/00_pseudobulk', 'output/03_model_biology/00_pseudobulk/02_disentangle', "datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023', 'Heart_Datar2026', 'PBMC_1k1k', 'PBMC_Perez2022', 'Lung_Sikkema2023'), "mod_root" = 'output/01_model_building/00_pseudobulk', "out_dir" = 'output/03_model_biology/00_pseudobulk/02_disentangle'),
    wildcards = list(),
    threads = 1,
    log = list('/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/03_model_biology/00_pseudobulk/02_disentangle.executed.ipynb', "notebook" = '/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/03_model_biology/00_pseudobulk/02_disentangle.executed.ipynb'),
    resources = list('tmpdir', "tmpdir" = '/tmp'),
    config = list("datasets" = list("Brain_Mathys2023" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/Brain_Mathys2023', "kind" = 'matrix_market', "raw" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz', "features" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz', "barcodes" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz', "metadata" = 'data/pseudobulk/raw/Brain_Mathys2023/meta.tsv', "cell_id_col" = 'cellName', "sample_col" = 'Individual', "sample_transform" = 'identity', "truth_v0_col" = 'Major_Cell_Type', "truth_v1_col" = 'Cell_Type', "raw_cell_type_col" = 'Major_Cell_Type', "projection_label_col" = 'Major_Cell_Type', "cohort_manifest" = 'data/pseudobulk/Brain_Mathys2023/patient_info.csv'), "Brain_Xiong2023" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/Brain_Xiong2023', "kind" = 'matrix_market', "raw" = 'data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz', "features" = 'data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz', "barcodes" = 'data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz', "metadata" = 'data/pseudobulk/raw/Brain_Xiong2023/meta.tsv', "cell_id_col" = 'cellId', "sample_col" = 'Individual', "sample_transform" = 'hyphen_to_underscore', "truth_v0_col" = 'Celltype', "truth_v1_col" = 'Subcelltype', "raw_cell_type_col" = 'Celltype', "projection_label_col" = 'Celltype', "cohort_manifest" = 'data/pseudobulk/Brain_Xiong2023/patient_info.csv'), "Heart_Datar2026" = list("build_pseudobulk" = TRUE, "kind" = 'h5ad', "raw" = 'data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad', "matrix" = 'X', "sample_col" = 'donor_id', "sample_transform" = 'identity', "truth_v0_col" = 'cell_type__ontology_label', "raw_cell_type_col" = 'cell_type__ontology_label', "projection_label_col" = 'cell_type__ontology_label', "min_cells" = 400, "exclude" = list("cell_type__ontology_label" = c('cell')), "truth_v0_map" = list("adipocyte" = 'Adipocyte', "regular atrial cardiac myocyte" = 'AtrialCM', "endocardial cell" = 'Endocardial', "cardiac endothelial cell" = 'Endothelial', "mesothelial cell of epicardium" = 'Epicardial', "fibroblast of cardiac tissue" = 'Fibroblast', "endothelial cell of lymphatic vessel" = 'LymphaticEndothelial', "lymphocyte" = 'Lymphocyte', "macrophage" = 'Macrophage', "mast cell" = 'Mast', "cardiac neuron" = 'Neuronal', "pericyte" = 'Pericyte', "vascular associated smooth muscle cell" = 'VSMC', "regular ventricular cardiac myocyte" = 'VentricularCM'), "projection_label_map" = list("adipocyte" = 'Adipocyte', "regular atrial cardiac myocyte" = 'AtrialCM', "endocardial cell" = 'Endocardial', "cardiac endothelial cell" = 'Endothelial', "mesothelial cell of epicardium" = 'Epicardial', "fibroblast of cardiac tissue" = 'Fibroblast', "endothelial cell of lymphatic vessel" = 'LymphaticEndothelial', "lymphocyte" = 'Lymphocyte', "macrophage" = 'Macrophage', "mast cell" = 'Mast', "cardiac neuron" = 'Neuronal', "pericyte" = 'Pericyte', "vascular associated smooth muscle cell" = 'VSMC', "regular ventricular cardiac myocyte" = 'VentricularCM')), "PBMC_1k1k" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/PBMC_1k1k', "kind" = 'h5ad', "raw" = 'data/pseudobulk/raw/PBMC_1k1k/PBMC_1k1k_raw.h5ad', "matrix" = 'X', "sample_col" = 'donor_id', "sample_transform" = 'sample_prefix_hyphen_to_underscore', "truth_v0_col" = 'predicted.celltype.l2', "raw_cell_type_col" = 'predicted.celltype.l2', "projection_label_col" = 'predicted.celltype.l2', "cohort_manifest" = 'data/pseudobulk/PBMC_1k1k/patient_info.csv', "truth_v0_map" = list("CD4 CTL" = 'CD4_T', "CD4 Naive" = 'CD4_T', "CD4 Proliferating" = 'CD4_T', "CD4 TCM" = 'CD4_T', "CD4 TEM" = 'CD4_T', "Treg" = 'CD4_T', "CD8 Naive" = 'CD8_T', "CD8 Proliferating" = 'CD8_T', "CD8 TCM" = 'CD8_T', "CD8 TEM" = 'CD8_T', "gdT" = 'gd_T', "B intermediate" = 'B_cell', "B memory" = 'B_cell', "B naive" = 'B_cell', "Plasmablast" = 'Plasma_B', "CD14 Mono" = 'CD14_Mono', "CD16 Mono" = 'CD16_Mono', "cDC1" = 'DC', "cDC2" = 'DC', "ASDC" = 'DC', "NK" = 'NK', "NK Proliferating" = 'NK', "NK_CD56bright" = 'NK'), "projection_label_map" = list("CD4 CTL" = 'CD4_T', "CD4 Naive" = 'CD4_T', "CD4 Proliferating" = 'CD4_T', "CD4 TCM" = 'CD4_T', "CD4 TEM" = 'CD4_T', "Treg" = 'CD4_T', "CD8 Naive" = 'CD8_T', "CD8 Proliferating" = 'CD8_T', "CD8 TCM" = 'CD8_T', "CD8 TEM" = 'CD8_T', "gdT" = 'gd_T', "B intermediate" = 'B_cell', "B memory" = 'B_cell', "B naive" = 'B_cell', "Plasmablast" = 'Plasma_B', "CD14 Mono" = 'CD14_Mono', "CD16 Mono" = 'CD16_Mono', "cDC1" = 'DC', "cDC2" = 'DC', "ASDC" = 'DC', "NK" = 'NK', "NK Proliferating" = 'NK', "NK_CD56bright" = 'NK')), "PBMC_Perez2022" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/PBMC_Perez2022', "kind" = 'h5ad', "raw" = 'data/pseudobulk/raw/PBMC_Perez2022/PBMC_Perez2022_raw.h5ad', "matrix" = 'raw.X', "sample_col" = 'ind_cov', "sample_transform" = 'sample_prefix_hyphen_to_underscore', "truth_v0_col" = 'cell_type', "raw_cell_type_col" = 'cell_type', "projection_label_col" = 'cell_type', "cohort_manifest" = 'data/pseudobulk/PBMC_Perez2022/patient_info.csv', "truth_v0_map" = list("B cell" = 'B_cell', "plasmablast" = 'B_cell', "classical monocyte" = 'Myeloid', "non-classical monocyte" = 'Myeloid', "conventional dendritic cell" = 'Myeloid', "plasmacytoid dendritic cell" = 'Myeloid', "progenitor cell" = 'Myeloid', "natural killer cell" = 'NK', "CD4-positive, alpha-beta T cell" = 'T_cell', "CD8-positive, alpha-beta T cell" = 'T_cell', "lymphocyte" = 'T_cell'), "projection_label_map" = list("B cell" = 'B_cell', "plasmablast" = 'B_cell', "classical monocyte" = 'Myeloid', "non-classical monocyte" = 'Myeloid', "conventional dendritic cell" = 'Myeloid', "plasmacytoid dendritic cell" = 'Myeloid', "progenitor cell" = 'Myeloid', "natural killer cell" = 'NK', "CD4-positive, alpha-beta T cell" = 'T_cell', "CD8-positive, alpha-beta T cell" = 'T_cell', "lymphocyte" = 'T_cell')), "Lung_Sikkema2023" = list("build_pseudobulk" = TRUE, "kind" = 'h5ad', "raw" = 'data/pseudobulk/Lung_Sikkema2023/lung_HLCA.h5ad', "matrix" = 'raw.X', "sample_col" = 'donor_id', "sample_transform" = 'identity', "truth_v0_col" = 'ann_level_2', "truth_v1_col" = 'ann_finest_level', "raw_cell_type_col" = 'ann_level_3', "projection_label_col" = 'ann_level_2', "min_cells" = 400)), "methods" = list("CLAMPbase" = 'CLAMPbase/B.csv', "CLAMPfull" = 'CLAMPfull/B.csv', "PLIER" = 'PLIER/B.csv', "PCA" = 'PCA/B.csv', "NMF" = 'NMF/B.csv', "ICA" = 'ICA/B.csv', "Flashier" = 'flashier/B.csv', "MOFA-FLEX" = 'MOFA_FLEX_PRIOR/B.csv', "GSSig" = 'GSS/B.csv', "CoGAPS" = 'CoGAPS/B.csv'), "paths" = list("production" = 'output/01_model_building/00_pseudobulk', "biology" = 'output/03_model_biology/00_pseudobulk', "model_notebooks" = 'nbs/01_model_building/00_pseudobulk', "biology_notebooks" = 'nbs/03_model_biology/00_pseudobulk', "panels" = 'output/99_panels', "panels_notebooks" = 'nbs/99_panels'), "references" = list("go_bp_url" = 'https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025', "go_bp_file" = 'data/pathways/GO_Biological_Process_2025.gmt', "go_bp_sha256" = '0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee', "cell_marker_file" = 'data/pathways/Cell_marker_Human.xlsx', "allen_brain_gmt_file" = 'data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt', "azimuth_file" = 'data/pathways/Azimuth_2023.txt', "gtex_tissues_pathmat" = 'data/archs4/GTEx_Tissues_pathMat.rds', "brain_datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023')), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "seed" = 123), "clamp" = list("max_iter" = 500, "seed" = 123), "grouped_cv" = list("n_folds" = 5, "group_col" = 'sample', "split_seed" = 42, "min_train_lv_cor" = 0.5, "bootstrap_seed" = 123, "bootstrap_replicates" = 10000), "flashier" = list("backfit_maxiter" = 20), "cogaps" = list("n_iterations" = 5000, "n_threads" = 4, "seed" = 123), "mofa_flex" = list("max_epochs" = 1000, "seed" = 123), "projection" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "top_fraction" = 0.01), "cell_type_analysis" = list("excluded_targets" = list("Brain_Mathys2023" = c('Vas'), "Brain_Xiong2023" = c('Vas'), "Lung_Sikkema2023" = c('Hematopoietic stem cells', 'Mesothelium', 'Smooth muscle'))), "gtex" = list("raw_url" = 'https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', "raw_gz" = 'data/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', "metadata" = 'data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt', "xcell_scores" = 'data/gtex/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt', "paths" = list("production" = 'output/01_model_building/01_gtex', "biology" = 'output/03_model_biology/01_gtex', "model_notebooks" = 'nbs/01_model_building/01_gtex', "biology_notebooks" = 'nbs/03_model_biology/01_gtex'), "raw_data" = list("chunk_size" = 100, "n_cores" = 1), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "seed" = 123), "clamp" = list("max_iter" = 500, "seed" = 123), "flashier" = list("backfit_maxiter" = 20), "mofa_flex_prior" = list("min_fraction" = 0.4, "min_count" = 40, "max_count" = 200, "similarity_threshold" = 0.8, "max_epochs" = 1000, "seed" = 123), "cogaps" = list("n_iterations" = 5000, "n_threads" = 4, "seed" = 123, "timeout_days" = 7), "gss" = list("d_cluster" = 4, "seed" = 123), "kmeans_clustering" = list("min_samples" = 50, "ari_min_samples" = 1, "base_seed" = 10000, "n_reps_per_k" = 50, "gene_fractions" = c(1.0, 0.75, 0.5, 0.25, 0.1, 0.05, 0.01)), "lv_importance" = list("global_seed" = 42, "min_rf_accuracy" = 0.9), "subtissue_inference" = list("n_folds" = 5, "global_seed" = 42, "min_rf_accuracy" = 0.85, "min_subtissue_samples" = 20, "n_jobs_per_fold" = 8, "anatomical_spec" = 'workflow/config/gtex_anatomical_subtissues.tsv', "permutation_repeats" = 1000, "bootstrap_repeats" = 1000, "evaluation_jobs" = 8, "tissues" = c('Adipose Tissue', 'Blood', 'Blood Vessel', 'Brain', 'Colon', 'Esophagus', 'Heart', 'Kidney', 'Skin'))), "runtime_benchmark" = list("seeds" = c(123, 456, 789), "threads" = 4, "methods" = c('CLAMPfull', 'CLAMPbase', 'PLIER', 'CoGAPS', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), "output_root" = 'output/02_model_performance/00_pseudobulk/00_computational_timing', "notebook" = 'nbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb'), "runtime_benchmark_gtex" = list("dataset" = 'GTEx', "seeds" = c(123, 456, 789), "threads" = 4, "methods" = c('CLAMPfull', 'CLAMPbase', 'PLIER', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), "excluded_methods" = list("CoGAPS" = 'rule cogaps_gtex was run to the end of its hard wall-clock budget (gtex.cogaps.timeout_days = 7) and killed without converging; the evidence is on disk at output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt. CoGAPS therefore has no finite GTEx runtime to report, and re-running it here would only re-derive the same censored value at a cost of 21 days. Reported as a right-censored ">7 days, did not converge", not as a data point.  Same reason it is absent from rule full_models_gtex.\n', "MOFA-FLEX_base" = 'No prior-free MOFA-FLEX GTEx production model exists: rule mofa_flex_base_gtex fails on this dataset, so there is no published GTEx fit whose runtime could be measured.\n'), "cogaps_evidence" = 'output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt', "output_root" = 'output/02_model_performance/01_gtex/00_computational_timing', "notebook" = 'nbs/02_model_performance/01_gtex/00_computational_timing.ipynb'), "donor_bulk" = list("datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023', 'Heart_Datar2026', 'PBMC_1k1k', 'PBMC_Perez2022', 'Lung_Sikkema2023'), "paths" = list("production" = 'output/01_model_building/00_pseudobulk/donor_bulk', "biology" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery', "model_notebooks" = 'nbs/01_model_building/00_pseudobulk', "biology_notebooks" = 'nbs/03_model_biology/00_pseudobulk'), "aggregation" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "sample_cells" = 60000, "minimum_per_type" = 250, "seed" = 123), "umap" = list("target_sum" = 10000, "n_hvg" = 2000, "n_pcs" = 50, "n_neighbors" = 30, "min_dist" = 0.3, "seed" = 123), "projection" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "duplicate_gene_policy" = 'sum'))),
    rule = 'disentangle_pseudobulk',
    bench_iteration = as.numeric(NA),
    scriptdir = '/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/03_model_biology/00_pseudobulk',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
setwd('/home/msubirana/Documents/pivlab/clamp-analyses-revert');

######## snakemake preamble end #########

# %% [markdown]
# # CLAMPfull pseudobulk disentanglement proof
#
# Checks that CLAMPfull's latent variables (LVs) disentangle cell types: each cell
# type correlates with one distinct LV (from `00_benchmark`), and that LV's
# top-loading genes independently recover markers of the same cell type using a
# combined CellMarker, Allen Brain Atlas, and dataset-matched Azimuth reference.

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %% [markdown]
# ## Libraries

# %%
library(here)
library(yaml)
library(dplyr)
library(tidyr)
library(ggplot2)
library(patchwork)
library(stringr)

source(here("scripts", "pseudobulk", "common.R"))
# Out:
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses-revert
# Attaching package: ‘dplyr’
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ## Settings

# %%
DATASETS     <- snakemake@params[["datasets"]]
MOD_ROOT     <- here(snakemake@params[["mod_root"]])
OUT_DIR      <- here(snakemake@params[["out_dir"]])
TOP_GENE_PCT <- 0.01     # top 1% gene loadings for ORA

dir.create(OUT_DIR, recursive = TRUE, showWarnings = FALSE)
set.seed(42)

# Resolve the truth table the same way 00_benchmark does: datasets built by
# build_pseudobulk.py live under MOD_ROOT, lab-provided ones under their
# configured pseudobulk_dir. Hardcoding the MOD_ROOT path here would silently
# pick up stale rebuild artifacts for the lab-provided datasets.
pseudobulk_dir <- function(ds) {
  cfg <- snakemake@config$datasets[[ds]]
  if (isTRUE(cfg$build_pseudobulk)) {
    file.path(MOD_ROOT, ds, 'pseudobulk')
  } else {
    here(cfg$pseudobulk_dir)
  }
}

truth_v0_path <- function(ds) {
  path <- file.path(pseudobulk_dir(ds), "truthFrac_v0.csv")
  if (!file.exists(path))
    stop("truthFrac_v0.csv not found for ", ds, " at ", path)
  path
}

ct_labels_df <- read.csv(here("data", "pseudobulk", "cell_type_labels.csv"),
                         stringsAsFactors = FALSE)
CT_LABELS    <- setNames(ct_labels_df$label, ct_labels_df$cell_type)
ct_label     <- function(x) ifelse(x %in% names(CT_LABELS), CT_LABELS[x], x)

# %% [markdown]
# ## Each cell type correlates with a distinct LV

# %%
ASSIGNMENTS_PATH <- snakemake@input[["assignments"]]

top_lvs_df <- read.csv(ASSIGNMENTS_PATH, stringsAsFactors = FALSE)

top_lvs_df <- top_lvs_df[top_lvs_df$dataset %in% DATASETS, ]
rownames(top_lvs_df) <- NULL

cat("CLAMPfull LV assignments loaded:", nrow(top_lvs_df), "rows\n")
cat("Datasets:\n")
print(table(top_lvs_df$dataset))
cat("\nSample (first 10 rows):\n")
print(head(top_lvs_df, 10))
# Out:
# CLAMPfull LV assignments loaded: 47 rows
# Datasets:
# Brain_Mathys2023  Brain_Xiong2023  Heart_Datar2026 Lung_Sikkema2023
#                6                6               14                8
#        PBMC_1k1k   PBMC_Perez2022
#                9                4
# Sample (first 10 rows):
#    cell_type   LV       cor r_next_best_ct r_next_best_lv  margin_ct margin_lv
# 1        Ast LV17 0.9162621      0.3105916     0.44085758 0.60567042 0.4754045
# 2        Exc LV11 0.6016309      0.5740468     0.10497533 0.02758405 0.4966555
# 3        Inh  LV4 0.8197967      0.6270630     0.45835200 0.19273372 0.3614447
# 4        Mic  LV6 0.9631104      0.4841141     0.25985591 0.47899628 0.7032545
# 5        Oli LV18 0.9702103      0.4673459     0.13636762 0.50286441 0.8338427
# 6        Opc  LV7 0.4672024      0.2700432     0.16620466 0.19715919 0.3009978
# 7        Ast  LV5 0.9451393      0.4712899     0.50621425 0.47384939 0.4389250
# 8        Exc LV13 0.7197340      0.6265292    -0.06930073 0.09320480 0.7890347
# 9        Inh  LV2 0.5860211      0.5062142     0.46680100 0.07980685 0.1192201
# 10       Mic LV17 0.8747079      0.8265211     0.52189422 0.04818684 0.3528137
#             dataset
# 1  Brain_Mathys2023
# 2  Brain_Mathys2023
# 3  Brain_Mathys2023
# 4  Brain_Mathys2023
# 5  Brain_Mathys2023
# 6  Brain_Mathys2023
# 7   Brain_Xiong2023
# 8   Brain_Xiong2023
# 9   Brain_Xiong2023
# 10  Brain_Xiong2023

# %% [markdown]
# ## Different cell types are captured by different LVs

# %%
CORR_FULL_PATH <- snakemake@input[["corr"]]
lv_corr_full   <- read.csv(CORR_FULL_PATH, stringsAsFactors = FALSE)
lv_corr_full   <- lv_corr_full[lv_corr_full$dataset %in% DATASETS, ]

cat("Full LV x cell-type correlation matrix loaded:", nrow(lv_corr_full), "rows\n")

heatmap_panels <- lapply(DATASETS, function(ds) {
    d <- lv_corr_full[lv_corr_full$dataset == ds, ]
    if (nrow(d) == 0) return(NULL)

    d <- d[!is.na(d$cell_type) & d$cell_type != "NA", ]
    assigned <- top_lvs_df[top_lvs_df$dataset == ds, c("cell_type", "LV")]
    assigned <- assigned[!is.na(assigned$cell_type) & assigned$cell_type != "NA", ]
    if (nrow(d) == 0 || nrow(assigned) == 0) return(NULL)
    d <- d[d$LV %in% assigned$LV & d$cell_type %in% assigned$cell_type, ]
    d$cell_type_label <- ct_label(d$cell_type)

    ord      <- order(assigned$cell_type)
    lv_order <- unique(assigned$LV[ord])
    ct_order <- unique(ct_label(assigned$cell_type[ord]))
    d$LV              <- factor(d$LV, levels = lv_order)
    d$cell_type_label <- factor(d$cell_type_label, levels = ct_order)

    p <- ggplot(d, aes(x = cell_type_label, y = LV, fill = cor)) +
        geom_tile(color = "white", linewidth = 0.4) +
        geom_text(aes(label = sprintf("%.2f", cor)), size = 2.5) +
        scale_fill_gradientn(colours = c("#b2182b", "#fdf7f7", "white", "#f7fbf7", "#007a33"),
                             values = scales::rescale(c(-1, -0.5, 0, 0.5, 1)),
                             limits = c(-1, 1), name = "r") +
        coord_fixed() +
        theme_bw(base_size = 9) +
        theme(axis.text.x = element_text(angle = 45, hjust = 1),
              plot.title  = element_text(face = "bold", size = 10, hjust = 0.5)) +
        labs(x = NULL, y = NULL, title = ds)

    list(dataset = ds, plot = p, n_cell_types = length(ct_order), n_lvs = length(lv_order))
})
heatmap_panels <- Filter(Negate(is.null), heatmap_panels)

for (panel in heatmap_panels) {
    p <- panel$plot + theme(legend.position = "right")
    print(p)
}
# Out:
# Full LV x cell-type correlation matrix loaded: 2472 rows
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
## Combined correlation heatmap (all datasets in one figure, for the
## supplementary panel).
combined_heatmap <- patchwork::wrap_plots(
    lapply(heatmap_panels, `[[`, "plot"),
    ncol = 3, guides = "collect"
) & theme(legend.position = "right")
combined_heatmap
# Out:
# plot without title

# %% [markdown]
# ## Assignment quality — correlation, specificity, and one-vs-rest AUROC

# %%
# Assignment quality: mean correlation, Tau specificity, and one-vs-rest
# AUROC of the Property-2 (top_lvs_df) LV <-> cell-type assignment. AUROC
# needs per-sample scores that aren't in the correlation matrices, so it's
# the only piece that re-reads B.csv/truthFrac_v0.csv here (same paths/
# filtering run_module_pipeline uses later, inlined since that code isn't
# defined yet).
auroc_rows <- lapply(unique(top_lvs_df$dataset), function(ds) {
    b_path     <- file.path(MOD_ROOT, ds, "models", "CLAMPfull", "B.csv")
    truth_path <- truth_v0_path(ds)
    if (!file.exists(b_path)) return(NULL)

    B     <- t(as.matrix(read.csv(b_path, row.names = 1, check.names = FALSE)))
    truth <- filter_analysis_cell_types(
      read.csv(truth_path, row.names = 1, check.names = FALSE),
      ds, snakemake@config$cell_type_analysis$excluded_targets
    )
    sample_ct <- setNames(colnames(truth)[apply(truth, 1, which.max)], rownames(truth))
    shared    <- intersect(rownames(B), names(sample_ct))

    ds_rows <- top_lvs_df[top_lvs_df$dataset == ds, ]
    do.call(rbind, lapply(seq_len(nrow(ds_rows)), function(i) {
        ct <- ds_rows$cell_type[i]; lv <- ds_rows$LV[i]
        if (!lv %in% colnames(B)) return(NULL)
        in_idx <- sample_ct[shared] == ct
        x_in   <- B[shared, lv][in_idx]
        x_out  <- B[shared, lv][!in_idx]
        if (length(x_in) < 3 || length(x_out) < 3) return(NULL)
        wt <- suppressWarnings(wilcox.test(x_in, x_out))
        data.frame(dataset = ds, cell_type = ct, LV = lv,
                   auroc = as.numeric(wt$statistic) / (length(x_in) * length(x_out)),
                   stringsAsFactors = FALSE)
    }))
})
auroc_df <- do.call(rbind, auroc_rows)

# Tau specificity (Yanai et al. 2005), computed per assigned LV from
# lv_corr_full -- its correlation with every cell type in that dataset,
# negative correlations clipped to 0 before normalizing. Unlike margin_lv
# (top-1 vs top-2 gap only), tau uses the LV's full correlation profile
# across all cell types: tau=1 means the LV's signal is concentrated
# entirely on its matched cell type, tau=0 means it's spread uniformly
# across every cell type in the dataset.
specificity_rows <- lapply(seq_len(nrow(top_lvs_df)), function(i) {
    ds <- top_lvs_df$dataset[i]; lv <- top_lvs_df$LV[i]
    x  <- lv_corr_full$cor[lv_corr_full$dataset == ds & lv_corr_full$LV == lv]
    x[x < 0] <- 0
    n <- length(x)
    if (n < 2 || max(x) <= 0) return(data.frame(tau = NA_real_))
    xhat <- x / max(x)
    data.frame(tau = sum(1 - xhat) / (n - 1))
})
specificity_df <- do.call(rbind, specificity_rows)

# metric/value long table -- mirrors the `overall` summary convention already
# used in 03_b_matrix_singlecell.ipynb. mean/sd kept as separate numeric
# columns (useful downstream); `label` is the printable "mean +/- sd" form.
summarize_metric <- function(x) data.frame(mean = mean(x, na.rm = TRUE), sd = sd(x, na.rm = TRUE))

assignment_quality <- dplyr::bind_rows(
    cbind(metric = "mean_cor_matched", summarize_metric(top_lvs_df$cor)),
    cbind(metric = "mean_tau",         summarize_metric(specificity_df$tau)),
    cbind(metric = "mean_auroc",       summarize_metric(auroc_df$auroc))
)
assignment_quality$label <- sprintf("%.3f ± %.3f", assignment_quality$mean, assignment_quality$sd)
assignment_quality

# Same three metrics, but broken out per dataset (rather than pooled) --
# needed for supp1 Panel D, which annotates each dataset's own correlation
# heatmap facet with its own mean Tau/AUROC rather than one figure-wide
# number. specificity_df is built row-aligned with top_lvs_df (one row per
# top_lvs_df row), so it gets a dataset column for free from there.
specificity_df$dataset <- top_lvs_df$dataset

assignment_quality_by_dataset <- dplyr::bind_rows(lapply(unique(top_lvs_df$dataset), function(ds) {
    dplyr::bind_rows(
        cbind(dataset = ds, metric = "mean_cor_matched",
              summarize_metric(top_lvs_df$cor[top_lvs_df$dataset == ds])),
        cbind(dataset = ds, metric = "mean_tau",
              summarize_metric(specificity_df$tau[specificity_df$dataset == ds])),
        cbind(dataset = ds, metric = "mean_auroc",
              summarize_metric(auroc_df$auroc[auroc_df$dataset == ds]))
    )
}))
assignment_quality_by_dataset$label <- sprintf("%.3f ± %.3f", assignment_quality_by_dataset$mean, assignment_quality_by_dataset$sd)
assignment_quality_by_dataset
# Out:
#   metric           mean      sd         label
# 1 mean_cor_matched 0.7646225 0.18974216 0.765 ± 0.190
# 2 mean_tau         0.8972975 0.07587416 0.897 ± 0.076
# 3 mean_auroc       0.9316052 0.06483492 0.932 ± 0.065
#    dataset          metric           mean      sd         label
# 1  Brain_Mathys2023 mean_cor_matched 0.7897021 0.20926232 0.790 ± 0.209
# 2  Brain_Mathys2023 mean_tau         0.8768612 0.07795617 0.877 ± 0.078
# 3  Brain_Mathys2023 mean_auroc       0.9277643 0.08046978 0.928 ± 0.080
# 4  Brain_Xiong2023  mean_cor_matched 0.7661281 0.20355104 0.766 ± 0.204
# 5  Brain_Xiong2023  mean_tau         0.8325472 0.14064749 0.833 ± 0.141
# 6  Brain_Xiong2023  mean_auroc       0.8752718 0.13411620 0.875 ± 0.134
# 7  Heart_Datar2026  mean_cor_matched 0.7179881 0.18431902 0.718 ± 0.184
# 8  Heart_Datar2026  mean_tau         0.9162805 0.03699788 0.916 ± 0.037
# 9  Heart_Datar2026  mean_auroc       0.9060431 0.05021716 0.906 ± 0.050
# 10 PBMC_1k1k        mean_cor_matched 0.7533190 0.24281082 0.753 ± 0.243
# 11 PBMC_1k1k        mean_tau         0.9013419 0.07410222 0.901 ± 0.074
# 12 PBMC_1k1k        mean_auroc       0.9605944 0.02787266 0.961 ± 0.028
# 13 PBMC_Perez2022   mean_cor_matched 0.8879996 0.03522513 0.888 ± 0.035
# 14 PBMC_Perez2022   mean_tau         0.9199365 0.07729749 0.920 ± 0.077
# 15 PBMC_Perez2022   mean_auroc       0.9362319 0.01112632 0.936 ± 0.011
# 16 Lung_Sikkema2023 mean_cor_matched 0.7773215 0.17540998 0.777 ± 0.175
# 17 Lung_Sikkema2023 mean_tau         0.9120980 0.05239616 0.912 ± 0.052
# 18 Lung_Sikkema2023 mean_auroc       0.9674616 0.04009504 0.967 ± 0.040

# %% [markdown]
# ## Module-level marker recovery — top-loading genes recover independent cell-type markers

# %%
CELLMARKER_PATH <- snakemake@input[["cell_marker_file"]]
ALLEN_PATH      <- snakemake@input[["allen_brain_gmt_file"]]
AZIMUTH_PATH    <- snakemake@input[["azimuth_file"]]

load_cellmarker_sets <- function(path) {
    df <- readxl::read_excel(path, sheet = "human")
    df <- df[df$species == "Human" & !is.na(df$Symbol) & nzchar(df$Symbol), ]
    lapply(split(df$Symbol, df$cell_name), unique)
}

read_gmt_sets <- function(path) {
    sp <- strsplit(readLines(path, warn = FALSE), "\t", fixed = TRUE)
    sp <- sp[lengths(sp) >= 3]
    setNames(lapply(sp, function(x) unique(x[-c(1, 2)])),
             vapply(sp, `[`, character(1), 1))
}

cellmarker_t2g <- load_cellmarker_sets(CELLMARKER_PATH)
allen_raw <- read_gmt_sets(ALLEN_PATH)
allen_t2g <- allen_raw[grepl("^Human ", names(allen_raw)) &
                        grepl(" up$", names(allen_raw))]
BRAIN_DS <- unlist(snakemake@config$references$brain_datasets)

normalize_marker_text <- function(x) {
    stringr::str_squish(gsub("[^a-z0-9]+", " ", tolower(x)))
}

CELL_TYPE_ALIASES <- list(
    Ast = c("astrocyte"), Exc = c("excitatory neuron", "glutamatergic neuron"),
    Inh = c("inhibitory neuron", "gabaergic neuron"),
    Mic = c("microglia", "microglial"), Oli = c("oligodendrocyte"),
    Opc = c("oligodendrocyte precursor", "oligodendrocyte progenitor", "opc"),
    B_cell = c("b cell", "b lymphocyte"), NK = c("natural killer", "nk cell"),
    CD4_T = c("cd4 t cell", "cd4 positive t cell"),
    CD8_T = c("cd8 t cell", "cd8 positive t cell"),
    CD14_Mono = c("cd14 monocyte", "classical monocyte", "monocyte"),
    CD16_Mono = c("cd16 monocyte", "non classical monocyte", "monocyte"),
    DC = c("dendritic cell"), gd_T = c("gamma delta t cell", "gd t cell"),
    Plasma_B = c("plasma cell", "plasmablast"),
    Myeloid = c("myeloid", "monocyte", "macrophage"),
    T_cell = c("t cell", "t lymphocyte"),
    Macrophage = c("macrophage", "myeloid"),
    Endothelial = c("endothelial cell"), Pericyte = c("pericyte"),
    VentricularCM = c("ventricular cardiomyocyte", "cardiomyocyte"),
    AtrialCM = c("atrial cardiomyocyte", "cardiomyocyte"),
    Fibroblast = c("fibroblast"), Adipocyte = c("adipocyte"),
    Endocardial = c("endocardial cell", "endothelial cell"),
    Epicardial = c("epicardial cell", "mesothelial cell"),
    LymphaticEndothelial = c("lymphatic endothelial"),
    Lymphocyte = c("lymphocyte", "t cell", "b cell", "natural killer"),
    Mast = c("mast cell"), Neuronal = c("neuron", "neuronal"),
    VSMC = c("vascular smooth muscle", "smooth muscle cell"),
    `Blood vessels` = c("endothelial cell", "vascular endothelial"),
    Lymphoid = c("lymphocyte", "t cell", "b cell", "natural killer"),
    `Alveolar epithelium` = c("alveolar epithelial", "type i pneumocyte", "type ii pneumocyte"),
    `Airway epithelium` = c("ciliated cell", "club cell", "goblet cell", "basal cell"),
    `Fibroblast lineage` = c("fibroblast", "myofibroblast"),
    `Lymphatic EC` = c("lymphatic endothelial"),
    `Submucosal Gland` = c("submucosal gland", "serous cell", "mucous cell")
)

cellmarker_terms_for <- function(cell_type) {
    aliases <- CELL_TYPE_ALIASES[[cell_type]]
    if (is.null(aliases)) aliases <- ct_label(cell_type)
    aliases <- normalize_marker_text(aliases)
    terms_norm <- normalize_marker_text(names(cellmarker_t2g))
    names(cellmarker_t2g)[vapply(terms_norm, function(term)
        any(vapply(aliases, function(alias)
            grepl(paste0(" ", alias, " "), paste0(" ", term, " "),
                  fixed = TRUE), logical(1))), logical(1))]
}

ALLEN_ALIAS_MAP <- list(
    Ast = "Astro", Exc = "Exc", Inh = "Inh", Mic = "Micro",
    Oli = "Oligo", Opc = "OPC"
)

allen_terms_for <- function(dataset, cell_type) {
    if (!dataset %in% BRAIN_DS) return(character(0))
    prefixes <- ALLEN_ALIAS_MAP[[cell_type]]
    if (is.null(prefixes)) return(character(0))
    pattern <- paste0("^Human (", paste(prefixes, collapse = "|"), ") ")
    names(allen_t2g)[grepl(pattern, names(allen_t2g))]
}

read_azimuth_sets <- function(path) {
    sp <- strsplit(readLines(path, warn = FALSE), "\t", fixed = TRUE)
    sp <- sp[lengths(sp) >= 3]
    setNames(lapply(sp, function(x) unique(x[-c(1, 2)])),
             vapply(sp, `[`, character(1), 1))
}
azimuth_t2g <- read_azimuth_sets(AZIMUTH_PATH)

# Explicit, atlas-matched marker terms. These are the same Azimuth reference
# families used by Figure 2e, extended to every scored pseudobulk cell type.
AZIMUTH_TERM_MAP <- list(
    Brain_Mathys2023 = list(
        Oli = "Motor Cortex-subclass-oligodendrocyte",
        Exc = "Motor Cortex-class-Glutamatergic Neuron",
        Ast = "Motor Cortex-subclass-Astrocyte",
        Inh = "Motor Cortex-class-GABAergic Neuron",
        Mic = "Motor Cortex-subclass-microglia / Perivascular Macrophage",
        Opc = "Motor Cortex-subclass-oligodendrocyte Precursor Cell"
    ),
    Brain_Xiong2023 = list(
        Oli = "Motor Cortex-subclass-oligodendrocyte",
        Exc = "Motor Cortex-class-Glutamatergic Neuron",
        Ast = "Motor Cortex-subclass-Astrocyte",
        Inh = "Motor Cortex-class-GABAergic Neuron",
        Mic = "Motor Cortex-subclass-microglia / Perivascular Macrophage",
        Opc = "Motor Cortex-subclass-oligodendrocyte Precursor Cell"
    ),
    Heart_Datar2026 = list(
        Macrophage = "Heart-L2-Macrophage",
        Endothelial = "Heart-L2-Endothelial",
        Pericyte = "Heart-L2-Pericyte",
        VentricularCM = "Heart-L2-Ventricular Cardiomyocyte",
        Fibroblast = "Heart-L2-Fibroblast",
        Adipocyte = "Heart-L2-Adipocyte",
        AtrialCM = "Heart-L2-Atrial Cardiomyocyte",
        Endocardial = "Heart-L2-Endocardial",
        Epicardial = "Heart-L2-Mesothelial",
        LymphaticEndothelial = "Heart-L2-Lymphatic Endothelial",
        Lymphocyte = c("Heart-L2-B", "Heart-L2-ILC", "Heart-L2-NK", "Heart-L2-T"),
        Mast = "Heart-L2-Mast",
        Neuronal = "Heart-L2-Neuronal",
        VSMC = "Heart-L2-Smooth Muscle"
    ),
    PBMC_1k1k = list(
        B_cell = "PBMC-L1-B Cell",
        NK = "PBMC-L1-natural Killer Cell",
        CD4_T = "PBMC-L1-CD4+ T Cell",
        CD8_T = "PBMC-L1-CD8+ T Cell",
        CD14_Mono = "PBMC-L2-CD14+ Monocyte",
        CD16_Mono = "PBMC-L2-CD16+ Monocyte",
        DC = "PBMC-L1-dendritic Cell",
        gd_T = "PBMC-L2-gamma-delta T",
        Plasma_B = "PBMC-L2-Plasmablast"
    ),
    PBMC_Perez2022 = list(
        Myeloid = c("PBMC-L1-Monocyte", "PBMC-L1-dendritic Cell"),
        T_cell = c("PBMC-L1-CD4+ T Cell", "PBMC-L1-CD8+ T Cell",
                   "PBMC-L1-other T Cell"),
        B_cell = "PBMC-L1-B Cell",
        NK = "PBMC-L1-natural Killer Cell"
    ),
    Lung_Sikkema2023 = list(
        "Blood vessels" = "Lung V2 (HLCA)-ann Level 2-Blood Vessels",
        Lymphoid = "Lung V2 (HLCA)-ann Level 2-Lymphoid",
        "Alveolar epithelium" = "Lung V2 (HLCA)-ann Level 2-Alveolar Epithelium",
        "Airway epithelium" = "Lung V2 (HLCA)-ann Level 2-Airway Epithelium",
        Myeloid = "Lung V2 (HLCA)-ann Level 2-Myeloid",
        "Fibroblast lineage" = "Lung V2 (HLCA)-ann Level 2-Fibroblast Lineage",
        "Lymphatic EC" = "Lung V2 (HLCA)-ann Level 2-Lymphatic EC",
        "Submucosal Gland" = "Lung V2 (HLCA)-ann Level 2-Submucosal Gland"
    )
)

mapped_terms <- unique(unlist(AZIMUTH_TERM_MAP, recursive = TRUE, use.names = FALSE))
missing_terms <- setdiff(mapped_terms, names(azimuth_t2g))
if (length(missing_terms))
    stop("Azimuth mapping contains missing terms: ", paste(missing_terms, collapse = "; "))

azimuth_terms_for <- function(dataset, cell_type) {
    ds_map <- AZIMUTH_TERM_MAP[[dataset]]
    if (is.null(ds_map) || is.null(ds_map[[cell_type]]))
        stop("No Azimuth marker mapping for ", dataset, " / ", cell_type)
    ds_map[[cell_type]]
}

azimuth_dataset_terms <- function(dataset, cell_types = names(AZIMUTH_TERM_MAP[[dataset]])) {
    unique(unlist(AZIMUTH_TERM_MAP[[dataset]][cell_types], use.names = FALSE))
}

prefix_marker_sets <- function(sets, source) {
    stats::setNames(sets, paste0(source, "::", names(sets)))
}

prefix_marker_terms <- function(terms, source) {
    if (length(terms) == 0) return(character(0))
    paste0(source, "::", terms)
}

reference_sets_for <- function(dataset, cell_types = names(AZIMUTH_TERM_MAP[[dataset]])) {
    az_terms <- azimuth_dataset_terms(dataset, cell_types)
    out <- c(prefix_marker_sets(cellmarker_t2g, "CellMarker"),
             prefix_marker_sets(azimuth_t2g[az_terms], "Azimuth"))
    if (dataset %in% BRAIN_DS)
        out <- c(out, prefix_marker_sets(allen_t2g, "Allen"))
    out
}

target_reference_terms <- function(dataset, cell_type) {
    unique(c(prefix_marker_terms(cellmarker_terms_for(cell_type), "CellMarker"),
             prefix_marker_terms(azimuth_terms_for(dataset, cell_type), "Azimuth"),
             prefix_marker_terms(allen_terms_for(dataset, cell_type), "Allen")))
}

build_marker_sets <- function(dataset, cell_types, gene_universe, min_size = 5,
                              promiscuity_max_frac = 0.5) {
    references <- reference_sets_for(dataset, cell_types)
    sets <- lapply(cell_types, function(ct) {
        terms <- intersect(target_reference_terms(dataset, ct), names(references))
        intersect(unique(unlist(references[terms], use.names = FALSE)), gene_universe)
    })
    names(sets) <- cell_types
    too_small <- names(sets)[lengths(sets) < min_size]
    if (length(too_small))
        stop("Combined marker sets below min_size for ", dataset, ": ",
             paste(too_small, collapse = ", "))

    if (length(sets) > 1) {
        gene_counts <- table(unlist(sets))
        promiscuous <- names(gene_counts)[gene_counts > promiscuity_max_frac * length(sets)]
        sets <- lapply(sets, function(g) setdiff(g, promiscuous))
        too_small <- names(sets)[lengths(sets) < min_size]
        if (length(too_small))
            stop("Combined marker sets below min_size after promiscuity filter for ",
                 dataset, ": ", paste(too_small, collapse = ", "))
    }
    sets
}

read_B_matrix <- function(path) {
    df  <- read.csv(path, row.names = 1, check.names = FALSE)
    mat <- as.matrix(df)
    storage.mode(mat) <- "numeric"
    t(mat)   # samples x LVs
}

assign_dominant_ct <- function(truth_path) {
    truth    <- read.csv(truth_path, row.names = 1, check.names = FALSE)
    ct_names <- colnames(truth)
    dom      <- ct_names[apply(truth, 1, which.max)]
    setNames(dom, rownames(truth))
}

cat("CellMarker sets:", length(cellmarker_t2g),
    "| Allen human-up sets:", length(allen_t2g),
    "| Azimuth sets:", length(azimuth_t2g),
    "| mapped Azimuth terms:", length(mapped_terms), "\n")
# Out:
# CellMarker sets: 1598 | Allen human-up sets: 111 | Azimuth sets: 1425 | mapped Azimuth terms: 42

# %%
# One-vs-rest Wilcoxon test per LV per cell type, then a one-to-one greedy
# assignment (like 00_benchmark's oneToOneMask) so no LV is reused within a
# dataset. Cell types never dominant enough to test fall back to Property 2's
# correlation-based assignment (top_lvs_df); fallback LVs are reserved first so
# the two selection paths can't collide.
one_vs_rest_test <- function(B, sample_ct) {
    shared <- intersect(rownames(B), names(sample_ct))
    B  <- B[shared, , drop = FALSE]
    ct <- sample_ct[shared]

    out <- do.call(rbind, lapply(unique(ct), function(this_ct) {
        in_idx <- ct == this_ct
        do.call(rbind, lapply(colnames(B), function(lv) {
            x_in  <- B[in_idx,  lv]
            x_out <- B[!in_idx, lv]
            if (length(x_in) < 3 || length(x_out) < 3) return(NULL)
            wt <- suppressWarnings(wilcox.test(x_in, x_out, alternative = "greater"))
            data.frame(
                cell_type = this_ct, LV = lv,
                n_in = length(x_in), n_out = length(x_out),
                mean_in = mean(x_in), mean_out = mean(x_out),
                effect  = mean(x_in) - mean(x_out),
                pvalue  = wt$p.value,
                stringsAsFactors = FALSE
            )
        }))
    }))
    out$qvalue <- p.adjust(out$pvalue, method = "BH")
    out
}

select_top_lv <- function(ovr_df, qval_threshold = 0.05, reserved_lvs = character(0)) {
    d <- ovr_df[!(ovr_df$LV %in% reserved_lvs), ]
    if (nrow(d) == 0) return(ovr_df[0, ])
    d$is_significant <- d$qvalue < qval_threshold & d$effect > 0
    d <- d[order(-d$is_significant, -d$effect), ]

    assigned <- list()
    used_lvs <- character(0)
    for (i in seq_len(nrow(d))) {
        row <- d[i, ]
        if (row$cell_type %in% names(assigned) || row$LV %in% used_lvs) next
        row$weak_evidence <- !row$is_significant
        assigned[[row$cell_type]] <- row
        used_lvs <- c(used_lvs, row$LV)
    }
    if (length(assigned) == 0) return(ovr_df[0, ])
    do.call(rbind, assigned)
}

run_module_pipeline <- function(ds, method = "CLAMPfull") {
    b_path     <- file.path(MOD_ROOT, ds, "models", method, "B.csv")
    z_path     <- file.path(MOD_ROOT, ds, "models", method, "Z.csv")
    truth_path <- truth_v0_path(ds)
    if (!all(file.exists(b_path), file.exists(z_path))) return(NULL)

    B         <- read_B_matrix(b_path)
    Z         <- read.csv(z_path, row.names = 1, check.names = FALSE)
    truth <- filter_analysis_cell_types(
      read.csv(truth_path, row.names = 1, check.names = FALSE),
      ds, snakemake@config$cell_type_analysis$excluded_targets
    )
    sample_ct <- setNames(colnames(truth)[apply(truth, 1, which.max)], rownames(truth))
    all_cts   <- colnames(truth)

    universe    <- rownames(Z)
    marker_sets <- build_marker_sets(ds, all_cts, universe)

    ovr <- one_vs_rest_test(B, sample_ct)
    ovr <- ovr[ovr$cell_type %in% names(marker_sets), ]

    sel_fallback <- NULL
    if (method == "CLAMPfull") {
        missing_cts <- setdiff(names(marker_sets), unique(ovr$cell_type))
        fallback <- top_lvs_df[top_lvs_df$dataset == ds & top_lvs_df$cell_type %in% missing_cts, ]
        if (nrow(fallback) > 0) sel_fallback <- data.frame(
            cell_type = fallback$cell_type, LV = fallback$LV,
            n_in = NA_real_, n_out = NA_real_, mean_in = NA_real_, mean_out = NA_real_,
            effect = fallback$cor, pvalue = NA_real_, qvalue = NA_real_,
            is_significant = FALSE, weak_evidence = TRUE,
            selection_method = "correlation_fallback", stringsAsFactors = FALSE
        )
    }
    fallback_lvs <- if (!is.null(sel_fallback)) sel_fallback$LV else character(0)

    sel_ovr <- if (nrow(ovr) > 0) select_top_lv(ovr, reserved_lvs = fallback_lvs) else
        data.frame(cell_type = character(), LV = character(), effect = numeric(),
                  qvalue = numeric(), is_significant = logical(), weak_evidence = logical(),
                  stringsAsFactors = FALSE)
    if (nrow(sel_ovr) > 0) sel_ovr$selection_method <- "one_vs_rest"

    sel <- dplyr::bind_rows(sel_ovr, sel_fallback)

    list(dataset = ds, method = method, ovr = ovr, selected = sel,
         marker_sets = marker_sets, marker_source = "CellMarker + Allen + Azimuth",
         universe = universe)
}

module_results <- lapply(DATASETS, run_module_pipeline)
names(module_results) <- DATASETS
module_results <- Filter(Negate(is.null), module_results)

ovr_all_df <- dplyr::bind_rows(lapply(names(module_results), function(ds)
    cbind(dataset = ds, module_results[[ds]]$ovr)))
selected_all_df <- dplyr::bind_rows(lapply(names(module_results), function(ds)
    cbind(dataset = ds, module_results[[ds]]$selected)))

cat("One-vs-rest tests:", nrow(ovr_all_df), "\n")
cat("Selected LVs (one per cell type per dataset, all cell types covered):", nrow(selected_all_df), "\n")
print(table(selected_all_df$selection_method))
print(selected_all_df[, c("dataset", "cell_type", "LV", "effect", "selection_method", "is_significant")])
# Out:
# One-vs-rest tests: 1066
# Selected LVs (one per cell type per dataset, all cell types covered): 47
# correlation_fallback          one_vs_rest
#                   26                   21
#                              dataset            cell_type   LV    effect
# Oli...1             Brain_Mathys2023                  Oli LV18 2.5031900
# Exc...2             Brain_Mathys2023                  Exc LV19 1.4442476
# ...3                Brain_Mathys2023                  Ast LV17 0.9162621
# ...4                Brain_Mathys2023                  Inh  LV4 0.8197967
# ...5                Brain_Mathys2023                  Mic  LV6 0.9631104
# ...6                Brain_Mathys2023                  Opc  LV7 0.4672024
# Oli...7              Brain_Xiong2023                  Oli LV14 2.4531618
# Exc...8              Brain_Xiong2023                  Exc  LV1 1.5653056
# Inh                  Brain_Xiong2023                  Inh  LV8 0.9126555
# ...10                Brain_Xiong2023                  Ast  LV5 0.9451393
# ...11                Brain_Xiong2023                  Mic LV17 0.8747079
# ...12                Brain_Xiong2023                  Opc LV11 0.4837165
# Macrophage           Heart_Datar2026           Macrophage LV26 2.0455276
# Endothelial          Heart_Datar2026          Endothelial LV27 1.0457637
# Pericyte             Heart_Datar2026             Pericyte LV32 1.0394390
# VentricularCM        Heart_Datar2026        VentricularCM LV46 0.9030765
# Fibroblast           Heart_Datar2026           Fibroblast LV28 0.8631007
# ...18                Heart_Datar2026            Adipocyte LV17 0.7301385
# ...19                Heart_Datar2026             AtrialCM LV23 0.7798936
# ...20                Heart_Datar2026          Endocardial LV25 0.9260398
# ...21                Heart_Datar2026           Epicardial LV35 0.8281088
# ...22                Heart_Datar2026 LymphaticEndothelial LV37 0.4944495
# ...23                Heart_Datar2026           Lymphocyte LV10 0.9457562
# ...24                Heart_Datar2026                 Mast LV51 0.4173376
# ...25                Heart_Datar2026             Neuronal  LV3 0.3991150
# ...26                Heart_Datar2026                 VSMC LV38 0.5512607
# B_cell                     PBMC_1k1k               B_cell LV40 2.2910165
# NK                         PBMC_1k1k                   NK  LV1 1.0467971
# CD4_T                      PBMC_1k1k                CD4_T LV28 0.8642658
# CD8_T                      PBMC_1k1k                CD8_T LV48 0.6315864
# ...31                      PBMC_1k1k            CD14_Mono  LV2 0.9862407
# ...32                      PBMC_1k1k            CD16_Mono LV20 0.9480427
# ...33                      PBMC_1k1k                   DC LV38 0.4184312
# ...34                      PBMC_1k1k                 gd_T LV71 0.2803543
# ...35                      PBMC_1k1k             Plasma_B LV22 0.8747832
# Myeloid...36          PBMC_Perez2022              Myeloid  LV2 1.8030109
# T_cell                PBMC_Perez2022               T_cell LV52 1.2328317
# ...38                 PBMC_Perez2022               B_cell LV10 0.9348591
# ...39                 PBMC_Perez2022                   NK  LV6 0.8877003
# Blood vessels       Lung_Sikkema2023        Blood vessels  LV8 4.2056615
# Lymphoid            Lung_Sikkema2023             Lymphoid LV10 2.5882113
# Alveolar epithelium Lung_Sikkema2023  Alveolar epithelium  LV6 2.3406099
# Airway epithelium   Lung_Sikkema2023    Airway epithelium  LV1 1.4697038
# Myeloid...44        Lung_Sikkema2023              Myeloid LV12 1.3554933
# ...45               Lung_Sikkema2023   Fibroblast lineage LV11 0.9145147
# ...46               Lung_Sikkema2023         Lymphatic EC  LV5 0.5764531
# ...47               Lung_Sikkema2023     Submucosal Gland LV14 0.4565030
#                         selection_method is_significant
# Oli...1                      one_vs_rest           TRUE
# Exc...2                      one_vs_rest           TRUE
# ...3                correlation_fallback          FALSE
# ...4                correlation_fallback          FALSE
# ...5                correlation_fallback          FALSE
# ...6                correlation_fallback          FALSE
# Oli...7                      one_vs_rest           TRUE
# Exc...8                      one_vs_rest           TRUE
# Inh                          one_vs_rest          FALSE
# ...10               correlation_fallback          FALSE
# ...11               correlation_fallback          FALSE
# ...12               correlation_fallback          FALSE
# Macrophage                   one_vs_rest           TRUE
# Endothelial                  one_vs_rest           TRUE
# Pericyte                     one_vs_rest           TRUE
# VentricularCM                one_vs_rest           TRUE
# Fibroblast                   one_vs_rest           TRUE
# ...18               correlation_fallback          FALSE
# ...19               correlation_fallback          FALSE
# ...20               correlation_fallback          FALSE
# ...21               correlation_fallback          FALSE
# ...22               correlation_fallback          FALSE
# ...23               correlation_fallback          FALSE
# ...24               correlation_fallback          FALSE
# ...25               correlation_fallback          FALSE
# ...26               correlation_fallback          FALSE
# B_cell                       one_vs_rest           TRUE
# NK                           one_vs_rest           TRUE
# CD4_T                        one_vs_rest           TRUE
# CD8_T                        one_vs_rest           TRUE
# ...31               correlation_fallback          FALSE
# ...32               correlation_fallback          FALSE
# ...33               correlation_fallback          FALSE
# ...34               correlation_fallback          FALSE
# ...35               correlation_fallback          FALSE
# Myeloid...36                 one_vs_rest           TRUE
# T_cell                       one_vs_rest           TRUE
# ...38               correlation_fallback          FALSE
# ...39               correlation_fallback          FALSE
# Blood vessels                one_vs_rest           TRUE
# Lymphoid                     one_vs_rest           TRUE
# Alveolar epithelium          one_vs_rest           TRUE
# Airway epithelium            one_vs_rest           TRUE
# Myeloid...44                 one_vs_rest           TRUE
# ...45               correlation_fallback          FALSE
# ...46               correlation_fallback          FALSE
# ...47               correlation_fallback          FALSE

# %%
coverage_df <- selected_all_df[, c("dataset", "cell_type", "selection_method")]

cat("Selection method breakdown:\n")
print(table(coverage_df$selection_method))
cat("\nCell types selected via correlation fallback (no one-vs-rest test possible):\n")
print(coverage_df[coverage_df$selection_method == "correlation_fallback",
                  c("dataset", "cell_type")])
# Out:
# Selection method breakdown:
# correlation_fallback          one_vs_rest
#                   26                   21
# Cell types selected via correlation fallback (no one-vs-rest test possible):
#                dataset            cell_type
# ...3  Brain_Mathys2023                  Ast
# ...4  Brain_Mathys2023                  Inh
# ...5  Brain_Mathys2023                  Mic
# ...6  Brain_Mathys2023                  Opc
# ...10  Brain_Xiong2023                  Ast
# ...11  Brain_Xiong2023                  Mic
# ...12  Brain_Xiong2023                  Opc
# ...18  Heart_Datar2026            Adipocyte
# ...19  Heart_Datar2026             AtrialCM
# ...20  Heart_Datar2026          Endocardial
# ...21  Heart_Datar2026           Epicardial
# ...22  Heart_Datar2026 LymphaticEndothelial
# ...23  Heart_Datar2026           Lymphocyte
# ...24  Heart_Datar2026                 Mast
# ...25  Heart_Datar2026             Neuronal
# ...26  Heart_Datar2026                 VSMC
# ...31        PBMC_1k1k            CD14_Mono
# ...32        PBMC_1k1k            CD16_Mono
# ...33        PBMC_1k1k                   DC
# ...34        PBMC_1k1k                 gd_T
# ...35        PBMC_1k1k             Plasma_B
# ...38   PBMC_Perez2022               B_cell
# ...39   PBMC_Perez2022                   NK
# ...45 Lung_Sikkema2023   Fibroblast lineage
# ...46 Lung_Sikkema2023         Lymphatic EC
# ...47 Lung_Sikkema2023     Submucosal Gland

# %%
# ORA per selected LV against the combined CellMarker, Allen, and
# dataset-matched Azimuth marker reference. Allen is included for brain only.
# The top 1% of gene loadings is tested first; an LV with no significant hit is
# retried once at 3%. Recovery requires an exact hit to a reference term mapped
# a priori to the true pseudobulk cell type in any of the applicable resources.
suppressPackageStartupMessages(library(clusterProfiler))

get_top_genes <- function(Z, lv, top_pct) {
    if (!lv %in% colnames(Z)) return(character(0))
    loadings <- Z[[lv]]; names(loadings) <- rownames(Z)
    n_genes  <- max(1L, ceiling(length(loadings) * top_pct))
    ord      <- order(loadings, decreasing = TRUE)
    names(loadings)[ord][seq_len(n_genes)]
}

TOP_GENE_PCT_FALLBACK <- 0.03
TOP_N_PATHWAYS        <- 3
ORA_TERM_SEP          <- " || "  # CellMarker term names can contain commas

run_enricher_once <- function(Z, LV, pct, term2gene_full, universe) {
    top_genes <- get_top_genes(Z, LV, pct)
    tryCatch(
        clusterProfiler::enricher(gene = top_genes, universe = universe,
                                  TERM2GENE = term2gene_full, pvalueCutoff = 1,
                                  qvalueCutoff = 1, minGSSize = 1, maxGSSize = Inf),
        error = function(e) NULL)
}

significant_ora <- function(res) {
    if (is.null(res) || nrow(res@result) == 0) return(data.frame())
    res@result[res@result$p.adjust < 0.05, , drop = FALSE]
}

run_lv_ora_topn <- function(ds, LV, term2gene_full, universe) {
    z_path <- file.path(MOD_ROOT, ds, "models", "CLAMPfull", "Z.csv")
    Z      <- read.csv(z_path, row.names = 1, check.names = FALSE)

    res <- run_enricher_once(Z, LV, TOP_GENE_PCT, term2gene_full, universe)
    sig <- significant_ora(res)
    pct_used <- TOP_GENE_PCT
    if (nrow(sig) == 0) {
        res <- run_enricher_once(Z, LV, TOP_GENE_PCT_FALLBACK,
                                 term2gene_full, universe)
        sig <- significant_ora(res)
        pct_used <- TOP_GENE_PCT_FALLBACK
    }
    if (nrow(sig) == 0)
        return(data.frame(top_pathways = NA_character_, top_fdr = NA_character_,
                          top_gene_pct_used = pct_used))

    topN <- head(sig[order(sig$p.adjust), ], TOP_N_PATHWAYS)
    data.frame(top_pathways = paste(topN$ID, collapse = ORA_TERM_SEP),
               top_fdr = paste(formatC(topN$p.adjust, format = "e", digits = 2),
                               collapse = ORA_TERM_SEP),
               top_gene_pct_used = pct_used)
}

top_pathway_df <- dplyr::bind_rows(lapply(names(module_results), function(ds) {
    universe <- module_results[[ds]]$universe
    sel_ds   <- selected_all_df[selected_all_df$dataset == ds, ]
    references <- reference_sets_for(ds, sel_ds$cell_type)
    term2gene_full <- dplyr::bind_rows(lapply(names(references), function(term) {
        genes <- intersect(references[[term]], universe)
        if (length(genes) == 0) return(NULL)
        data.frame(term = term, gene = genes, stringsAsFactors = FALSE)
    }))

    dplyr::bind_rows(lapply(seq_len(nrow(sel_ds)), function(i) {
        row <- sel_ds[i, ]
        target_terms <- target_reference_terms(ds, row$cell_type)
        cbind(row[, c("dataset", "cell_type", "LV")],
              marker_source = "CellMarker + Allen + Azimuth",
              marker_reference_terms = paste(target_terms, collapse = " | "),
              run_lv_ora_topn(ds, row$LV, term2gene_full, universe))
    }))
}))

any_of_topn <- function(dataset, cell_type, top_str) {
    if (is.na(top_str)) return(FALSE)
    terms <- strsplit(top_str, ORA_TERM_SEP, fixed = TRUE)[[1]]
    any(terms %in% target_reference_terms(dataset, cell_type))
}
top_pathway_df$recovered <- mapply(
    any_of_topn, top_pathway_df$dataset, top_pathway_df$cell_type,
    top_pathway_df$top_pathways
)

top_pathway_table <- top_pathway_df
top_pathway_table$cell_type <- ct_label(top_pathway_table$cell_type)
top_pathway_table <- top_pathway_table[
    order(top_pathway_table$dataset, top_pathway_table$cell_type), ]
rownames(top_pathway_table) <- NULL

cat("Combined marker ORA recovered:", sum(top_pathway_table$recovered), "/",
    nrow(top_pathway_table), "\n")
top_pathway_table
# Out:
# Combined marker ORA recovered: 40 / 47
#    dataset          cell_type                       LV
# 1  Brain_Mathys2023 Astrocytes                      LV17
# 2  Brain_Mathys2023 Excitatory neurons              LV19
# 3  Brain_Mathys2023 Inhibitory neurons              LV4
# 4  Brain_Mathys2023 Microglia                       LV6
# 5  Brain_Mathys2023 Oligodendrocyte Precursor Cells LV7
# 6  Brain_Mathys2023 Oligodendrocytes                LV18
# 7  Brain_Xiong2023  Astrocytes                      LV5
# 8  Brain_Xiong2023  Excitatory neurons              LV1
# 9  Brain_Xiong2023  Inhibitory neurons              LV8
# 10 Brain_Xiong2023  Microglia                       LV17
# 11 Brain_Xiong2023  Oligodendrocyte Precursor Cells LV11
# 12 Brain_Xiong2023  Oligodendrocytes                LV14
# 13 Heart_Datar2026  Adipocyte                       LV17
# 14 Heart_Datar2026  AtrialCM                        LV23
# 15 Heart_Datar2026  Endocardial                     LV25
# 16 Heart_Datar2026  Endothelial cells               LV27
# 17 Heart_Datar2026  Epicardial                      LV35
# 18 Heart_Datar2026  Fibroblasts                     LV28
# 19 Heart_Datar2026  LymphaticEndothelial            LV37
# 20 Heart_Datar2026  Lymphocyte                      LV10
# 21 Heart_Datar2026  Macrophage                      LV26
# 22 Heart_Datar2026  Mast cells                      LV51
# 23 Heart_Datar2026  Neuronal                        LV3
# 24 Heart_Datar2026  Pericyte                        LV32
# 25 Heart_Datar2026  VentricularCM                   LV46
# 26 Heart_Datar2026  VSMC                            LV38
# 27 Lung_Sikkema2023 Airway epithelium               LV1
# 28 Lung_Sikkema2023 Alveolar epithelium             LV6
# 29 Lung_Sikkema2023 Blood vessels                   LV8
# 30 Lung_Sikkema2023 Fibroblast lineage              LV11
# 31 Lung_Sikkema2023 Lymphatic EC                    LV5
# 32 Lung_Sikkema2023 Lymphoid                        LV10
# 33 Lung_Sikkema2023 Myeloid cells                   LV12
# 34 Lung_Sikkema2023 Submucosal Gland                LV14
# 35 PBMC_1k1k        B cells                         LV40
# 36 PBMC_1k1k        CD14+ Monocytes                 LV2
# 37 PBMC_1k1k        CD16+ Monocytes                 LV20
# 38 PBMC_1k1k        CD4+ T cells                    LV28
# 39 PBMC_1k1k        CD8+ T cells                    LV48
# 40 PBMC_1k1k        Dendritic cells                 LV38
# 41 PBMC_1k1k        gd T cells                      LV71
# 42 PBMC_1k1k        NK cells                        LV1
# 43 PBMC_1k1k        Plasma B cells                  LV22
# 44 PBMC_Perez2022   B cells                         LV10
# 45 PBMC_Perez2022   Myeloid cells                   LV2
# 46 PBMC_Perez2022   NK cells                        LV6
# 47 PBMC_Perez2022   T cells                         LV52
#    marker_source
# 1  CellMarker + Allen + Azimuth
# 2  CellMarker + Allen + Azimuth
# 3  CellMarker + Allen + Azimuth
# 4  CellMarker + Allen + Azimuth
# 5  CellMarker + Allen + Azimuth
# 6  CellMarker + Allen + Azimuth
# 7  CellMarker + Allen + Azimuth
# 8  CellMarker + Allen + Azimuth
# 9  CellMarker + Allen + Azimuth
# 10 CellMarker + Allen + Azimuth
# 11 CellMarker + Allen + Azimuth
# 12 CellMarker + Allen + Azimuth
# 13 CellMarker + Allen + Azimuth
# 14 CellMarker + Allen + Azimuth
# 15 CellMarker + Allen + Azimuth
# 16 CellMarker + Allen + Azimuth
# 17 CellMarker + Allen + Azimuth
# 18 CellMarker + Allen + Azimuth
# 19 CellMarker + Allen + Azimuth
# 20 CellMarker + Allen + Azimuth
# 21 CellMarker + Allen + Azimuth
# 22 CellMarker + Allen + Azimuth
# 23 CellMarker + Allen + Azimuth
# 24 CellMarker + Allen + Azimuth
# 25 CellMarker + Allen + Azimuth
# 26 CellMarker + Allen + Azimuth
# 27 CellMarker + Allen + Azimuth
# 28 CellMarker + Allen + Azimuth
# 29 CellMarker + Allen + Azimuth
# 30 CellMarker + Allen + Azimuth
# 31 CellMarker + Allen + Azimuth
# 32 CellMarker + Allen + Azimuth
# 33 CellMarker + Allen + Azimuth
# 34 CellMarker + Allen + Azimuth
# 35 CellMarker + Allen + Azimuth
# 36 CellMarker + Allen + Azimuth
# 37 CellMarker + Allen + Azimuth
# 38 CellMarker + Allen + Azimuth
# 39 CellMarker + Allen + Azimuth
# 40 CellMarker + Allen + Azimuth
# 41 CellMarker + Allen + Azimuth
# 42 CellMarker + Allen + Azimuth
# 43 CellMarker + Allen + Azimuth
# 44 CellMarker + Allen + Azimuth
# 45 CellMarker + Allen + Azimuth
# 46 CellMarker + Allen + Azimuth
# 47 CellMarker + Allen + Azimuth
#    marker_reference_terms                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 1  CellMarker::A1 astrocyte | CellMarker::A2 astrocyte | CellMarker::Astrocyte | CellMarker::Astrocyte progenitor cell | CellMarker::Fibrous astrocyte | CellMarker::Mature astrocyte | CellMarker::Mature Astrocyte | CellMarker::Pan-reactive astrocyte | CellMarker::Reactive astrocyte | CellMarker::Retinal astrocyte | Azimuth::Motor Cortex-subclass-Astrocyte | Allen::Human Astro L1 FGFR3 SERPINI2 up | Allen::Human Astro L1-6 FGFR3 AQP1 up | Allen::Human Astro L1-6 FGFR3 PLCG1 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 2  CellMarker::Broad excitatory neuron | CellMarker::Deep layer excitatory neuron | CellMarker::Excitatory neuron | CellMarker::Glutamatergic neuron | CellMarker::Superficial layer excitatory neuron | Azimuth::Motor Cortex-class-Glutamatergic Neuron | Allen::Human Exc L2 LAMP5 KCNG3 up | Allen::Human Exc L2 LINC00507 ATP7B up | Allen::Human Exc L2 LINC00507 GLRA3 up | Allen::Human Exc L2-3 LINC00507 DSG3 up | Allen::Human Exc L2-3 RORB CCDC68 up | Allen::Human Exc L3 LAMP5 CARM1P1 up | Allen::Human Exc L3 RORB OTOGL up | Allen::Human Exc L3 THEMIS ENPEP up | Allen::Human Exc L3-5 FEZF2 ASGR2 up | Allen::Human Exc L3-5 FEZF2 LINC01107 up | Allen::Human Exc L3-5 RORB LAMA4 up | Allen::Human Exc L3-5 RORB LINC01202 up | Allen::Human Exc L3-5 RORB LNX2 up | Allen::Human Exc L3-5 RORB RPRM up | Allen::Human Exc L3-5 RORB TNNT2 up | Allen::Human Exc L5 FEZF2 CSN1S1 up | Allen::Human Exc L5 FEZF2 NREP-AS1 up | Allen::Human Exc L5 FEZF2 PKD2L1 up | Allen::Human Exc L5 FEZF2 RNF144A-AS1 up | Allen::Human Exc L5 RORB MED8 up | Allen::Human Exc L5 THEMIS FGF10 up | Allen::Human Exc L5 THEMIS LINC01116 up | Allen::Human Exc L5 THEMIS RGPD6 up | Allen::Human Exc L5 THEMIS VILL up | Allen::Human Exc L5-6 FEZF2 C9orf135-AS1 up | Allen::Human Exc L5-6 FEZF2 CFTR up | Allen::Human Exc L5-6 FEZF2 FILIP1L up | Allen::Human Exc L5-6 FEZF2 IFNG-AS1 up | Allen::Human Exc L5-6 FEZF2 LPO up | Allen::Human Exc L5-6 FEZF2 OR1L8 up | Allen::Human Exc L5-6 FEZF2 SH2D1B up | Allen::Human Exc L5-6 THEMIS SMYD1 up | Allen::Human Exc L6 FEZF2 FFAR4 up | Allen::Human Exc L6 FEZF2 KLK7 up | Allen::Human Exc L6 FEZF2 PDYN up | Allen::Human Exc L6 FEZF2 POGK up | Allen::Human Exc L6 FEZF2 PROKR2 up | Allen::Human Exc L6 THEMIS LINC00343 up | Allen::Human Exc L6 THEMIS SLN up | Allen::Human Exc L6 THEMIS SNTG2 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 3  CellMarker::GABAergic neuron | CellMarker::Inhibitory neuron | Azimuth::Motor Cortex-class-GABAergic Neuron | Allen::Human Inh L1 LAMP5 BMP2 up | Allen::Human Inh L1 LAMP5 NMBR up | Allen::Human Inh L1 LAMP5 PVRL2 up | Allen::Human Inh L1 LAMP5 RAB11FIP1 up | Allen::Human Inh L1 PAX6 MIR101-1 up | Allen::Human Inh L1 PVALB SST ASIC4 up | Allen::Human Inh L1 SST P4HA3 up | Allen::Human Inh L1 VIP KLHDC8B up | Allen::Human Inh L1-2 PVALB CDK20 up | Allen::Human Inh L1-2 SST CLIC6 up | Allen::Human Inh L1-2 SST PRRT4 up | Allen::Human Inh L1-2 VIP EXPH5 up | Allen::Human Inh L1-2 VIP HTR3A up | Allen::Human Inh L1-2 VIP PTGER3 up | Allen::Human Inh L1-2 VIP SCML4 up | Allen::Human Inh L1-2 VIP WNT4 up | Allen::Human Inh L1-3 VIP CBLN1 up | Allen::Human Inh L1-3 VIP CHRNA2 up | Allen::Human Inh L1-3 VIP FNDC1 up | Allen::Human Inh L1-5 VIP CD27-AS1 up | Allen::Human Inh L1-5 VIP LINC01013 up | Allen::Human Inh L1-5 VIP PHLDB3 up | Allen::Human Inh L1-6 LAMP5 AARD up | Allen::Human Inh L1-6 LAMP5 CA1 up | Allen::Human Inh L1-6 PVALB COL15A1 up | Allen::Human Inh L1-6 SST NPY up | Allen::Human Inh L1-6 VIP SLC7A6OS up | Allen::Human Inh L2 PAX6 FREM2 up | Allen::Human Inh L2 PVALB FRZB up | Allen::Human Inh L2 VIP SLC6A16 up | Allen::Human Inh L2-5 PVALB HHIPL1 up | Allen::Human Inh L2-5 PVALB RPH3AL up | Allen::Human Inh L2-5 VIP BSPRY up | Allen::Human Inh L2-5 VIP SOX11 up | Allen::Human Inh L3 PVALB SAMD13 up | Allen::Human Inh L3-5 PVALB ISG20 up | Allen::Human Inh L3-5 SST CDH3 up | Allen::Human Inh L3-5 VIP HS3ST3A1 up | Allen::Human Inh L3-5 VIP IGDCC3 up | Allen::Human Inh L3-6 PAX6 LINC01497 up | Allen::Human Inh L3-6 VIP UG0898H09 up | Allen::Human Inh L3-6 VIP ZIM2-AS1 up | Allen::Human Inh L5 PVALB LRIG3 up | Allen::Human Inh L5-6 LAMP5 CRABP1 up | Allen::Human Inh L5-6 PVALB FAM150B up | Allen::Human Inh L5-6 PVALB GAPDHP60 up | Allen::Human Inh L5-6 PVALB KCNIP2 up | Allen::Human Inh L5-6 PVALB MEPE up | Allen::Human Inh L5-6 PVALB SST CRHR2 up | Allen::Human Inh L5-6 PVALB ZFPM2-AS1 up | Allen::Human Inh L5-6 SST BEAN1 up | Allen::Human Inh L5-6 SST C4orf26 up | Allen::Human Inh L5-6 SST DNAJC14 up | Allen::Human Inh L5-6 SST FBN2 up | Allen::Human Inh L5-6 SST ISX up | Allen::Human Inh L5-6 SST KLHL1 up | Allen::Human Inh L5-6 SST PAWR up | Allen::Human Inh L5-6 SST PIK3CD up | Allen::Human Inh L5-6 VIP COL4A3 up | Allen::Human Inh L6 SST TH up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 4  CellMarker::Activated microglial cell | CellMarker::Demyelinating microglial cell | CellMarker::Disease-associated microglial cell | CellMarker::Homeostatic microglial cell | CellMarker::M1 microglial cell | CellMarker::M2 microglial cell | CellMarker::Microglia-derived tumor-associated macrophage(Mg-TAM) | CellMarker::Microglia‐like cell | CellMarker::Microglial cell | CellMarker::Microglial cell | CellMarker::Microglial-specific cell | CellMarker::Pro-tumor M2 microglial cell | CellMarker::Resting microglial cell | CellMarker::Tumor-associated microglia cell | Azimuth::Motor Cortex-subclass-microglia / Perivascular Macrophage | Allen::Human Micro L1-6 TYROBP CD74 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 5  CellMarker::Oligodendrocyte precursor cell | CellMarker::Oligodendrocyte progenitor cell | Azimuth::Motor Cortex-subclass-oligodendrocyte Precursor Cell | Allen::Human OPC L1-6 PDGFRA COL20A1 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 6  CellMarker::Mature oligodendrocyte | CellMarker::Oligodendrocyte | CellMarker::Oligodendrocyte precursor cell | CellMarker::Oligodendrocyte progenitor cell | CellMarker::Oligodendrocyte‐like cell | Azimuth::Motor Cortex-subclass-oligodendrocyte | Allen::Human Oligo L2-6 OPALIN FTH1P3 up | Allen::Human Oligo L2-6 OPALIN MAP6D1 up | Allen::Human Oligo L3-6 OPALIN ENPP6 up | Allen::Human Oligo L5-6 OPALIN LDLRAP1 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 7  CellMarker::A1 astrocyte | CellMarker::A2 astrocyte | CellMarker::Astrocyte | CellMarker::Astrocyte progenitor cell | CellMarker::Fibrous astrocyte | CellMarker::Mature astrocyte | CellMarker::Mature Astrocyte | CellMarker::Pan-reactive astrocyte | CellMarker::Reactive astrocyte | CellMarker::Retinal astrocyte | Azimuth::Motor Cortex-subclass-Astrocyte | Allen::Human Astro L1 FGFR3 SERPINI2 up | Allen::Human Astro L1-6 FGFR3 AQP1 up | Allen::Human Astro L1-6 FGFR3 PLCG1 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 8  CellMarker::Broad excitatory neuron | CellMarker::Deep layer excitatory neuron | CellMarker::Excitatory neuron | CellMarker::Glutamatergic neuron | CellMarker::Superficial layer excitatory neuron | Azimuth::Motor Cortex-class-Glutamatergic Neuron | Allen::Human Exc L2 LAMP5 KCNG3 up | Allen::Human Exc L2 LINC00507 ATP7B up | Allen::Human Exc L2 LINC00507 GLRA3 up | Allen::Human Exc L2-3 LINC00507 DSG3 up | Allen::Human Exc L2-3 RORB CCDC68 up | Allen::Human Exc L3 LAMP5 CARM1P1 up | Allen::Human Exc L3 RORB OTOGL up | Allen::Human Exc L3 THEMIS ENPEP up | Allen::Human Exc L3-5 FEZF2 ASGR2 up | Allen::Human Exc L3-5 FEZF2 LINC01107 up | Allen::Human Exc L3-5 RORB LAMA4 up | Allen::Human Exc L3-5 RORB LINC01202 up | Allen::Human Exc L3-5 RORB LNX2 up | Allen::Human Exc L3-5 RORB RPRM up | Allen::Human Exc L3-5 RORB TNNT2 up | Allen::Human Exc L5 FEZF2 CSN1S1 up | Allen::Human Exc L5 FEZF2 NREP-AS1 up | Allen::Human Exc L5 FEZF2 PKD2L1 up | Allen::Human Exc L5 FEZF2 RNF144A-AS1 up | Allen::Human Exc L5 RORB MED8 up | Allen::Human Exc L5 THEMIS FGF10 up | Allen::Human Exc L5 THEMIS LINC01116 up | Allen::Human Exc L5 THEMIS RGPD6 up | Allen::Human Exc L5 THEMIS VILL up | Allen::Human Exc L5-6 FEZF2 C9orf135-AS1 up | Allen::Human Exc L5-6 FEZF2 CFTR up | Allen::Human Exc L5-6 FEZF2 FILIP1L up | Allen::Human Exc L5-6 FEZF2 IFNG-AS1 up | Allen::Human Exc L5-6 FEZF2 LPO up | Allen::Human Exc L5-6 FEZF2 OR1L8 up | Allen::Human Exc L5-6 FEZF2 SH2D1B up | Allen::Human Exc L5-6 THEMIS SMYD1 up | Allen::Human Exc L6 FEZF2 FFAR4 up | Allen::Human Exc L6 FEZF2 KLK7 up | Allen::Human Exc L6 FEZF2 PDYN up | Allen::Human Exc L6 FEZF2 POGK up | Allen::Human Exc L6 FEZF2 PROKR2 up | Allen::Human Exc L6 THEMIS LINC00343 up | Allen::Human Exc L6 THEMIS SLN up | Allen::Human Exc L6 THEMIS SNTG2 up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 9  CellMarker::GABAergic neuron | CellMarker::Inhibitory neuron | Azimuth::Motor Cortex-class-GABAergic Neuron | Allen::Human Inh L1 LAMP5 BMP2 up | Allen::Human Inh L1 LAMP5 NMBR up | Allen::Human Inh L1 LAMP5 PVRL2 up | Allen::Human Inh L1 LAMP5 RAB11FIP1 up | Allen::Human Inh L1 PAX6 MIR101-1 up | Allen::Human Inh L1 PVALB SST ASIC4 up | Allen::Human Inh L1 SST P4HA3 up | Allen::Human Inh L1 VIP KLHDC8B up | Allen::Human Inh L1-2 PVALB CDK20 up | Allen::Human Inh L1-2 SST CLIC6 up | Allen::Human Inh L1-2 SST PRRT4 up | Allen::Human Inh L1-2 VIP EXPH5 up | Allen::Human Inh L1-2 VIP HTR3A up | Allen::Human Inh L1-2 VIP PTGER3 up | Allen::Human Inh L1-2 VIP SCML4 up | Allen::Human Inh L1-2 VIP WNT4 up | Allen::Human Inh L1-3 VIP CBLN1 up | Allen::Human Inh L1-3 VIP CHRNA2 up | Allen::Human Inh L1-3 VIP FNDC1 up | Allen::Human Inh L1-5 VIP CD27-AS1 up | Allen::Human Inh L1-5 VIP LINC01013 up | Allen::Human Inh L1-5 VIP PHLDB3 up | Allen::Human Inh L1-6 LAMP5 AARD up | Allen::Human Inh L1-6 LAMP5 CA1 up | Allen::Human Inh L1-6 PVALB COL15A1 up | Allen::Human Inh L1-6 SST NPY up | Allen::Human Inh L1-6 VIP SLC7A6OS up | Allen::Human Inh L2 PAX6 FREM2 up | Allen::Human Inh L2 PVALB FRZB up | Allen::Human Inh L2 VIP SLC6A16 up | Allen::Human Inh L2-5 PVALB HHIPL1 up | Allen::Human Inh L2-5 PVALB RPH3AL up | Allen::Human Inh L2-5 VIP BSPRY up | Allen::Human Inh L2-5 VIP SOX11 up | Allen::Human Inh L3 PVALB SAMD13 up | Allen::Human Inh L3-5 PVALB ISG20 up | Allen::Human Inh L3-5 SST CDH3 up | Allen::Human Inh L3-5 VIP HS3ST3A1 up | Allen::Human Inh L3-5 VIP IGDCC3 up | Allen::Human Inh L3-6 PAX6 LINC01497 up | Allen::Human Inh L3-6 VIP UG0898H09 up | Allen::Human Inh L3-6 VIP ZIM2-AS1 up | Allen::Human Inh L5 PVALB LRIG3 up | Allen::Human Inh L5-6 LAMP5 CRABP1 up | Allen::Human Inh L5-6 PVALB FAM150B up | Allen::Human Inh L5-6 PVALB GAPDHP60 up | Allen::Human Inh L5-6 PVALB KCNIP2 up | Allen::Human Inh L5-6 PVALB MEPE up | Allen::Human Inh L5-6 PVALB SST CRHR2 up | Allen::Human Inh L5-6 PVALB ZFPM2-AS1 up | Allen::Human Inh L5-6 SST BEAN1 up | Allen::Human Inh L5-6 SST C4orf26 up | Allen::Human Inh L5-6 SST DNAJC14 up | Allen::Human Inh L5-6 SST FBN2 up | Allen::Human Inh L5-6 SST ISX up | Allen::Human Inh L5-6 SST KLHL1 up | Allen::Human Inh L5-6 SST PAWR up | Allen::Human Inh L5-6 SST PIK3CD up | Allen::Human Inh L5-6 VIP COL4A3 up | Allen::Human Inh L6 SST TH up                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# ...
# 47 CellMarker::Activated CD25+ regulatory T cell | CellMarker::Activated CD4+ T cell | CellMarker::Activated CD8+ T cell | CellMarker::Activated double-positive T cell | CellMarker::Activated effector memory CD4+ T cell | CellMarker::Activated effector memory CD8+ T cell | CellMarker::Activated memory CD8+ T cell | CellMarker::Activated memory T cell | CellMarker::Activated naive CD8+ T cell | CellMarker::Activated naive T cell | CellMarker::Activated peripheral helper T cell | CellMarker::Activated regulatory T cell | CellMarker::Activated T cell | CellMarker::Activated tissue resident memory CD4+ T cell | CellMarker::Activated tissue resident memory CD8+ T cell | CellMarker::Angiogenic T cell | CellMarker::Cancer-associated antigen-specific T cell | CellMarker::CAR-T cell | CellMarker::CD25 LAG3+ T cell | CellMarker::CD25+LAG3+ T cell | CellMarker::CD3/CD28-stimulated T cell | CellMarker::CD34+ pre-T cell | CellMarker::CD4 peripherally derived regulatory T cell | CellMarker::CD4 T cell | CellMarker::CD4-CD28- T cell | CellMarker::CD4-CD28+ T cell | CellMarker::CD4+ cytotoxic T lymphocyte | CellMarker::CD4+ recently activated effector memory or effector T cell (CTL) | CellMarker::CD4+ T cell | CellMarker::CD4+CD25+ regulatory T cell | CellMarker::CD8 T cell | CellMarker::CD8+ mucosal-associated invariant T cell(CD8+ MAIT) | CellMarker::CD8+ recently activated effector memory or effector T cell (CTL) | CellMarker::CD8+ T cell | CellMarker::CD8+ terminally differentiated effector memory re-expressing CD45RA T cell(CD8+ TEMRA) | CellMarker::CD8+ tissue-resident memory T cell | CellMarker::Central memory CD4+ T cell | CellMarker::Central memory CD8+ T cell | CellMarker::Central memory T cell | CellMarker::Central memory T cell precursor | CellMarker::Chronically activated CD4+ T cell | CellMarker::Chronically activated CD8+ T cell | CellMarker::Circulating memory T cell | CellMarker::Conventional CD4 T cell | CellMarker::Conventional CD4+ T cell | CellMarker::Conventional CD8+ T cell | CellMarker::Cytotoxic CD4+ T cell | CellMarker::Cytotoxic CD8 T cell | CellMarker::Cytotoxic CD8+ T cell | CellMarker::Cytotoxic double-positive T cell | CellMarker::Cytotoxic effector memory T cell | CellMarker::Cytotoxic effector T cell | CellMarker::Cytotoxic T cell | CellMarker::Cytotoxic T cell 2 | CellMarker::Differentiated effector T cell | CellMarker::Dividing T cell | CellMarker::Double-negative T cell | CellMarker::Double-positive T cell | CellMarker::Dysfunctional T cell | CellMarker::Early activated CD4+ T cell | CellMarker::Early activated CD8+ T cell | CellMarker::Early effector T cell | CellMarker::Early T cell progenitor (ETP) | CellMarker::Effector (EMRA) CD8+ T cell | CellMarker::Effector CD4+ T cell | CellMarker::Effector CD8 T cell | CellMarker::Effector CD8+ T cell | CellMarker::Effector memory CD4 T cell | CellMarker::Effector memory CD4+ T cell | CellMarker::Effector memory CD8 T cell | CellMarker::Effector memory CD8+ T cell | CellMarker::Effector memory T cell | CellMarker::Effector T cell | CellMarker::EMRA CD4+ T cell | CellMarker::Eomesodermin homolog(EOMES)+ regulatory T cell type 1 | CellMarker::Exhasuted CD8+ T cell | CellMarker::Exhausted CD4+ T cell | CellMarker::Exhausted CD8 + T cell | CellMarker::Exhausted CD8+ T cell | CellMarker::Exhausted double-positive T cell | CellMarker::Exhausted T cell progenitor | CellMarker::Finally highly effector (TEMRA) memory T cell | CellMarker::Follicular cytotoxic CD8+ T cell | CellMarker::Follicular helper (Tfh) T cell | CellMarker::Follicular T cell | CellMarker::Foxp3+ regulatory T cell | CellMarker::Foxp3+IL-17+ T cell | CellMarker::Gamma delta(γδ) T cell | CellMarker::GZMB+ T cell | CellMarker::GZMK+ T cell | CellMarker::Highly differentiated effector CD8 + T cell | CellMarker::IL-17Ralpha T cell | CellMarker::Intermediate exhausted T cell | CellMarker::KIR + RA + T cell | CellMarker::Mature cytotoxic T lymphocyte | CellMarker::Memory CD4 T cell | CellMarker::Memory CD4+ T  ...
#    top_pathways
# 1  CellMarker::Astrocyte || Allen::Human Astro L1 FGFR3 SERPINI2 up || Allen::Human Astro L1-6 FGFR3 PLCG1 up
# 2  Azimuth::Motor Cortex-class-Glutamatergic Neuron || CellMarker::Ciliated epithelial cell || CellMarker::Oogenesis phase fetal germ cell
# 3  CellMarker::Neuron || CellMarker::Excitatory neuron || CellMarker::Inhibitory neuron
# 4  CellMarker::Microglial cell || CellMarker::Paneth cell || CellMarker::Monocyte
# 5  CellMarker::Oligodendrocyte progenitor cell || CellMarker::Oligodendrocyte precursor cell || CellMarker::Neural crest cell
# 6  Allen::Human Oligo L3-6 OPALIN ENPP6 up || Allen::Human Oligo L5-6 OPALIN LDLRAP1 up || Allen::Human Oligo L2-6 OPALIN FTH1P3 up
# 7  CellMarker::Astrocyte || Allen::Human Astro L1 FGFR3 SERPINI2 up || Allen::Human Astro L1-6 FGFR3 PLCG1 up
# 8  CellMarker::Natural killer T (NKT) cell || Allen::Human Exc L3-5 RORB RPRM up || Allen::Human Inh L5-6 SST C4orf26 up
# 9  CellMarker::Natural killer T (NKT) cell || Allen::Human Exc L3-5 FEZF2 ASGR2 up || CellMarker::Erythroblast
# 10 CellMarker::Monocyte || CellMarker::Paneth cell || CellMarker::Microglial cell
# 11 CellMarker::Oligodendrocyte progenitor cell || CellMarker::Oligodendrocyte precursor cell || Azimuth::Motor Cortex-subclass-oligodendrocyte Precursor Cell
# 12 Allen::Human Oligo L3-6 OPALIN ENPP6 up || Allen::Human Oligo L5-6 OPALIN LDLRAP1 up || Allen::Human Oligo L2-6 OPALIN FTH1P3 up
# 13 Azimuth::Heart-L2-Adipocyte || CellMarker::Adipocyte || CellMarker::Cytotrophoblast
# 14 Azimuth::Heart-L2-Atrial Cardiomyocyte || CellMarker::Cardiomyocyte || CellMarker::Atrial cell
# 15 Azimuth::Heart-L2-Endocardial || CellMarker::Endothelial cell || Azimuth::Heart-L2-Endothelial
# 16 CellMarker::Endothelial cell || CellMarker::MKI67+ progenitor cell || CellMarker::Pan-endothelial cell
# 17 CellMarker::Mesothelial cell || CellMarker::Trophectoderm cell || CellMarker::Cancer cell
# 18 CellMarker::Natural killer T (NKT) cell
# 19 NA
# 20 CellMarker::T cell || CellMarker::Natural killer cell || CellMarker::Natural killer T (NKT) cell
# 21 CellMarker::Paneth cell || CellMarker::Microglial cell || CellMarker::Macrophage
# 22 Azimuth::Heart-L2-Mast || Azimuth::Heart-L2-ILC
# 23 NA
# 24 Azimuth::Heart-L2-Pericyte || CellMarker::Pericyte || Azimuth::Heart-L2-Mast
# 25 Azimuth::Heart-L2-Ventricular Cardiomyocyte || CellMarker::Cardiomyocyte || CellMarker::Neuron
# 26 CellMarker::Gonadal endothelial cell || CellMarker::Endothelial cell || CellMarker::Mesodermal progenitor cell
# 27 CellMarker::Secretory progenitor cell || CellMarker::Neuroectoderm cell || CellMarker::Goblet cell
# 28 Azimuth::Lung V2 (HLCA)-ann Level 2-Alveolar Epithelium || CellMarker::Alveolar epithelial cell Type 2 || CellMarker::Alveolar type II (ATII) cell
# 29 CellMarker::MKI67+ progenitor cell || CellMarker::Endothelial cell || Azimuth::Lung V2 (HLCA)-ann Level 2-Blood Vessels
# 30 CellMarker::Leydig precursor cell || CellMarker::Fibroblast || CellMarker::DCLK1+ progenitor cell
# 31 CellMarker::Lymphatic endothelial cell || CellMarker::Alveolar cell Type 1 || CellMarker::Fibroblastic reticular cell
# 32 CellMarker::Natural killer cell || CellMarker::T cell || CellMarker::Natural killer T (NKT) cell
# 33 CellMarker::Microglial cell || CellMarker::Paneth cell || CellMarker::Monocyte
# 34 CellMarker::Leydig precursor cell || CellMarker::Mitotic fetal germ cell || CellMarker::Microglial cell
# 35 CellMarker::B cell || CellMarker::Regulatory T (Treg) cell || CellMarker::Plasmacytoid dendritic cell
# 36 CellMarker::Monocyte || CellMarker::CD1C+_B dendritic cell || CellMarker::Neutrophil
# 37 CellMarker::CD1C-CD141- dendritic cell || CellMarker::Monocyte || CellMarker::Paneth cell
# 38 CellMarker::Naive CD8+ T cell || CellMarker::Naive CD4+ T cell || CellMarker::Central memory CD8+ T cell
# 39 CellMarker::T cell || CellMarker::CD8+ T cell || CellMarker::Natural killer cell
# 40 CellMarker::Monocyte || CellMarker::Neutrophil || CellMarker::CD1C+_B dendritic cell
# 41 CellMarker::Cytotoxic CD4+ T cell || CellMarker::Effector CD8+ memory T (Tem) cell || CellMarker::Natural killer cell
# 42 CellMarker::Natural killer cell || CellMarker::T cell || CellMarker::Lymphoid cell
# 43 CellMarker::Plasma cell || CellMarker::Plasmablast || CellMarker::B cell
# 44 CellMarker::B cell || CellMarker::Follicular B cell || CellMarker::Naive B cell
# 45 CellMarker::Monocyte || CellMarker::CD1C+_B dendritic cell || CellMarker::Myeloid cell
# 46 CellMarker::Natural killer cell || CellMarker::Cytotoxic CD4+ T cell || CellMarker::Effector CD8+ memory T (Tem) cell
# 47 CellMarker::Naive CD8+ T cell || CellMarker::Naive CD4+ T cell || CellMarker::Central memory CD8+ T cell
#    top_fdr                          top_gene_pct_used recovered
# 1  2.93e-28 || 1.52e-26 || 1.90e-21 0.01               TRUE
# 2  4.99e-07 || 1.47e-05 || 2.18e-02 0.01               TRUE
# 3  2.17e-03 || 6.41e-03 || 6.41e-03 0.01               TRUE
# 4  2.76e-76 || 1.29e-56 || 7.34e-28 0.01               TRUE
# 5  1.79e-07 || 3.49e-07 || 3.32e-04 0.01               TRUE
# 6  1.21e-51 || 1.68e-36 || 6.37e-28 0.01               TRUE
# 7  4.25e-48 || 3.26e-28 || 3.02e-27 0.01               TRUE
# 8  4.97e-34 || 1.11e-27 || 1.22e-22 0.01               TRUE
# 9  9.76e-06 || 7.58e-03 || 3.05e-02 0.01              FALSE
# 10 2.74e-42 || 9.90e-35 || 3.37e-31 0.01               TRUE
# 11 4.73e-11 || 1.23e-08 || 1.33e-04 0.01               TRUE
# 12 3.80e-33 || 8.72e-24 || 8.25e-15 0.01               TRUE
# 13 3.29e-12 || 6.56e-12 || 2.87e-03 0.01               TRUE
# 14 1.29e-06 || 1.29e-06 || 2.65e-04 0.01               TRUE
# 15 2.57e-10 || 3.50e-06 || 1.76e-04 0.01               TRUE
# 16 1.66e-24 || 1.12e-23 || 1.38e-12 0.01               TRUE
# 17 2.66e-04 || 1.13e-03 || 1.13e-03 0.01               TRUE
# 18 5.97e-03                         0.01              FALSE
# 19 NA                               0.03              FALSE
# 20 8.83e-71 || 4.84e-52 || 3.34e-34 0.01               TRUE
# 21 1.86e-52 || 7.62e-39 || 3.20e-35 0.01               TRUE
# 22 8.18e-05 || 1.86e-03             0.01               TRUE
# 23 NA                               0.03              FALSE
# 24 1.00e-12 || 2.08e-06 || 2.24e-04 0.01               TRUE
# 25 4.74e-05 || 9.68e-04 || 9.68e-04 0.01               TRUE
# 26 2.13e-05 || 4.02e-05 || 2.17e-02 0.01              FALSE
# 27 4.00e-06 || 7.91e-05 || 4.46e-04 0.01               TRUE
# 28 1.24e-06 || 1.04e-05 || 1.04e-05 0.01               TRUE
# 29 2.74e-38 || 2.64e-37 || 4.73e-16 0.01               TRUE
# 30 3.49e-38 || 1.54e-33 || 2.47e-31 0.01               TRUE
# 31 7.02e-03 || 3.64e-02 || 3.64e-02 0.03               TRUE
# 32 4.88e-41 || 3.00e-38 || 1.82e-31 0.01               TRUE
# 33 7.66e-23 || 1.55e-11 || 5.23e-09 0.01               TRUE
# 34 1.07e-13 || 1.95e-12 || 7.24e-08 0.01              FALSE
# 35 7.19e-35 || 1.03e-03 || 7.52e-03 0.01               TRUE
# 36 2.73e-69 || 7.47e-43 || 1.67e-27 0.01               TRUE
# 37 2.53e-61 || 1.01e-36 || 4.30e-19 0.01               TRUE
# 38 1.05e-61 || 2.60e-36 || 7.07e-17 0.01               TRUE
# 39 1.14e-26 || 2.37e-17 || 1.25e-15 0.01               TRUE
# 40 2.32e-45 || 2.21e-30 || 2.38e-29 0.01               TRUE
# 41 7.75e-29 || 9.54e-21 || 5.76e-10 0.01              FALSE
# 42 1.15e-30 || 1.53e-11 || 1.24e-10 0.01               TRUE
# 43 2.78e-50 || 6.16e-20 || 2.28e-18 0.01               TRUE
# 44 4.91e-77 || 2.29e-14 || 2.29e-14 0.01               TRUE
# 45 3.07e-27 || 6.13e-13 || 1.54e-10 0.01               TRUE
# 46 6.99e-41 || 2.24e-27 || 5.77e-16 0.01               TRUE
# 47 9.23e-23 || 6.31e-15 || 3.23e-09 0.01               TRUE

# %%
# Pooled-marker-set ORA (module_results$marker_sets, the combined resources),
# used for the recovery dot-grid plot below: rows = every candidate cell type
# in the dataset, giving the full specificity picture per LV. Column labels
# reuse Table 1's single top (rank-1) pathway per LV instead of the coarse
# alias-group name.
build_term2gene <- function(marker_sets) {
    dplyr::bind_rows(lapply(names(marker_sets), function(ct) {
        data.frame(term = ct, gene = marker_sets[[ct]], stringsAsFactors = FALSE)
    }))
}

run_ora_enrichment <- function(selected_lvs_df, Z, term2gene, universe, top_pct) {
    do.call(rbind, lapply(seq_len(nrow(selected_lvs_df)), function(i) {
        row       <- selected_lvs_df[i, ]
        top_genes <- get_top_genes(Z, row$LV, top_pct)
        res <- tryCatch(
            clusterProfiler::enricher(gene = top_genes, universe = universe,
                                      TERM2GENE = term2gene, pvalueCutoff = 1,
                                      qvalueCutoff = 1, minGSSize = 1, maxGSSize = Inf),
            error = function(e) NULL)
        if (is.null(res) || nrow(res@result) == 0) return(NULL)
        rdf <- res@result
        data.frame(lv_cell_type = row$cell_type, LV = row$LV,
                  marker_cell_type = rdf$ID, Count = rdf$Count,
                  pvalue = rdf$pvalue, FDR = rdf$p.adjust, stringsAsFactors = FALSE)
    }))
}

run_enrichment_for_datasets <- function(results_list, fun, ...) {
    dplyr::bind_rows(lapply(names(results_list), function(ds) {
        res       <- results_list[[ds]]
        z_path    <- file.path(MOD_ROOT, ds, "models", res$method, "Z.csv")
        Z         <- read.csv(z_path, row.names = 1, check.names = FALSE)
        term2gene <- build_term2gene(res$marker_sets)
        enr <- fun(res$selected, Z, term2gene, res$universe, ...)
        if (is.null(enr) || nrow(enr) == 0) return(NULL)
        enr$marker_reference_terms <- vapply(enr$marker_cell_type, function(ct)
            paste(target_reference_terms(ds, ct), collapse = " | "), character(1))
        cbind(dataset = ds, marker_source = res$marker_source, enr)
    }))
}

enrichment_res <- run_enrichment_for_datasets(module_results, run_ora_enrichment, TOP_GENE_PCT)
# No significance filter and no hardcoded cap on neg_log10_fdr -- size reflects
# the true, continuous -log10(FDR) for every tested pair. A near-miss (e.g.
# Brain_Mathys2023 Excitatory neurons/LV19: own-set FDR = 0.068, one-vs-rest
# effect strongly significant at q=1e-8) still renders as a small-but-real dot
# instead of being deleted outright, while a truly null result (FDR ~ 1, e.g.
# PBMC_1k1k CD8+ T cells/LV57's own set) naturally shrinks to near-invisible
# without needing a hard cutoff. Only genuine zero-overlap pairs (enricher()
# returns nothing at all) are absent here, later filled blank by
# tidyr::complete() in the plot below.
enrichment_res$neg_log10_fdr <- -log10(enrichment_res$FDR + 1e-300)

# Column labels show the best significant term from any applicable marker
# resource that is mapped to the true cell type.
LABEL_MAX_TERMS <- 2
pick_label_hit <- function(dataset, cell_type, top_str, top_fdr_str) {
    if (is.na(top_str) || is.na(top_fdr_str))
        return(data.frame(top1_pathway = NA_character_, top1_fdr = NA_real_))
    paths <- strsplit(top_str, ORA_TERM_SEP, fixed = TRUE)[[1]]
    fdrs  <- as.numeric(strsplit(top_fdr_str, ORA_TERM_SEP, fixed = TRUE)[[1]])
    matches <- paths %in% target_reference_terms(dataset, cell_type)
    if (any(matches)) {
        ord   <- order(fdrs[matches])
        keep  <- head(ord, LABEL_MAX_TERMS)
        label <- paste(paths[matches][keep], collapse = " - ")
        fdr   <- min(fdrs[matches])
    } else {
        label <- paths[1]
        fdr   <- fdrs[1]
    }
    data.frame(top1_pathway = label, top1_fdr = fdr, stringsAsFactors = FALSE)
}
top_pathway_hits <- dplyr::bind_rows(mapply(
    pick_label_hit, top_pathway_df$dataset, top_pathway_df$cell_type,
    top_pathway_df$top_pathways, top_pathway_df$top_fdr,
    SIMPLIFY = FALSE
))
top_pathway_df$top1_pathway <- top_pathway_hits$top1_pathway
top_pathway_df$top1_fdr     <- top_pathway_hits$top1_fdr

shorten_marker_label <- function(x) {
    out <- sub("^(CellMarker|Azimuth|Allen)::", "", x)
    out <- sub("^(PBMC-L[123]|Motor Cortex-(class|subclass)|Heart-L[12]|Lung V2 \\(HLCA\\)-ann Level [12])-",
               "", out)
    out <- sub("microglia / Perivascular Macrophage", "Microglia", out,
               fixed = TRUE)
    out <- sub("^natural Killer Cell$", "Natural killer cell", out)
    out
}

# NA (nothing significant) shows only the LV code, never the true cell type.
top_pathway_df$top_pathway_label <- ifelse(
    is.na(top_pathway_df$top1_pathway), top_pathway_df$LV,
    shorten_marker_label(top_pathway_df$top1_pathway)
)

cat("Combined marker ORA enrichment tests (pooled sets):",
    nrow(enrichment_res), "\n")
# Out:
# Combined marker ORA enrichment tests (pooled sets): 336

# %%
lv_effect_all <- dplyr::bind_rows(lapply(names(module_results), function(ds) {
    res <- module_results[[ds]]
    ovr_lookup <- if (nrow(res$ovr) > 0) res$ovr[, c("cell_type", "LV", "effect")] else
        data.frame(cell_type = character(), LV = character(), effect = numeric())
    names(ovr_lookup) <- c("marker_cell_type", "LV", "ovr_effect")
    corr_lookup <- lv_corr_full[lv_corr_full$dataset == ds, c("LV", "cell_type", "cor")]
    names(corr_lookup) <- c("LV", "marker_cell_type", "corr_effect")

    eff <- merge(corr_lookup, ovr_lookup, by = c("marker_cell_type", "LV"), all = TRUE)
    eff$row_effect <- ifelse(!is.na(eff$ovr_effect), eff$ovr_effect, eff$corr_effect)
    eff <- eff[!is.na(eff$row_effect), c("marker_cell_type", "LV", "row_effect")]
    cbind(dataset = ds, eff)
}))

enr_all <- dplyr::bind_rows(lapply(names(module_results), function(ds) {
    res <- module_results[[ds]]
    enr <- enrichment_res[enrichment_res$dataset == ds, ]
    if (nrow(res$selected) == 0 || nrow(enr) == 0) return(NULL)

    eff <- lv_effect_all[lv_effect_all$dataset == ds,
                         c("dataset", "marker_cell_type", "LV", "row_effect")]
    merge(enr, eff, by = c("dataset", "marker_cell_type", "LV"), all.x = TRUE)
}))

Z_LIM <- max(abs(lv_effect_all$row_effect), na.rm = TRUE)
recovered_top_q <- -log10(top_pathway_df$top1_fdr[top_pathway_df$recovered %in% TRUE] + 1e-300)
Q_LIM <- max(c(enr_all$neg_log10_fdr, recovered_top_q), na.rm = TRUE)

module_panels <- lapply(names(module_results), function(ds) {
    res <- module_results[[ds]]
    sel <- res$selected
    enr <- enr_all[enr_all$dataset == ds, ]
    if (nrow(sel) == 0 || nrow(enr) == 0) return(NULL)

    ct_order <- sort(sel$cell_type)

    tp_ds  <- top_pathway_df[top_pathway_df$dataset == ds, ]
    tp_lut <- setNames(tp_ds$top_pathway_label, tp_ds$cell_type)
    col_labels <- setNames(
        ifelse(tp_lut[sel$cell_type] == sel$LV, sel$LV, paste0(tp_lut[sel$cell_type], " - ", sel$LV)),
        sel$cell_type)
    enr <- enr[enr$marker_cell_type %in% ct_order, ]
    enr$lv_col_label     <- factor(col_labels[enr$lv_cell_type], levels = unname(col_labels[ct_order]))
    enr$marker_row_label <- factor(ct_label(enr$marker_cell_type), levels = ct_label(ct_order))

    row_label_to_ct <- setNames(ct_order, ct_label(ct_order))
    col_label_to_lv <- setNames(sel$LV, unname(col_labels[sel$cell_type]))

    enr <- tidyr::complete(enr, marker_row_label, lv_col_label,
                           fill = list(neg_log10_fdr = 0))
    enr$marker_cell_type <- row_label_to_ct[as.character(enr$marker_row_label)]
    enr$LV               <- col_label_to_lv[as.character(enr$lv_col_label)]
    enr$lv_cell_type      <- sel$cell_type[match(enr$LV, sel$LV)]
    enr$is_diagonal       <- enr$lv_cell_type == enr$marker_cell_type

    enr$row_effect <- NULL
    effect_lookup <- lv_effect_all[lv_effect_all$dataset == ds,
                                   c("marker_cell_type", "LV", "row_effect")]
    enr <- merge(enr, effect_lookup, by = c("marker_cell_type", "LV"), all.x = TRUE)
    enr$row_effect[is.na(enr$row_effect)] <- 0

    rec_lookup <- top_pathway_df[top_pathway_df$dataset == ds,
                                 c("cell_type", "LV", "recovered", "top1_fdr")]
    names(rec_lookup) <- c("lv_cell_type", "LV", "recovered", "top1_fdr")
    enr <- merge(enr, rec_lookup, by = c("lv_cell_type", "LV"), all.x = TRUE)
    enr$top1_neg_log10_fdr <- -log10(enr$top1_fdr + 1e-300)
    recover_idx <- enr$is_diagonal %in% TRUE & enr$recovered %in% TRUE &
                   !is.na(enr$top1_neg_log10_fdr)
    enr$neg_log10_fdr[recover_idx] <- pmax(enr$neg_log10_fdr[recover_idx],
                                           enr$top1_neg_log10_fdr[recover_idx])
    diag_recovered <- enr[enr$is_diagonal %in% TRUE & enr$recovered %in% TRUE, ]

    n_samples <- nrow(read.csv(truth_v0_path(ds), row.names = 1, check.names = FALSE))

    panel_plot <- ggplot(enr, aes(x = lv_col_label, y = marker_row_label)) +
        geom_point(aes(size = neg_log10_fdr, color = row_effect)) +
        { if (nrow(diag_recovered) > 0)
            geom_point(data = diag_recovered, aes(size = neg_log10_fdr),
                       shape = 1, color = "black", stroke = 1.3) } +
        scale_size_continuous(limits = c(0, Q_LIM), range = c(1, 9),
                              name = expression("Combined marker ORA " * -log[10] ~ "(FDR)")) +
        scale_color_gradientn(colors = c("#b2182b", "#f4a582", "#f7f7f7", "#a1d99b", "#007a33"),
                              values = c(0, 0.35, 0.5, 0.65, 1),
                              limits = c(-Z_LIM, Z_LIM),
                              name = "LV effect\n(one-vs-rest,\nor r fallback)") +
        scale_x_discrete(drop = FALSE) +
        scale_y_discrete(drop = FALSE) +
        theme_bw(base_size = 9) +
        theme(axis.text.x = element_text(angle = 45, hjust = 1),
              plot.title  = element_text(face = "bold", size = 10, hjust = 0.5)) +
        labs(x = NULL, y = NULL, title = paste0(ds, " (n = ", n_samples, " samples)"))

    panel_export <- data.frame(
        dataset          = ds,
        marker_source    = res$marker_source,
        marker_row_label = as.character(enr$marker_row_label),
        marker_row_rank  = as.integer(enr$marker_row_label),
        lv_col_label     = as.character(enr$lv_col_label),
        lv_col_rank      = as.integer(enr$lv_col_label),
        neg_log10_fdr    = enr$neg_log10_fdr,
        row_effect       = enr$row_effect,
        diag_recovered   = enr$is_diagonal %in% TRUE & enr$recovered %in% TRUE,
        n_samples        = n_samples,
        Z_LIM            = Z_LIM,
        Q_LIM            = Q_LIM,
        stringsAsFactors = FALSE
    )

    list(plot = panel_plot, data = panel_export)
})
module_panels <- Filter(Negate(is.null), module_panels)

module_panel_export <- dplyr::bind_rows(lapply(module_panels, `[[`, "data"))

options(repr.plot.width = 20, repr.plot.height = 12)
p_module <- wrap_plots(lapply(module_panels, `[[`, "plot"), ncol = 3, guides = "collect") &
    theme(legend.position = "right")
print(p_module)
# Out:
# plot without title

# %%
write.csv(ovr_all_df,        file.path(OUT_DIR, "module_ovr_specificity.csv"),        row.names = FALSE)
write.csv(selected_all_df,   file.path(OUT_DIR, "module_selected_lvs.csv"),           row.names = FALSE)
write.csv(top_pathway_table, file.path(OUT_DIR, "module_top_pathways.csv"),           row.names = FALSE)
write.csv(enr_all,           file.path(OUT_DIR, "marker_enrichment_long.csv"),         row.names = FALSE)
write.csv(lv_effect_all,     file.path(OUT_DIR, "lv_marker_effects.csv"),              row.names = FALSE)
write.csv(top_pathway_df,    file.path(OUT_DIR, "marker_pathway_recovery.csv"),        row.names = FALSE)
write.csv(module_panel_export, file.path(OUT_DIR, "module_panel_ready.csv"),        row.names = FALSE)

cat("Module-level marker recovery outputs saved to:", OUT_DIR, "\n")
# Out:
# Module-level marker recovery outputs saved to: /home/msubirana/Documents/pivlab/clamp-analyses-revert/output/03_model_biology/00_pseudobulk/02_disentangle

# %% [markdown]
# ## Save outputs

# %%
write.csv(top_lvs_df, file.path(OUT_DIR, "top_lvs_per_celltype.csv"), row.names = FALSE)
write.csv(
  top_lvs_df %>% dplyr::select(dataset, cell_type, LV, cor,
                                r_next_best_ct, r_next_best_lv, margin_ct, margin_lv),
  file.path(OUT_DIR, "lv_specificity_margins.csv"), row.names = FALSE
)
write.csv(assignment_quality, file.path(OUT_DIR, "lv_assignment_quality.csv"), row.names = FALSE)
write.csv(assignment_quality_by_dataset, file.path(OUT_DIR, "lv_assignment_quality_by_dataset.csv"), row.names = FALSE)

cat("All outputs saved to:", OUT_DIR, "\n")
# Out:
# All outputs saved to: /home/msubirana/Documents/pivlab/clamp-analyses-revert/output/03_model_biology/00_pseudobulk/02_disentangle
