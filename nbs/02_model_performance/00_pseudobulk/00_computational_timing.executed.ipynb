# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/MOFA-FLEX/seed_789.csv', 'workflow/config/pseudobulk.yaml', 'workflow/config/runtime_benchmark.yaml', 'config.yaml', '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb', "timings" = c('output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Mathys2023/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Brain_Xiong2023/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Heart_Datar2026/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_1k1k/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/PBMC_Perez2022/MOFA-FLEX/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPfull/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPfull/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPfull/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPbase/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPbase/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CLAMPbase/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PLIER/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PLIER/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PLIER/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CoGAPS/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CoGAPS/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/CoGAPS/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/Flashier/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/Flashier/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/Flashier/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/NMF/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/NMF/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/NMF/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PCA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PCA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/PCA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/ICA/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/ICA/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/ICA/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/GSSig/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/GSSig/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/GSSig/seed_789.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/MOFA-FLEX/seed_123.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/MOFA-FLEX/seed_456.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/timings/Lung_Sikkema2023/MOFA-FLEX/seed_789.csv'), "pseudobulk_config" = 'workflow/config/pseudobulk.yaml', "runtime_config" = 'workflow/config/runtime_benchmark.yaml', "figure_config" = 'config.yaml', "notebook" = '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb'),
    output = list('output/02_model_performance/00_pseudobulk/00_computational_timing/runtime_long.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/runtime_seed_totals.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/runtime_summary.csv', 'output/02_model_performance/00_pseudobulk/00_computational_timing/notebook.complete', "long" = 'output/02_model_performance/00_pseudobulk/00_computational_timing/runtime_long.csv', "seed_totals" = 'output/02_model_performance/00_pseudobulk/00_computational_timing/runtime_seed_totals.csv', "summary" = 'output/02_model_performance/00_pseudobulk/00_computational_timing/runtime_summary.csv', "complete" = 'output/02_model_performance/00_pseudobulk/00_computational_timing/notebook.complete'),
    params = list(c('Brain_Mathys2023', 'Brain_Xiong2023', 'Heart_Datar2026', 'PBMC_1k1k', 'PBMC_Perez2022', 'Lung_Sikkema2023'), c('CLAMPfull', 'CLAMPbase', 'PLIER', 'CoGAPS', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), c(123, 456, 789), 'output/02_model_performance/00_pseudobulk/00_computational_timing', "datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023', 'Heart_Datar2026', 'PBMC_1k1k', 'PBMC_Perez2022', 'Lung_Sikkema2023'), "methods" = c('CLAMPfull', 'CLAMPbase', 'PLIER', 'CoGAPS', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), "seeds" = c(123, 456, 789), "out_dir" = 'output/02_model_performance/00_pseudobulk/00_computational_timing'),
    wildcards = list(),
    threads = 1,
    log = list('output/02_model_performance/00_pseudobulk/00_computational_timing/00_computational_timing.executed.ipynb', "notebook" = 'output/02_model_performance/00_pseudobulk/00_computational_timing/00_computational_timing.executed.ipynb'),
    resources = list('tmpdir', "tmpdir" = '/tmp'),
    config = list("datasets" = list("Brain_Mathys2023" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/Brain_Mathys2023', "kind" = 'matrix_market', "raw" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz', "features" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz', "barcodes" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz', "metadata" = 'data/pseudobulk/raw/Brain_Mathys2023/meta.tsv', "cell_id_col" = 'cellName', "sample_col" = 'Individual', "sample_transform" = 'identity', "truth_v0_col" = 'Major_Cell_Type', "truth_v1_col" = 'Cell_Type', "raw_cell_type_col" = 'Major_Cell_Type', "projection_label_col" = 'Major_Cell_Type', "cohort_manifest" = 'data/pseudobulk/Brain_Mathys2023/patient_info.csv'), "Brain_Xiong2023" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/Brain_Xiong2023', "kind" = 'matrix_market', "raw" = 'data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz', "features" = 'data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz', "barcodes" = 'data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz', "metadata" = 'data/pseudobulk/raw/Brain_Xiong2023/meta.tsv', "cell_id_col" = 'cellId', "sample_col" = 'Individual', "sample_transform" = 'hyphen_to_underscore', "truth_v0_col" = 'Celltype', "truth_v1_col" = 'Subcelltype', "raw_cell_type_col" = 'Celltype', "projection_label_col" = 'Celltype', "cohort_manifest" = 'data/pseudobulk/Brain_Xiong2023/patient_info.csv'), "Heart_Datar2026" = list("build_pseudobulk" = TRUE, "kind" = 'h5ad', "raw" = 'data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad', "matrix" = 'X', "sample_col" = 'donor_id', "sample_transform" = 'identity', "truth_v0_col" = 'cell_type__ontology_label', "raw_cell_type_col" = 'cell_type__ontology_label', "projection_label_col" = 'cell_type__ontology_label', "min_cells" = 400, "exclude" = list("cell_type__ontology_label" = c('cell')), "truth_v0_map" = list("adipocyte" = 'Adipocyte', "regular atrial cardiac myocyte" = 'AtrialCM', "endocardial cell" = 'Endocardial', "cardiac endothelial cell" = 'Endothelial', "mesothelial cell of epicardium" = 'Epicardial', "fibroblast of cardiac tissue" = 'Fibroblast', "endothelial cell of lymphatic vessel" = 'LymphaticEndothelial', "lymphocyte" = 'Lymphocyte', "macrophage" = 'Macrophage', "mast cell" = 'Mast', "cardiac neuron" = 'Neuronal', "pericyte" = 'Pericyte', "vascular associated smooth muscle cell" = 'VSMC', "regular ventricular cardiac myocyte" = 'VentricularCM'), "projection_label_map" = list("adipocyte" = 'Adipocyte', "regular atrial cardiac myocyte" = 'AtrialCM', "endocardial cell" = 'Endocardial', "cardiac endothelial cell" = 'Endothelial', "mesothelial cell of epicardium" = 'Epicardial', "fibroblast of cardiac tissue" = 'Fibroblast', "endothelial cell of lymphatic vessel" = 'LymphaticEndothelial', "lymphocyte" = 'Lymphocyte', "macrophage" = 'Macrophage', "mast cell" = 'Mast', "cardiac neuron" = 'Neuronal', "pericyte" = 'Pericyte', "vascular associated smooth muscle cell" = 'VSMC', "regular ventricular cardiac myocyte" = 'VentricularCM')), "PBMC_1k1k" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/PBMC_1k1k', "kind" = 'h5ad', "raw" = 'data/pseudobulk/raw/PBMC_1k1k/PBMC_1k1k_raw.h5ad', "matrix" = 'X', "sample_col" = 'donor_id', "sample_transform" = 'sample_prefix_hyphen_to_underscore', "truth_v0_col" = 'predicted.celltype.l2', "raw_cell_type_col" = 'predicted.celltype.l2', "projection_label_col" = 'predicted.celltype.l2', "cohort_manifest" = 'data/pseudobulk/PBMC_1k1k/patient_info.csv', "truth_v0_map" = list("CD4 CTL" = 'CD4_T', "CD4 Naive" = 'CD4_T', "CD4 Proliferating" = 'CD4_T', "CD4 TCM" = 'CD4_T', "CD4 TEM" = 'CD4_T', "Treg" = 'CD4_T', "CD8 Naive" = 'CD8_T', "CD8 Proliferating" = 'CD8_T', "CD8 TCM" = 'CD8_T', "CD8 TEM" = 'CD8_T', "gdT" = 'gd_T', "B intermediate" = 'B_cell', "B memory" = 'B_cell', "B naive" = 'B_cell', "Plasmablast" = 'Plasma_B', "CD14 Mono" = 'CD14_Mono', "CD16 Mono" = 'CD16_Mono', "cDC1" = 'DC', "cDC2" = 'DC', "ASDC" = 'DC', "NK" = 'NK', "NK Proliferating" = 'NK', "NK_CD56bright" = 'NK'), "projection_label_map" = list("CD4 CTL" = 'CD4_T', "CD4 Naive" = 'CD4_T', "CD4 Proliferating" = 'CD4_T', "CD4 TCM" = 'CD4_T', "CD4 TEM" = 'CD4_T', "Treg" = 'CD4_T', "CD8 Naive" = 'CD8_T', "CD8 Proliferating" = 'CD8_T', "CD8 TCM" = 'CD8_T', "CD8 TEM" = 'CD8_T', "gdT" = 'gd_T', "B intermediate" = 'B_cell', "B memory" = 'B_cell', "B naive" = 'B_cell', "Plasmablast" = 'Plasma_B', "CD14 Mono" = 'CD14_Mono', "CD16 Mono" = 'CD16_Mono', "cDC1" = 'DC', "cDC2" = 'DC', "ASDC" = 'DC', "NK" = 'NK', "NK Proliferating" = 'NK', "NK_CD56bright" = 'NK')), "PBMC_Perez2022" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/PBMC_Perez2022', "kind" = 'h5ad', "raw" = 'data/pseudobulk/raw/PBMC_Perez2022/PBMC_Perez2022_raw.h5ad', "matrix" = 'raw.X', "sample_col" = 'ind_cov', "sample_transform" = 'sample_prefix_hyphen_to_underscore', "truth_v0_col" = 'cell_type', "raw_cell_type_col" = 'cell_type', "projection_label_col" = 'cell_type', "cohort_manifest" = 'data/pseudobulk/PBMC_Perez2022/patient_info.csv', "truth_v0_map" = list("B cell" = 'B_cell', "plasmablast" = 'B_cell', "classical monocyte" = 'Myeloid', "non-classical monocyte" = 'Myeloid', "conventional dendritic cell" = 'Myeloid', "plasmacytoid dendritic cell" = 'Myeloid', "progenitor cell" = 'Myeloid', "natural killer cell" = 'NK', "CD4-positive, alpha-beta T cell" = 'T_cell', "CD8-positive, alpha-beta T cell" = 'T_cell', "lymphocyte" = 'T_cell'), "projection_label_map" = list("B cell" = 'B_cell', "plasmablast" = 'B_cell', "classical monocyte" = 'Myeloid', "non-classical monocyte" = 'Myeloid', "conventional dendritic cell" = 'Myeloid', "plasmacytoid dendritic cell" = 'Myeloid', "progenitor cell" = 'Myeloid', "natural killer cell" = 'NK', "CD4-positive, alpha-beta T cell" = 'T_cell', "CD8-positive, alpha-beta T cell" = 'T_cell', "lymphocyte" = 'T_cell')), "Lung_Sikkema2023" = list("build_pseudobulk" = TRUE, "kind" = 'h5ad', "raw" = 'data/pseudobulk/Lung_Sikkema2023/lung_HLCA.h5ad', "matrix" = 'raw.X', "sample_col" = 'donor_id', "sample_transform" = 'identity', "truth_v0_col" = 'ann_level_2', "truth_v1_col" = 'ann_finest_level', "raw_cell_type_col" = 'ann_level_3', "projection_label_col" = 'ann_level_2', "min_cells" = 400)), "methods" = list("CLAMPbase" = 'CLAMPbase/B.csv', "CLAMPfull" = 'CLAMPfull/B.csv', "PLIER" = 'PLIER/B.csv', "PCA" = 'PCA/B.csv', "NMF" = 'NMF/B.csv', "ICA" = 'ICA/B.csv', "Flashier" = 'flashier/B.csv', "MOFA-FLEX" = 'MOFA_FLEX_PRIOR/B.csv', "GSSig" = 'GSS/B.csv', "CoGAPS" = 'CoGAPS/B.csv'), "paths" = list("production" = 'output/01_model_building/00_pseudobulk', "biology" = 'output/03_model_biology/00_pseudobulk', "model_notebooks" = 'nbs/01_model_building/00_pseudobulk', "biology_notebooks" = 'nbs/03_model_biology/00_pseudobulk', "panels" = 'output/99_panels', "panels_notebooks" = 'nbs/99_panels'), "references" = list("go_bp_url" = 'https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025', "go_bp_file" = 'output/01_model_building/00_pseudobulk/references/GO_Biological_Process_2025.gmt', "go_bp_sha256" = '0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee', "cell_marker_file" = 'data/pathways/Cell_marker_Human.xlsx', "allen_brain_gmt_file" = 'data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt', "brain_datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023')), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "seed" = 123), "clamp" = list("max_iter" = 500, "seed" = 123), "grouped_cv" = list("n_folds" = 5, "group_col" = 'sample', "split_seed" = 42, "min_train_lv_cor" = 0.5, "bootstrap_seed" = 123, "bootstrap_replicates" = 10000), "flashier" = list("backfit_maxiter" = 10), "cogaps" = list("n_iterations" = 5000, "n_threads" = 4, "seed" = 123), "mofa_flex" = list("max_epochs" = 200, "seed" = 123), "projection" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "top_fraction" = 0.01), "gtex" = list("raw_url" = 'https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', "raw_gz" = 'data/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', "metadata" = 'data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt', "paths" = list("production" = 'output/01_model_building/01_gtex', "biology" = 'output/03_model_biology/01_gtex', "model_notebooks" = 'nbs/01_model_building/01_gtex', "biology_notebooks" = 'nbs/03_model_biology/01_gtex'), "raw_data" = list("chunk_size" = 100, "n_cores" = 1), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "seed" = 123), "clamp" = list("max_iter" = 500, "seed" = 123), "flashier" = list("backfit_maxiter" = 20), "mofa_flex_prior" = list("msigdb_category" = 'c5.go.bp', "msigdb_dbver" = '2026.1.Hs', "min_fraction" = 0.4, "min_count" = 40, "max_count" = 200, "similarity_threshold" = 0.8, "max_epochs" = 1000, "seed" = 123), "cogaps" = list("n_iterations" = 5000, "n_threads" = 4, "seed" = 123, "timeout_days" = 7), "gss" = list("d_cluster" = 4, "seed" = 123), "kmeans_clustering" = list("min_samples" = 50, "ari_min_samples" = 1, "base_seed" = 10000, "n_reps_per_k" = 50, "gene_fractions" = c(1.0, 0.75, 0.5, 0.25, 0.1, 0.05, 0.01)), "lv_importance" = list("global_seed" = 42, "min_rf_accuracy" = 0.9), "subtissue_inference" = list("n_folds" = 5, "global_seed" = 42, "min_rf_accuracy" = 0.85, "min_subtissue_samples" = 20, "n_jobs_per_fold" = 8, "anatomical_spec" = 'workflow/config/gtex_anatomical_subtissues.tsv', "permutation_repeats" = 1000, "bootstrap_repeats" = 1000, "evaluation_jobs" = 8, "tissues" = c('Adipose Tissue', 'Blood', 'Blood Vessel', 'Brain', 'Colon', 'Esophagus', 'Heart', 'Kidney', 'Skin'))), "runtime_benchmark" = list("seeds" = c(123, 456, 789), "threads" = 4, "methods" = c('CLAMPfull', 'CLAMPbase', 'PLIER', 'CoGAPS', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), "output_root" = 'output/02_model_performance/00_pseudobulk/00_computational_timing', "notebook" = 'nbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb')),
    rule = 'computational_timing_report_pseudobulk',
    bench_iteration = as.numeric(NA),
    scriptdir = '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/02_model_performance/00_pseudobulk',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
setwd('/home/msubirana/Documents/pivlab/clamp-analyses');

######## snakemake preamble end #########

# %% [markdown]
# # Pooled pseudobulk computational timing
#
# Aggregate the controlled dataset/method/seed timing records. Each plotted observation is the total wall time for one seed summed across all six production pseudobulk datasets.

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %%
suppressPackageStartupMessages({
  library(data.table)
  library(ggplot2)
  library(yaml)
  library(here)
  library(scales)
})

# %%
if (exists("snakemake")) {
  timing_paths <- as.character(snakemake@input[["timings"]])
  expected_datasets <- as.character(snakemake@params[["datasets"]])
  expected_methods <- as.character(snakemake@params[["methods"]])
  expected_seeds <- as.integer(snakemake@params[["seeds"]])
  out_long <- snakemake@output[["long"]]
  out_seed_totals <- snakemake@output[["seed_totals"]]
  out_summary <- snakemake@output[["summary"]]
} else {
  workflow_cfg <- yaml::read_yaml(here("workflow/config/pseudobulk.yaml"))
  runtime_cfg <- yaml::read_yaml(here("workflow/config/runtime_benchmark.yaml"))$runtime_benchmark
  expected_datasets <- names(workflow_cfg$datasets)
  expected_methods <- unlist(runtime_cfg$methods, use.names = FALSE)
  expected_seeds <- as.integer(unlist(runtime_cfg$seeds, use.names = FALSE))
  out_dir <- Sys.getenv("CLAMP_TIMING_ROOT", unset = here(runtime_cfg$output_root))
  timing_paths <- list.files(file.path(out_dir, "timings"), pattern = "[.]csv$",
                            recursive = TRUE, full.names = TRUE)
  out_long <- file.path(out_dir, "runtime_long.csv")
  out_seed_totals <- file.path(out_dir, "runtime_seed_totals.csv")
  out_summary <- file.path(out_dir, "runtime_summary.csv")
}

expected_runs <- length(expected_datasets) * length(expected_methods) * length(expected_seeds)
stopifnot(length(timing_paths) == expected_runs)

# %% [markdown]
# ## Validate and aggregate all 180 fits

# %%
runtime_long <- rbindlist(lapply(timing_paths, fread), use.names = TRUE, fill = TRUE)
required_columns <- c("dataset", "method", "seed", "threads", "n_genes",
                      "n_samples", "elapsed_seconds", "started_at",
                      "finished_at", "command", "status", "exit_code")
stopifnot(all(required_columns %in% names(runtime_long)))
stopifnot(nrow(runtime_long) == expected_runs)
stopifnot(uniqueN(runtime_long, by = c("dataset", "method", "seed")) == expected_runs)
stopifnot(setequal(runtime_long$dataset, expected_datasets))
stopifnot(setequal(runtime_long$method, expected_methods))
stopifnot(setequal(as.integer(runtime_long$seed), expected_seeds))
stopifnot(all(runtime_long$threads == 4L))
stopifnot(all(runtime_long$status == "success"), all(runtime_long$exit_code == 0L))
stopifnot(all(is.finite(runtime_long$elapsed_seconds)), all(runtime_long$elapsed_seconds > 0))

coverage <- runtime_long[, .(n_datasets = uniqueN(dataset), n_runs = .N), by = .(method, seed)]
stopifnot(nrow(coverage) == length(expected_methods) * length(expected_seeds))
stopifnot(all(coverage$n_datasets == length(expected_datasets)))
stopifnot(all(coverage$n_runs == length(expected_datasets)))

runtime_seed_totals <- runtime_long[, .(
  total_seconds = sum(elapsed_seconds),
  total_minutes = sum(elapsed_seconds) / 60,
  n_datasets = uniqueN(dataset),
  n_runs = .N
), by = .(method, seed)]
stopifnot(nrow(runtime_seed_totals) == 30L)
stopifnot(all(runtime_seed_totals$n_datasets == 6L), all(runtime_seed_totals$n_runs == 6L))

runtime_summary <- runtime_seed_totals[, .(
  n_seeds = .N,
  median_minutes = median(total_minutes),
  q1_minutes = as.numeric(quantile(total_minutes, 0.25)),
  q3_minutes = as.numeric(quantile(total_minutes, 0.75)),
  min_minutes = min(total_minutes),
  max_minutes = max(total_minutes)
), by = method]
stopifnot(nrow(runtime_summary) == 10L, all(runtime_summary$n_seeds == 3L))
timing_method_order <- runtime_summary[order(median_minutes), method]
runtime_seed_totals[, method := factor(method, levels = timing_method_order)]
setorder(runtime_seed_totals, method, seed)
setorder(runtime_summary, median_minutes)

for (path in c(out_long, out_seed_totals, out_summary)) {
  dir.create(dirname(path), recursive = TRUE, showWarnings = FALSE)
}
fwrite(runtime_long, out_long)
fwrite(runtime_seed_totals, out_seed_totals)
fwrite(runtime_summary, out_summary)

# %% [markdown]
# ## Total runtime across the six datasets

# %%
figure_cfg <- yaml::read_yaml(here("config.yaml"))
method_colors <- unlist(figure_cfg$MODEL_COLORS)
names(method_colors)[names(method_colors) == "GenomicSuperSignature"] <- "GSSig"
runtime_seed_totals[, method := factor(method, levels = timing_method_order)]

runtime_plot <- ggplot(runtime_seed_totals, aes(method, total_minutes, fill = method)) +
  geom_boxplot(width = 0.58, outlier.shape = NA, color = "black", linewidth = 0.35) +
  geom_point(aes(shape = factor(seed)), position = position_jitter(width = 0.08, height = 0),
             size = 2.2, fill = "white", color = "black", stroke = 0.5) +
  scale_fill_manual(values = method_colors, na.value = "grey70") +
  scale_shape_manual(values = c(`123` = 21, `456` = 22, `789` = 24), name = "Seed") +
  scale_y_log10(breaks = scales::log_breaks(n = 6), labels = scales::label_number()) +
  labs(x = NULL, y = "Total wall time across six datasets (min)") +
  theme_classic(base_size = 9, base_family = "Helvetica") +
  theme(axis.text.x = element_text(angle = 40, hjust = 1),
        legend.position = "top", legend.title = element_text(face = "plain"))

options(repr.plot.width = 7.2, repr.plot.height = 3.15)
runtime_plot
# Out:
# plot without title
