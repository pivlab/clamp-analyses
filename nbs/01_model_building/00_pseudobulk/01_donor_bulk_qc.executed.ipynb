# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/usr/lib/python3/dist-packages', '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/01_model_building/00_pseudobulk']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95h5\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cKoutput/01_model_building/00_pseudobulk/donor_bulk/qc/validation_summary.csv\x94\x8c_output/01_model_building/00_pseudobulk/donor_bulk/Brain_Mathys2023/bulk/aggregation_summary.csv\x94\x8c^output/01_model_building/00_pseudobulk/donor_bulk/Brain_Xiong2023/bulk/aggregation_summary.csv\x94\x8c^output/01_model_building/00_pseudobulk/donor_bulk/Heart_Datar2026/bulk/aggregation_summary.csv\x94\x8cXoutput/01_model_building/00_pseudobulk/donor_bulk/PBMC_1k1k/bulk/aggregation_summary.csv\x94\x8c]output/01_model_building/00_pseudobulk/donor_bulk/PBMC_Perez2022/bulk/aggregation_summary.csv\x94\x8c_output/01_model_building/00_pseudobulk/donor_bulk/Lung_Sikkema2023/bulk/aggregation_summary.csv\x94\x8ceoutput/01_model_building/00_pseudobulk/donor_bulk/Brain_Mathys2023/preprocessing/rank_diagnostics.csv\x94\x8cdoutput/01_model_building/00_pseudobulk/donor_bulk/Brain_Xiong2023/preprocessing/rank_diagnostics.csv\x94\x8cdoutput/01_model_building/00_pseudobulk/donor_bulk/Heart_Datar2026/preprocessing/rank_diagnostics.csv\x94\x8c^output/01_model_building/00_pseudobulk/donor_bulk/PBMC_1k1k/preprocessing/rank_diagnostics.csv\x94\x8ccoutput/01_model_building/00_pseudobulk/donor_bulk/PBMC_Perez2022/preprocessing/rank_diagnostics.csv\x94\x8ceoutput/01_model_building/00_pseudobulk/donor_bulk/Lung_Sikkema2023/preprocessing/rank_diagnostics.csv\x94\x8cpoutput/01_model_building/00_pseudobulk/donor_bulk/Brain_Mathys2023/single_cell_projection/projection_summary.csv\x94\x8cooutput/01_model_building/00_pseudobulk/donor_bulk/Brain_Xiong2023/single_cell_projection/projection_summary.csv\x94\x8cooutput/01_model_building/00_pseudobulk/donor_bulk/Heart_Datar2026/single_cell_projection/projection_summary.csv\x94\x8cioutput/01_model_building/00_pseudobulk/donor_bulk/PBMC_1k1k/single_cell_projection/projection_summary.csv\x94\x8cnoutput/01_model_building/00_pseudobulk/donor_bulk/PBMC_Perez2022/single_cell_projection/projection_summary.csv\x94\x8cpoutput/01_model_building/00_pseudobulk/donor_bulk/Lung_Sikkema2023/single_cell_projection/projection_summary.csv\x94\x8cdoutput/01_model_building/00_pseudobulk/donor_bulk/Brain_Mathys2023/single_cell_umap/umap_summary.csv\x94\x8ccoutput/01_model_building/00_pseudobulk/donor_bulk/Brain_Xiong2023/single_cell_umap/umap_summary.csv\x94\x8ccoutput/01_model_building/00_pseudobulk/donor_bulk/Heart_Datar2026/single_cell_umap/umap_summary.csv\x94\x8c]output/01_model_building/00_pseudobulk/donor_bulk/PBMC_1k1k/single_cell_umap/umap_summary.csv\x94\x8cboutput/01_model_building/00_pseudobulk/donor_bulk/PBMC_Perez2022/single_cell_umap/umap_summary.csv\x94\x8cdoutput/01_model_building/00_pseudobulk/donor_bulk/Lung_Sikkema2023/single_cell_umap/umap_summary.csv\x94\x8cj/home/msubirana/Documents/pivlab/clamp-analyses/nbs/01_model_building/00_pseudobulk/01_donor_bulk_qc.ipynb\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c
\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h%}\x94h3]\x94(h5h6eh5h9h;\x85\x94R\x94(h;)}\x94h?h5sNt\x94bh6h9h;\x85\x94R\x94(h;)}\x94h?h6sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h%}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh3]\x94(h5h6eh5h9h;\x85\x94R\x94(h;)}\x94h?h5sNt\x94bh6h9h;\x85\x94R\x94(h;)}\x94h?h6sNt\x94bh\xbeK\x01h\xc0K\x01h\xc2h\xbbub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cs/home/msubirana/Documents/pivlab/clamp-analyses/nbs/01_model_building/00_pseudobulk/01_donor_bulk_qc.executed.ipynb\x94a}\x94(h%}\x94h1K\x00N\x86\x94sh3]\x94(h5h6eh5h9h;\x85\x94R\x94(h;)}\x94h?h5sNt\x94bh6h9h;\x85\x94R\x94(h;)}\x94h?h6sNt\x94bh1h\xd1ub\x8c\x06config\x94}\x94(\x8c\x08datasets\x94}\x94(\x8c\x10Brain_Mathys2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c data/pseudobulk/Brain_Mathys2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c8data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz\x94\x8c\x08features\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz\x94\x8c\x08barcodes\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c-data/pseudobulk/raw/Brain_Mathys2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x08cellName\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0ctruth_v1_col\x94\x8c\tCell_Type\x94\x8c\x11raw_cell_type_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x14projection_label_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0fcohort_manifest\x94\x8c1data/pseudobulk/Brain_Mathys2023/patient_info.csv\x94u\x8c\x0fBrain_Xiong2023\x94}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1fdata/pseudobulk/Brain_Xiong2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c1data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz\x94\x8c\x08features\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz\x94\x8c\x08barcodes\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c,data/pseudobulk/raw/Brain_Xiong2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x06cellId\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x14hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x08Celltype\x94\x8c\x0ctruth_v1_col\x94\x8c\x0bSubcelltype\x94\x8c\x11raw_cell_type_col\x94\x8c\x08Celltype\x94\x8c\x14projection_label_col\x94\x8c\x08Celltype\x94\x8c\x0fcohort_manifest\x94\x8c0data/pseudobulk/Brain_Xiong2023/patient_info.csv\x94u\x8c\x0fHeart_Datar2026\x94}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8
x8c\x0fCLAMPfull/B.csv\x94\x8c\x05PLIER\x94\x8c\x0bPLIER/B.csv\x94\x8c\x03PCA\x94\x8c\tPCA/B.csv\x94\x8c\x03NMF\x94\x8c\tNMF/B.csv\x94\x8c\x03ICA\x94\x8c\tICA/B.csv\x94\x8c\x08Flashier\x94\x8c\x0eflashier/B.csv\x94\x8c\tMOFA-FLEX\x94\x8c\x15MOFA_FLEX_PRIOR/B.csv\x94\x8c\x05GSSig\x94\x8c\tGSS/B.csv\x94\x8c\x06CoGAPS\x94\x8c\x0cCoGAPS/B.csv\x94u\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c&output/01_model_building/00_pseudobulk\x94\x8c\x07biology\x94\x8c%output/03_model_biology/00_pseudobulk\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94\x8c\x06panels\x94\x8c\x10output/99_panels\x94\x8c\x10panels_notebooks\x94\x8c\rnbs/99_panels\x94u\x8c\nreferences\x94}\x94(\x8c\tgo_bp_url\x94\x8c_https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025\x94\x8c\ngo_bp_file\x94\x8cPoutput/01_model_building/00_pseudobulk/references/GO_Biological_Process_2025.gmt\x94\x8c\x0cgo_bp_sha256\x94\x8c@0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee\x94\x8c\x10cell_marker_file\x94\x8c$data/pathways/Cell_marker_Human.xlsx\x94\x8c\x14allen_brain_gmt_file\x94\x8c2data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt\x94\x8c\x0cazimuth_file\x94\x8c\x1edata/pathways/Azimuth_2023.txt\x94\x8c\x14gtex_tissues_pathmat\x94\x8c$data/archs4/GTEx_Tissues_pathMat.rds\x94\x8c\x0ebrain_datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94eu\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\ngrouped_cv\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\tgroup_col\x94\x8c\x06sample\x94\x8c\nsplit_seed\x94K*\x8c\x10min_train_lv_cor\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x0ebootstrap_seed\x94K{\x8c\x14bootstrap_replicates\x94M\x10\'u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\ns\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{u\x8c\tmofa_flex\x94}\x94(\x8c\nmax_epochs\x94K\xc8\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0ctop_fraction\x94G?\x84z\xe1G\xae\x14{u\x8c\x04gtex\x94}\x94(\x8c\x07raw_url\x94\x8cwhttps://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x06raw_gz\x94\x8cCdata/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x08metadata\x94\x8c=data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt\x94\x8c\x0cxcell_scores\x94\x8c7data/gtex/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt\x94\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c output/01_model_building/01_gtex\x94\x8c\x07biology\x94\x8c\x1foutput/03_model_biology/01_gtex\x94\x8c\x0fmodel_notebooks\x94\x8c\x1dnbs/01_model_building/01_gtex\x94\x8c\x11biology_notebooks\x94\x8c\x1cnbs/03_model_biology/01_gtex\x94u\x8c\x08raw_data\x94}\x94(\x8c\nchunk_size\x94Kd\x8c\x07n_cores\x94K\x01u\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x0fmofa_flex_prior\x94}\x94(\x8c\x0fmsigdb_category\x94\x8c\x08c5.go.bp\x94\x8c\x0cmsigdb_dbver\x94\x8c\t2026.1.Hs\x94\x8c\x0cmin_fraction\x94G?\xd9\x99\x99\x99\x99\x99\x9a\x8c\tmin_count\x94K(\x8c\tmax_count\x94K\xc8\x8c\x14similarity_threshold\x94G?\xe9\x99\x99\x99\x99\x99\x9a\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{\x8c\x0ctimeout_days\x94K\x07u\x8c\x03gss\x94}\x94(\x8c\td_cluster\x94K\x04\x8c\x04seed\x94K{u\x8c\x11kmeans_clustering\x94}\x94(\x8c\x0bmin_samples\x94K2\x8c\x0fari_min_samples\x94K\x01\x8c\tbase_seed\x94M\x10\'\x8c\x0cn_reps_per_k\x94K2\x8c\x0egene_fractions\x94]\x94(G?\xf0\x00\x00\x00\x00\x00\x00G?\xe8\x00\x00\x00\x00\x00\x00G?\xe0\x00\x00\x00\x00\x00\x00G?\xd0\x00\x00\x00\x00\x00\x00G?\xb9\x99\x99\x99\x99\x99\x9aG?\xa9\x99\x99\x99\x99\x99\x9aG?\x84z\xe1G\xae\x14{eu\x8c\rlv_importance\x94}\x94(\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xec\xcc\xcc\xcc\xcc\xcc\xcdu\x8c\x13subtissue_inference\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\x0bglobal_seed\x94K*\x8c\x0fmin_rf_accuracy\x94G?\xeb333333\x8c\x15min_subtissue_samples\x94K\x14\x8c\x0fn_jobs_per_fold\x94K\x08\x8c\x0fanatomical_spec\x94\x8c.workflow/config/gtex_anatomical_subtissues.tsv\x94\x8c\x13permutation_repeats\x94M\xe8\x03\x8c\x11bootstrap_repeats\x94M\xe8\x03\x8c\x0fevaluation_jobs\x94K\x08\x8c\x07tissues\x94]\x94(\x8c\x0eAdipose Tissue\x94\x8c\x05Blood\x94\x8c\x0cBlood Vessel\x94\x8c\x05Brain\x94\x8c\x05Colon\x94\x8c\tEsophagus\x94\x8c\x05Heart\x94\x8c\x06Kidney\x94\x8c\x04Skin\x94euu\x8c\x11runtime_benchmark\x94}\x94(\x8c\x05seeds\x94]\x94(K{M\xc8\x01M\x15\x03e\x8c\x07threads\x94K\x04\x8c\x07methods\x94]\x94(\x8c\tCLAMPfull\x94\x8c\tCLAMPbase\x94\x8c\x05PLIER\x94\x8c\x06CoGAPS\x94\x8c\x08Flashier\x94\x8c\x03NMF\x94\x8c\x03PCA\x94\x8c\x03ICA\x94\x8c\x05GSSig\x94\x8c\tMOFA-FLEX\x94e\x8c\x0boutput_root\x94\x8cAoutput/02_model_performance/00_pseudobulk/00_computational_timing\x94\x8c\x08notebook\x94\x8cDnbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb\x94u\x8c\ndonor_bulk\x94}\x94(\x8c\x08datasets\x94]\x94(h\x91h\x92h\x93h\x94h\x95h\x96e\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c1output/01_model_building/00_pseudobulk/donor_bulk\x94\x8c\x07biology\x94\x8c<output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94u\x8c\x0baggregation\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0csample_cells\x94M`\xea\x8c\x10minimum_per_type\x94K\xfa\x8c\x04seed\x94K{u\x8c\x04umap\x94}\x94(\x8c\ntarget_sum\x94M\x10\'\x8c\x05n_hvg\x94M\xd0\x07\x8c\x05n_pcs\x94K2\x8c\x0bn_neighbors\x94K\x1e\x8c\x08min_dist\x94G?\xd3333333\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x15duplicate_gene_policy\x94\x8c\x03sum\x94uuu\x8c\x04rule\x94\x8c\x13donor_bulk_model_qc\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cS/home/msubirana/Documents/pivlab/clamp-analyses/nbs/01_model_building/00_pseudobulk\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/msubirana/Documents/pivlab/clamp-analyses');
######## snakemake preamble end #########

# %% [markdown]
# # Donor-bulk production quality control
#
# Data-only QC report for donor raw-count aggregation, matched controls, CLAMPfull models, grouped folds, all-cell projection, and independent expression UMAPs.

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %%
from pathlib import Path
import pandas as pd

DATASETS = list(snakemake.params.datasets)
OUT = Path(snakemake.params.out_dir)
OUT.mkdir(parents=True, exist_ok=True)

# %%
def read_many(paths, source):
    frames = []
    for path in paths:
        frame = pd.read_csv(path)
        if "dataset" not in frame.columns:
            parts = Path(path).parts
            frame["dataset"] = parts[parts.index("donor_bulk") + 1]
        frame["qc_source"] = source
        frames.append(frame)
    return pd.concat(frames, ignore_index=True, sort=False)

aggregation = read_many(list(snakemake.input.aggregation), "aggregation")
ranks = read_many(list(snakemake.input.ranks), "rank")
projections = read_many(list(snakemake.input.projections), "projection")
umaps = read_many(list(snakemake.input.umaps), "expression_umap")
validation = pd.read_csv(snakemake.input.validation)

stopifnot = lambda condition, message: condition or (_ for _ in ()).throw(AssertionError(message))
stopifnot(set(aggregation.dataset) == set(DATASETS), "aggregation coverage")
stopifnot(set(projections.dataset) == set(DATASETS), "projection coverage")
stopifnot(set(umaps.dataset) == set(DATASETS), "UMAP coverage")
stopifnot(validation.shape[0] == len(DATASETS), "validation coverage")
stopifnot(validation.truth_denominator_exact.all(), "truth denominators")
stopifnot(validation.folds_leakage_free.all(), "donor leakage")
stopifnot(validation.all_model_matrices_finite.all(), "finite models")
stopifnot(validation.expression_umap_independent.all(), "expression UMAP source")
# Out:
# np.True_

# %%
rank_summary = ranks.groupby("dataset", as_index=False)["k"].first().rename(columns={"k": "selected_rank"})
qc = (validation
      .merge(aggregation[["dataset", "n_cells_raw", "n_cells_retained", "n_cells_sampled",
                          "n_genes_raw", "n_genes_output", "raw_validation_scope",
                          "truth_denominators_equal_expression_cells"]], on="dataset", validate="one_to_one")
      .merge(projections[["dataset", "n_cells_projected", "n_cells_mapped",
                          "duplicate_gene_policy", "normalization"]], on="dataset", validate="one_to_one")
      .merge(umaps[["dataset", "n_cells", "n_hvg", "n_pcs",
                    "embedding_source", "seed"]], on="dataset", validate="one_to_one")
      .merge(rank_summary, on="dataset", validate="one_to_one"))
qc.to_csv(snakemake.output.summary, index=False)
qc
# Out:
#             dataset  n_genes  n_donors  n_retained_cells  \
# 0  Brain_Mathys2023    18934        80            409642
# 1   Brain_Xiong2023    33538        74            347284
# 2   Heart_Datar2026    36601       209           2465668
# 3         PBMC_1k1k    35518       776            979154
# 4    PBMC_Perez2022    30162       209           1026830
# 5  Lung_Sikkema2023    27394       100            583392
#
#    n_sampled_umap_cells  full_rank  n_projected_cells  projection_lvs  \
# 0                 60000         19            2327742              19
# 1                 60000         18             414964              18
# 2                 60000         52            2479674              52
# 3                 60000        130            1248980             130
# 4                 60000         52            1263676              52
# 5                 60000         24             584944              24
#
# ...

# %% [markdown]
# The source notebook is deliberately output-clean. Snakemake stores this table and the executed notebook; no figure files are produced here.
