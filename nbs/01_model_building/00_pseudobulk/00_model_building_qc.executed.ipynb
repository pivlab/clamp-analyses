put/01_model_building/00_pseudobulk/Brain_Xiong2023/models/flashier/B.csv\x94\x8cSoutput/01_model_building/00_pseudobulk/Brain_Xiong2023/models/MOFA_FLEX_PRIOR/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/Brain_Xiong2023/models/GSS/B.csv\x94\x8cJoutput/01_model_building/00_pseudobulk/Brain_Xiong2023/models/CoGAPS/B.csv\x94\x8cMoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/CLAMPbase/B.csv\x94\x8cMoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/CLAMPfull/B.csv\x94\x8cIoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/PLIER/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/PCA/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/NMF/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/ICA/B.csv\x94\x8cLoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/flashier/B.csv\x94\x8cSoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/MOFA_FLEX_PRIOR/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/GSS/B.csv\x94\x8cJoutput/01_model_building/00_pseudobulk/Heart_Datar2026/models/CoGAPS/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/CLAMPbase/B.csv\x94\x8cGoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/CLAMPfull/B.csv\x94\x8cCoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/PLIER/B.csv\x94\x8cAoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/PCA/B.csv\x94\x8cAoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/NMF/B.csv\x94\x8cAoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/ICA/B.csv\x94\x8cFoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/flashier/B.csv\x94\x8cMoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/MOFA_FLEX_PRIOR/B.csv\x94\x8cAoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/GSS/B.csv\x94\x8cDoutput/01_model_building/00_pseudobulk/PBMC_1k1k/models/CoGAPS/B.csv\x94\x8cLoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/CLAMPbase/B.csv\x94\x8cLoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/CLAMPfull/B.csv\x94\x8cHoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/PLIER/B.csv\x94\x8cFoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/PCA/B.csv\x94\x8cFoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/NMF/B.csv\x94\x8cFoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/ICA/B.csv\x94\x8cKoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/flashier/B.csv\x94\x8cRoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/MOFA_FLEX_PRIOR/B.csv\x94\x8cFoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/GSS/B.csv\x94\x8cIoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/models/CoGAPS/B.csv\x94\x8cNoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/CLAMPbase/B.csv\x94\x8cNoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/CLAMPfull/B.csv\x94\x8cJoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/PLIER/B.csv\x94\x8cHoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/PCA/B.csv\x94\x8cHoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/NMF/B.csv\x94\x8cHoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/ICA/B.csv\x94\x8cMoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/flashier/B.csv\x94\x8cToutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/MOFA_FLEX_PRIOR/B.csv\x94\x8cHoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/GSS/B.csv\x94\x8cKoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/models/CoGAPS/B.csv\x94\x8ceoutput/01_model_building/00_pseudobulk/Brain_Mathys2023/single_cell_projection/projection_summary.csv\x94\x8cdoutput/01_model_building/00_pseudobulk/Brain_Xiong2023/single_cell_projection/projection_summary.csv\x94\x8cdoutput/01_model_building/00_pseudobulk/Heart_Datar2026/single_cell_projection/projection_summary.csv\x94\x8c^output/01_model_building/00_pseudobulk/PBMC_1k1k/single_cell_projection/projection_summary.csv\x94\x8ccoutput/01_model_building/00_pseudobulk/PBMC_Perez2022/single_cell_projection/projection_summary.csv\x94\x8ceoutput/01_model_building/00_pseudobulk/Lung_Sikkema2023/single_cell_projection/projection_summary.csv\x94\x8cu/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/01_model_building/00_pseudobulk/00_model_building_qc.ipynb\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\npseudobulk\x94K\x00K\x06\x86\x94\x8c\x06builds\x94K\x06K\x08\x86\x94\x8c\x05ranks\x94K\x08K\x0e\x86\x94\x8c\x06models\x94K\x0eKJ\x86\x94\x8c\x0bprojections\x94KJKP\x86\x94\x8c\x08notebook\x94KPN\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ehl\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(hr)}\x94\x8c\x05_name\x94hlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bh^h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ch\rh\x0eh\x0fe}\x94(h\\}\x94hj]\x94(hlhmehlhphr\x85\x94R\x94(hr)}\x94hvhlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bubh`h})\x81\x94(h\x10h\x11e}\x94(h\\}\x94hj]\x94(hlhmehlhphr\x85\x94R\x94(hr)}\x94hvhlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bubhbh})\x81\x94(h\x12h\x13h\x14h\x15h\x16h\x17e}\x94(h\\}\x94hj]\x94(hlhmehlhphr\x85\x94R\x94(hr)}\x94hvhlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bubhdh})\x81\x94(h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhSe}\x94(h\\}\x94hj]\x94(hlhmehlhphr\x85\x94R\x94(hr)}\x94hvhlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bubhfh})\x81\x94(hThUhVhWhXhYe}\x94(h\\}\x94hj]\x94(hlhmehlhphr\x85\x94R\x94(hr)}\x94hvhlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bubhhhZub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x
ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c~/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/01_model_building/00_pseudobulk/00_model_building_qc.executed.ipynb\x94a}\x94(h\\}\x94hhK\x00N\x86\x94shj]\x94(hlhmehlhphr\x85\x94R\x94(hr)}\x94hvhlsNt\x94bhmhphr\x85\x94R\x94(hr)}\x94hvhmsNt\x94bhhj1\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\x08datasets\x94}\x94(h\xd7}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c data/pseudobulk/Brain_Mathys2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c8data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz\x94\x8c\x08features\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz\x94\x8c\x08barcodes\x94\x8c:data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c-data/pseudobulk/raw/Brain_Mathys2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x08cellName\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0ctruth_v1_col\x94\x8c\tCell_Type\x94\x8c\x11raw_cell_type_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x14projection_label_col\x94\x8c\x0fMajor_Cell_Type\x94\x8c\x0fcohort_manifest\x94\x8c1data/pseudobulk/Brain_Mathys2023/patient_info.csv\x94uh\xd8}\x94(\x8c\x10build_pseudobulk\x94\x89\x8c\x0epseudobulk_dir\x94\x8c\x1fdata/pseudobulk/Brain_Xiong2023\x94\x8c\x04kind\x94\x8c\rmatrix_market\x94\x8c\x03raw\x94\x8c1data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz\x94\x8c\x08features\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz\x94\x8c\x08barcodes\x94\x8c3data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz\x94\x8c\x08metadata\x94\x8c,data/pseudobulk/raw/Brain_Xiong2023/meta.tsv\x94\x8c\x0bcell_id_col\x94\x8c\x06cellId\x94\x8c\nsample_col\x94\x8c\nIndividual\x94\x8c\x10sample_transform\x94\x8c\x14hyphen_to_underscore\x94\x8c\x0ctruth_v0_col\x94\x8c\x08Celltype\x94\x8c\x0ctruth_v1_col\x94\x8c\x0bSubcelltype\x94\x8c\x11raw_cell_type_col\x94\x8c\x08Celltype\x94\x8c\x14projection_label_col\x94\x8c\x08Celltype\x94\x8c\x0fcohort_manifest\x94\x8c0data/pseudobulk/Brain_Xiong2023/patient_info.csv\x94uh\xd9}\x94(\x8c\x10build_pseudobulk\x94\x88\x8c\x04kind\x94\x8c\x04h5ad\x94\x8c\x03raw\x94\x8c=data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad\x94\x8c\x06matrix\x94\x8c\x01X\x94\x8c\nsample_col\x94\x8c\x08donor_id\x94\x8c\x10sample_transform\x94\x8c\x08identity\x94\x8c\x0ctruth_v0_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x11raw_cell_type_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\x14projection_label_col\x94\x8c\x19cell_type__ontology_label\x94\x8c\tmin_cells\x94M\x90\x01\x8c\x07exclude\x94}\x94\x8c\x19cell_type__ontology
x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\ngrouped_cv\x94}\x94(\x8c\x07n_folds\x94K\x05\x8c\tgroup_col\x94\x8c\x06sample\x94\x8c\nsplit_seed\x94K*\x8c\x10min_train_lv_cor\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x0ebootstrap_seed\x94K{\x8c\x14bootstrap_replicates\x94M\x10\'u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x06cogaps\x94}\x94(\x8c\x0cn_iterations\x94M\x88\x13\x8c\tn_threads\x94K\x04\x8c\x04seed\x94K{u\x8c\tmofa_flex\x94}\x94(\x8c\nmax_epochs\x94M\xe8\x03\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0ctop_fraction\x94G?\x84z\xe1G\xae\x14{u\x8c\x12cell_type_analysis\x94}\x94\x8c\x10excluded_targets\x94}\x94(\x8c\x10Brain_Mathys2023\x94]\x94\x8c\x03Vas\x94a\x8c\x0fBrain_Xiong2023\x94]\x94\x8c\x03Vas\x94a\x8c\x10Lung_Sikkema2023\x94]\x94(\x8c\x18Hematopoietic stem cells\x94\x8c\x0bMesothelium\x94\x8c\rSmooth muscle\x94eus\x8c\x04gtex\x94}\x94(\x8c\x07raw_url\x94\x8cwhttps://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x06raw_gz\x94\x8cCdata/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz\x94\x8c\x08metadata\x94\x8c=data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt\x94\x8c\x0cxcell_scores\x94\x8c7data/gtex/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt\x94\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c output/01_model_building/01_gtex\x94\x8c\x07biology\x94\x8c\x1foutput/03_model_biology/01_gtex\x94\x8c\x0fmodel_notebooks\x94\x8c\x1dnbs/01_model_building/01_gtex\x94\x8c\x11biology_notebooks\x94\x8c\x1cnbs/03_model_biology/01_gtex\x94u\x8c\x08raw_data\x94}\x94(\x8c\nchunk_size\x94Kd\x8c\x07n_cores\x94K\x01u\x8c\npreprocess\x94}\x94(\x8c\x0bmean_cutoff\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\nvar_cutoff\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x04seed\x94K{u\x8c\x05clamp\x94}\x94(\x8c\x08max_iter\x94M\xf4\x01\x8c\x04seed\x94K{u\x8c\x08flashier\x94}\x94\x8c\x0fbackfit_maxiter\x94K\x14s\x8c\x0fmofa_flex_prior\x94}\x94(\x8c\x0cmin_fraction\x94G?\xd9\x99\x99\x99\x99\x99\x9a\x8c\tmin_count\x94K(\x8c\tmax_count\x94K\xc8\x8c\x14similarity_threshold\x94G?\xe9\x99\x99\x99\x99\x99\x9a\x8c\nmax_epochs\x
94X\xec\x01\x00\x00rule cogaps_gtex was run to the end of its hard wall-clock budget (gtex.cogaps.timeout_days = 7) and killed without converging; the evidence is on disk at output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt. CoGAPS therefore has no finite GTEx runtime to report, and re-running it here would only re-derive the same censored value at a cost of 21 days. Reported as a right-censored ">7 days, did not converge", not as a data point.  Same reason it is absent from rule full_models_gtex.\n\x94\x8c\x0eMOFA-FLEX_base\x94\x8c\xa9No prior-free MOFA-FLEX GTEx production model exists: rule mofa_flex_base_gtex fails on this dataset, so there is no published GTEx fit whose runtime could be measured.\n\x94u\x8c\x0fcogaps_evidence\x94\x8c9output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt\x94\x8c\x0boutput_root\x94\x8c;output/02_model_performance/01_gtex/00_computational_timing\x94\x8c\x08notebook\x94\x8c>nbs/02_model_performance/01_gtex/00_computational_timing.ipynb\x94u\x8c\ndonor_bulk\x94}\x94(\x8c\x08datasets\x94]\x94(\x8c\x10Brain_Mathys2023\x94\x8c\x0fBrain_Xiong2023\x94\x8c\x0fHeart_Datar2026\x94\x8c\tPBMC_1k1k\x94\x8c\x0ePBMC_Perez2022\x94\x8c\x10Lung_Sikkema2023\x94e\x8c\x05paths\x94}\x94(\x8c\nproduction\x94\x8c1output/01_model_building/00_pseudobulk/donor_bulk\x94\x8c\x07biology\x94\x8c<output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery\x94\x8c\x0fmodel_notebooks\x94\x8c#nbs/01_model_building/00_pseudobulk\x94\x8c\x11biology_notebooks\x94\x8c"nbs/03_model_biology/00_pseudobulk\x94u\x8c\x0baggregation\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x0csample_cells\x94M`\xea\x8c\x10minimum_per_type\x94K\xfa\x8c\x04seed\x94K{u\x8c\x04umap\x94}\x94(\x8c\ntarget_sum\x94M\x10\'\x8c\x05n_hvg\x94M\xd0\x07\x8c\x05n_pcs\x94K2\x8c\x0bn_neighbors\x94K\x1e\x8c\x08min_dist\x94G?\xd3333333\x8c\x04seed\x94K{u\x8c\nprojection\x94}\x94(\x8c\x0bchunk_cells\x94M N\x8c\tchunk_nnz\x94J\x00-1\x01\x8c\x15duplicate_gene_policy\x94\x8c\x03sum\x94uuu\x8c\x04rule\x94\x8c\x1cmodel_building_qc_pseudobulk\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cZ/home/msubirana/Documents/pivlab/clamp-analyses-revert/nbs/01_model_building/00_pseudobulk\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/msubirana/Documents/pivlab/clamp-analyses-revert');
######## snakemake preamble end #########

# %% [markdown]
# # Pseudobulk production quality control
#
# This report reads Snakemake models.

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %% [markdown]
# ## Libraries

# %%
from pathlib import Path
import csv
import pandas as pd
import matplotlib.pyplot as plt
from pyprojroot import here

# %% [markdown]
# ## Settings

# %%
ROOT = Path(here())
CONFIG = snakemake.config
DATASETS = list(snakemake.params.datasets)
PROD = Path(snakemake.params.mod_root)
OUT = Path(snakemake.params.out_dir)
OUT.mkdir(parents=True, exist_ok=True)

# %%
def csv_shape(path):
    # Count rows as bytes so QC never parses/materializes large numeric model matrices.
    with open(path, 'rb') as handle:
        header_line = handle.readline()
        n_rows = 0
        while chunk := handle.read(8 * 1024 * 1024):
            n_rows += chunk.count(b'\n')
    with open(path, newline='') as handle:
        header = next(csv.reader(handle))
    return n_rows, len(header) - int(bool(header) and header[0] == '')

rows = []; model_rows = []
methods = [Path(rel_path).parent.name for rel_path in snakemake.params.methods.values()]
for dataset in DATASETS:
    dataset_cfg = CONFIG['datasets'][dataset]
    is_built = bool(dataset_cfg.get('build_pseudobulk', False))
    pb_dir = (PROD / dataset / 'pseudobulk') if is_built else (ROOT / dataset_cfg['pseudobulk_dir'])
    pseudobulk_genes, pseudobulk_samples = csv_shape(pb_dir / 'bulk_expr.csv')
    rank = pd.read_csv(PROD / dataset / 'preprocessing/k.csv')['k'].iloc[0]
    with open(PROD / dataset / 'single_cell_projection/projection_summary.csv', newline='') as handle:
        projection = next(csv.DictReader(handle))
    model_complete = 0
    for method in methods:
        b_path = PROD / dataset / 'models' / method / 'B.csv'
        z_path = PROD / dataset / 'models' / method / 'Z.csv'
        complete = b_path.exists() and z_path.exists(); model_complete += int(complete)
        b_rows, b_cols = csv_shape(b_path) if b_path.exists() else (None, None)
        z_rows, z_cols = csv_shape(z_path) if z_path.exists() else (None, None)
        model_rows.append({'dataset':dataset,'method':method,'complete':complete,
          'B_rows':b_rows,'B_cols':b_cols,'Z_rows':z_rows,'Z_cols':z_cols})
    rows.append({
        'dataset': dataset, 'pseudobulk_source': 'raw-built' if is_built else 'lab-provided',
        'pseudobulk_samples': pseudobulk_samples,
        'pseudobulk_genes': pseudobulk_genes, 'rank': int(rank),
        'models_complete': model_complete, 'models_expected': len(methods),
        'raw_cells': int(projection['n_cells_raw']),
        'projected_cells': int(projection['n_cells_projected']),
        'mapped_cells': int(projection['n_cells_mapped']),
        'projection_passes': int(projection['passes']),
    })
qc = pd.DataFrame(rows)
qc.to_csv(OUT / 'model_building_qc.csv', index=False)
pd.DataFrame(model_rows).to_csv(OUT / 'model_matrix_qc.csv', index=False)
qc
# Out:
#             dataset pseudobulk_source  pseudobulk_samples  pseudobulk_genes  \
# 0  Brain_Mathys2023      lab-provided                  80             17135
# 1   Brain_Xiong2023      lab-provided                  74             25944
# 2   Heart_Datar2026         raw-built                 209             36601
# 3         PBMC_1k1k      lab-provided                 776             19356
# 4    PBMC_Perez2022      lab-provided                 209             18854
# 5  Lung_Sikkema2023         raw-built                 100             27394
#
#    rank  models_complete  models_expected  raw_cells  projected_cells  \
# 0    19               10               10    2327742          2327742
# 1    18               10               10     414964           414964
# 2    52               10               10    2479674          2479674
# 3   130               10               10    1248980          1248980
# 4    52               10               10    1263676          1263676
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))
axes[0].barh(qc.dataset, qc.pseudobulk_samples)
axes[0].set_xlabel('Pseudobulk samples')
axes[0].set_title('Pseudobulk inputs')
axes[1].barh(qc.dataset, qc.projected_cells / 1e6)
axes[1].set_xlabel('Projected cells (millions)')
axes[1].set_title('All-cell CLAMP projection')
fig.tight_layout()
plt.show()
