# %% [markdown]
# # ARCHS4 CLAMP models: Effect of CLAMP_K (1% study-based sampling)

# %% [markdown]
# **Environment:** `clamp-analyses`
#
# This notebook evaluates the effect of different CLAMP_K values on model results using 1% study-based sampling of ARCHS4 data.
#
# Instead of estimating CLAMP_K via `num.pc()`, we fix it to: 50, 100, 250, 500, 750, 1000.
#
# For each CLAMP_K value, 5 models are built with different random seeds (and thus different subsamples and SVDs).
#
# Structure per seed:
# 1. Subsample ARCHS4 data (1% coverage, study-based shuffling)
# 2. Compute SVD (shared across CLAMP_K values for the same seed)
# 3. For each CLAMP_K: run CLAMPbase, then CLAMPfull with BP prior

# %% [markdown]
# ## Load libraries

# %%
if (!requireNamespace("CLAMP", quietly = TRUE)) {
    REPO_PATH <- "/home/msubirana/Documents/pivlab/CLAMP" 
    remotes::install_local(REPO_PATH, force = TRUE, dependencies = FALSE)
}

library(bigstatsr)
library(data.table)
library(dplyr)
library(rsvd)
library(glmnet)
library(Matrix)
library(knitr)
library(here)
library(CLAMP)
library(rhdf5)

source(here("config.R"))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-10
#
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses

# %% [markdown]
# ## Configuration

# %%
# Base output directory
base_output_dir <- config$ARCHS4$DATASET_FOLDER

# Coverage level
coverage <- 0.01
coverage_pct <- coverage * 100

# CLAMP_K values to test
clamp_k_values <- c(50, 100, 250, 500, 750, 1000)

# Data path for priors
data_path <- here::here('data/archs4')
archs4_file <- here('data/archs4/human_gene_v2.5.h5')

# SVD parameters
N_CORES <- 4

# Seeds for 5 runs
base_seed <- config$ARCHS4$CLAMP_PARAMS$RANDOM_SVD_SEED
seeds <- base_seed + 0:4
n_runs <- length(seeds)

# Output directory
output_base <- file.path(base_output_dir, "clamp_k_effect_01_study")
dir.create(output_base, showWarnings = FALSE, recursive = TRUE)

message("CLAMP_K values: ", paste(clamp_k_values, collapse = ", "))
message("Seeds: ", paste(seeds, collapse = ", "))
message("Coverage: ", coverage_pct, "%")
message("Output: ", output_base)
# Out:
# CLAMP_K values: 50, 100, 250, 500, 750, 1000
#
# Seeds: 123, 124, 125, 126, 127
#
# Coverage: 1%
#
# Output: /home/msubirana/Documents/pivlab/clamp-analyses/output/archs4/clamp_k_effect_01_study

# %% [markdown]
# ## Load preprocessed data

# %%
# Load metadata
meta <- readRDS(file.path(base_output_dir, "metadata_filtered.rds"))
n_genes_thin <- meta$n_genes_thin
n_samples_total <- meta$n_samples
archs4_genes <- meta$gene_symbols_thin

# Load sample names
all_samples <- readRDS(file.path(base_output_dir, "all_samples.rds"))
sample_names_total <- all_samples[seq_len(n_samples_total)]

# Load BP pathway
BP_pathMat <- readRDS(file.path(data_path, "BP_pathMat.rds"))
BP_matched <- getMatchedPathwayMat(BP_pathMat, archs4_genes)
message("Loaded and matched BP pathway matrix")

# Load FBM
fbm_file <- file.path(base_output_dir, "fbm")
output_file <- paste0(fbm_file, "_filtered")

archs4_fbm_filt <- FBM(
  nrow        = n_genes_thin,
  ncol        = n_samples_total,
  backingfile = output_file,
  create_bk   = FALSE
)

message("Loaded FBM with ", n_genes_thin, " genes and ", n_samples_total, " samples")

# Get series information from ARCHS4 HDF5 file
message("Getting series information from ARCHS4 HDF5 file...")

geo_acc <- h5read(archs4_file, "/meta/samples/geo_accession")
series_id <- h5read(archs4_file, "/meta/samples/series_id")

gsm_to_gse <- data.frame(
  geo_accession = geo_acc,
  series_id = series_id,
  stringsAsFactors = FALSE
)

# Create mapping of our filtered samples to series
sample_series_df <- data.frame(
  sample_idx = seq_len(n_samples_total),
  sample_name = sample_names_total,
  stringsAsFactors = FALSE
) %>%
  left_join(gsm_to_gse, by = c("sample_name" = "geo_accession"))

# Get unique series and their sample counts
series_counts <- sample_series_df %>%
  group_by(series_id) %>%
  summarise(n_samples = n(), .groups = "drop") %>%
  arrange(series_id)

message("Found ", nrow(series_counts), " unique studies")
# Out:
# There are 11936 genes in the intersection between data and prior
#
# Removing 2059 pathways
#
# Loaded and matched BP pathway matrix
#
# Loaded FBM with 18423 genes and 605614 samples
#
# Getting series information from ARCHS4 HDF5 file...
#
# Found 18084 unique studies

# %% [markdown]
# ## Run models: 5 seeds x 6 CLAMP_K values
#
# For each seed: study-based subsample → SVD (once), then loop over CLAMP_K values for CLAMPbase + CLAMPfull_BP.

# %%
n_samples_target <- round(n_samples_total * coverage)

SVD_K <- min(n_samples_target - 1, n_genes_thin - 1)

message("Target samples per run: ", n_samples_target, " (", coverage_pct, "% of ", n_samples_total, ")")
message("SVD K: ", SVD_K)

results_summary <- data.frame(
  run = integer(),
  seed = integer(),
  CLAMP_K = integer(),
  n_samples = integer(),
  n_studies = integer(),
  stringsAsFactors = FALSE
)

for (run_idx in seq_len(n_runs)) {
  current_seed <- seeds[run_idx]
  message("\n", strrep("=", 60))
  message("SEED ", run_idx, "/", n_runs, " (", current_seed, ")")
  message(strrep("=", 60))
  
  seed_dir <- file.path(output_base, paste0("seed_", run_idx))
  dir.create(seed_dir, showWarnings = FALSE, recursive = TRUE)
  
  # --- Study-based sample selection ---
  set.seed(current_seed)
  shuffled_series <- sample(series_counts$series_id)
  
  selected_samples <- c()
  selected_series <- c()
  n_collected <- 0
  
  for (s in shuffled_series) {
    if (n_collected >= n_samples_target) break
    series_samples <- sample_series_df$sample_idx[sample_series_df$series_id == s]
    n_series_samples <- length(series_samples)
    
    if (n_series_samples == 0) {
      warning("No samples found for series: ", s)
      next
    }
    
    if (n_collected + n_series_samples <= n_samples_target) {
      selected_samples <- c(selected_samples, series_samples)
      selected_series <- c(selected_series, s)
      n_collected <- n_collected + n_series_samples
    } else {
      n_needed <- n_samples_target - n_collected
      selected_samples <- c(selected_samples, series_samples[1:n_needed])
      selected_series <- c(selected_series, s)
      n_collected <- n_collected + n_needed
      break
    }
  }
  
  sample_idx <- sort(selected_samples)
  n_samples <- length(sample_idx)
  sample_names <- sample_names_total[sample_idx]
  
  message("Selected ", length(selected_series), " studies with ", n_samples, " total samples")
  
  saveRDS(list(
    run = run_idx,
    seed = current_seed,
    coverage = coverage,
    n_samples = n_samples,
    sample_idx = sample_idx,
    sample_names = sample_names,
    selected_series = selected_series,
    sampling_method = "study_based"
  ), file = file.path(seed_dir, "subsample_info.rds"))
  
  # --- Create subsampled FBM ---
  message("Creating subsampled FBM...")
  fbm_sub_file <- file.path(seed_dir, "fbm_subsampled")
  
  Y_sub <- big_copy(
    archs4_fbm_filt,
    ind.col = sample_idx,
    backingfile = fbm_sub_file
  )
  
  # --- SVD (once per seed) ---
  message("Computing SVD (k=", SVD_K, ")...")
  
  if (N_CORES > 1) {
    options(bigstatsr.check.parallel.blas = FALSE)
    blas_nproc <- getOption("default.nproc.blas")
    options(default.nproc.blas = NULL)
  }
  
  svd_result <- big_randomSVD(Y_sub, k = SVD_K, ncores = N_CORES)
  
  if (N_CORES > 1) {
    options(bigstatsr.check.parallel.blas = TRUE)
    options(default.nproc.blas = blas_nproc)
  }
  
  valid_idx <- which(!is.nan(svd_result$d))
  svd_result$d <- svd_result$d[valid_idx]
  svd_result$u <- svd_result$u[, valid_idx, drop = FALSE]
  svd_result$v <- svd_result$v[, valid_idx, drop = FALSE]
  
  saveRDS(svd_result, file = file.path(seed_dir, "svd.rds"))
  message("SVD done: ", length(svd_result$d), " valid components")
  
  # --- Loop over CLAMP_K values ---
  for (CLAMP_K in clamp_k_values) {
    message("\n--- CLAMP_K = ", CLAMP_K, " (seed ", run_idx, ") ---")
    
    k_dir <- file.path(seed_dir, paste0("clamp_k_", CLAMP_K))
    dir.create(k_dir, showWarnings = FALSE, recursive = TRUE)
    
    saveRDS(CLAMP_K, file = file.path(k_dir, "CLAMP_K.rds"))
    
    # CLAMPbase
    message("Running CLAMPbase...")
    baseRes <- CLAMPbase(
      Y = Y_sub,
      svdres = svd_result,
      trace = TRUE,
      clamp_k = CLAMP_K
    )
    
    baseRes$Z <- data.frame(baseRes$Z)
    rownames(baseRes$Z) <- archs4_genes
    baseRes$B <- data.frame(baseRes$B)
    colnames(baseRes$B) <- sample_names
    
    saveRDS(baseRes, file = file.path(k_dir, "CLAMPbase.rds"))
    
    model_dir <- file.path(k_dir, "CLAMPbase")
    dir.create(model_dir, showWarnings = FALSE, recursive = TRUE)
    write.csv(baseRes$B, file.path(model_dir, "B.csv"))
    write.csv(baseRes$Z, file.path(model_dir, "Z.csv"))
    
    # CLAMPfull with BP prior
    message("Running CLAMPfull with BP prior...")
    fullRes <- CLAMPfull(
      Y = Y_sub,
      svdres = svd_result,
      priorMat = BP_matched,
      clamp.base.result = baseRes,
      use_cpp = TRUE,
      trace = TRUE,
      clamp_k = CLAMP_K
    )
    
    fullRes$Z <- data.frame(fullRes$Z)
    rownames(fullRes$Z) <- archs4_genes
    fullRes$B <- data.frame(fullRes$B)
    colnames(fullRes$B) <- sample_names
    fullRes$summary <- fullRes$summary %>%
      dplyr::rename(LV = LV_index) %>%
      dplyr::mutate(LV = paste0('LV', LV))
    
    saveRDS(fullRes, file = file.path(k_dir, "CLAMPfull_BP.rds"))
    
    model_dir <- file.path(k_dir, "CLAMPfull_BP")
    dir.create(model_dir, showWarnings = FALSE, recursive = TRUE)
    write.csv(fullRes$B, file.path(model_dir, "B.csv"))
    write.csv(fullRes$Z, file.path(model_dir, "Z.csv"))
    write.csv(fullRes$summary, file.path(model_dir, "summary.csv"))
    
    # Store summary
    results_summary <- rbind(results_summary, data.frame(
      run = run_idx,
      seed = current_seed,
      CLAMP_K = CLAMP_K,
      n_samples = n_samples,
      n_studies = length(selected_series)
    ))
    
    rm(baseRes, fullRes)
    gc()
  }
  
  rm(Y_sub, svd_result)
  gc()
}

message("\n", strrep("=", 60))
message("All runs completed!")
message(strrep("=", 60))
# Out:
# Target samples per run: 6056 (1% of 605614)
#
# SVD K: 6055
#
#
# ============================================================
#
# SEED 1/5 (123)
#
# ============================================================
#
# Selected 220 studies with 6056 total samples
#
# Creating subsampled FBM...
#
# Computing SVD (k=6055)...
#
# SVD done: 6048 valid components
#
#
# --- CLAMP_K = 50 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 50
#
# L1 is set to 130.551867390849
#
# L2 is set to 391.655602172546
#
# Progress 1 / 200 | Bdiff=0.354029, minCor=0.930865
#
# Progress 2 / 200 | Bdiff=0.025436, minCor=0.951031
#
# Progress 3 / 200 | Bdiff=0.009703, minCor=0.983865
#
# Progress 4 / 200 | Bdiff=0.006176, minCor=0.989988
#
# Progress 5 / 200 | Bdiff=0.004542, minCor=0.992612
#
# Progress 6 / 200 | Bdiff=0.003675, minCor=0.994058
#
# Progress 7 / 200 | Bdiff=0.003168, minCor=0.995008
#
# Progress 8 / 200 | Bdiff=0.002839, minCor=0.995596
#
# Progress 9 / 200 | Bdiff=0.002620, minCor=0.996307
#
# Progress 10 / 200 | Bdiff=0.002473, minCor=0.996631
#
# Progress 11 / 200 | Bdiff=0.002362, minCor=0.996730
#
# Progress 12 / 200 | Bdiff=0.002253, minCor=0.996748
#
# Progress 13 / 200 | Bdiff=0.002127, minCor=0.996519
#
# Progress 14 / 200 | Bdiff=0.001972, minCor=0.996530
#
# Progress 15 / 200 | Bdiff=0.001800, minCor=0.996778
#
# Progress 16 / 200 | Bdiff=0.001635, minCor=0.997137
#
# Progress 17 / 200 | Bdiff=0.001493, minCor=0.997366
#
# Progress 18 / 200 | Bdiff=0.001384, minCor=0.997466
#
# Progress 19 / 200 | Bdiff=0.001296, minCor=0.997702
#
# Progress 20 / 200 | Bdiff=0.037308, minCor=0.963219
#
# Progress 21 / 200 | Bdiff=0.013716, minCor=0.975990
#
# Progress 22 / 200 | Bdiff=0.009350, minCor=0.982981
#
# Progress 23 / 200 | Bdiff=0.006713, minCor=0.980365
#
# Progress 24 / 200 | Bdiff=0.005093, minCor=0.981256
#
# Progress 25 / 200 | Bdiff=0.004204, minCor=0.981820
#
# Progress 26 / 200 | Bdiff=0.003481, minCor=0.985385
#
# Progress 27 / 200 | Bdiff=0.002896, minCor=0.987873
#
# Progress 28 / 200 | Bdiff=0.002492, minCor=0.989123
#
# Progress 29 / 200 | Bdiff=0.002054, minCor=0.990214
#
# Progress 30 / 200 | Bdiff=0.001419, minCor=0.992414
#
# Progress 31 / 200 | Bdiff=0.000995, minCor=0.994541
#
# Progress 32 / 200 | Bdiff=0.000754, minCor=0.996289
#
# Progress 33 / 200 | Bdiff=0.000634, minCor=0.996828
#
# Progress 34 / 200 | Bdiff=0.000562, minCor=0.996191
#
# Progress 35 / 200 | Bdiff=0.000540, minCor=0.995706
#
# Progress 36 / 200 | Bdiff=0.000504, minCor=0.996191
#
# Progress 37 / 200 | Bdiff=0.000515, minCor=0.995146
#
# Progress 38 / 200 | Bdiff=0.000509, minCor=0.996333
#
# Progress 39 / 200 | Bdiff=0.000535, minCor=0.994011
#
# Progress 40 / 200 | Bdiff=0.000554, minCor=0.991569
#
# Progress 41 / 200 | Bdiff=0.000505, minCor=0.990649
#
# Progress 42 / 200 | Bdiff=0.000383, minCor=0.993751
#
# Converged at iteration= 42 | Bdiff=0.000383,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 50
#
# L1=130.551867390849; L2=391.655602172546
#
# Progress 1 / 30 | Bdiff=0.000317
#
# Progress 2 / 30 | Bdiff=0.001685
#
# Progress 3 / 30 | Bdiff=0.001107
#
# Estimated total runtime: ~2.9 min
#
# Progress 4 / 30 | Bdiff=0.000556
#
# Progress 5 / 30 | Bdiff=0.000700
#
# Progress 6 / 30 | Bdiff=0.000521
#
# Progress 7 / 30 | Bdiff=0.000536
#
# Progress 8 / 30 | Bdiff=0.000521
#
# Progress 9 / 30 | Bdiff=0.000943
#
# Progress 10 / 30 | Bdiff=0.000594
#
# Progress 11 / 30 | Bdiff=0.000524
#
# Progress 12 / 30 | Bdiff=0.000356
#
# Progress 13 / 30 | Bdiff=0.000306
#
# Progress 14 / 30 | Bdiff=0.000343
#
# Progress 15 / 30 | Bdiff=0.000339
#
# Progress 16 / 30 | Bdiff=0.000266
#
# Progress 17 / 30 | Bdiff=0.000373
#
# Progress 18 / 30 | Bdiff=0.000226
#
# Progress 19 / 30 | Bdiff=0.000378
#
# Progress 20 / 30 | Bdiff=0.000447
#
# Progress 21 / 30 | Bdiff=0.000359
#
# Progress 22 / 30 | Bdiff=0.000386
#
# Progress 23 / 30 | Bdiff=0.000287
#
# Progress 24 / 30 | Bdiff=0.000348
#
# Progress 25 / 30 | Bdiff=0.000390
#
# Progress 26 / 30 | Bdiff=0.000403
#
# Progress 27 / 30 | Bdiff=0.000339
#
# Progress 28 / 30 | Bdiff=0.000315
#
# Progress 29 / 30 | Bdiff=0.000250
#
# Progress 30 / 30 | Bdiff=0.000246
#
# Updating Z for CV
#
# crossValidation
#
# There are 46 LVs with AUC>0.70
#
# There are 38 LVs with AUC>0.90
#
#
# --- CLAMP_K = 100 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 100
#
# L1 is set to 79.7602912129328
#
# L2 is set to 239.280873638798
#
# Progress 1 / 200 | Bdiff=0.288331, minCor=0.785445
#
# Progress 2 / 200 | Bdiff=0.020953, minCor=0.945445
#
# Progress 3 / 200 | Bdiff=0.009071, minCor=0.982949
#
# Progress 4 / 200 | Bdiff=0.006501, minCor=0.987538
#
# Progress 5 / 200 | Bdiff=0.005152, minCor=0.990678
#
# Progress 6 / 200 | Bdiff=0.004338, minCor=0.993279
#
# Progress 7 / 200 | Bdiff=0.003820, minCor=0.994924
#
# Progress 8 / 200 | Bdiff=0.003473, minCor=0.995638
#
# Progress 9 / 200 | Bdiff=0.003234, minCor=0.995649
#
# Progress 10 / 200 | Bdiff=0.003051, minCor=0.995842
#
# Progress 11 / 200 | Bdiff=0.002873, minCor=0.995936
#
# Progress 12 / 200 | Bdiff=0.002667, minCor=0.995850
#
# Progress 13 / 200 | Bdiff=0.002433, minCor=0.996209
#
# Progress 14 / 200 | Bdiff=0.002183, minCor=0.996774
#
# Progress 15 / 200 | Bdiff=0.001944, minCor=0.996998
#
# Progress 16 / 200 | Bdiff=0.001740, minCor=0.997294
#
# Progress 17 / 200 | Bdiff=0.001589, minCor=0.997552
#
# Progress 18 / 200 | Bdiff=0.001482, minCor=0.997784
#
# Progress 19 / 200 | Bdiff=0.001403, minCor=0.997678
#
# Progress 20 / 200 | Bdiff=0.049389, minCor=0.950537
#
# Progress 21 / 200 | Bdiff=0.015413, minCor=0.972341
#
# Progress 22 / 200 | Bdiff=0.011896, minCor=0.972298
#
# Progress 23 / 200 | Bdiff=0.009288, minCor=0.966859
#
# Progress 24 / 200 | Bdiff=0.007341, minCor=0.971584
#
# Progress 25 / 200 | Bdiff=0.006116, minCor=0.978915
#
# Progress 26 / 200 | Bdiff=0.005019, minCor=0.976585
#
# Progress 27 / 200 | Bdiff=0.004151, minCor=0.972169
#
# Progress 28 / 200 | Bdiff=0.003320, minCor=0.978869
#
# Progress 29 / 200 | Bdiff=0.002676, minCor=0.988536
#
# Progress 30 / 200 | Bdiff=0.002112, minCor=0.992256
#
# Progress 31 / 200 | Bdiff=0.001757, minCor=0.991494
#
# Progress 32 / 200 | Bdiff=0.001430, minCor=0.992509
#
# Progress 33 / 200 | Bdiff=0.001224, minCor=0.992065
#
# Progress 34 / 200 | Bdiff=0.001095, minCor=0.991222
#
# Progress 35 / 200 | Bdiff=0.001000, minCor=0.987245
#
# Progress 36 / 200 | Bdiff=0.000922, minCor=0.984492
#
# Progress 37 / 200 | Bdiff=0.000871, minCor=0.987727
#
# Progress 38 / 200 | Bdiff=0.000792, minCor=0.988941
#
# Progress 39 / 200 | Bdiff=0.000724, minCor=0.991321
#
# Progress 40 / 200 | Bdiff=0.000625, minCor=0.989148
#
# Progress 41 / 200 | Bdiff=0.000513, minCor=0.989246
#
# Progress 42 / 200 | Bdiff=0.000485, minCor=0.988561
#
# Converged at iteration= 42 | Bdiff=0.000485,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 100
#
# L1=79.7602912129328; L2=239.280873638798
#
# Progress 1 / 30 | Bdiff=0.000448
#
# Progress 2 / 30 | Bdiff=0.003756
#
# Progress 3 / 30 | Bdiff=0.001783
#
# Estimated total runtime: ~4.1 min
#
# Progress 4 / 30 | Bdiff=0.001407
#
# Progress 5 / 30 | Bdiff=0.001549
#
# Progress 6 / 30 | Bdiff=0.001107
#
# Progress 7 / 30 | Bdiff=0.000861
#
# Progress 8 / 30 | Bdiff=0.000975
#
# Progress 9 / 30 | Bdiff=0.000894
#
# Progress 10 / 30 | Bdiff=0.000819
#
# Progress 11 / 30 | Bdiff=0.000899
#
# Progress 12 / 30 | Bdiff=0.000718
#
# Progress 13 / 30 | Bdiff=0.000588
#
# Progress 14 / 30 | Bdiff=0.000866
#
# Progress 15 / 30 | Bdiff=0.000732
#
# Progress 16 / 30 | Bdiff=0.000756
#
# Progress 17 / 30 | Bdiff=0.000793
#
# Progress 18 / 30 | Bdiff=0.000711
#
# Progress 19 / 30 | Bdiff=0.000642
#
# Progress 20 / 30 | Bdiff=0.000695
#
# Progress 21 / 30 | Bdiff=0.000574
#
# Progress 22 / 30 | Bdiff=0.000655
#
# Progress 23 / 30 | Bdiff=0.000681
#
# Progress 24 / 30 | Bdiff=0.000620
#
# Progress 25 / 30 | Bdiff=0.000567
#
# Progress 26 / 30 | Bdiff=0.000709
#
# Progress 27 / 30 | Bdiff=0.000568
#
# Progress 28 / 30 | Bdiff=0.000564
#
# Progress 29 / 30 | Bdiff=0.000563
#
# Progress 30 / 30 | Bdiff=0.000487
#
# Updating Z for CV
#
# crossValidation
#
# There are 91 LVs with AUC>0.70
#
# There are 55 LVs with AUC>0.90
#
#
# --- CLAMP_K = 250 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 250
#
# L1 is set to 49.4614340812896
#
# L2 is set to 148.384302243869
#
# Progress 1 / 200 | Bdiff=0.323703, minCor=0.768031
#
# Progress 2 / 200 | Bdiff=0.020152, minCor=0.963177
#
# Progress 3 / 200 | Bdiff=0.008963, minCor=0.987508
#
# Progress 4 / 200 | Bdiff=0.006882, minCor=0.990238
#
# Progress 5 / 200 | Bdiff=0.005754, minCor=0.991356
#
# Progress 6 / 200 | Bdiff=0.005037, minCor=0.991462
#
# Progress 7 / 200 | Bdiff=0.004542, minCor=0.992107
#
# Progress 8 / 200 | Bdiff=0.004190, minCor=0.993059
#
# Progress 9 / 200 | Bdiff=0.003924, minCor=0.994167
#
# Progress 10 / 200 | Bdiff=0.003691, minCor=0.995344
#
# Progress 11 / 200 | Bdiff=0.003456, minCor=0.996032
#
# Progress 12 / 200 | Bdiff=0.003208, minCor=0.996362
#
# Progress 13 / 200 | Bdiff=0.002952, minCor=0.996545
#
# Progress 14 / 200 | Bdiff=0.002707, minCor=0.996582
#
# Progress 15 / 200 | Bdiff=0.002484, minCor=0.996391
#
# Progress 16 / 200 | Bdiff=0.002283, minCor=0.996170
#
# Progress 17 / 200 | Bdiff=0.002109, minCor=0.995983
#
# Progress 18 / 200 | Bdiff=0.001957, minCor=0.995778
#
# Progress 19 / 200 | Bdiff=0.001825, minCor=0.995678
#
# Progress 20 / 200 | Bdiff=0.057639, minCor=0.894442
#
# Progress 21 / 200 | Bdiff=0.019689, minCor=0.965958
#
# Progress 22 / 200 | Bdiff=0.014180, minCor=0.973860
#
# Progress 23 / 200 | Bdiff=0.011287, minCor=0.977836
#
# Progress 24 / 200 | Bdiff=0.009053, minCor=0.982993
#
# Progress 25 / 200 | Bdiff=0.007444, minCor=0.980820
#
# Progress 26 / 200 | Bdiff=0.006283, minCor=0.985301
#
# Progress 27 / 200 | Bdiff=0.005361, minCor=0.983673
#
# Progress 28 / 200 | Bdiff=0.004582, minCor=0.987125
#
# Progress 29 / 200 | Bdiff=0.003997, minCor=0.985521
#
# Progress 30 / 200 | Bdiff=0.003497, minCor=0.986712
#
# Progress 31 / 200 | Bdiff=0.002951, minCor=0.990704
#
# Progress 32 / 200 | Bdiff=0.002489, minCor=0.986017
#
# Progress 33 / 200 | Bdiff=0.002149, minCor=0.977022
#
# Progress 34 / 200 | Bdiff=0.001940, minCor=0.968331
#
# Progress 35 / 200 | Bdiff=0.001744, minCor=0.976337
#
# Progress 36 / 200 | Bdiff=0.001565, minCor=0.986282
#
# Progress 37 / 200 | Bdiff=0.001403, minCor=0.992110
#
# Progress 38 / 200 | Bdiff=0.001231, minCor=0.992539
#
# Progress 39 / 200 | Bdiff=0.001117, minCor=0.991465
#
# Progress 40 / 200 | Bdiff=0.001007, minCor=0.990221
#
# Progress 41 / 200 | Bdiff=0.000946, minCor=0.991485
#
# Progress 42 / 200 | Bdiff=0.000879, minCor=0.991862
#
# Progress 43 / 200 | Bdiff=0.000829, minCor=0.992784
#
# Progress 44 / 200 | Bdiff=0.000803, minCor=0.991912
#
# Progress 45 / 200 | Bdiff=0.000786, minCor=0.992739
#
# Progress 46 / 200 | Bdiff=0.000740, minCor=0.995172
#
# Progress 47 / 200 | Bdiff=0.000743, minCor=0.993900
#
# Progress 48 / 200 | Bdiff=0.000677, minCor=0.994021
#
# Progress 49 / 200 | Bdiff=0.000657, minCor=0.993652
#
# Progress 50 / 200 | Bdiff=0.000618, minCor=0.993338
#
# Progress 51 / 200 | Bdiff=0.000565, minCor=0.992908
#
# Progress 52 / 200 | Bdiff=0.000544, minCor=0.993002
#
# Progress 53 / 200 | Bdiff=0.000500, minCor=0.992970
#
# Converged at iteration= 53 | Bdiff=0.000500,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 250
#
# L1=49.4614340812896; L2=148.384302243869
#
# Progress 1 / 30 | Bdiff=0.000464
#
# Progress 2 / 30 | Bdiff=0.009106
#
# Progress 3 / 30 | Bdiff=0.005043
#
# Estimated total runtime: ~9.1 min
#
# Progress 4 / 30 | Bdiff=0.003234
#
# Progress 5 / 30 | Bdiff=0.003214
#
# Progress 6 / 30 | Bdiff=0.002530
#
# Progress 7 / 30 | Bdiff=0.002187
#
# Progress 8 / 30 | Bdiff=0.002027
#
# Progress 9 / 30 | Bdiff=0.001589
#
# Progress 10 / 30 | Bdiff=0.001621
#
# Progress 11 / 30 | Bdiff=0.001749
#
# Progress 12 / 30 | Bdiff=0.001490
#
# Progress 13 / 30 | Bdiff=0.001464
#
# Progress 14 / 30 | Bdiff=0.001654
#
# Progress 15 / 30 | Bdiff=0.001592
#
# Progress 16 / 30 | Bdiff=0.001359
#
# Progress 17 / 30 | Bdiff=0.001779
#
# Progress 18 / 30 | Bdiff=0.001427
#
# Progress 19 / 30 | Bdiff=0.001397
#
# Progress 20 / 30 | Bdiff=0.001660
#
# Progress 21 / 30 | Bdiff=0.001441
#
# Progress 22 / 30 | Bdiff=0.001299
#
# Progress 23 / 30 | Bdiff=0.001847
#
# Progress 24 / 30 | Bdiff=0.001478
#
# Progress 25 / 30 | Bdiff=0.001338
#
# Progress 26 / 30 | Bdiff=0.001738
#
# Progress 27 / 30 | Bdiff=0.001502
#
# Progress 28 / 30 | Bdiff=0.001261
#
# Progress 29 / 30 | Bdiff=0.001920
#
# Progress 30 / 30 | Bdiff=0.001306
#
# Updating Z for CV
#
# crossValidation
#
# There are 216 LVs with AUC>0.70
#
# There are 120 LVs with AUC>0.90
#
#
# --- CLAMP_K = 500 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 500
#
# L1 is set to 39.3758127902391
#
# L2 is set to 118.127438370717
#
# Progress 1 / 200 | Bdiff=0.428280, minCor=0.757918
#
# Progress 2 / 200 | Bdiff=0.021470, minCor=0.970892
#
# Progress 3 / 200 | Bdiff=0.009755, minCor=0.984124
#
# Progress 4 / 200 | Bdiff=0.007719, minCor=0.987690
#
# Progress 5 / 200 | Bdiff=0.006640, minCor=0.989262
#
# Progress 6 / 200 | Bdiff=0.005898, minCor=0.990293
#
# Progress 7 / 200 | Bdiff=0.005334, minCor=0.991642
#
# Progress 8 / 200 | Bdiff=0.004874, minCor=0.992967
#
# Progress 9 / 200 | Bdiff=0.004459, minCor=0.992992
#
# Progress 10 / 200 | Bdiff=0.004063, minCor=0.992349
#
# Progress 11 / 200 | Bdiff=0.003682, minCor=0.991993
#
# Progress 12 / 200 | Bdiff=0.003319, minCor=0.992103
#
# Progress 13 / 200 | Bdiff=0.002989, minCor=0.992712
#
# Progress 14 / 200 | Bdiff=0.002703, minCor=0.993730
#
# Progress 15 / 200 | Bdiff=0.002459, minCor=0.994955
#
# Progress 16 / 200 | Bdiff=0.002255, minCor=0.995900
#
# Progress 17 / 200 | Bdiff=0.002083, minCor=0.996033
#
# Progress 18 / 200 | Bdiff=0.001938, minCor=0.996454
#
# Progress 19 / 200 | Bdiff=0.001812, minCor=0.996532
#
# Progress 20 / 200 | Bdiff=0.056355, minCor=0.872906
#
# Progress 21 / 200 | Bdiff=0.021427, minCor=0.931277
#
# Progress 22 / 200 | Bdiff=0.014626, minCor=0.955688
#
# Progress 23 / 200 | Bdiff=0.011585, minCor=0.958055
#
# Progress 24 / 200 | Bdiff=0.009866, minCor=0.971771
#
# Progress 25 / 200 | Bdiff=0.008482, minCor=0.967144
#
# Progress 26 / 200 | Bdiff=0.007620, minCor=0.959334
#
# Progress 27 / 200 | Bdiff=0.006756, minCor=0.970843
#
# Progress 28 / 200 | Bdiff=0.005838, minCor=0.973073
#
# Progress 29 / 200 | Bdiff=0.005033, minCor=0.977474
#
# Progress 30 / 200 | Bdiff=0.004315, minCor=0.953913
#
# Progress 31 / 200 | Bdiff=0.003845, minCor=0.955564
#
# Progress 32 / 200 | Bdiff=0.003278, minCor=0.973693
#
# Progress 33 / 200 | Bdiff=0.002825, minCor=0.986365
#
# Progress 34 / 200 | Bdiff=0.002463, minCor=0.988260
#
# Progress 35 / 200 | Bdiff=0.002141, minCor=0.989538
#
# Progress 36 / 200 | Bdiff=0.001889, minCor=0.988154
#
# Progress 37 / 200 | Bdiff=0.001721, minCor=0.989211
#
# Progress 38 / 200 | Bdiff=0.001568, minCor=0.988766
#
# Progress 39 / 200 | Bdiff=0.001442, minCor=0.991721
#
# Progress 40 / 200 | Bdiff=0.001314, minCor=0.990860
#
# Progress 41 / 200 | Bdiff=0.001227, minCor=0.987121
#
# Progress 42 / 200 | Bdiff=0.001153, minCor=0.984007
#
# Progress 43 / 200 | Bdiff=0.001057, minCor=0.982071
#
# Progress 44 / 200 | Bdiff=0.001007, minCor=0.984352
#
# Progress 45 / 200 | Bdiff=0.000918, minCor=0.988686
#
# Progress 46 / 200 | Bdiff=0.000875, minCor=0.983220
#
# Progress 47 / 200 | Bdiff=0.000829, minCor=0.982056
#
# Progress 48 / 200 | Bdiff=0.000772, minCor=0.988914
#
# Progress 49 / 200 | Bdiff=0.000729, minCor=0.991954
#
# Progress 50 / 200 | Bdiff=0.000686, minCor=0.994779
#
# Progress 51 / 200 | Bdiff=0.000619, minCor=0.993350
#
# Progress 52 / 200 | Bdiff=0.000573, minCor=0.989166
#
# Progress 53 / 200 | Bdiff=0.000532, minCor=0.987659
#
# Progress 54 / 200 | Bdiff=0.000507, minCor=0.989724
#
# Progress 55 / 200 | Bdiff=0.000495, minCor=0.990003
#
# Converged at iteration= 55 | Bdiff=0.000495,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 500
#
# L1=39.3758127902391; L2=118.127438370717
#
# Progress 1 / 30 | Bdiff=0.000471
#
# Progress 2 / 30 | Bdiff=0.013568
#
# Progress 3 / 30 | Bdiff=0.006909
#
# Estimated total runtime: ~19.6 min
#
# Progress 4 / 30 | Bdiff=0.005009
#
# Progress 5 / 30 | Bdiff=0.004491
#
# Progress 6 / 30 | Bdiff=0.003685
#
# Progress 7 / 30 | Bdiff=0.003011
#
# Progress 8 / 30 | Bdiff=0.003883
#
# Progress 9 / 30 | Bdiff=0.002837
#
# Progress 10 / 30 | Bdiff=0.002619
#
# Progress 11 / 30 | Bdiff=0.003218
#
# Progress 12 / 30 | Bdiff=0.002296
#
# Progress 13 / 30 | Bdiff=0.002164
#
# Progress 14 / 30 | Bdiff=0.002659
#
# Progress 15 / 30 | Bdiff=0.002148
#
# Progress 16 / 30 | Bdiff=0.002143
#
# Progress 17 / 30 | Bdiff=0.003069
#
# Progress 18 / 30 | Bdiff=0.002145
#
# Progress 19 / 30 | Bdiff=0.002142
#
# Progress 20 / 30 | Bdiff=0.002814
#
# Progress 21 / 30 | Bdiff=0.002049
#
# Progress 22 / 30 | Bdiff=0.001934
#
# Progress 23 / 30 | Bdiff=0.002711
#
# Progress 24 / 30 | Bdiff=0.002075
#
# Progress 25 / 30 | Bdiff=0.001886
#
# Progress 26 / 30 | Bdiff=0.002360
#
# Progress 27 / 30 | Bdiff=0.002051
#
# Progress 28 / 30 | Bdiff=0.001945
#
# Progress 29 / 30 | Bdiff=0.002492
#
# Progress 30 / 30 | Bdiff=0.002109
#
# Updating Z for CV
#
# crossValidation
#
# There are 420 LVs with AUC>0.70
#
# There are 207 LVs with AUC>0.90
#
#
# --- CLAMP_K = 750 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 750
#
# L1 is set to 32.7402270590983
#
# L2 is set to 98.2206811772948
#
# Progress 1 / 200 | Bdiff=0.452811, minCor=0.753706
#
# Progress 2 / 200 | Bdiff=0.022915, minCor=0.957774
#
# Progress 3 / 200 | Bdiff=0.010577, minCor=0.981221
#
# Progress 4 / 200 | Bdiff=0.008436, minCor=0.986423
#
# Progress 5 / 200 | Bdiff=0.007140, minCor=0.989297
#
# Progress 6 / 200 | Bdiff=0.006158, minCor=0.990410
#
# Progress 7 / 200 | Bdiff=0.005383, minCor=0.990359
#
# Progress 8 / 200 | Bdiff=0.004760, minCor=0.990807
#
# Progress 9 / 200 | Bdiff=0.004239, minCor=0.991776
#
# Progress 10 / 200 | Bdiff=0.003792, minCor=0.990497
#
# Progress 11 / 200 | Bdiff=0.003406, minCor=0.989898
#
# Progress 12 / 200 | Bdiff=0.003074, minCor=0.990105
#
# Progress 13 / 200 | Bdiff=0.002792, minCor=0.987385
#
# Progress 14 / 200 | Bdiff=0.002555, minCor=0.985257
#
# Progress 15 / 200 | Bdiff=0.002359, minCor=0.986468
#
# Progress 16 / 200 | Bdiff=0.002198, minCor=0.990019
#
# Progress 17 / 200 | Bdiff=0.002062, minCor=0.992571
#
# Progress 18 / 200 | Bdiff=0.001945, minCor=0.992709
#
# Progress 19 / 200 | Bdiff=0.001843, minCor=0.991484
#
# Progress 20 / 200 | Bdiff=0.058938, minCor=0.888495
#
# Progress 21 / 200 | Bdiff=0.020378, minCor=0.957743
#
# Progress 22 / 200 | Bdiff=0.014026, minCor=0.938505
#
# Progress 23 / 200 | Bdiff=0.011309, minCor=0.945771
#
# Progress 24 / 200 | Bdiff=0.009647, minCor=0.961612
#
# Progress 25 / 200 | Bdiff=0.008507, minCor=0.953419
#
# Progress 26 / 200 | Bdiff=0.007283, minCor=0.960347
#
# Progress 27 / 200 | Bdiff=0.006402, minCor=0.964005
#
# Progress 28 / 200 | Bdiff=0.005598, minCor=0.958266
#
# Progress 29 / 200 | Bdiff=0.004911, minCor=0.955347
#
# Progress 30 / 200 | Bdiff=0.004343, minCor=0.947468
#
# Progress 31 / 200 | Bdiff=0.003882, minCor=0.959461
#
# Progress 32 / 200 | Bdiff=0.003501, minCor=0.951021
#
# Progress 33 / 200 | Bdiff=0.003132, minCor=0.966170
#
# Progress 34 / 200 | Bdiff=0.002842, minCor=0.965556
#
# Progress 35 / 200 | Bdiff=0.002615, minCor=0.976695
#
# Progress 36 / 200 | Bdiff=0.002360, minCor=0.974890
#
# Progress 37 / 200 | Bdiff=0.002239, minCor=0.968302
#
# Progress 38 / 200 | Bdiff=0.002170, minCor=0.956029
#
# Progress 39 / 200 | Bdiff=0.002021, minCor=0.965520
#
# Progress 40 / 200 | Bdiff=0.001872, minCor=0.983657
#
# Progress 41 / 200 | Bdiff=0.001751, minCor=0.986333
#
# Progress 42 / 200 | Bdiff=0.001635, minCor=0.988589
#
# Progress 43 / 200 | Bdiff=0.001496, minCor=0.990890
#
# Progress 44 / 200 | Bdiff=0.001454, minCor=0.991334
#
# Progress 45 / 200 | Bdiff=0.001339, minCor=0.993658
#
# Progress 46 / 200 | Bdiff=0.001251, minCor=0.994637
#
# Progress 47 / 200 | Bdiff=0.001172, minCor=0.992730
#
# Progress 48 / 200 | Bdiff=0.001089, minCor=0.994055
#
# Progress 49 / 200 | Bdiff=0.001038, minCor=0.993936
#
# Progress 50 / 200 | Bdiff=0.000964, minCor=0.995248
#
# Progress 51 / 200 | Bdiff=0.000903, minCor=0.995306
#
# Progress 52 / 200 | Bdiff=0.000837, minCor=0.995462
#
# Progress 53 / 200 | Bdiff=0.000766, minCor=0.995272
#
# Progress 54 / 200 | Bdiff=0.000738, minCor=0.994575
#
# Progress 55 / 200 | Bdiff=0.000717, minCor=0.992893
#
# Progress 56 / 200 | Bdiff=0.000669, minCor=0.993399
#
# Progress 57 / 200 | Bdiff=0.000641, minCor=0.991950
#
# Progress 58 / 200 | Bdiff=0.000625, minCor=0.987512
#
# Progress 59 / 200 | Bdiff=0.000631, minCor=0.978821
#
# Progress 60 / 200 | Bdiff=0.000671, minCor=0.937301
#
# Progress 61 / 200 | Bdiff=0.000643, minCor=0.935541
#
# Progress 62 / 200 | Bdiff=0.000579, minCor=0.978120
#
# Progress 63 / 200 | Bdiff=0.000536, minCor=0.991180
#
# Progress 64 / 200 | Bdiff=0.000498, minCor=0.990030
#
# Converged at iteration= 64 | Bdiff=0.000498,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 750
#
# L1=32.7402270590983; L2=98.2206811772948
#
# Progress 1 / 30 | Bdiff=0.000479
#
# Progress 2 / 30 | Bdiff=0.013242
#
# Progress 3 / 30 | Bdiff=0.007396
#
# Estimated total runtime: ~33.0 min
#
# Progress 4 / 30 | Bdiff=0.006415
#
# Progress 5 / 30 | Bdiff=0.006070
#
# Progress 6 / 30 | Bdiff=0.005965
#
# Progress 7 / 30 | Bdiff=0.005777
#
# Progress 8 / 30 | Bdiff=0.005540
#
# Progress 9 / 30 | Bdiff=0.005023
#
# Progress 10 / 30 | Bdiff=0.004751
#
# Progress 11 / 30 | Bdiff=0.004948
#
# Progress 12 / 30 | Bdiff=0.003738
#
# Progress 13 / 30 | Bdiff=0.003315
#
# Progress 14 / 30 | Bdiff=0.004292
#
# Progress 15 / 30 | Bdiff=0.003323
#
# Progress 16 / 30 | Bdiff=0.003201
#
# Progress 17 / 30 | Bdiff=0.004346
#
# Progress 18 / 30 | Bdiff=0.002986
#
# Progress 19 / 30 | Bdiff=0.002711
#
# Progress 20 / 30 | Bdiff=0.003720
#
# Progress 21 / 30 | Bdiff=0.002698
#
# Progress 22 / 30 | Bdiff=0.002295
#
# Progress 23 / 30 | Bdiff=0.003313
#
# Progress 24 / 30 | Bdiff=0.002239
#
# Progress 25 / 30 | Bdiff=0.001989
#
# Progress 26 / 30 | Bdiff=0.003442
#
# Progress 27 / 30 | Bdiff=0.002205
#
# Progress 28 / 30 | Bdiff=0.002097
#
# Progress 29 / 30 | Bdiff=0.003125
#
# Progress 30 / 30 | Bdiff=0.002369
#
# Updating Z for CV
#
# crossValidation
#
# There are 595 LVs with AUC>0.70
#
# There are 256 LVs with AUC>0.90
#
#
# --- CLAMP_K = 1000 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 1000
#
# L1 is set to 27.9318007185334
#
# L2 is set to 83.7954021556003
#
# Progress 1 / 200 | Bdiff=0.447670, minCor=0.751402
#
# Progress 2 / 200 | Bdiff=0.024126, minCor=0.954350
#
# Progress 3 / 200 | Bdiff=0.011369, minCor=0.976588
#
# Progress 4 / 200 | Bdiff=0.008980, minCor=0.983545
#
# Progress 5 / 200 | Bdiff=0.007400, minCor=0.987789
#
# Progress 6 / 200 | Bdiff=0.006200, minCor=0.989014
#
# Progress 7 / 200 | Bdiff=0.005281, minCor=0.987991
#
# Progress 8 / 200 | Bdiff=0.004583, minCor=0.985358
#
# Progress 9 / 200 | Bdiff=0.004043, minCor=0.984699
#
# Progress 10 / 200 | Bdiff=0.003609, minCor=0.987047
#
# Progress 11 / 200 | Bdiff=0.003245, minCor=0.991145
#
# Progress 12 / 200 | Bdiff=0.002939, minCor=0.992537
#
# Progress 13 / 200 | Bdiff=0.002682, minCor=0.992345
#
# Progress 14 / 200 | Bdiff=0.002469, minCor=0.989197
#
# Progress 15 / 200 | Bdiff=0.002292, minCor=0.986427
#
# Progress 16 / 200 | Bdiff=0.002145, minCor=0.985912
#
# Progress 17 / 200 | Bdiff=0.002019, minCor=0.987992
#
# Progress 18 / 200 | Bdiff=0.001910, minCor=0.991262
#
# Progress 19 / 200 | Bdiff=0.001815, minCor=0.992317
#
# Progress 20 / 200 | Bdiff=0.060466, minCor=0.888421
#
# Progress 21 / 200 | Bdiff=0.020202, minCor=0.931395
#
# Progress 22 / 200 | Bdiff=0.013815, minCor=0.952311
#
# Progress 23 / 200 | Bdiff=0.010925, minCor=0.938777
#
# Progress 24 / 200 | Bdiff=0.009259, minCor=0.950748
#
# Progress 25 / 200 | Bdiff=0.008059, minCor=0.946282
#
# Progress 26 / 200 | Bdiff=0.006986, minCor=0.961180
#
# Progress 27 / 200 | Bdiff=0.006259, minCor=0.966667
#
# Progress 28 / 200 | Bdiff=0.005658, minCor=0.960502
#
# Progress 29 / 200 | Bdiff=0.004943, minCor=0.971976
#
# Progress 30 / 200 | Bdiff=0.004251, minCor=0.976894
#
# Progress 31 / 200 | Bdiff=0.003710, minCor=0.982925
#
# Progress 32 / 200 | Bdiff=0.003271, minCor=0.974602
#
# Progress 33 / 200 | Bdiff=0.002911, minCor=0.967991
#
# Progress 34 / 200 | Bdiff=0.002701, minCor=0.970643
#
# Progress 35 / 200 | Bdiff=0.002534, minCor=0.974366
#
# Progress 36 / 200 | Bdiff=0.002383, minCor=0.981359
#
# Progress 37 / 200 | Bdiff=0.002249, minCor=0.983440
#
# Progress 38 / 200 | Bdiff=0.002087, minCor=0.984938
#
# Progress 39 / 200 | Bdiff=0.001972, minCor=0.985534
#
# Progress 40 / 200 | Bdiff=0.001815, minCor=0.983351
#
# Progress 41 / 200 | Bdiff=0.001698, minCor=0.982617
#
# Progress 42 / 200 | Bdiff=0.001603, minCor=0.983036
#
# Progress 43 / 200 | Bdiff=0.001521, minCor=0.987210
#
# Progress 44 / 200 | Bdiff=0.001452, minCor=0.987791
#
# Progress 45 / 200 | Bdiff=0.001380, minCor=0.985381
#
# Progress 46 / 200 | Bdiff=0.001300, minCor=0.985746
#
# Progress 47 / 200 | Bdiff=0.001234, minCor=0.989302
#
# Progress 48 / 200 | Bdiff=0.001193, minCor=0.990943
#
# Progress 49 / 200 | Bdiff=0.001174, minCor=0.991341
#
# Progress 50 / 200 | Bdiff=0.001144, minCor=0.990214
#
# Progress 51 / 200 | Bdiff=0.001156, minCor=0.987645
#
# Progress 52 / 200 | Bdiff=0.001132, minCor=0.990601
#
# Progress 53 / 200 | Bdiff=0.001100, minCor=0.990088
#
# Progress 54 / 200 | Bdiff=0.001047, minCor=0.989151
#
# Progress 55 / 200 | Bdiff=0.001050, minCor=0.988486
#
# Progress 56 / 200 | Bdiff=0.001049, minCor=0.986948
#
# Progress 57 / 200 | Bdiff=0.001007, minCor=0.988507
#
# Progress 58 / 200 | Bdiff=0.000972, minCor=0.984568
#
# Progress 59 / 200 | Bdiff=0.000955, minCor=0.977966
#
# Progress 60 / 200 | Bdiff=0.000916, minCor=0.976630
#
# Progress 61 / 200 | Bdiff=0.000897, minCor=0.980303
#
# Progress 62 / 200 | Bdiff=0.000843, minCor=0.991914
#
# Progress 63 / 200 | Bdiff=0.000799, minCor=0.992002
#
# Progress 64 / 200 | Bdiff=0.000766, minCor=0.991950
#
# Progress 65 / 200 | Bdiff=0.000749, minCor=0.986188
#
# Progress 66 / 200 | Bdiff=0.000736, minCor=0.983588
#
# Progress 67 / 200 | Bdiff=0.000690, minCor=0.985640
#
# Progress 68 / 200 | Bdiff=0.000651, minCor=0.989351
#
# Progress 69 / 200 | Bdiff=0.000613, minCor=0.992767
#
# Progress 70 / 200 | Bdiff=0.000588, minCor=0.992056
#
# Progress 71 / 200 | Bdiff=0.000563, minCor=0.991435
#
# Progress 72 / 200 | Bdiff=0.000539, minCor=0.990114
#
# Progress 73 / 200 | Bdiff=0.000533, minCor=0.988879
#
# Progress 74 / 200 | Bdiff=0.000518, minCor=0.990905
#
# Progress 75 / 200 | Bdiff=0.000502, minCor=0.993083
#
# Progress 76 / 200 | Bdiff=0.000474, minCor=0.990776
#
# Converged at iteration= 76 | Bdiff=0.000474,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 1000
#
# L1=27.9318007185334; L2=83.7954021556003
#
# Progress 1 / 30 | Bdiff=0.000473
#
# Progress 2 / 30 | Bdiff=0.012309
#
# Progress 3 / 30 | Bdiff=0.009274
#
# Estimated total runtime: ~48.1 min
#
# Progress 4 / 30 | Bdiff=0.006920
#
# Progress 5 / 30 | Bdiff=0.006239
#
# Progress 6 / 30 | Bdiff=0.006072
#
# Progress 7 / 30 | Bdiff=0.005780
#
# Progress 8 / 30 | Bdiff=0.005679
#
# Progress 9 / 30 | Bdiff=0.005570
#
# Progress 10 / 30 | Bdiff=0.005420
#
# Progress 11 / 30 | Bdiff=0.005873
#
# Progress 12 / 30 | Bdiff=0.004267
#
# Progress 13 / 30 | Bdiff=0.003853
#
# Progress 14 / 30 | Bdiff=0.004581
#
# Progress 15 / 30 | Bdiff=0.003381
#
# Progress 16 / 30 | Bdiff=0.002971
#
# Progress 17 / 30 | Bdiff=0.004005
#
# Progress 18 / 30 | Bdiff=0.002777
#
# Progress 19 / 30 | Bdiff=0.002711
#
# Progress 20 / 30 | Bdiff=0.003946
#
# Progress 21 / 30 | Bdiff=0.002744
#
# Progress 22 / 30 | Bdiff=0.002478
#
# Progress 23 / 30 | Bdiff=0.004204
#
# Progress 24 / 30 | Bdiff=0.002801
#
# Progress 25 / 30 | Bdiff=0.002332
#
# Progress 26 / 30 | Bdiff=0.004101
#
# Progress 27 / 30 | Bdiff=0.002515
#
# Progress 28 / 30 | Bdiff=0.002128
#
# Progress 29 / 30 | Bdiff=0.003512
#
# Progress 30 / 30 | Bdiff=0.002313
#
# Updating Z for CV
#
# crossValidation
#
# There are 775 LVs with AUC>0.70
#
# There are 328 LVs with AUC>0.90
#
#
# ============================================================
#
# SEED 2/5 (124)
#
# ============================================================
#
# Selected 310 studies with 6056 total samples
#
# Creating subsampled FBM...
#
# Computing SVD (k=6055)...
#
# SVD done: 6055 valid components
#
#
# --- CLAMP_K = 50 (seed 2) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 50
#
# L1 is set to 128.46119953971
#
# L2 is set to 385.383598619131
#
# Progress 1 / 200 | Bdiff=0.368443, minCor=0.885840
#
# Progress 2 / 200 | Bdiff=0.026649, minCor=0.947910
#
# Progress 3 / 200 | Bdiff=0.011581, minCor=0.983458
#
# Progress 4 / 200 | Bdiff=0.007649, minCor=0.986718
#
# Progress 5 / 200 | Bdiff=0.005635, minCor=0.990434
#
# Progress 6 / 200 | Bdiff=0.004481, minCor=0.993843
#
# Progress 7 / 200 | Bdiff=0.003711, minCor=0.995333
#
# Progress 8 / 200 | Bdiff=0.003136, minCor=0.995415
#
# Progress 9 / 200 | Bdiff=0.002682, minCor=0.995616
#
# Progress 10 / 200 | Bdiff=0.002324, minCor=0.995638
#
# Progress 11 / 200 | Bdiff=0.002043, minCor=0.995072
#
# Progress 12 / 200 | Bdiff=0.001820, minCor=0.994746
#
# Progress 13 / 200 | Bdiff=0.001639, minCor=0.994984
#
# Progress 14 / 200 | Bdiff=0.001484, minCor=0.995883
#
# Progress 15 / 200 | Bdiff=0.001349, minCor=0.997179
#
# Progress 16 / 200 | Bdiff=0.001232, minCor=0.997331
#
# Progress 17 / 200 | Bdiff=0.001139, minCor=0.997459
#
# Progress 18 / 200 | Bdiff=0.001070, minCor=0.997610
#
# Progress 19 / 200 | Bdiff=0.001018, minCor=0.997789
#
# Progress 20 / 200 | Bdiff=0.037016, minCor=0.963936
#
# Progress 21 / 200 | Bdiff=0.010612, minCor=0.977816
#
# Progress 22 / 200 | Bdiff=0.007085, minCor=0.982361
#
# Progress 23 / 200 | Bdiff=0.005247, minCor=0.985414
#
# Progress 24 / 200 | Bdiff=0.004356, minCor=0.983480
#
# Progress 25 / 200 | Bdiff=0.003896, minCor=0.984144
#
# Progress 26 / 200 | Bdiff=0.003152, minCor=0.986585
#
# Progress 27 / 200 | Bdiff=0.002431, minCor=0.991391
#
# Progress 28 / 200 | Bdiff=0.001751, minCor=0.990520
#
# Progress 29 / 200 | Bdiff=0.001256, minCor=0.988908
#
# Progress 30 / 200 | Bdiff=0.001044, minCor=0.989544
#
# Progress 31 / 200 | Bdiff=0.000890, minCor=0.990956
#
# Progress 32 / 200 | Bdiff=0.000778, minCor=0.992910
#
# Progress 33 / 200 | Bdiff=0.000665, minCor=0.993254
#
# Progress 34 / 200 | Bdiff=0.000565, minCor=0.994920
#
# Progress 35 / 200 | Bdiff=0.000474, minCor=0.996926
#
# Converged at iteration= 35 | Bdiff=0.000474,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 50
#
# L1=128.46119953971; L2=385.383598619131
#
# Progress 1 / 30 | Bdiff=0.000404
#
# Progress 2 / 30 | Bdiff=0.001172
#
# Progress 3 / 30 | Bdiff=0.000800
#
# Estimated total runtime: ~2.5 min
#
# Progress 4 / 30 | Bdiff=0.000582
#
# Progress 5 / 30 | Bdiff=0.000537
#
# Progress 6 / 30 | Bdiff=0.000600
#
# Progress 7 / 30 | Bdiff=0.000447
#
# Progress 8 / 30 | Bdiff=0.000511
#
# Progress 9 / 30 | Bdiff=0.000507
#
# Progress 10 / 30 | Bdiff=0.000564
#
# Progress 11 / 30 | Bdiff=0.000420
#
# Progress 12 / 30 | Bdiff=0.000487
#
# Progress 13 / 30 | Bdiff=0.000368
#
# Progress 14 / 30 | Bdiff=0.000353
#
# Progress 15 / 30 | Bdiff=0.000349
#
# Progress 16 / 30 | Bdiff=0.000436
#
# Progress 17 / 30 | Bdiff=0.000291
#
# Progress 18 / 30 | Bdiff=0.000409
#
# Progress 19 / 30 | Bdiff=0.000384
#
# Progress 20 / 30 | Bdiff=0.000397
#
# Progress 21 / 30 | Bdiff=0.000399
#
# Progress 22 / 30 | Bdiff=0.000578
#
# Progress 23 / 30 | Bdiff=0.000398
#
# Progress 24 / 30 | Bdiff=0.000404
#
# Progress 25 / 30 | Bdiff=0.000291
#
# Progress 26 / 30 | Bdiff=0.000435
#
# Progress 27 / 30 | Bdiff=0.000383
#
# Progress 28 / 30 | Bdiff=0.000498
#
# Progress 29 / 30 | Bdiff=0.000431
#
# Progress 30 / 30 | Bdiff=0.000507
#
# Updating Z for CV
#
# crossValidation
#
# There are 48 LVs with AUC>0.70
#
# There are 35 LVs with AUC>0.90
#
#
# --- CLAMP_K = 100 (seed 2) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 100
#
# L1 is set to 83.3025399786155
#
# L2 is set to 249.907619935846
#
# Progress 1 / 200 | Bdiff=0.326500, minCor=0.908799
#
# Progress 2 / 200 | Bdiff=0.023239, minCor=0.961201
#
# Progress 3 / 200 | Bdiff=0.010726, minCor=0.986794
#
# Progress 4 / 200 | Bdiff=0.007633, minCor=0.989723
#
# Progress 5 / 200 | Bdiff=0.005964, minCor=0.992004
#
# Progress 6 / 200 | Bdiff=0.004929, minCor=0.993121
#
# Progress 7 / 200 | Bdiff=0.004207, minCor=0.993521
#
# Progress 8 / 200 | Bdiff=0.003647, minCor=0.994123
#
# Progress 9 / 200 | Bdiff=0.003187, minCor=0.994393
#
# Progress 10 / 200 | Bdiff=0.002804, minCor=0.994949
#
# Progress 11 / 200 | Bdiff=0.002487, minCor=0.995687
#
# Progress 12 / 200 | Bdiff=0.002232, minCor=0.996142
#
# Progress 13 / 200 | Bdiff=0.002037, minCor=0.996328
#
# Progress 14 / 200 | Bdiff=0.001893, minCor=0.996566
#
# Progress 15 / 200 | Bdiff=0.001790, minCor=0.996813
#
# Progress 16 / 200 | Bdiff=0.001716, minCor=0.997029
#
# Progress 17 / 200 | Bdiff=0.001660, minCor=0.997255
#
# Progress 18 / 200 | Bdiff=0.001613, minCor=0.997307
#
# Progress 19 / 200 | Bdiff=0.001567, minCor=0.997421
#
# Progress 20 / 200 | Bdiff=0.050715, minCor=0.938744
#
# Progress 21 / 200 | Bdiff=0.014646, minCor=0.972010
#
# Progress 22 / 200 | Bdiff=0.010308, minCor=0.975943
#
# Progress 23 / 200 | Bdiff=0.007861, minCor=0.981068
#
# Progress 24 / 200 | Bdiff=0.005780, minCor=0.985369
#
# Progress 25 / 200 | Bdiff=0.004602, minCor=0.987045
#
# Progress 26 / 200 | Bdiff=0.003641, minCor=0.988272
#
# Progress 27 / 200 | Bdiff=0.002973, minCor=0.987105
#
# Progress 28 / 200 | Bdiff=0.002567, minCor=0.988182
#
# Progress 29 / 200 | Bdiff=0.002207, minCor=0.988956
#
# Progress 30 / 200 | Bdiff=0.001854, minCor=0.989087
#
# Progress 31 / 200 | Bdiff=0.001620, minCor=0.988714
#
# Progress 32 / 200 | Bdiff=0.001438, minCor=0.987394
#
# Progress 33 / 200 | Bdiff=0.001222, minCor=0.988848
#
# Progress 34 / 200 | Bdiff=0.001068, minCor=0.990426
#
# Progress 35 / 200 | Bdiff=0.000914, minCor=0.992522
#
# Progress 36 / 200 | Bdiff=0.000785, minCor=0.992537
#
# Progress 37 / 200 | Bdiff=0.000687, minCor=0.993128
#
# Progress 38 / 200 | Bdiff=0.000613, minCor=0.993983
#
# Progress 39 / 200 | Bdiff=0.000538, minCor=0.995827
#
# Progress 40 / 200 | Bdiff=0.000488, minCor=0.996427
#
# Converged at iteration= 40 | Bdiff=0.000488,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 100
#
# L1=83.3025399786155; L2=249.907619935846
#
# Progress 1 / 30 | Bdiff=0.000431
#
# Progress 2 / 30 | Bdiff=0.002809
#
# Progress 3 / 30 | Bdiff=0.001870
#
# Estimated total runtime: ~3.7 min
#
# Progress 4 / 30 | Bdiff=0.001115
#
# Progress 5 / 30 | Bdiff=0.001359
#
# Progress 6 / 30 | Bdiff=0.001040
#
# Progress 7 / 30 | Bdiff=0.001269
#
# Progress 8 / 30 | Bdiff=0.001162
#
# Progress 9 / 30 | Bdiff=0.001447
#
# Progress 10 / 30 | Bdiff=0.001090
#
# Progress 11 / 30 | Bdiff=0.001295
#
# Progress 12 / 30 | Bdiff=0.001094
#
# Progress 13 / 30 | Bdiff=0.001002
#
# Progress 14 / 30 | Bdiff=0.001058
#
# Progress 15 / 30 | Bdiff=0.000697
#
# Progress 16 / 30 | Bdiff=0.000799
#
# Progress 17 / 30 | Bdiff=0.000787
#
# Progress 18 / 30 | Bdiff=0.000853
#
# Progress 19 / 30 | Bdiff=0.000874
#
# Progress 20 / 30 | Bdiff=0.000785
#
# Progress 21 / 30 | Bdiff=0.000608
#
# Progress 22 / 30 | Bdiff=0.000748
#
# Progress 23 / 30 | Bdiff=0.000724
#
# Progress 24 / 30 | Bdiff=0.000628
#
# Progress 25 / 30 | Bdiff=0.000582
#
# Progress 26 / 30 | Bdiff=0.000679
#
# Progress 27 / 30 | Bdiff=0.000595
#
# Progress 28 / 30 | Bdiff=0.000547
#
# Progress 29 / 30 | Bdiff=0.000568
#
# Progress 30 / 30 | Bdiff=0.000524
#
# Updating Z for CV
#
# crossValidation
#
# There are 93 LVs with AUC>0.70
#
# There are 66 LVs with AUC>0.90
#
#
# --- CLAMP_K = 250 (seed 2) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 250
#
# L1 is set to 49.0653004664884
#
# L2 is set to 147.195901399465
#
# Progress 1 / 200 | Bdiff=0.320390, minCor=0.853940
#
# Progress 2 / 200 | Bdiff=0.021094, minCor=0.959435
#
# Progress 3 / 200 | Bdiff=0.010356, minCor=0.982917
#
# Progress 4 / 200 | Bdiff=0.007951, minCor=0.984457
#
# Progress 5 / 200 | Bdiff=0.006546, minCor=0.988363
#
# Progress 6 / 200 | Bdiff=0.005589, minCor=0.991596
#
# Progress 7 / 200 | Bdiff=0.004875, minCor=0.993096
#
# Progress 8 / 200 | Bdiff=0.004305, minCor=0.993921
#
# Progress 9 / 200 | Bdiff=0.003838, minCor=0.994896
#
# Progress 10 / 200 | Bdiff=0.003451, minCor=0.995872
#
# Progress 11 / 200 | Bdiff=0.003131, minCor=0.996412
#
# Progress 12 / 200 | Bdiff=0.002859, minCor=0.996559
#
# Progress 13 / 200 | Bdiff=0.002627, minCor=0.996840
#
# Progress 14 / 200 | Bdiff=0.002430, minCor=0.997218
#
# Progress 15 / 200 | Bdiff=0.002260, minCor=0.997391
#
# Progress 16 / 200 | Bdiff=0.002109, minCor=0.997540
#
# Progress 17 / 200 | Bdiff=0.001972, minCor=0.997345
#
# Progress 18 / 200 | Bdiff=0.001847, minCor=0.997090
#
# Progress 19 / 200 | Bdiff=0.001731, minCor=0.996912
#
# Progress 20 / 200 | Bdiff=0.060535, minCor=0.912738
#
# Progress 21 / 200 | Bdiff=0.017021, minCor=0.967780
#
# Progress 22 / 200 | Bdiff=0.011647, minCor=0.972734
#
# Progress 23 / 200 | Bdiff=0.009328, minCor=0.973127
#
# Progress 24 / 200 | Bdiff=0.008086, minCor=0.975269
#
# Progress 25 / 200 | Bdiff=0.006989, minCor=0.977054
#
# Progress 26 / 200 | Bdiff=0.006127, minCor=0.977418
#
# Progress 27 / 200 | Bdiff=0.005362, minCor=0.980498
#
# Progress 28 / 200 | Bdiff=0.004486, minCor=0.984425
#
# Progress 29 / 200 | Bdiff=0.003787, minCor=0.980380
#
# Progress 30 / 200 | Bdiff=0.003148, minCor=0.980606
#
# Progress 31 / 200 | Bdiff=0.002744, minCor=0.989280
#
# Progress 32 / 200 | Bdiff=0.002399, minCor=0.991512
#
# Progress 33 / 200 | Bdiff=0.002103, minCor=0.992956
#
# Progress 34 / 200 | Bdiff=0.001898, minCor=0.992640
#
# Progress 35 / 200 | Bdiff=0.001758, minCor=0.991351
#
# Progress 36 / 200 | Bdiff=0.001598, minCor=0.989913
#
# Progress 37 / 200 | Bdiff=0.001434, minCor=0.993496
#
# Progress 38 / 200 | Bdiff=0.001339, minCor=0.993760
#
# Progress 39 / 200 | Bdiff=0.001223, minCor=0.994053
#
# Progress 40 / 200 | Bdiff=0.001157, minCor=0.993718
#
# Progress 41 / 200 | Bdiff=0.001048, minCor=0.994386
#
# Progress 42 / 200 | Bdiff=0.000947, minCor=0.994556
#
# Progress 43 / 200 | Bdiff=0.000874, minCor=0.995189
#
# Progress 44 / 200 | Bdiff=0.000806, minCor=0.994572
#
# Progress 45 / 200 | Bdiff=0.000737, minCor=0.994592
#
# Progress 46 / 200 | Bdiff=0.000660, minCor=0.996019
#
# Progress 47 / 200 | Bdiff=0.000603, minCor=0.996220
#
# Progress 48 / 200 | Bdiff=0.000565, minCor=0.995888
#
# Progress 49 / 200 | Bdiff=0.000515, minCor=0.995624
#
# Progress 50 / 200 | Bdiff=0.000485, minCor=0.992990
#
# Converged at iteration= 50 | Bdiff=0.000485,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 250
#
# L1=49.0653004664884; L2=147.195901399465
#
# Progress 1 / 30 | Bdiff=0.000480
#
# Progress 2 / 30 | Bdiff=0.007322
#
# Progress 3 / 30 | Bdiff=0.004203
#
# Estimated total runtime: ~8.0 min
#
# Progress 4 / 30 | Bdiff=0.003189
#
# Progress 5 / 30 | Bdiff=0.003256
#
# Progress 6 / 30 | Bdiff=0.002557
#
# Progress 7 / 30 | Bdiff=0.002184
#
# Progress 8 / 30 | Bdiff=0.002251
#
# Progress 9 / 30 | Bdiff=0.001845
#
# Progress 10 / 30 | Bdiff=0.001695
#
# Progress 11 / 30 | Bdiff=0.002046
#
# Progress 12 / 30 | Bdiff=0.001526
#
# Progress 13 / 30 | Bdiff=0.001495
#
# Progress 14 / 30 | Bdiff=0.001736
#
# Progress 15 / 30 | Bdiff=0.001537
#
# Progress 16 / 30 | Bdiff=0.001153
#
# Progress 17 / 30 | Bdiff=0.001456
#
# Progress 18 / 30 | Bdiff=0.001199
#
# Progress 19 / 30 | Bdiff=0.001180
#
# Progress 20 / 30 | Bdiff=0.001401
#
# Progress 21 / 30 | Bdiff=0.001041
#
# Progress 22 / 30 | Bdiff=0.001040
#
# Progress 23 / 30 | Bdiff=0.001329
#
# Progress 24 / 30 | Bdiff=0.001020
#
# Progress 25 / 30 | Bdiff=0.001030
#
# Progress 26 / 30 | Bdiff=0.001113
#
# Progress 27 / 30 | Bdiff=0.000916
#
# Progress 28 / 30 | Bdiff=0.000882
#
# Progress 29 / 30 | Bdiff=0.001135
#
# Progress 30 / 30 | Bdiff=0.000869
#
# Updating Z for CV
#
# crossValidation
#
# There are 215 LVs with AUC>0.70
#
# There are 124 LVs with AUC>0.90
#
#
# --- CLAMP_K = 500 (seed 2) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 500
#
# L1 is set to 38.6057492592039
#
# L2 is set to 115.817247777612
#
# Progress 1 / 200 | Bdiff=0.417445, minCor=0.853305
#
# Progress 2 / 200 | Bdiff=0.023142, minCor=0.967502
#
# Progress 3 / 200 | Bdiff=0.011499, minCor=0.980213
#
# Progress 4 / 200 | Bdiff=0.009143, minCor=0.983775
#
# Progress 5 / 200 | Bdiff=0.007763, minCor=0.987457
#
# Progress 6 / 200 | Bdiff=0.006727, minCor=0.990027
#
# Progress 7 / 200 | Bdiff=0.005870, minCor=0.992299
#
# Progress 8 / 200 | Bdiff=0.005143, minCor=0.994031
#
# Progress 9 / 200 | Bdiff=0.004526, minCor=0.994614
#
# Progress 10 / 200 | Bdiff=0.004011, minCor=0.994897
#
# Progress 11 / 200 | Bdiff=0.003576, minCor=0.995030
#
# Progress 12 / 200 | Bdiff=0.003211, minCor=0.995386
#
# Progress 13 / 200 | Bdiff=0.002904, minCor=0.995930
#
# Progress 14 / 200 | Bdiff=0.002639, minCor=0.996480
#
# Progress 15 / 200 | Bdiff=0.002408, minCor=0.996569
#
# Progress 16 / 200 | Bdiff=0.002206, minCor=0.996233
#
# Progress 17 / 200 | Bdiff=0.002026, minCor=0.995931
#
# Progress 18 / 200 | Bdiff=0.001872, minCor=0.995649
#
# Progress 19 / 200 | Bdiff=0.001737, minCor=0.995428
#
# Progress 20 / 200 | Bdiff=0.058332, minCor=0.911898
#
# Progress 21 / 200 | Bdiff=0.020730, minCor=0.956332
#
# Progress 22 / 200 | Bdiff=0.013689, minCor=0.963570
#
# Progress 23 / 200 | Bdiff=0.010623, minCor=0.968691
#
# Progress 24 / 200 | Bdiff=0.008862, minCor=0.977879
#
# Progress 25 / 200 | Bdiff=0.007773, minCor=0.978246
#
# Progress 26 / 200 | Bdiff=0.006853, minCor=0.966777
#
# Progress 27 / 200 | Bdiff=0.005840, minCor=0.972604
#
# Progress 28 / 200 | Bdiff=0.005007, minCor=0.967173
#
# Progress 29 / 200 | Bdiff=0.004333, minCor=0.960134
#
# Progress 30 / 200 | Bdiff=0.003734, minCor=0.975939
#
# Progress 31 / 200 | Bdiff=0.003299, minCor=0.988080
#
# Progress 32 / 200 | Bdiff=0.002960, minCor=0.983473
#
# Progress 33 / 200 | Bdiff=0.002639, minCor=0.977902
#
# Progress 34 / 200 | Bdiff=0.002426, minCor=0.977750
#
# Progress 35 / 200 | Bdiff=0.002203, minCor=0.983235
#
# Progress 36 / 200 | Bdiff=0.002032, minCor=0.978440
#
# Progress 37 / 200 | Bdiff=0.001890, minCor=0.971737
#
# Progress 38 / 200 | Bdiff=0.001769, minCor=0.977646
#
# Progress 39 / 200 | Bdiff=0.001619, minCor=0.988783
#
# Progress 40 / 200 | Bdiff=0.001477, minCor=0.991407
#
# Progress 41 / 200 | Bdiff=0.001363, minCor=0.991875
#
# Progress 42 / 200 | Bdiff=0.001276, minCor=0.990631
#
# Progress 43 / 200 | Bdiff=0.001166, minCor=0.991191
#
# Progress 44 / 200 | Bdiff=0.001099, minCor=0.992312
#
# Progress 45 / 200 | Bdiff=0.001013, minCor=0.994832
#
# Progress 46 / 200 | Bdiff=0.000929, minCor=0.995066
#
# Progress 47 / 200 | Bdiff=0.000893, minCor=0.995656
#
# Progress 48 / 200 | Bdiff=0.000817, minCor=0.994089
#
# Progress 49 / 200 | Bdiff=0.000763, minCor=0.991485
#
# Progress 50 / 200 | Bdiff=0.000732, minCor=0.989123
#
# Progress 51 / 200 | Bdiff=0.000692, minCor=0.988535
#
# Progress 52 / 200 | Bdiff=0.000659, minCor=0.988995
#
# Progress 53 / 200 | Bdiff=0.000635, minCor=0.989903
#
# Progress 54 / 200 | Bdiff=0.000605, minCor=0.990693
#
# Progress 55 / 200 | Bdiff=0.000551, minCor=0.993912
#
# Progress 56 / 200 | Bdiff=0.000520, minCor=0.993275
#
# Progress 57 / 200 | Bdiff=0.000497, minCor=0.993619
#
# Converged at iteration= 57 | Bdiff=0.000497,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 500
#
# L1=38.6057492592039; L2=115.817247777612
#
# Progress 1 / 30 | Bdiff=0.000469
#
# Progress 2 / 30 | Bdiff=0.010869
#
# Progress 3 / 30 | Bdiff=0.006578
#
# Estimated total runtime: ~17.4 min
#
# Progress 4 / 30 | Bdiff=0.005741
#
# Progress 5 / 30 | Bdiff=0.006023
#
# Progress 6 / 30 | Bdiff=0.005004
#
# Progress 7 / 30 | Bdiff=0.004490
#
# Progress 8 / 30 | Bdiff=0.004707
#
# Progress 9 / 30 | Bdiff=0.003972
#
# Progress 10 / 30 | Bdiff=0.003285
#
# Progress 11 / 30 | Bdiff=0.003975
#
# Progress 12 / 30 | Bdiff=0.002908
#
# Progress 13 / 30 | Bdiff=0.002787
#
# Progress 14 / 30 | Bdiff=0.003538
#
# Progress 15 / 30 | Bdiff=0.002603
#
# Progress 16 / 30 | Bdiff=0.002294
#
# Progress 17 / 30 | Bdiff=0.003267
#
# Progress 18 / 30 | Bdiff=0.002305
#
# Progress 19 / 30 | Bdiff=0.002234
#
# Progress 20 / 30 | Bdiff=0.003177
#
# Progress 21 / 30 | Bdiff=0.002280
#
# Progress 22 / 30 | Bdiff=0.002286
#
# Progress 23 / 30 | Bdiff=0.003263
#
# Progress 24 / 30 | Bdiff=0.002216
#
# Progress 25 / 30 | Bdiff=0.002129
#
# Progress 26 / 30 | Bdiff=0.003064
#
# Progress 27 / 30 | Bdiff=0.002246
#
# Progress 28 / 30 | Bdiff=0.002131
#
# Progress 29 / 30 | Bdiff=0.003014
#
# Progress 30 / 30 | Bdiff=0.002470
#
# Updating Z for CV
#
# crossValidation
#
# There are 421 LVs with AUC>0.70
#
# There are 215 LVs with AUC>0.90
#
#
# --- CLAMP_K = 750 (seed 2) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 750
#
# L1 is set to 32.0732036265952
#
# L2 is set to 96.2196108797856
#
# Progress 1 / 200 | Bdiff=0.440282, minCor=0.874206
#
# Progress 2 / 200 | Bdiff=0.024551, minCor=0.954196
#
# Progress 3 / 200 | Bdiff=0.012237, minCor=0.976760
#
# Progress 4 / 200 | Bdiff=0.009875, minCor=0.984171
#
# Progress 5 / 200 | Bdiff=0.008274, minCor=0.986278
#
# Progress 6 / 200 | Bdiff=0.006974, minCor=0.988937
#
# Progress 7 / 200 | Bdiff=0.005912, minCor=0.990300
#
# Progress 8 / 200 | Bdiff=0.005053, minCor=0.989699
#
# Progress 9 / 200 | Bdiff=0.004365, minCor=0.990232
#
# Progress 10 / 200 | Bdiff=0.003813, minCor=0.992027
#
# Progress 11 / 200 | Bdiff=0.003363, minCor=0.994149
#
# Progress 12 / 200 | Bdiff=0.002994, minCor=0.995193
#
# Progress 13 / 200 | Bdiff=0.002687, minCor=0.994456
#
# Progress 14 / 200 | Bdiff=0.002430, minCor=0.993434
#
# Progress 15 / 200 | Bdiff=0.002215, minCor=0.992558
#
# Progress 16 / 200 | Bdiff=0.002033, minCor=0.992289
#
# Progress 17 / 200 | Bdiff=0.001876, minCor=0.992829
#
# Progress 18 / 200 | Bdiff=0.001742, minCor=0.993902
#
# Progress 19 / 200 | Bdiff=0.001627, minCor=0.995091
#
# Progress 20 / 200 | Bdiff=0.061108, minCor=0.900235
#
# Progress 21 / 200 | Bdiff=0.020009, minCor=0.949843
#
# Progress 22 / 200 | Bdiff=0.013071, minCor=0.965137
#
# Progress 23 / 200 | Bdiff=0.009890, minCor=0.970369
#
# Progress 24 / 200 | Bdiff=0.008167, minCor=0.960729
#
# Progress 25 / 200 | Bdiff=0.007156, minCor=0.956482
#
# Progress 26 / 200 | Bdiff=0.006447, minCor=0.949069
#
# Progress 27 / 200 | Bdiff=0.005768, minCor=0.961485
#
# Progress 28 / 200 | Bdiff=0.005039, minCor=0.969842
#
# Progress 29 / 200 | Bdiff=0.004511, minCor=0.973516
#
# Progress 30 / 200 | Bdiff=0.004122, minCor=0.976319
#
# Progress 31 / 200 | Bdiff=0.003760, minCor=0.978148
#
# Progress 32 / 200 | Bdiff=0.003489, minCor=0.980182
#
# Progress 33 / 200 | Bdiff=0.003202, minCor=0.977399
#
# Progress 34 / 200 | Bdiff=0.002948, minCor=0.980810
#
# Progress 35 / 200 | Bdiff=0.002712, minCor=0.985640
#
# Progress 36 / 200 | Bdiff=0.002444, minCor=0.987434
#
# Progress 37 / 200 | Bdiff=0.002209, minCor=0.982953
#
# Progress 38 / 200 | Bdiff=0.001981, minCor=0.983688
#
# Progress 39 / 200 | Bdiff=0.001865, minCor=0.983202
#
# Progress 40 / 200 | Bdiff=0.001777, minCor=0.980650
#
# Progress 41 / 200 | Bdiff=0.001688, minCor=0.979830
#
# Progress 42 / 200 | Bdiff=0.001613, minCor=0.975344
#
# Progress 43 / 200 | Bdiff=0.001540, minCor=0.977760
#
# Progress 44 / 200 | Bdiff=0.001462, minCor=0.988313
#
# Progress 45 / 200 | Bdiff=0.001408, minCor=0.985957
#
# Progress 46 / 200 | Bdiff=0.001315, minCor=0.984974
#
# Progress 47 / 200 | Bdiff=0.001266, minCor=0.985745
#
# Progress 48 / 200 | Bdiff=0.001208, minCor=0.988681
#
# Progress 49 / 200 | Bdiff=0.001140, minCor=0.989094
#
# Progress 50 / 200 | Bdiff=0.001096, minCor=0.987306
#
# Progress 51 / 200 | Bdiff=0.001076, minCor=0.988502
#
# Progress 52 / 200 | Bdiff=0.001039, minCor=0.989017
#
# Progress 53 / 200 | Bdiff=0.000988, minCor=0.988179
#
# Progress 54 / 200 | Bdiff=0.000969, minCor=0.989467
#
# Progress 55 / 200 | Bdiff=0.000956, minCor=0.991804
#
# Progress 56 / 200 | Bdiff=0.000894, minCor=0.993240
#
# Progress 57 / 200 | Bdiff=0.000820, minCor=0.993077
#
# Progress 58 / 200 | Bdiff=0.000782, minCor=0.989847
#
# Progress 59 / 200 | Bdiff=0.000735, minCor=0.989968
#
# Progress 60 / 200 | Bdiff=0.000690, minCor=0.978107
#
# Progress 61 / 200 | Bdiff=0.000683, minCor=0.960091
#
# Progress 62 / 200 | Bdiff=0.000680, minCor=0.957267
#
# Progress 63 / 200 | Bdiff=0.000623, minCor=0.974220
#
# Progress 64 / 200 | Bdiff=0.000584, minCor=0.989763
#
# Progress 65 / 200 | Bdiff=0.000553, minCor=0.989132
#
# Progress 66 / 200 | Bdiff=0.000544, minCor=0.989682
#
# Progress 67 / 200 | Bdiff=0.000515, minCor=0.990525
#
# Progress 68 / 200 | Bdiff=0.000499, minCor=0.991526
#
# Converged at iteration= 68 | Bdiff=0.000499,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 750
#
# L1=32.0732036265952; L2=96.2196108797856
#
# Progress 1 / 30 | Bdiff=0.000488
#
# Progress 2 / 30 | Bdiff=0.014120
#
# Progress 3 / 30 | Bdiff=0.009951
#
# Estimated total runtime: ~31.7 min
#
# Progress 4 / 30 | Bdiff=0.007054
#
# Progress 5 / 30 | Bdiff=0.006313
#
# Progress 6 / 30 | Bdiff=0.005278
#
# Progress 7 / 30 | Bdiff=0.004527
#
# Progress 8 / 30 | Bdiff=0.005050
#
# Progress 9 / 30 | Bdiff=0.003911
#
# Progress 10 / 30 | Bdiff=0.003699
#
# Progress 11 / 30 | Bdiff=0.004580
#
# Progress 12 / 30 | Bdiff=0.003757
#
# Progress 13 / 30 | Bdiff=0.003267
#
# Progress 14 / 30 | Bdiff=0.004571
#
# Progress 15 / 30 | Bdiff=0.003502
#
# Progress 16 / 30 | Bdiff=0.003189
#
# Progress 17 / 30 | Bdiff=0.004528
#
# Progress 18 / 30 | Bdiff=0.002969
#
# Progress 19 / 30 | Bdiff=0.003036
#
# Progress 20 / 30 | Bdiff=0.003993
#
# Progress 21 / 30 | Bdiff=0.002877
#
# Progress 22 / 30 | Bdiff=0.002686
#
# Progress 23 / 30 | Bdiff=0.003424
#
# Progress 24 / 30 | Bdiff=0.002587
#
# ...
#
# Progress 68 / 200 | Bdiff=0.000512, minCor=0.993610
#
# Progress 69 / 200 | Bdiff=0.000465, minCor=0.994816
#
# Converged at iteration= 69 | Bdiff=0.000465,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 250
#
# L1=51.8922826145139; L2=155.676847843542
#
# Progress 1 / 30 | Bdiff=0.000431
#
# Progress 2 / 30 | Bdiff=0.009992
#
# Progress 3 / 30 | Bdiff=0.004696
#
# Estimated total runtime: ~8.2 min
#
# Progress 4 / 30 | Bdiff=0.003954
#
# Progress 5 / 30 | Bdiff=0.003382
#
# Progress 6 / 30 | Bdiff=0.003115
#
# Progress 7 / 30 | Bdiff=0.002803
#
# Progress 8 / 30 | Bdiff=0.002738
#
# Progress 9 / 30 | Bdiff=0.002266
#
# Progress 10 / 30 | Bdiff=0.003124
#
# Progress 11 / 30 | Bdiff=0.003219
#
# Progress 12 / 30 | Bdiff=0.003277
#
# Progress 13 / 30 | Bdiff=0.002719
#
# Progress 14 / 30 | Bdiff=0.002803
#
# Progress 15 / 30 | Bdiff=0.002329
#
# Progress 16 / 30 | Bdiff=0.002277
#
# Progress 17 / 30 | Bdiff=0.002532
#
# Progress 18 / 30 | Bdiff=0.001885
#
# Progress 19 / 30 | Bdiff=0.001606
#
# Progress 20 / 30 | Bdiff=0.002159
#
# Progress 21 / 30 | Bdiff=0.001600
#
# Progress 22 / 30 | Bdiff=0.001596
#
# Progress 23 / 30 | Bdiff=0.001963
#
# Progress 24 / 30 | Bdiff=0.001601
#
# Progress 25 / 30 | Bdiff=0.001603
#
# Progress 26 / 30 | Bdiff=0.001539
#
# Progress 27 / 30 | Bdiff=0.001272
#
# Progress 28 / 30 | Bdiff=0.001362
#
# Progress 29 / 30 | Bdiff=0.001808
#
# Progress 30 / 30 | Bdiff=0.001462
#
# Updating Z for CV
#
# crossValidation
#
# There are 212 LVs with AUC>0.70
#
# There are 111 LVs with AUC>0.90
#
#
# --- CLAMP_K = 500 (seed 5) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 500
#
# L1 is set to 43.7370078567877
#
# L2 is set to 131.211023570363
#
# Progress 1 / 200 | Bdiff=0.537229, minCor=0.774837
#
# Progress 2 / 200 | Bdiff=0.027449, minCor=0.956034
#
# Progress 3 / 200 | Bdiff=0.011576, minCor=0.984153
#
# Progress 4 / 200 | Bdiff=0.008251, minCor=0.986464
#
# Progress 5 / 200 | Bdiff=0.006591, minCor=0.989484
#
# Progress 6 / 200 | Bdiff=0.005541, minCor=0.990889
#
# Progress 7 / 200 | Bdiff=0.004787, minCor=0.991345
#
# Progress 8 / 200 | Bdiff=0.004184, minCor=0.992294
#
# Progress 9 / 200 | Bdiff=0.003690, minCor=0.993380
#
# Progress 10 / 200 | Bdiff=0.003287, minCor=0.994427
#
# Progress 11 / 200 | Bdiff=0.002956, minCor=0.994870
#
# Progress 12 / 200 | Bdiff=0.002684, minCor=0.994464
#
# Progress 13 / 200 | Bdiff=0.002462, minCor=0.994117
#
# Progress 14 / 200 | Bdiff=0.002273, minCor=0.993880
#
# Progress 15 / 200 | Bdiff=0.002112, minCor=0.994068
#
# Progress 16 / 200 | Bdiff=0.001971, minCor=0.994521
#
# Progress 17 / 200 | Bdiff=0.001845, minCor=0.995458
#
# Progress 18 / 200 | Bdiff=0.001730, minCor=0.996586
#
# Progress 19 / 200 | Bdiff=0.001623, minCor=0.997017
#
# Progress 20 / 200 | Bdiff=0.060597, minCor=0.919892
#
# Progress 21 / 200 | Bdiff=0.018649, minCor=0.953671
#
# Progress 22 / 200 | Bdiff=0.011895, minCor=0.978047
#
# Progress 23 / 200 | Bdiff=0.008780, minCor=0.980326
#
# Progress 24 / 200 | Bdiff=0.007338, minCor=0.979162
#
# Progress 25 / 200 | Bdiff=0.006487, minCor=0.982823
#
# Progress 26 / 200 | Bdiff=0.005829, minCor=0.985964
#
# Progress 27 / 200 | Bdiff=0.005342, minCor=0.982388
#
# Progress 28 / 200 | Bdiff=0.004847, minCor=0.986870
#
# Progress 29 / 200 | Bdiff=0.004305, minCor=0.986895
#
# Progress 30 / 200 | Bdiff=0.003665, minCor=0.989354
#
# Progress 31 / 200 | Bdiff=0.003156, minCor=0.991453
#
# Progress 32 / 200 | Bdiff=0.002730, minCor=0.993143
#
# Progress 33 / 200 | Bdiff=0.002367, minCor=0.992456
#
# Progress 34 / 200 | Bdiff=0.002099, minCor=0.991849
#
# Progress 35 / 200 | Bdiff=0.001879, minCor=0.992533
#
# Progress 36 / 200 | Bdiff=0.001733, minCor=0.991934
#
# Progress 37 / 200 | Bdiff=0.001615, minCor=0.992228
#
# Progress 38 / 200 | Bdiff=0.001511, minCor=0.992749
#
# Progress 39 / 200 | Bdiff=0.001451, minCor=0.993007
#
# Progress 40 / 200 | Bdiff=0.001391, minCor=0.992340
#
# Progress 41 / 200 | Bdiff=0.001283, minCor=0.994120
#
# Progress 42 / 200 | Bdiff=0.001231, minCor=0.994070
#
# Progress 43 / 200 | Bdiff=0.001182, minCor=0.993056
#
# Progress 44 / 200 | Bdiff=0.001137, minCor=0.992413
#
# Progress 45 / 200 | Bdiff=0.001068, minCor=0.991510
#
# Progress 46 / 200 | Bdiff=0.000994, minCor=0.994481
#
# Progress 47 / 200 | Bdiff=0.000960, minCor=0.994418
#
# Progress 48 / 200 | Bdiff=0.000921, minCor=0.995245
#
# Progress 49 / 200 | Bdiff=0.000884, minCor=0.995821
#
# Progress 50 / 200 | Bdiff=0.000864, minCor=0.994987
#
# Progress 51 / 200 | Bdiff=0.000816, minCor=0.994391
#
# Progress 52 / 200 | Bdiff=0.000794, minCor=0.994607
#
# Progress 53 / 200 | Bdiff=0.000772, minCor=0.994443
#
# Progress 54 / 200 | Bdiff=0.000751, minCor=0.994949
#
# Progress 55 / 200 | Bdiff=0.000682, minCor=0.995696
#
# Progress 56 / 200 | Bdiff=0.000633, minCor=0.995844
#
# Progress 57 / 200 | Bdiff=0.000589, minCor=0.995778
#
# Progress 58 / 200 | Bdiff=0.000536, minCor=0.995388
#
# Progress 59 / 200 | Bdiff=0.000494, minCor=0.996281
#
# Converged at iteration= 59 | Bdiff=0.000494,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 500
#
# L1=43.7370078567877; L2=131.211023570363
#
# Progress 1 / 30 | Bdiff=0.000453
#
# Progress 2 / 30 | Bdiff=0.009524
#
# Progress 3 / 30 | Bdiff=0.006758
#
# Estimated total runtime: ~12.4 min
#
# Progress 4 / 30 | Bdiff=0.005217
#
# Progress 5 / 30 | Bdiff=0.005161
#
# Progress 6 / 30 | Bdiff=0.004785
#
# Progress 7 / 30 | Bdiff=0.004113
#
# Progress 8 / 30 | Bdiff=0.005071
#
# Progress 9 / 30 | Bdiff=0.004868
#
# Progress 10 / 30 | Bdiff=0.005286
#
# Progress 11 / 30 | Bdiff=0.006098
#
# Progress 12 / 30 | Bdiff=0.004224
#
# Progress 13 / 30 | Bdiff=0.003390
#
# Progress 14 / 30 | Bdiff=0.005186
#
# Progress 15 / 30 | Bdiff=0.003232
#
# Progress 16 / 30 | Bdiff=0.003041
#
# Progress 17 / 30 | Bdiff=0.004774
#
# Progress 18 / 30 | Bdiff=0.003224
#
# Progress 19 / 30 | Bdiff=0.002793
#
# Progress 20 / 30 | Bdiff=0.004235
#
# Progress 21 / 30 | Bdiff=0.003011
#
# Progress 22 / 30 | Bdiff=0.002843
#
# Progress 23 / 30 | Bdiff=0.004073
#
# Progress 24 / 30 | Bdiff=0.003315
#
# Progress 25 / 30 | Bdiff=0.003592
#
# Progress 26 / 30 | Bdiff=0.005926
#
# Progress 27 / 30 | Bdiff=0.004163
#
# Progress 28 / 30 | Bdiff=0.003287
#
# Progress 29 / 30 | Bdiff=0.004052
#
# Progress 30 / 30 | Bdiff=0.002769
#
# Updating Z for CV
#
# crossValidation
#
# There are 397 LVs with AUC>0.70
#
# There are 198 LVs with AUC>0.90
#
#
# --- CLAMP_K = 750 (seed 5) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 750
#
# L1 is set to 38.9394876411496
#
# L2 is set to 116.818462923449
#
# Progress 1 / 200 | Bdiff=0.623077, minCor=0.788962
#
# Progress 2 / 200 | Bdiff=0.027557, minCor=0.958893
#
# Progress 3 / 200 | Bdiff=0.011543, minCor=0.981657
#
# Progress 4 / 200 | Bdiff=0.008456, minCor=0.983799
#
# Progress 5 / 200 | Bdiff=0.006800, minCor=0.986956
#
# Progress 6 / 200 | Bdiff=0.005674, minCor=0.990113
#
# Progress 7 / 200 | Bdiff=0.004826, minCor=0.992274
#
# Progress 8 / 200 | Bdiff=0.004151, minCor=0.994122
#
# Progress 9 / 200 | Bdiff=0.003602, minCor=0.995521
#
# Progress 10 / 200 | Bdiff=0.003162, minCor=0.994826
#
# Progress 11 / 200 | Bdiff=0.002813, minCor=0.994058
#
# Progress 12 / 200 | Bdiff=0.002533, minCor=0.993291
#
# Progress 13 / 200 | Bdiff=0.002305, minCor=0.992705
#
# Progress 14 / 200 | Bdiff=0.002113, minCor=0.992369
#
# Progress 15 / 200 | Bdiff=0.001949, minCor=0.992471
#
# Progress 16 / 200 | Bdiff=0.001807, minCor=0.992807
#
# Progress 17 / 200 | Bdiff=0.001678, minCor=0.991657
#
# Progress 18 / 200 | Bdiff=0.001562, minCor=0.990811
#
# Progress 19 / 200 | Bdiff=0.001456, minCor=0.991138
#
# Progress 20 / 200 | Bdiff=0.063926, minCor=0.919936
#
# Progress 21 / 200 | Bdiff=0.018151, minCor=0.963086
#
# Progress 22 / 200 | Bdiff=0.010987, minCor=0.976731
#
# Progress 23 / 200 | Bdiff=0.008142, minCor=0.983095
#
# Progress 24 / 200 | Bdiff=0.006490, minCor=0.982835
#
# Progress 25 / 200 | Bdiff=0.005444, minCor=0.984958
#
# Progress 26 / 200 | Bdiff=0.004814, minCor=0.986423
#
# Progress 27 / 200 | Bdiff=0.004438, minCor=0.989856
#
# Progress 28 / 200 | Bdiff=0.004224, minCor=0.990668
#
# Progress 29 / 200 | Bdiff=0.003839, minCor=0.990796
#
# Progress 30 / 200 | Bdiff=0.003654, minCor=0.991217
#
# Progress 31 / 200 | Bdiff=0.003436, minCor=0.989971
#
# Progress 32 / 200 | Bdiff=0.003093, minCor=0.988658
#
# Progress 33 / 200 | Bdiff=0.002770, minCor=0.990186
#
# Progress 34 / 200 | Bdiff=0.002485, minCor=0.990457
#
# Progress 35 / 200 | Bdiff=0.002243, minCor=0.991228
#
# Progress 36 / 200 | Bdiff=0.002044, minCor=0.992798
#
# Progress 37 / 200 | Bdiff=0.001852, minCor=0.993454
#
# Progress 38 / 200 | Bdiff=0.001655, minCor=0.992266
#
# Progress 39 / 200 | Bdiff=0.001515, minCor=0.992760
#
# Progress 40 / 200 | Bdiff=0.001411, minCor=0.994241
#
# Progress 41 / 200 | Bdiff=0.001343, minCor=0.993285
#
# Progress 42 / 200 | Bdiff=0.001245, minCor=0.994702
#
# Progress 43 / 200 | Bdiff=0.001150, minCor=0.996128
#
# Progress 44 / 200 | Bdiff=0.001084, minCor=0.994737
#
# Progress 45 / 200 | Bdiff=0.001031, minCor=0.993689
#
# Progress 46 / 200 | Bdiff=0.000978, minCor=0.994121
#
# Progress 47 / 200 | Bdiff=0.000927, minCor=0.992513
#
# Progress 48 / 200 | Bdiff=0.000882, minCor=0.993984
#
# Progress 49 / 200 | Bdiff=0.000870, minCor=0.992002
#
# Progress 50 / 200 | Bdiff=0.000850, minCor=0.995528
#
# Progress 51 / 200 | Bdiff=0.000819, minCor=0.995612
#
# Progress 52 / 200 | Bdiff=0.000779, minCor=0.996112
#
# Progress 53 / 200 | Bdiff=0.000794, minCor=0.996381
#
# Progress 54 / 200 | Bdiff=0.000776, minCor=0.997064
#
# Progress 55 / 200 | Bdiff=0.000766, minCor=0.997404
#
# Progress 56 / 200 | Bdiff=0.000764, minCor=0.996891
#
# Progress 57 / 200 | Bdiff=0.000778, minCor=0.996967
#
# Progress 58 / 200 | Bdiff=0.000705, minCor=0.997413
#
# Progress 59 / 200 | Bdiff=0.000646, minCor=0.997271
#
# Progress 60 / 200 | Bdiff=0.000609, minCor=0.997159
#
# Progress 61 / 200 | Bdiff=0.000548, minCor=0.996923
#
# Progress 62 / 200 | Bdiff=0.000506, minCor=0.996656
#
# Progress 63 / 200 | Bdiff=0.000477, minCor=0.996424
#
# Converged at iteration= 63 | Bdiff=0.000477,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 750
#
# L1=38.9394876411496; L2=116.818462923449
#
# Progress 1 / 30 | Bdiff=0.000448
#
# Progress 2 / 30 | Bdiff=0.014506
#
# Progress 3 / 30 | Bdiff=0.008459
#
# Estimated total runtime: ~17.3 min
#
# Progress 4 / 30 | Bdiff=0.006955
#
# Progress 5 / 30 | Bdiff=0.006985
#
# Progress 6 / 30 | Bdiff=0.007452
#
# Progress 7 / 30 | Bdiff=0.006321
#
# Progress 8 / 30 | Bdiff=0.007384
#
# Progress 9 / 30 | Bdiff=0.005713
#
# Progress 10 / 30 | Bdiff=0.005116
#
# Progress 11 / 30 | Bdiff=0.007062
#
# Progress 12 / 30 | Bdiff=0.004793
#
# Progress 13 / 30 | Bdiff=0.005513
#
# Progress 14 / 30 | Bdiff=0.009824
#
# Progress 15 / 30 | Bdiff=0.005831
#
# Progress 16 / 30 | Bdiff=0.006011
#
# Progress 17 / 30 | Bdiff=0.007492
#
# Progress 18 / 30 | Bdiff=0.005044
#
# Progress 19 / 30 | Bdiff=0.004538
#
# Progress 20 / 30 | Bdiff=0.006354
#
# Progress 21 / 30 | Bdiff=0.005309
#
# Progress 22 / 30 | Bdiff=0.004039
#
# Progress 23 / 30 | Bdiff=0.007044
#
# Progress 24 / 30 | Bdiff=0.003976
#
# Progress 25 / 30 | Bdiff=0.003867
#
# Progress 26 / 30 | Bdiff=0.006815
#
# Progress 27 / 30 | Bdiff=0.003816
#
# Progress 28 / 30 | Bdiff=0.003819
#
# Progress 29 / 30 | Bdiff=0.006458
#
# Progress 30 / 30 | Bdiff=0.003522
#
# Updating Z for CV
#
# crossValidation
#
# There are 572 LVs with AUC>0.70
#
# There are 250 LVs with AUC>0.90
#
#
# --- CLAMP_K = 1000 (seed 5) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 1000
#
# L1 is set to 34.990348359906
#
# L2 is set to 104.971045079718
#
# Progress 1 / 200 | Bdiff=0.656342, minCor=0.780633
#
# Progress 2 / 200 | Bdiff=0.028488, minCor=0.957483
#
# Progress 3 / 200 | Bdiff=0.011987, minCor=0.977599
#
# Progress 4 / 200 | Bdiff=0.008828, minCor=0.984281
#
# Progress 5 / 200 | Bdiff=0.007023, minCor=0.989772
#
# Progress 6 / 200 | Bdiff=0.005771, minCor=0.992457
#
# Progress 7 / 200 | Bdiff=0.004841, minCor=0.994163
#
# Progress 8 / 200 | Bdiff=0.004125, minCor=0.995254
#
# Progress 9 / 200 | Bdiff=0.003561, minCor=0.995167
#
# Progress 10 / 200 | Bdiff=0.003110, minCor=0.994834
#
# Progress 11 / 200 | Bdiff=0.002750, minCor=0.994562
#
# Progress 12 / 200 | Bdiff=0.002463, minCor=0.994393
#
# Progress 13 / 200 | Bdiff=0.002226, minCor=0.994280
#
# Progress 14 / 200 | Bdiff=0.002031, minCor=0.994027
#
# Progress 15 / 200 | Bdiff=0.001865, minCor=0.993900
#
# Progress 16 / 200 | Bdiff=0.001720, minCor=0.992573
#
# Progress 17 / 200 | Bdiff=0.001592, minCor=0.991197
#
# Progress 18 / 200 | Bdiff=0.001477, minCor=0.990259
#
# Progress 19 / 200 | Bdiff=0.001374, minCor=0.990604
#
# Progress 20 / 200 | Bdiff=0.067995, minCor=0.927845
#
# Progress 21 / 200 | Bdiff=0.018178, minCor=0.969511
#
# Progress 22 / 200 | Bdiff=0.010742, minCor=0.982464
#
# Progress 23 / 200 | Bdiff=0.007945, minCor=0.986187
#
# Progress 24 / 200 | Bdiff=0.006229, minCor=0.984310
#
# Progress 25 / 200 | Bdiff=0.005194, minCor=0.982770
#
# Progress 26 / 200 | Bdiff=0.004596, minCor=0.983753
#
# Progress 27 / 200 | Bdiff=0.004113, minCor=0.990991
#
# Progress 28 / 200 | Bdiff=0.003692, minCor=0.991349
#
# Progress 29 / 200 | Bdiff=0.003447, minCor=0.991868
#
# Progress 30 / 200 | Bdiff=0.003214, minCor=0.992421
#
# Progress 31 / 200 | Bdiff=0.002923, minCor=0.993318
#
# Progress 32 / 200 | Bdiff=0.002756, minCor=0.993600
#
# Progress 33 / 200 | Bdiff=0.002631, minCor=0.991968
#
# Progress 34 / 200 | Bdiff=0.002486, minCor=0.988952
#
# Progress 35 / 200 | Bdiff=0.002342, minCor=0.987698
#
# Progress 36 / 200 | Bdiff=0.002146, minCor=0.987667
#
# Progress 37 / 200 | Bdiff=0.001939, minCor=0.988168
#
# Progress 38 / 200 | Bdiff=0.001785, minCor=0.987914
#
# Progress 39 / 200 | Bdiff=0.001662, minCor=0.992993
#
# Progress 40 / 200 | Bdiff=0.001559, minCor=0.993125
#
# Progress 41 / 200 | Bdiff=0.001480, minCor=0.993450
#
# Progress 42 / 200 | Bdiff=0.001419, minCor=0.993278
#
# Progress 43 / 200 | Bdiff=0.001349, minCor=0.993132
#
# Progress 44 / 200 | Bdiff=0.001346, minCor=0.994271
#
# Progress 45 / 200 | Bdiff=0.001356, minCor=0.995048
#
# Progress 46 / 200 | Bdiff=0.001357, minCor=0.995307
#
# Progress 47 / 200 | Bdiff=0.001299, minCor=0.995095
#
# Progress 48 / 200 | Bdiff=0.001194, minCor=0.995815
#
# Progress 49 / 200 | Bdiff=0.001086, minCor=0.996651
#
# Progress 50 / 200 | Bdiff=0.001024, minCor=0.996642
#
# Progress 51 / 200 | Bdiff=0.000926, minCor=0.996780
#
# Progress 52 / 200 | Bdiff=0.000877, minCor=0.995527
#
# Progress 53 / 200 | Bdiff=0.000797, minCor=0.995836
#
# Progress 54 / 200 | Bdiff=0.000729, minCor=0.995690
#
# Progress 55 / 200 | Bdiff=0.000692, minCor=0.995360
#
# Progress 56 / 200 | Bdiff=0.000656, minCor=0.994358
#
# Progress 57 / 200 | Bdiff=0.000622, minCor=0.993597
#
# Progress 58 / 200 | Bdiff=0.000597, minCor=0.993247
#
# Progress 59 / 200 | Bdiff=0.000564, minCor=0.991597
#
# Progress 60 / 200 | Bdiff=0.000532, minCor=0.991075
#
# Progress 61 / 200 | Bdiff=0.000500, minCor=0.992405
#
# Progress 62 / 200 | Bdiff=0.000458, minCor=0.994653
#
# Converged at iteration= 62 | Bdiff=0.000458,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 1000
#
# L1=34.990348359906; L2=104.971045079718
#
# Progress 1 / 30 | Bdiff=0.000434
#
# Progress 2 / 30 | Bdiff=0.012554
#
# Progress 3 / 30 | Bdiff=0.007413
#
# Estimated total runtime: ~20.1 min
#
# Progress 4 / 30 | Bdiff=0.006977
#
# Progress 5 / 30 | Bdiff=0.007637
#
# Progress 6 / 30 | Bdiff=0.006360
#
# Progress 7 / 30 | Bdiff=0.006368
#
# Progress 8 / 30 | Bdiff=0.007488
#
# Progress 9 / 30 | Bdiff=0.006106
#
# Progress 10 / 30 | Bdiff=0.005789
#
# Progress 11 / 30 | Bdiff=0.007965
#
# Progress 12 / 30 | Bdiff=0.007404
#
# Progress 13 / 30 | Bdiff=0.010109
#
# Progress 14 / 30 | Bdiff=0.008638
#
# Progress 15 / 30 | Bdiff=0.004927
#
# Progress 16 / 30 | Bdiff=0.004031
#
# Progress 17 / 30 | Bdiff=0.008669
#
# Progress 18 / 30 | Bdiff=0.004951
#
# Progress 19 / 30 | Bdiff=0.004164
#
# Progress 20 / 30 | Bdiff=0.008736
#
# Progress 21 / 30 | Bdiff=0.005350
#
# Progress 22 / 30 | Bdiff=0.004333
#
# Progress 23 / 30 | Bdiff=0.007120
#
# Progress 24 / 30 | Bdiff=0.003789
#
# Progress 25 / 30 | Bdiff=0.003091
#
# Progress 26 / 30 | Bdiff=0.006425
#
# Progress 27 / 30 | Bdiff=0.003563
#
# Progress 28 / 30 | Bdiff=0.003069
#
# Progress 29 / 30 | Bdiff=0.006832
#
# Progress 30 / 30 | Bdiff=0.003503
#
# Updating Z for CV
#
# crossValidation
#
# There are 731 LVs with AUC>0.70
#
# There are 305 LVs with AUC>0.90
#
#
# ============================================================
#
# All runs completed!
#
# ============================================================

# %% [markdown]
# ## Summary

# %%
# Save summary
write.csv(results_summary, file.path(output_base, "results_summary.csv"), row.names = FALSE)

kable(results_summary)
message("Results saved to: ", output_base)
# Out:
# | run| seed| CLAMP_K| n_samples| n_studies|
# |---:|----:|-------:|---------:|---------:|
# |   1|  123|      50|      6056|       220|
# |   1|  123|     100|      6056|       220|
# |   1|  123|     250|      6056|       220|
# |   1|  123|     500|      6056|       220|
# |   1|  123|     750|      6056|       220|
# |   1|  123|    1000|      6056|       220|
# |   2|  124|      50|      6056|       310|
# |   2|  124|     100|      6056|       310|
# |   2|  124|     250|      6056|       310|
# |   2|  124|     500|      6056|       310|
# |   2|  124|     750|      6056|       310|
# |   2|  124|    1000|      6056|       310|
# |   3|  125|      50|      6056|       284|
# |   3|  125|     100|      6056|       284|
# |   3|  125|     250|      6056|       284|
# |   3|  125|     500|      6056|       284|
# |   3|  125|     750|      6056|       284|
# |   3|  125|    1000|      6056|       284|
# |   4|  126|      50|      6056|       142|
# |   4|  126|     100|      6056|       142|
# |   4|  126|     250|      6056|       142|
# |   4|  126|     500|      6056|       142|
# |   4|  126|     750|      6056|       142|
# |   4|  126|    1000|      6056|       142|
# |   5|  127|      50|      6056|        55|
# |   5|  127|     100|      6056|        55|
# |   5|  127|     250|      6056|        55|
# |   5|  127|     500|      6056|        55|
# |   5|  127|     750|      6056|        55|
# |   5|  127|    1000|      6056|        55|
# Results saved to: /home/msubirana/Documents/pivlab/clamp-analyses/output/archs4/clamp_k_effect_01_study
