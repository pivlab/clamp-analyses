# %% [markdown]
# # ARCHS4 CLAMP models: Effect of CLAMP_K (5% study-based sampling)

# %% [markdown]
# **Environment:** `clamp-analyses`
#
# This notebook evaluates the effect of different CLAMP_K values on model results using 5% study-based sampling of ARCHS4 data.
#
# Instead of estimating CLAMP_K via `num.pc()`, we fix it to: 250, 500, 1250, 2500, 3750, 5000 (5x the 1% values, proportional to sample size).
#
# For each CLAMP_K value, 5 models are built with different random seeds (and thus different subsamples and SVDs).
#
# Structure per seed:
# 1. Subsample ARCHS4 data (5% coverage, study-based shuffling)
# 2. Compute SVD (shared across CLAMP_K values for the same seed)
# 3. For each CLAMP_K: run CLAMPbase, then CLAMPfull with BP prior

# %% [markdown]
# ## Load libraries

# %%
if (!requireNamespace("CLAMP", quietly = TRUE)) {
    REPO_PATH <- "/home/msubirana/Documents/pivlab/CLAMP" 
    remotes::install_local(REPO_PATH, force = TRUE, dependencies = FALSE)
}

library(bigstatsr)
library(data.table)
library(dplyr)
library(rsvd)
library(glmnet)
library(Matrix)
library(knitr)
library(here)
library(CLAMP)
library(rhdf5)

source(here("config.R"))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-10
#
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses

# %% [markdown]
# ## Configuration

# %%
# Base output directory
base_output_dir <- config$ARCHS4$DATASET_FOLDER

# Coverage level
coverage <- 0.05
coverage_pct <- coverage * 100

# CLAMP_K values to test (5x the 1% values, proportional to sample size)
clamp_k_values <- c(100, 250, 500, 1250, 2500, 3000)

# Data path for priors
data_path <- here::here('data/archs4')
archs4_file <- here('data/archs4/human_gene_v2.5.h5')

# SVD parameters
N_CORES <- 4

# Seeds for 5 runs
base_seed <- config$ARCHS4$CLAMP_PARAMS$RANDOM_SVD_SEED
seeds <- base_seed + 0:4
n_runs <- length(seeds)

# Output directory
output_base <- file.path(base_output_dir, "clamp_k_effect_05_study")
dir.create(output_base, showWarnings = FALSE, recursive = TRUE)

message("CLAMP_K values: ", paste(clamp_k_values, collapse = ", "))
message("Seeds: ", paste(seeds, collapse = ", "))
message("Coverage: ", coverage_pct, "%")
message("Output: ", output_base)
# Out:
# CLAMP_K values: 100, 250, 500, 1250, 2500, 3000
#
# Seeds: 123, 124, 125, 126, 127
#
# Coverage: 5%
#
# Output: /home/msubirana/Documents/pivlab/clamp-analyses/output/archs4/clamp_k_effect_05_study

# %% [markdown]
# ## Load preprocessed data

# %%
# Load metadata
meta <- readRDS(file.path(base_output_dir, "metadata_filtered.rds"))
n_genes_thin <- meta$n_genes_thin
n_samples_total <- meta$n_samples
archs4_genes <- meta$gene_symbols_thin

# Load sample names
all_samples <- readRDS(file.path(base_output_dir, "all_samples.rds"))
sample_names_total <- all_samples[seq_len(n_samples_total)]

# Load BP pathway
BP_pathMat <- readRDS(file.path(data_path, "BP_pathMat.rds"))
BP_matched <- getMatchedPathwayMat(BP_pathMat, archs4_genes)
message("Loaded and matched BP pathway matrix")

# Load FBM
fbm_file <- file.path(base_output_dir, "fbm")
output_file <- paste0(fbm_file, "_filtered")

archs4_fbm_filt <- FBM(
  nrow        = n_genes_thin,
  ncol        = n_samples_total,
  backingfile = output_file,
  create_bk   = FALSE
)

message("Loaded FBM with ", n_genes_thin, " genes and ", n_samples_total, " samples")

# Get series information from ARCHS4 HDF5 file
message("Getting series information from ARCHS4 HDF5 file...")

geo_acc <- h5read(archs4_file, "/meta/samples/geo_accession")
series_id <- h5read(archs4_file, "/meta/samples/series_id")

gsm_to_gse <- data.frame(
  geo_accession = geo_acc,
  series_id = series_id,
  stringsAsFactors = FALSE
)

# Create mapping of our filtered samples to series
sample_series_df <- data.frame(
  sample_idx = seq_len(n_samples_total),
  sample_name = sample_names_total,
  stringsAsFactors = FALSE
) %>%
  left_join(gsm_to_gse, by = c("sample_name" = "geo_accession"))

# Get unique series and their sample counts
series_counts <- sample_series_df %>%
  group_by(series_id) %>%
  summarise(n_samples = n(), .groups = "drop") %>%
  arrange(series_id)

message("Found ", nrow(series_counts), " unique studies")
# Out:
# There are 11936 genes in the intersection between data and prior
#
# Removing 2059 pathways
#
# Loaded and matched BP pathway matrix
#
# Loaded FBM with 18423 genes and 605614 samples
#
# Getting series information from ARCHS4 HDF5 file...
#
# Found 18084 unique studies

# %% [markdown]
# ## Run models: 5 seeds x 6 CLAMP_K values
#
# For each seed: study-based subsample → SVD (once), then loop over CLAMP_K values for CLAMPbase + CLAMPfull_BP.

# %%
n_samples_target <- round(n_samples_total * coverage)

SVD_K <- min(n_samples_target - 1, n_genes_thin - 1)

message("Target samples per run: ", n_samples_target, " (", coverage_pct, "% of ", n_samples_total, ")")
message("SVD K: ", SVD_K)

results_summary <- data.frame(
  run = integer(),
  seed = integer(),
  CLAMP_K = integer(),
  n_samples = integer(),
  n_studies = integer(),
  stringsAsFactors = FALSE
)

for (run_idx in seq_len(n_runs)) {
  current_seed <- seeds[run_idx]
  message("\n", strrep("=", 60))
  message("SEED ", run_idx, "/", n_runs, " (", current_seed, ")")
  message(strrep("=", 60))
  
  seed_dir <- file.path(output_base, paste0("seed_", run_idx))
  dir.create(seed_dir, showWarnings = FALSE, recursive = TRUE)
  
  # --- Study-based sample selection ---
  set.seed(current_seed)
  shuffled_series <- sample(series_counts$series_id)
  
  selected_samples <- c()
  selected_series <- c()
  n_collected <- 0
  
  for (s in shuffled_series) {
    if (n_collected >= n_samples_target) break
    series_samples <- sample_series_df$sample_idx[sample_series_df$series_id == s]
    n_series_samples <- length(series_samples)
    
    if (n_series_samples == 0) {
      warning("No samples found for series: ", s)
      next
    }
    
    if (n_collected + n_series_samples <= n_samples_target) {
      selected_samples <- c(selected_samples, series_samples)
      selected_series <- c(selected_series, s)
      n_collected <- n_collected + n_series_samples
    } else {
      n_needed <- n_samples_target - n_collected
      selected_samples <- c(selected_samples, series_samples[1:n_needed])
      selected_series <- c(selected_series, s)
      n_collected <- n_collected + n_needed
      break
    }
  }
  
  sample_idx <- sort(selected_samples)
  n_samples <- length(sample_idx)
  sample_names <- sample_names_total[sample_idx]
  
  message("Selected ", length(selected_series), " studies with ", n_samples, " total samples")
  
  saveRDS(list(
    run = run_idx,
    seed = current_seed,
    coverage = coverage,
    n_samples = n_samples,
    sample_idx = sample_idx,
    sample_names = sample_names,
    selected_series = selected_series,
    sampling_method = "study_based"
  ), file = file.path(seed_dir, "subsample_info.rds"))
  
  # --- Create subsampled FBM ---
  message("Creating subsampled FBM...")
  fbm_sub_file <- file.path(seed_dir, "fbm_subsampled")
  
  Y_sub <- big_copy(
    archs4_fbm_filt,
    ind.col = sample_idx,
    backingfile = fbm_sub_file
  )
  
  # --- SVD (once per seed) ---
  message("Computing SVD (k=", SVD_K, ")...")
  
  if (N_CORES > 1) {
    options(bigstatsr.check.parallel.blas = FALSE)
    blas_nproc <- getOption("default.nproc.blas")
    options(default.nproc.blas = NULL)
  }
  
  svd_result <- big_randomSVD(Y_sub, k = SVD_K, ncores = N_CORES)
  
  if (N_CORES > 1) {
    options(bigstatsr.check.parallel.blas = TRUE)
    options(default.nproc.blas = blas_nproc)
  }
  
  valid_idx <- which(!is.nan(svd_result$d))
  svd_result$d <- svd_result$d[valid_idx]
  svd_result$u <- svd_result$u[, valid_idx, drop = FALSE]
  svd_result$v <- svd_result$v[, valid_idx, drop = FALSE]
  
  saveRDS(svd_result, file = file.path(seed_dir, "svd.rds"))
  message("SVD done: ", length(svd_result$d), " valid components")
  
  # --- Loop over CLAMP_K values ---
  for (CLAMP_K in clamp_k_values) {
    message("\n--- CLAMP_K = ", CLAMP_K, " (seed ", run_idx, ") ---")
    
    k_dir <- file.path(seed_dir, paste0("clamp_k_", CLAMP_K))
    dir.create(k_dir, showWarnings = FALSE, recursive = TRUE)
    
    saveRDS(CLAMP_K, file = file.path(k_dir, "CLAMP_K.rds"))
    
    # CLAMPbase
    message("Running CLAMPbase...")
    baseRes <- CLAMPbase(
      Y = Y_sub,
      svdres = svd_result,
      trace = TRUE,
      clamp_k = CLAMP_K
    )
    
    baseRes$Z <- data.frame(baseRes$Z)
    rownames(baseRes$Z) <- archs4_genes
    baseRes$B <- data.frame(baseRes$B)
    colnames(baseRes$B) <- sample_names
    
    saveRDS(baseRes, file = file.path(k_dir, "CLAMPbase.rds"))
    
    model_dir <- file.path(k_dir, "CLAMPbase")
    dir.create(model_dir, showWarnings = FALSE, recursive = TRUE)
    write.csv(baseRes$B, file.path(model_dir, "B.csv"))
    write.csv(baseRes$Z, file.path(model_dir, "Z.csv"))
    
    # CLAMPfull with BP prior
    message("Running CLAMPfull with BP prior...")
    fullRes <- CLAMPfull(
      Y = Y_sub,
      svdres = svd_result,
      priorMat = BP_matched,
      clamp.base.result = baseRes,
      use_cpp = TRUE,
      trace = TRUE,
      clamp_k = CLAMP_K
    )
    
    fullRes$Z <- data.frame(fullRes$Z)
    rownames(fullRes$Z) <- archs4_genes
    fullRes$B <- data.frame(fullRes$B)
    colnames(fullRes$B) <- sample_names
    fullRes$summary <- fullRes$summary %>%
      dplyr::rename(LV = LV_index) %>%
      dplyr::mutate(LV = paste0('LV', LV))
    
    saveRDS(fullRes, file = file.path(k_dir, "CLAMPfull_BP.rds"))
    
    model_dir <- file.path(k_dir, "CLAMPfull_BP")
    dir.create(model_dir, showWarnings = FALSE, recursive = TRUE)
    write.csv(fullRes$B, file.path(model_dir, "B.csv"))
    write.csv(fullRes$Z, file.path(model_dir, "Z.csv"))
    write.csv(fullRes$summary, file.path(model_dir, "summary.csv"))
    
    # Store summary
    results_summary <- rbind(results_summary, data.frame(
      run = run_idx,
      seed = current_seed,
      CLAMP_K = CLAMP_K,
      n_samples = n_samples,
      n_studies = length(selected_series)
    ))
    
    rm(baseRes, fullRes)
    gc()
  }
  
  rm(Y_sub, svd_result)
  gc()
}

message("\n", strrep("=", 60))
message("All runs completed!")
message(strrep("=", 60))
# Out:
# Target samples per run: 30281 (5% of 605614)
#
# SVD K: 18422
# ============================================================
#
# SEED 1/5 (123)
#
# ============================================================
#
# Selected 997 studies with 30281 total samples
#
# Creating subsampled FBM...
#
# Computing SVD (k=18422)...
#
# SVD done: 18402 valid components
#
#
# --- CLAMP_K = 100 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 100
#
# L1 is set to 175.019559826134
#
# L2 is set to 525.058679478404
#
# Progress 1 / 200 | Bdiff=0.285007, minCor=0.879206
#
# Progress 2 / 200 | Bdiff=0.020044, minCor=0.968594
#
# Progress 3 / 200 | Bdiff=0.009224, minCor=0.984978
#
# Progress 4 / 200 | Bdiff=0.006725, minCor=0.987739
#
# Progress 5 / 200 | Bdiff=0.005373, minCor=0.990938
#
# Progress 6 / 200 | Bdiff=0.004476, minCor=0.991972
#
# Progress 7 / 200 | Bdiff=0.003831, minCor=0.993134
#
# Progress 8 / 200 | Bdiff=0.003330, minCor=0.994557
#
# Progress 9 / 200 | Bdiff=0.002947, minCor=0.995774
#
# Progress 10 / 200 | Bdiff=0.002676, minCor=0.996185
#
# Progress 11 / 200 | Bdiff=0.002477, minCor=0.996616
#
# Progress 12 / 200 | Bdiff=0.002324, minCor=0.996577
#
# Progress 13 / 200 | Bdiff=0.002207, minCor=0.996390
#
# Progress 14 / 200 | Bdiff=0.002113, minCor=0.996315
#
# Progress 15 / 200 | Bdiff=0.002031, minCor=0.996464
#
# Progress 16 / 200 | Bdiff=0.001955, minCor=0.996862
#
# Progress 17 / 200 | Bdiff=0.001879, minCor=0.997065
#
# Progress 18 / 200 | Bdiff=0.001803, minCor=0.997302
#
# Progress 19 / 200 | Bdiff=0.001724, minCor=0.997484
#
# Progress 20 / 200 | Bdiff=0.042623, minCor=0.949519
#
# Progress 21 / 200 | Bdiff=0.016467, minCor=0.968561
#
# Progress 22 / 200 | Bdiff=0.012677, minCor=0.975347
#
# Progress 23 / 200 | Bdiff=0.010082, minCor=0.977122
#
# Progress 24 / 200 | Bdiff=0.007656, minCor=0.976449
#
# Progress 25 / 200 | Bdiff=0.005758, minCor=0.984134
#
# Progress 26 / 200 | Bdiff=0.004223, minCor=0.985157
#
# Progress 27 / 200 | Bdiff=0.003235, minCor=0.989038
#
# Progress 28 / 200 | Bdiff=0.002569, minCor=0.987149
#
# Progress 29 / 200 | Bdiff=0.002176, minCor=0.984306
#
# Progress 30 / 200 | Bdiff=0.001954, minCor=0.984526
#
# Progress 31 / 200 | Bdiff=0.001817, minCor=0.987969
#
# Progress 32 / 200 | Bdiff=0.001723, minCor=0.988372
#
# Progress 33 / 200 | Bdiff=0.001584, minCor=0.987208
#
# Progress 34 / 200 | Bdiff=0.001365, minCor=0.990899
#
# Progress 35 / 200 | Bdiff=0.001093, minCor=0.992083
#
# Progress 36 / 200 | Bdiff=0.000913, minCor=0.994217
#
# Progress 37 / 200 | Bdiff=0.000780, minCor=0.994087
#
# Progress 38 / 200 | Bdiff=0.000702, minCor=0.993758
#
# Progress 39 / 200 | Bdiff=0.000672, minCor=0.992881
#
# Progress 40 / 200 | Bdiff=0.000635, minCor=0.991994
#
# Progress 41 / 200 | Bdiff=0.000635, minCor=0.992342
#
# Progress 42 / 200 | Bdiff=0.000590, minCor=0.993088
#
# Progress 43 / 200 | Bdiff=0.000555, minCor=0.993462
#
# Progress 44 / 200 | Bdiff=0.000487, minCor=0.994207
#
# Converged at iteration= 44 | Bdiff=0.000487,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 100
#
# L1=175.019559826134; L2=525.058679478404
#
# Progress 1 / 30 | Bdiff=0.000424
#
# Progress 2 / 30 | Bdiff=0.002945
#
# Progress 3 / 30 | Bdiff=0.001400
#
# Estimated total runtime: ~3.1 min
#
# Progress 4 / 30 | Bdiff=0.001433
#
# Progress 5 / 30 | Bdiff=0.001051
#
# Progress 6 / 30 | Bdiff=0.001384
#
# Progress 7 / 30 | Bdiff=0.001052
#
# Progress 8 / 30 | Bdiff=0.000991
#
# Progress 9 / 30 | Bdiff=0.001246
#
# Progress 10 / 30 | Bdiff=0.000925
#
# Progress 11 / 30 | Bdiff=0.001110
#
# Progress 12 / 30 | Bdiff=0.000760
#
# Progress 13 / 30 | Bdiff=0.000669
#
# Progress 14 / 30 | Bdiff=0.000712
#
# Progress 15 / 30 | Bdiff=0.000795
#
# Progress 16 / 30 | Bdiff=0.000770
#
# Progress 17 / 30 | Bdiff=0.000785
#
# Progress 18 / 30 | Bdiff=0.000853
#
# Progress 19 / 30 | Bdiff=0.000668
#
# Progress 20 / 30 | Bdiff=0.000904
#
# Progress 21 / 30 | Bdiff=0.000657
#
# Progress 22 / 30 | Bdiff=0.000550
#
# Progress 23 / 30 | Bdiff=0.000888
#
# Progress 24 / 30 | Bdiff=0.000812
#
# Progress 25 / 30 | Bdiff=0.000756
#
# Progress 26 / 30 | Bdiff=0.000822
#
# Progress 27 / 30 | Bdiff=0.000692
#
# Progress 28 / 30 | Bdiff=0.000731
#
# Progress 29 / 30 | Bdiff=0.000809
#
# Progress 30 / 30 | Bdiff=0.000830
#
# Updating Z for CV
#
# crossValidation
#
# There are 93 LVs with AUC>0.70
#
# There are 67 LVs with AUC>0.90
#
#
# --- CLAMP_K = 250 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 250
#
# L1 is set to 95.9169419990209
#
# L2 is set to 287.750825997063
#
# Progress 1 / 200 | Bdiff=0.266031, minCor=0.842737
#
# Progress 2 / 200 | Bdiff=0.019649, minCor=0.952797
#
# Progress 3 / 200 | Bdiff=0.009285, minCor=0.980238
#
# Progress 4 / 200 | Bdiff=0.007055, minCor=0.985859
#
# Progress 5 / 200 | Bdiff=0.005765, minCor=0.987874
#
# Progress 6 / 200 | Bdiff=0.004865, minCor=0.989989
#
# Progress 7 / 200 | Bdiff=0.004188, minCor=0.992093
#
# Progress 8 / 200 | Bdiff=0.003667, minCor=0.993773
#
# Progress 9 / 200 | Bdiff=0.003252, minCor=0.995066
#
# Progress 10 / 200 | Bdiff=0.002924, minCor=0.996069
#
# Progress 11 / 200 | Bdiff=0.002668, minCor=0.996437
#
# Progress 12 / 200 | Bdiff=0.002470, minCor=0.996237
#
# Progress 13 / 200 | Bdiff=0.002311, minCor=0.995976
#
# Progress 14 / 200 | Bdiff=0.002179, minCor=0.995783
#
# Progress 15 / 200 | Bdiff=0.002062, minCor=0.995772
#
# Progress 16 / 200 | Bdiff=0.001958, minCor=0.995829
#
# Progress 17 / 200 | Bdiff=0.001860, minCor=0.995775
#
# Progress 18 / 200 | Bdiff=0.001768, minCor=0.995902
#
# Progress 19 / 200 | Bdiff=0.001678, minCor=0.996173
#
# Progress 20 / 200 | Bdiff=0.049913, minCor=0.875872
#
# Progress 21 / 200 | Bdiff=0.017205, minCor=0.956398
#
# Progress 22 / 200 | Bdiff=0.012467, minCor=0.974056
#
# Progress 23 / 200 | Bdiff=0.010163, minCor=0.974598
#
# Progress 24 / 200 | Bdiff=0.008452, minCor=0.978123
#
# Progress 25 / 200 | Bdiff=0.007225, minCor=0.978352
#
# Progress 26 / 200 | Bdiff=0.006148, minCor=0.971115
#
# Progress 27 / 200 | Bdiff=0.005294, minCor=0.986447
#
# Progress 28 / 200 | Bdiff=0.004611, minCor=0.987830
#
# Progress 29 / 200 | Bdiff=0.003991, minCor=0.987497
#
# Progress 30 / 200 | Bdiff=0.003384, minCor=0.985499
#
# Progress 31 / 200 | Bdiff=0.002949, minCor=0.986986
#
# Progress 32 / 200 | Bdiff=0.002585, minCor=0.985755
#
# Progress 33 / 200 | Bdiff=0.002204, minCor=0.987843
#
# Progress 34 / 200 | Bdiff=0.001888, minCor=0.988697
#
# Progress 35 / 200 | Bdiff=0.001698, minCor=0.991402
#
# Progress 36 / 200 | Bdiff=0.001492, minCor=0.989993
#
# Progress 37 / 200 | Bdiff=0.001333, minCor=0.990963
#
# Progress 38 / 200 | Bdiff=0.001229, minCor=0.991953
#
# Progress 39 / 200 | Bdiff=0.001118, minCor=0.993282
#
# Progress 40 / 200 | Bdiff=0.001041, minCor=0.993511
#
# Progress 41 / 200 | Bdiff=0.000950, minCor=0.993193
#
# Progress 42 / 200 | Bdiff=0.000891, minCor=0.994044
#
# Progress 43 / 200 | Bdiff=0.000825, minCor=0.994324
#
# Progress 44 / 200 | Bdiff=0.000766, minCor=0.994043
#
# Progress 45 / 200 | Bdiff=0.000734, minCor=0.994570
#
# Progress 46 / 200 | Bdiff=0.000666, minCor=0.994307
#
# Progress 47 / 200 | Bdiff=0.000631, minCor=0.995373
#
# Progress 48 / 200 | Bdiff=0.000596, minCor=0.995660
#
# Progress 49 / 200 | Bdiff=0.000576, minCor=0.995665
#
# Progress 50 / 200 | Bdiff=0.000535, minCor=0.995663
#
# Progress 51 / 200 | Bdiff=0.000508, minCor=0.995368
#
# Progress 52 / 200 | Bdiff=0.000456, minCor=0.995312
#
# Converged at iteration= 52 | Bdiff=0.000456,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 250
#
# L1=95.9169419990209; L2=287.750825997063
#
# Progress 1 / 30 | Bdiff=0.000450
#
# Progress 2 / 30 | Bdiff=0.006016
#
# Progress 3 / 30 | Bdiff=0.003433
#
# Estimated total runtime: ~5.9 min
#
# Progress 4 / 30 | Bdiff=0.002913
#
# Progress 5 / 30 | Bdiff=0.003367
#
# Progress 6 / 30 | Bdiff=0.003360
#
# Progress 7 / 30 | Bdiff=0.002593
#
# Progress 8 / 30 | Bdiff=0.001941
#
# Progress 9 / 30 | Bdiff=0.001576
#
# Progress 10 / 30 | Bdiff=0.001296
#
# Progress 11 / 30 | Bdiff=0.001495
#
# Progress 12 / 30 | Bdiff=0.001328
#
# Progress 13 / 30 | Bdiff=0.001105
#
# Progress 14 / 30 | Bdiff=0.001356
#
# Progress 15 / 30 | Bdiff=0.001124
#
# Progress 16 / 30 | Bdiff=0.001086
#
# Progress 17 / 30 | Bdiff=0.001251
#
# Progress 18 / 30 | Bdiff=0.000933
#
# Progress 19 / 30 | Bdiff=0.000974
#
# Progress 20 / 30 | Bdiff=0.001243
#
# Progress 21 / 30 | Bdiff=0.001074
#
# Progress 22 / 30 | Bdiff=0.001026
#
# Progress 23 / 30 | Bdiff=0.001222
#
# Progress 24 / 30 | Bdiff=0.001048
#
# Progress 25 / 30 | Bdiff=0.000948
#
# Progress 26 / 30 | Bdiff=0.001329
#
# Progress 27 / 30 | Bdiff=0.001043
#
# Progress 28 / 30 | Bdiff=0.000868
#
# Progress 29 / 30 | Bdiff=0.000973
#
# Progress 30 / 30 | Bdiff=0.000879
#
# Updating Z for CV
#
# crossValidation
#
# There are 215 LVs with AUC>0.70
#
# There are 136 LVs with AUC>0.90
#
#
# --- CLAMP_K = 500 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 500
#
# L1 is set to 64.8316245476234
#
# L2 is set to 194.49487364287
#
# Progress 1 / 200 | Bdiff=0.288214, minCor=0.790889
#
# Progress 2 / 200 | Bdiff=0.021278, minCor=0.953694
#
# Progress 3 / 200 | Bdiff=0.009938, minCor=0.976949
#
# Progress 4 / 200 | Bdiff=0.007615, minCor=0.986521
#
# Progress 5 / 200 | Bdiff=0.006285, minCor=0.989197
#
# Progress 6 / 200 | Bdiff=0.005334, minCor=0.991343
#
# Progress 7 / 200 | Bdiff=0.004603, minCor=0.993107
#
# Progress 8 / 200 | Bdiff=0.004028, minCor=0.994529
#
# Progress 9 / 200 | Bdiff=0.003560, minCor=0.995604
#
# Progress 10 / 200 | Bdiff=0.003171, minCor=0.996029
#
# Progress 11 / 200 | Bdiff=0.002843, minCor=0.995962
#
# Progress 12 / 200 | Bdiff=0.002571, minCor=0.995966
#
# Progress 13 / 200 | Bdiff=0.002346, minCor=0.996117
#
# Progress 14 / 200 | Bdiff=0.002161, minCor=0.996408
#
# Progress 15 / 200 | Bdiff=0.002007, minCor=0.996784
#
# Progress 16 / 200 | Bdiff=0.001876, minCor=0.997141
#
# Progress 17 / 200 | Bdiff=0.001761, minCor=0.997176
#
# Progress 18 / 200 | Bdiff=0.001661, minCor=0.997245
#
# Progress 19 / 200 | Bdiff=0.001572, minCor=0.997361
#
# Progress 20 / 200 | Bdiff=0.048889, minCor=0.919470
#
# Progress 21 / 200 | Bdiff=0.016194, minCor=0.974351
#
# Progress 22 / 200 | Bdiff=0.011207, minCor=0.978171
#
# Progress 23 / 200 | Bdiff=0.009051, minCor=0.979613
#
# Progress 24 / 200 | Bdiff=0.007914, minCor=0.983843
#
# Progress 25 / 200 | Bdiff=0.007259, minCor=0.977728
#
# Progress 26 / 200 | Bdiff=0.006660, minCor=0.980557
#
# Progress 27 / 200 | Bdiff=0.006046, minCor=0.985388
#
# Progress 28 / 200 | Bdiff=0.005303, minCor=0.988853
#
# Progress 29 / 200 | Bdiff=0.004639, minCor=0.987310
#
# Progress 30 / 200 | Bdiff=0.004114, minCor=0.988633
#
# Progress 31 / 200 | Bdiff=0.003538, minCor=0.986623
#
# Progress 32 / 200 | Bdiff=0.003145, minCor=0.987010
#
# Progress 33 / 200 | Bdiff=0.002746, minCor=0.988448
#
# Progress 34 / 200 | Bdiff=0.002439, minCor=0.988309
#
# Progress 35 / 200 | Bdiff=0.002170, minCor=0.991397
#
# Progress 36 / 200 | Bdiff=0.001904, minCor=0.991863
#
# Progress 37 / 200 | Bdiff=0.001734, minCor=0.990739
#
# Progress 38 / 200 | Bdiff=0.001560, minCor=0.989693
#
# Progress 39 / 200 | Bdiff=0.001427, minCor=0.991159
#
# Progress 40 / 200 | Bdiff=0.001351, minCor=0.990972
#
# Progress 41 / 200 | Bdiff=0.001242, minCor=0.992430
#
# Progress 42 / 200 | Bdiff=0.001149, minCor=0.991478
#
# Progress 43 / 200 | Bdiff=0.001073, minCor=0.991470
#
# Progress 44 / 200 | Bdiff=0.000998, minCor=0.991957
#
# Progress 45 / 200 | Bdiff=0.000936, minCor=0.991557
#
# Progress 46 / 200 | Bdiff=0.000874, minCor=0.990476
#
# Progress 47 / 200 | Bdiff=0.000829, minCor=0.990340
#
# Progress 48 / 200 | Bdiff=0.000797, minCor=0.991500
#
# Progress 49 / 200 | Bdiff=0.000752, minCor=0.993261
#
# Progress 50 / 200 | Bdiff=0.000722, minCor=0.993735
#
# Progress 51 / 200 | Bdiff=0.000689, minCor=0.993066
#
# Progress 52 / 200 | Bdiff=0.000627, minCor=0.994669
#
# Progress 53 / 200 | Bdiff=0.000582, minCor=0.995989
#
# Progress 54 / 200 | Bdiff=0.000542, minCor=0.996784
#
# Progress 55 / 200 | Bdiff=0.000526, minCor=0.996816
#
# Progress 56 / 200 | Bdiff=0.000498, minCor=0.997422
#
# Converged at iteration= 56 | Bdiff=0.000498,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 500
#
# L1=64.8316245476234; L2=194.49487364287
#
# Progress 1 / 30 | Bdiff=0.000474
#
# Progress 2 / 30 | Bdiff=0.010330
#
# Progress 3 / 30 | Bdiff=0.005675
#
# Estimated total runtime: ~12.8 min
#
# Progress 4 / 30 | Bdiff=0.004132
#
# Progress 5 / 30 | Bdiff=0.004299
#
# Progress 6 / 30 | Bdiff=0.003568
#
# Progress 7 / 30 | Bdiff=0.003886
#
# Progress 8 / 30 | Bdiff=0.005796
#
# Progress 9 / 30 | Bdiff=0.003885
#
# Progress 10 / 30 | Bdiff=0.003266
#
# Progress 11 / 30 | Bdiff=0.004037
#
# Progress 12 / 30 | Bdiff=0.003075
#
# Progress 13 / 30 | Bdiff=0.002660
#
# Progress 14 / 30 | Bdiff=0.003298
#
# Progress 15 / 30 | Bdiff=0.002761
#
# Progress 16 / 30 | Bdiff=0.002477
#
# Progress 17 / 30 | Bdiff=0.003485
#
# Progress 18 / 30 | Bdiff=0.002295
#
# Progress 19 / 30 | Bdiff=0.001941
#
# Progress 20 / 30 | Bdiff=0.002676
#
# Progress 21 / 30 | Bdiff=0.001851
#
# Progress 22 / 30 | Bdiff=0.001614
#
# Progress 23 / 30 | Bdiff=0.002618
#
# Progress 24 / 30 | Bdiff=0.001709
#
# Progress 25 / 30 | Bdiff=0.001820
#
# Progress 26 / 30 | Bdiff=0.002736
#
# Progress 27 / 30 | Bdiff=0.002147
#
# Progress 28 / 30 | Bdiff=0.001907
#
# Progress 29 / 30 | Bdiff=0.002774
#
# Progress 30 / 30 | Bdiff=0.001670
#
# Updating Z for CV
#
# crossValidation
#
# There are 415 LVs with AUC>0.70
#
# There are 218 LVs with AUC>0.90
#
#
# --- CLAMP_K = 1250 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 1250
#
# L1 is set to 47.8204997292605
#
# L2 is set to 143.461499187781
#
# Progress 1 / 200 | Bdiff=0.421095, minCor=0.748317
#
# Progress 2 / 200 | Bdiff=0.026494, minCor=0.952457
#
# Progress 3 / 200 | Bdiff=0.012535, minCor=0.973642
#
# Progress 4 / 200 | Bdiff=0.009470, minCor=0.979625
#
# Progress 5 / 200 | Bdiff=0.007636, minCor=0.985180
#
# Progress 6 / 200 | Bdiff=0.006309, minCor=0.989800
#
# Progress 7 / 200 | Bdiff=0.005288, minCor=0.992927
#
# Progress 8 / 200 | Bdiff=0.004490, minCor=0.994789
#
# Progress 9 / 200 | Bdiff=0.003860, minCor=0.995766
#
# Progress 10 / 200 | Bdiff=0.003355, minCor=0.995947
#
# Progress 11 / 200 | Bdiff=0.002950, minCor=0.996086
#
# Progress 12 / 200 | Bdiff=0.002621, minCor=0.996203
#
# Progress 13 / 200 | Bdiff=0.002353, minCor=0.996313
#
# Progress 14 / 200 | Bdiff=0.002133, minCor=0.996445
#
# Progress 15 / 200 | Bdiff=0.001951, minCor=0.996745
#
# Progress 16 / 200 | Bdiff=0.001799, minCor=0.996981
#
# Progress 17 / 200 | Bdiff=0.001670, minCor=0.997234
#
# Progress 18 / 200 | Bdiff=0.001558, minCor=0.997258
#
# Progress 19 / 200 | Bdiff=0.001459, minCor=0.997034
#
# Progress 20 / 200 | Bdiff=0.037238, minCor=0.902792
#
# Progress 21 / 200 | Bdiff=0.014146, minCor=0.979424
#
# Progress 22 / 200 | Bdiff=0.008655, minCor=0.985032
#
# Progress 23 / 200 | Bdiff=0.006230, minCor=0.985977
#
# Progress 24 / 200 | Bdiff=0.004945, minCor=0.989493
#
# Progress 25 / 200 | Bdiff=0.004182, minCor=0.990866
#
# Progress 26 / 200 | Bdiff=0.003641, minCor=0.992441
#
# Progress 27 / 200 | Bdiff=0.003303, minCor=0.992538
#
# Progress 28 / 200 | Bdiff=0.003015, minCor=0.990239
#
# Progress 29 / 200 | Bdiff=0.002764, minCor=0.989512
#
# Progress 30 / 200 | Bdiff=0.002580, minCor=0.988951
#
# Progress 31 / 200 | Bdiff=0.002429, minCor=0.991816
#
# Progress 32 / 200 | Bdiff=0.002275, minCor=0.991128
#
# Progress 33 / 200 | Bdiff=0.002151, minCor=0.991818
#
# Progress 34 / 200 | Bdiff=0.002034, minCor=0.991778
#
# Progress 35 / 200 | Bdiff=0.001909, minCor=0.991688
#
# Progress 36 / 200 | Bdiff=0.001788, minCor=0.992046
#
# Progress 37 / 200 | Bdiff=0.001713, minCor=0.992946
#
# Progress 38 / 200 | Bdiff=0.001603, minCor=0.992731
#
# Progress 39 / 200 | Bdiff=0.001520, minCor=0.992715
#
# Progress 40 / 200 | Bdiff=0.001459, minCor=0.992605
#
# Progress 41 / 200 | Bdiff=0.001392, minCor=0.993773
#
# Progress 42 / 200 | Bdiff=0.001318, minCor=0.994280
#
# Progress 43 / 200 | Bdiff=0.001254, minCor=0.994197
#
# Progress 44 / 200 | Bdiff=0.001173, minCor=0.995137
#
# Progress 45 / 200 | Bdiff=0.001108, minCor=0.995163
#
# Progress 46 / 200 | Bdiff=0.001049, minCor=0.995754
#
# Progress 47 / 200 | Bdiff=0.000974, minCor=0.995309
#
# Progress 48 / 200 | Bdiff=0.000931, minCor=0.995180
#
# Progress 49 / 200 | Bdiff=0.000882, minCor=0.993920
#
# Progress 50 / 200 | Bdiff=0.000851, minCor=0.992654
#
# Progress 51 / 200 | Bdiff=0.000823, minCor=0.991440
#
# Progress 52 / 200 | Bdiff=0.000807, minCor=0.992631
#
# Progress 53 / 200 | Bdiff=0.000781, minCor=0.993338
#
# Progress 54 / 200 | Bdiff=0.000775, minCor=0.993643
#
# Progress 55 / 200 | Bdiff=0.000738, minCor=0.992870
#
# Progress 56 / 200 | Bdiff=0.000727, minCor=0.993770
#
# Progress 57 / 200 | Bdiff=0.000676, minCor=0.993980
#
# Progress 58 / 200 | Bdiff=0.000654, minCor=0.993485
#
# Progress 59 / 200 | Bdiff=0.000620, minCor=0.995487
#
# Progress 60 / 200 | Bdiff=0.000576, minCor=0.996153
#
# Progress 61 / 200 | Bdiff=0.000552, minCor=0.995583
#
# Progress 62 / 200 | Bdiff=0.000549, minCor=0.993532
#
# Progress 63 / 200 | Bdiff=0.000512, minCor=0.996119
#
# Progress 64 / 200 | Bdiff=0.000484, minCor=0.996691
#
# Converged at iteration= 64 | Bdiff=0.000484,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 1250
#
# L1=47.8204997292605; L2=143.461499187781
#
# Progress 1 / 30 | Bdiff=0.000472
#
# Progress 2 / 30 | Bdiff=0.013879
#
# Progress 3 / 30 | Bdiff=0.010054
#
# Estimated total runtime: ~41.8 min
#
# Progress 4 / 30 | Bdiff=0.008330
#
# Progress 5 / 30 | Bdiff=0.008052
#
# Progress 6 / 30 | Bdiff=0.006522
#
# Progress 7 / 30 | Bdiff=0.005892
#
# Progress 8 / 30 | Bdiff=0.006987
#
# Progress 9 / 30 | Bdiff=0.005570
#
# Progress 10 / 30 | Bdiff=0.005202
#
# Progress 11 / 30 | Bdiff=0.007779
#
# Progress 12 / 30 | Bdiff=0.005344
#
# Progress 13 / 30 | Bdiff=0.004850
#
# Progress 14 / 30 | Bdiff=0.008219
#
# Progress 15 / 30 | Bdiff=0.005383
#
# Progress 16 / 30 | Bdiff=0.004422
#
# Progress 17 / 30 | Bdiff=0.007805
#
# Progress 18 / 30 | Bdiff=0.004466
#
# Progress 19 / 30 | Bdiff=0.003925
#
# Progress 20 / 30 | Bdiff=0.007729
#
# Progress 21 / 30 | Bdiff=0.004340
#
# Progress 22 / 30 | Bdiff=0.003724
#
# Progress 23 / 30 | Bdiff=0.007838
#
# Progress 24 / 30 | Bdiff=0.004435
#
# Progress 25 / 30 | Bdiff=0.003746
#
# Progress 26 / 30 | Bdiff=0.008473
#
# Progress 27 / 30 | Bdiff=0.004632
#
# Progress 28 / 30 | Bdiff=0.003726
#
# Progress 29 / 30 | Bdiff=0.007452
#
# Progress 30 / 30 | Bdiff=0.004053
#
# Updating Z for CV
#
# crossValidation
#
# There are 889 LVs with AUC>0.70
#
# There are 358 LVs with AUC>0.90
#
#
# --- CLAMP_K = 2500 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 2500
#
# L1 is set to 37.1227470498813
#
# L2 is set to 111.368241149644
#
# Progress 1 / 200 | Bdiff=0.512099, minCor=0.776727
#
# Progress 2 / 200 | Bdiff=0.034066, minCor=0.936612
#
# Progress 3 / 200 | Bdiff=0.015766, minCor=0.972619
#
# Progress 4 / 200 | Bdiff=0.011111, minCor=0.982337
#
# Progress 5 / 200 | Bdiff=0.008284, minCor=0.987193
#
# Progress 6 / 200 | Bdiff=0.006421, minCor=0.990605
#
# Progress 7 / 200 | Bdiff=0.005149, minCor=0.993171
#
# Progress 8 / 200 | Bdiff=0.004249, minCor=0.995029
#
# Progress 9 / 200 | Bdiff=0.003595, minCor=0.996050
#
# Progress 10 / 200 | Bdiff=0.003101, minCor=0.996459
#
# Progress 11 / 200 | Bdiff=0.002716, minCor=0.996492
#
# Progress 12 / 200 | Bdiff=0.002410, minCor=0.996631
#
# Progress 13 / 200 | Bdiff=0.002163, minCor=0.996837
#
# Progress 14 / 200 | Bdiff=0.001959, minCor=0.996972
#
# Progress 15 / 200 | Bdiff=0.001787, minCor=0.997235
#
# Progress 16 / 200 | Bdiff=0.001640, minCor=0.997551
#
# Progress 17 / 200 | Bdiff=0.001514, minCor=0.997626
#
# Progress 18 / 200 | Bdiff=0.001405, minCor=0.997497
#
# Progress 19 / 200 | Bdiff=0.001311, minCor=0.997356
#
# Progress 20 / 200 | Bdiff=0.032158, minCor=0.923838
#
# Progress 21 / 200 | Bdiff=0.011687, minCor=0.981672
#
# Progress 22 / 200 | Bdiff=0.006956, minCor=0.989529
#
# Progress 23 / 200 | Bdiff=0.004814, minCor=0.990868
#
# Progress 24 / 200 | Bdiff=0.003710, minCor=0.991417
#
# Progress 25 / 200 | Bdiff=0.003068, minCor=0.992547
#
# Progress 26 / 200 | Bdiff=0.002608, minCor=0.992725
#
# Progress 27 / 200 | Bdiff=0.002259, minCor=0.991393
#
# Progress 28 / 200 | Bdiff=0.001985, minCor=0.992691
#
# Progress 29 / 200 | Bdiff=0.001771, minCor=0.994159
#
# Progress 30 / 200 | Bdiff=0.001587, minCor=0.996190
#
# Progress 31 / 200 | Bdiff=0.001446, minCor=0.996835
#
# Progress 32 / 200 | Bdiff=0.001330, minCor=0.996603
#
# Progress 33 / 200 | Bdiff=0.001230, minCor=0.996301
#
# Progress 34 / 200 | Bdiff=0.001160, minCor=0.995447
#
# Progress 35 / 200 | Bdiff=0.001106, minCor=0.994700
#
# Progress 36 / 200 | Bdiff=0.001048, minCor=0.995077
#
# Progress 37 / 200 | Bdiff=0.000984, minCor=0.994904
#
# Progress 38 / 200 | Bdiff=0.000938, minCor=0.994341
#
# Progress 39 / 200 | Bdiff=0.000897, minCor=0.994854
#
# Progress 40 / 200 | Bdiff=0.000851, minCor=0.995904
#
# Progress 41 / 200 | Bdiff=0.000815, minCor=0.996176
#
# Progress 42 / 200 | Bdiff=0.000762, minCor=0.996878
#
# Progress 43 / 200 | Bdiff=0.000708, minCor=0.997488
#
# Progress 44 / 200 | Bdiff=0.000676, minCor=0.997204
#
# Progress 45 / 200 | Bdiff=0.000629, minCor=0.997547
#
# Progress 46 / 200 | Bdiff=0.000597, minCor=0.997194
#
# Progress 47 / 200 | Bdiff=0.000563, minCor=0.996502
#
# Progress 48 / 200 | Bdiff=0.000553, minCor=0.996627
#
# Progress 49 / 200 | Bdiff=0.000523, minCor=0.996817
#
# Progress 50 / 200 | Bdiff=0.000487, minCor=0.997441
#
# Converged at iteration= 50 | Bdiff=0.000487,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 2500
#
# L1=37.1227470498813; L2=111.368241149644
#
# Progress 1 / 30 | Bdiff=0.000492
#
# Progress 2 / 30 | Bdiff=0.019109
#
# Progress 3 / 30 | Bdiff=0.013456
#
# Estimated total runtime: ~128.7 min
#
# Progress 4 / 30 | Bdiff=0.010858
#
# Progress 5 / 30 | Bdiff=0.008968
#
# Progress 6 / 30 | Bdiff=0.007640
#
# Progress 7 / 30 | Bdiff=0.007268
#
# Progress 8 / 30 | Bdiff=0.008005
#
# Progress 9 / 30 | Bdiff=0.007188
#
# Progress 10 / 30 | Bdiff=0.006897
#
# Progress 11 / 30 | Bdiff=0.008996
#
# Progress 12 / 30 | Bdiff=0.007283
#
# Progress 13 / 30 | Bdiff=0.007021
#
# Progress 14 / 30 | Bdiff=0.010440
#
# Progress 15 / 30 | Bdiff=0.007530
#
# Progress 16 / 30 | Bdiff=0.007065
#
# Progress 17 / 30 | Bdiff=0.011417
#
# Progress 18 / 30 | Bdiff=0.007630
#
# Progress 19 / 30 | Bdiff=0.006901
#
# Progress 20 / 30 | Bdiff=0.012233
#
# Progress 21 / 30 | Bdiff=0.007687
#
# Progress 22 / 30 | Bdiff=0.006868
#
# Progress 23 / 30 | Bdiff=0.011944
#
# Progress 24 / 30 | Bdiff=0.007462
#
# Progress 25 / 30 | Bdiff=0.006395
#
# Progress 26 / 30 | Bdiff=0.012527
#
# Progress 27 / 30 | Bdiff=0.006984
#
# Progress 28 / 30 | Bdiff=0.005867
#
# Progress 29 / 30 | Bdiff=0.011842
#
# Progress 30 / 30 | Bdiff=0.006540
#
# Updating Z for CV
#
# crossValidation
#
# There are 1694 LVs with AUC>0.70
#
# There are 578 LVs with AUC>0.90
#
#
# --- CLAMP_K = 3000 (seed 1) ---
#
# Running CLAMPbase...
#
# ****
#
# CLAMP k is set to 3000
#
# L1 is set to 33.9368895734599
#
# L2 is set to 101.81066872038
#
# Progress 1 / 200 | Bdiff=0.518700, minCor=0.771109
#
# Progress 2 / 200 | Bdiff=0.036811, minCor=0.930504
#
# Progress 3 / 200 | Bdiff=0.016781, minCor=0.969149
#
# Progress 4 / 200 | Bdiff=0.011486, minCor=0.981564
#
# Progress 5 / 200 | Bdiff=0.008382, minCor=0.987804
#
# Progress 6 / 200 | Bdiff=0.006422, minCor=0.991539
#
# Progress 7 / 200 | Bdiff=0.005122, minCor=0.994085
#
# Progress 8 / 200 | Bdiff=0.004215, minCor=0.995344
#
# Progress 9 / 200 | Bdiff=0.003557, minCor=0.995986
#
# Progress 10 / 200 | Bdiff=0.003058, minCor=0.996217
#
# Progress 11 / 200 | Bdiff=0.002671, minCor=0.996300
#
# Progress 12 / 200 | Bdiff=0.002365, minCor=0.996457
#
# Progress 13 / 200 | Bdiff=0.002118, minCor=0.996712
#
# Progress 14 / 200 | Bdiff=0.001914, minCor=0.996982
#
# Progress 15 / 200 | Bdiff=0.001743, minCor=0.997297
#
# Progress 16 / 200 | Bdiff=0.001598, minCor=0.997612
#
# Progress 17 / 200 | Bdiff=0.001473, minCor=0.997967
#
# Progress 18 / 200 | Bdiff=0.001366, minCor=0.998276
#
# Progress 19 / 200 | Bdiff=0.001275, minCor=0.998211
#
# Progress 20 / 200 | Bdiff=0.031125, minCor=0.948406
#
# Progress 21 / 200 | Bdiff=0.011324, minCor=0.984452
#
# Progress 22 / 200 | Bdiff=0.006728, minCor=0.988869
#
# Progress 23 / 200 | Bdiff=0.004699, minCor=0.991050
#
# Progress 24 / 200 | Bdiff=0.003561, minCor=0.993742
#
# Progress 25 / 200 | Bdiff=0.002946, minCor=0.993305
#
# Progress 26 / 200 | Bdiff=0.002487, minCor=0.993966
#
# Progress 27 / 200 | Bdiff=0.002147, minCor=0.995070
#
# Progress 28 / 200 | Bdiff=0.001902, minCor=0.993661
#
# Progress 29 / 200 | Bdiff=0.001669, minCor=0.994030
#
# Progress 30 / 200 | Bdiff=0.001510, minCor=0.994169
#
# Progress 31 / 200 | Bdiff=0.001348, minCor=0.995125
#
# Progress 32 / 200 | Bdiff=0.001225, minCor=0.995101
#
# Progress 33 / 200 | Bdiff=0.001135, minCor=0.992962
#
# Progress 34 / 200 | Bdiff=0.001050, minCor=0.995135
#
# Progress 35 / 200 | Bdiff=0.000981, minCor=0.995426
#
# Progress 36 / 200 | Bdiff=0.000915, minCor=0.995289
#
# Progress 37 / 200 | Bdiff=0.000874, minCor=0.996717
#
# Progress 38 / 200 | Bdiff=0.000805, minCor=0.996693
#
# Progress 39 / 200 | Bdiff=0.000762, minCor=0.996422
#
# Progress 40 / 200 | Bdiff=0.000734, minCor=0.996497
#
# Progress 41 / 200 | Bdiff=0.000704, minCor=0.996364
#
# Progress 42 / 200 | Bdiff=0.000666, minCor=0.996660
#
# Progress 43 / 200 | Bdiff=0.000653, minCor=0.997059
#
# Progress 44 / 200 | Bdiff=0.000624, minCor=0.997294
#
# Progress 45 / 200 | Bdiff=0.000608, minCor=0.997961
#
# Progress 46 / 200 | Bdiff=0.000573, minCor=0.997820
#
# Progress 47 / 200 | Bdiff=0.000551, minCor=0.998143
#
# Progress 48 / 200 | Bdiff=0.000530, minCor=0.998361
#
# Progress 49 / 200 | Bdiff=0.000516, minCor=0.998075
#
# Progress 50 / 200 | Bdiff=0.000498, minCor=0.998200
#
# Converged at iteration= 50 | Bdiff=0.000498,  tol=0.000500
#
# Running CLAMPfull with BP prior...
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 3000
#
# L1=33.9368895734599; L2=101.81066872038
#
# Progress 1 / 30 | Bdiff=0.000471
#
# Progress 2 / 30 | Bdiff=0.018505
#
# Progress 3 / 30 | Bdiff=0.015290
#
# Estimated total runtime: ~192.7 min
#
# Progress 4 / 30 | Bdiff=0.011840
#
# Progress 5 / 30 | Bdiff=0.010039
#
# Progress 6 / 30 | Bdiff=0.008406
#
# Progress 7 / 30 | Bdiff=0.007487
#
# Progress 8 / 30 | Bdiff=0.007596
#
# Progress 9 / 30 | Bdiff=0.006655
#
# Progress 10 / 30 | Bdiff=0.006406
#
# Progress 11 / 30 | Bdiff=0.007908
#
# Progress 12 / 30 | Bdiff=0.006674
#
# Progress 13 / 30 | Bdiff=0.006645
#
# Progress 14 / 30 | Bdiff=0.009254
#
# Progress 15 / 30 | Bdiff=0.007229
#
# Progress 16 / 30 | Bdiff=0.006903
#
# Progress 17 / 30 | Bdiff=0.010319
#
# Progress 18 / 30 | Bdiff=0.007348
#
# Progress 19 / 30 | Bdiff=0.006859
#
# Progress 20 / 30 | Bdiff=0.011043
#
# Progress 21 / 30 | Bdiff=0.007403
#
# Progress 22 / 30 | Bdiff=0.006673
#
# Progress 23 / 30 | Bdiff=0.011813
#
# Progress 24 / 30 | Bdiff=0.007242
#
# Progress 25 / 30 | Bdiff=0.006364
#
# Progress 26 / 30 | Bdiff=0.012524
#
# Progress 27 / 30 | Bdiff=0.007169
#
# Progress 28 / 30 | Bdiff=0.006156
#
# Progress 29 / 30 | Bdiff=0.012106
#
# Progress 30 / 30 | Bdiff=0.006738
#
# Updating Z for CV
#
# crossValidation
#
# There are 2020 LVs with AUC>0.70
#
# There are 644 LVs with AUC>0.90
#
#
# ============================================================
#
# SEED 2/5 (124)
#
# ============================================================
#
# Selected 830 studies with 30281 total samples
#
# Creating subsampled FBM...
#
# Computing SVD (k=18422)...

# %% [markdown]
# ## Summary

# %%
# Save summary
write.csv(results_summary, file.path(output_base, "results_summary.csv"), row.names = FALSE)

kable(results_summary)
message("Results saved to: ", output_base)
