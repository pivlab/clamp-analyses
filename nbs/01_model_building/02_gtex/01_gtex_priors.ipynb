# %% [markdown]
# # GTEx model with different priors using CLAMP

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %% [markdown]
# This notebook create different CLAMP GTEx models using different biological pathway priors. It loads a pre-computed CLAMP base model, SVD decomposition, and preprocessed GTEx data, then systematically evaluates distinct biological knowledge sources as priors. Each prior is run independently through CLAMPfull to generate and a final combined model incorporates all 13 priors simultaneously.

# %% [markdown]
# ## Load libraries

# %%
library(bigstatsr)
library(data.table)
library(dplyr)
library(rsvd)
library(glmnet)
library(Matrix)
library(knitr)
library(here)
library(PLIER)
library(CLAMP)

source(here("config.R"))

set.seed(config$GTEx$RANDOM_SVD_SEED)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-10
#
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses
#
# Loading required package: RColorBrewer
#
# Loading required package: gplots
#
#
# ---------------------
# gplots 3.3.0 loaded:
#   * Use citation('gplots') for citation info.
#   * Homepage: https://talgalili.github.io/gplots/
#   * Report issues: https://github.com/talgalili/gplots/issues
#   * Ask questions: https://stackoverflow.com/questions/tagged/gplots
#   * Suppress this message with: suppressPackageStartupMessages(library(gplots))
# ---------------------
#
#
#
# Attaching package: ‘gplots’
#
#
# The following object is masked from ‘package:stats’:
#
#     lowess
#
#
# Loading required package: pheatmap
#
# Loading required package: qvalue
#
#
# Attaching package: ‘CLAMP’
#
#
# The following object is masked from ‘package:PLIER’:
#
#     num.pc

# %% [markdown]
# ## Output directory

# %%
output_data_dir <- config$GTEx$OUTPUT_DIR
dir.create(output_data_dir, showWarnings = FALSE, recursive = TRUE)

# %% [markdown]
# # Load GTEx CLAMP base model

# %%
gtex_baseRes <- readRDS(file.path(output_data_dir, "CLAMPbase.rds"))

# %%
gtex_svdRes <- readRDS(file.path(output_data_dir, "gtex_svdRes.rds"))

# %%
CLAMP_K_gtex <- readRDS(file.path(output_data_dir, "CLAMP_K_gtex.rds"))

# %%
gtex_fbm_filt <- readRDS(file.path(output_data_dir, "gtex_fbm_filt.rds"))

# %%
gtex_genes <- readRDS(file.path(output_data_dir, "gtex_genes.rds"))

# %%
samples <- readRDS(file.path(output_data_dir, "gtex_samples.rds"))

# %% [markdown]
# ## Prior KEGG

# %%
# Vector of prior URLs
prior_urls <- c(
  "https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=KEGG_2021_Human",
  "https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025",
  "https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GTEx_Tissues_V8_2023",
  "https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=CellMarker_2024"
)

# Names are exactly what's after libraryName=
names(prior_urls) <- sub(".*libraryName=", "", prior_urls)

results <- list()

for (prior_name in names(prior_urls)) {
  url <- prior_urls[[prior_name]]
  message(">>> Running CLAMP for prior: ", prior_name)

  try({
    gmt <- getGMT(url)
    gmt_list <- list()
    gmt_list[[prior_name]] <- gmt

    pathMat   <- gmtListToSparseMat(gmt_list)
    matched   <- getMatchedPathwayMat(pathMat, gtex_genes)
    if (is.null(matched) || ncol(matched) == 0) {
      warning("No matched pathways for ", prior_name, "; skipping.")
      next
    }

    fullRes <- CLAMPfull(
      Y                 = gtex_fbm_filt,
      priorMat          = as.matrix(matched),
      svdres            = gtex_svdRes,
      clamp.base.result = gtex_baseRes,
      clamp_k           = CLAMP_K_gtex,
      doCrossval        = TRUE,
      trace             = TRUE,
      use_cpp           = TRUE
    )

    if (!is.null(fullRes$B)) colnames(fullRes$B) <- samples
    if (!is.null(fullRes$Z)) colnames(fullRes$Z) <- paste0("LV", seq_len(ncol(fullRes$Z)))
    if (!is.null(fullRes$summary)) {
      fullRes$summary <- fullRes$summary |>
        dplyr::rename(LV = LV_index) |>
        dplyr::mutate(LV = paste0("LV", LV))
    }

    out_file <- file.path(output_data_dir, sprintf("gtex_%s_CLAMP.rds", prior_name))
    saveRDS(fullRes, file = out_file)
    results[[prior_name]] <- fullRes

    message("Saved: ", out_file)
  }, silent = FALSE)
}

invisible(results)
# Out:
# >>> Running CLAMP for prior: KEGG_2021_Human
#
# Auto-detected name: KEGG_2021_Human
# Using cached file for KEGG_2021_Human
#
# There are 6409 genes in the intersection between data and prior
#
# Removing 10 pathways
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 412
#
# L1=45.2778145717356; L2=135.833443715207
#
# Progress 1 / 30 | Bdiff=0.000454
#
# Progress 2 / 30 | Bdiff=0.037546
#
# Progress 3 / 30 | Bdiff=0.015150
#
# Estimated total runtime: ~23.4 min
#
# Progress 4 / 30 | Bdiff=0.012746
#
# Progress 5 / 30 | Bdiff=0.008826
#
# Progress 6 / 30 | Bdiff=0.006481
#
# Progress 7 / 30 | Bdiff=0.005373
#
# Progress 8 / 30 | Bdiff=0.004867
#
# Progress 9 / 30 | Bdiff=0.004852
#
# Progress 10 / 30 | Bdiff=0.004826
#
# Progress 11 / 30 | Bdiff=0.004933
#
# Progress 12 / 30 | Bdiff=0.004677
#
# Progress 13 / 30 | Bdiff=0.004147
#
# Progress 14 / 30 | Bdiff=0.004070
#
# Progress 15 / 30 | Bdiff=0.003906
#
# Progress 16 / 30 | Bdiff=0.003736
#
# Progress 17 / 30 | Bdiff=0.003686
#
# Progress 18 / 30 | Bdiff=0.003392
#
# Progress 19 / 30 | Bdiff=0.003286
#
# Progress 20 / 30 | Bdiff=0.003282
#
# Progress 21 / 30 | Bdiff=0.003239
#
# Progress 22 / 30 | Bdiff=0.003281
#
# Progress 23 / 30 | Bdiff=0.003466
#
# Progress 24 / 30 | Bdiff=0.003468
#
# Progress 25 / 30 | Bdiff=0.003246
#
# Progress 26 / 30 | Bdiff=0.003047
#
# Progress 27 / 30 | Bdiff=0.002809
#
# Progress 28 / 30 | Bdiff=0.002754
#
# Progress 29 / 30 | Bdiff=0.002697
#
# Progress 30 / 30 | Bdiff=0.002445
#
# Updating Z for CV
#
# crossValidation
#
# There are 212 LVs with AUC>0.70
#
# There are 53 LVs with AUC>0.90
#
# Saved: /home/msubirana/Documents/pivlab/clamp-analyses/output/gtex/gtex_KEGG_2021_Human_CLAMP.rds
#
# >>> Running CLAMP for prior: GO_Biological_Process_2025
#
# Auto-detected name: GO_Biological_Process_2025
#
# Using cached file for GO_Biological_Process_2025
#
# There are 12116 genes in the intersection between data and prior
#
# Removing 2020 pathways
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 412
#
# L1=45.2778145717356; L2=135.833443715207
#
# Progress 1 / 30 | Bdiff=0.000454
#
# Progress 2 / 30 | Bdiff=0.037505
#
# Progress 3 / 30 | Bdiff=0.014963
#
# Estimated total runtime: ~22.9 min
#
# Progress 4 / 30 | Bdiff=0.012739
#
# Progress 5 / 30 | Bdiff=0.008867
#
# Progress 6 / 30 | Bdiff=0.006545
#
# Progress 7 / 30 | Bdiff=0.005425
#
# Progress 8 / 30 | Bdiff=0.005269
#
# Progress 9 / 30 | Bdiff=0.005164
#
# Progress 10 / 30 | Bdiff=0.004992
#
# Progress 11 / 30 | Bdiff=0.005037
#
# Progress 12 / 30 | Bdiff=0.004660
#
# Progress 13 / 30 | Bdiff=0.004143
#
# Progress 14 / 30 | Bdiff=0.004156
#
# Progress 15 / 30 | Bdiff=0.003834
#
# Progress 16 / 30 | Bdiff=0.003593
#
# Progress 17 / 30 | Bdiff=0.003689
#
# Progress 18 / 30 | Bdiff=0.003308
#
# Progress 19 / 30 | Bdiff=0.003189
#
# Progress 20 / 30 | Bdiff=0.003172
#
# Progress 21 / 30 | Bdiff=0.003105
#
# Progress 22 / 30 | Bdiff=0.003228
#
# Progress 23 / 30 | Bdiff=0.003401
#
# Progress 24 / 30 | Bdiff=0.003368
#
# Progress 25 / 30 | Bdiff=0.003223
#
# Progress 26 / 30 | Bdiff=0.003261
#
# Progress 27 / 30 | Bdiff=0.002765
#
# Progress 28 / 30 | Bdiff=0.002730
#
# Progress 29 / 30 | Bdiff=0.002799
#
# Progress 30 / 30 | Bdiff=0.002588
#
# Updating Z for CV
#
# crossValidation
#
# There are 330 LVs with AUC>0.70
#
# There are 156 LVs with AUC>0.90
#
# Saved: /home/msubirana/Documents/pivlab/clamp-analyses/output/gtex/gtex_GO_Biological_Process_2025_CLAMP.rds
#
# >>> Running CLAMP for prior: GTEx_Tissues_V8_2023
#
# Auto-detected name: GTEx_Tissues_V8_2023
#
# Using cached file for GTEx_Tissues_V8_2023
#
# There are 6121 genes in the intersection between data and prior
#
# Removing 0 pathways
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 412
#
# L1=45.2778145717356; L2=135.833443715207
#
# Progress 1 / 30 | Bdiff=0.000454
#
# Progress 2 / 30 | Bdiff=0.038112
#
# Progress 3 / 30 | Bdiff=0.016066
#
# Estimated total runtime: ~23.0 min
#
# Progress 4 / 30 | Bdiff=0.012093
#
# Progress 5 / 30 | Bdiff=0.008121
#
# Progress 6 / 30 | Bdiff=0.006206
#
# Progress 7 / 30 | Bdiff=0.005366
#
# Progress 8 / 30 | Bdiff=0.005073
#
# Progress 9 / 30 | Bdiff=0.005051
#
# Progress 10 / 30 | Bdiff=0.004611
#
# Progress 11 / 30 | Bdiff=0.004351
#
# Progress 12 / 30 | Bdiff=0.004096
#
# Progress 13 / 30 | Bdiff=0.003814
#
# Progress 14 / 30 | Bdiff=0.003807
#
# Progress 15 / 30 | Bdiff=0.003588
#
# Progress 16 / 30 | Bdiff=0.003464
#
# Progress 17 / 30 | Bdiff=0.003532
#
# Progress 18 / 30 | Bdiff=0.003148
#
# Progress 19 / 30 | Bdiff=0.003071
#
# Progress 20 / 30 | Bdiff=0.002913
#
# Progress 21 / 30 | Bdiff=0.002844
#
# Progress 22 / 30 | Bdiff=0.002976
#
# Progress 23 / 30 | Bdiff=0.002966
#
# Progress 24 / 30 | Bdiff=0.003020
#
# Progress 25 / 30 | Bdiff=0.002971
#
# Progress 26 / 30 | Bdiff=0.002807
#
# Progress 27 / 30 | Bdiff=0.002579
#
# Progress 28 / 30 | Bdiff=0.002570
#
# Progress 29 / 30 | Bdiff=0.002701
#
# Progress 30 / 30 | Bdiff=0.002608
#
# Updating Z for CV
#
# crossValidation
#
# There are 259 LVs with AUC>0.70
#
# There are 118 LVs with AUC>0.90
#
# Saved: /home/msubirana/Documents/pivlab/clamp-analyses/output/gtex/gtex_GTEx_Tissues_V8_2023_CLAMP.rds
#
# >>> Running CLAMP for prior: CellMarker_2024
#
# Auto-detected name: CellMarker_2024
#
# Using cached file for CellMarker_2024
#
# There are 11124 genes in the intersection between data and prior
#
# Removing 965 pathways
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 412
#
# L1=45.2778145717356; L2=135.833443715207
#
# Progress 1 / 30 | Bdiff=0.000454
#
# Progress 2 / 30 | Bdiff=0.037632
#
# Progress 3 / 30 | Bdiff=0.015847
#
# Estimated total runtime: ~21.0 min
#
# Progress 4 / 30 | Bdiff=0.011984
#
# Progress 5 / 30 | Bdiff=0.008092
#
# Progress 6 / 30 | Bdiff=0.006138
#
# Progress 7 / 30 | Bdiff=0.005224
#
# Progress 8 / 30 | Bdiff=0.004931
#
# Progress 9 / 30 | Bdiff=0.005022
#
# Progress 10 / 30 | Bdiff=0.004642
#
# Progress 11 / 30 | Bdiff=0.004458
#
# Progress 12 / 30 | Bdiff=0.004193
#
# Progress 13 / 30 | Bdiff=0.003919
#
# Progress 14 / 30 | Bdiff=0.003949
#
# Progress 15 / 30 | Bdiff=0.003684
#
# Progress 16 / 30 | Bdiff=0.003573
#
# Progress 17 / 30 | Bdiff=0.003514
#
# Progress 18 / 30 | Bdiff=0.003196
#
# Progress 19 / 30 | Bdiff=0.003201
#
# Progress 20 / 30 | Bdiff=0.003002
#
# Progress 21 / 30 | Bdiff=0.002992
#
# Progress 22 / 30 | Bdiff=0.003065
#
# Progress 23 / 30 | Bdiff=0.003237
#
# Progress 24 / 30 | Bdiff=0.003284
#
# Progress 25 / 30 | Bdiff=0.003087
#
# Progress 26 / 30 | Bdiff=0.003178
#
# Progress 27 / 30 | Bdiff=0.002853
#
# Progress 28 / 30 | Bdiff=0.002818
#
# Progress 29 / 30 | Bdiff=0.002979
#
# Progress 30 / 30 | Bdiff=0.002777
#
# Updating Z for CV
#
# crossValidation
#
# There are 258 LVs with AUC>0.70
#
# There are 138 LVs with AUC>0.90
#
# Saved: /home/msubirana/Documents/pivlab/clamp-analyses/output/gtex/gtex_CellMarker_2024_CLAMP.rds

# %%
# priors
gtex_gmtList <- list(
  KEGG = getGMT("https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=KEGG_2021_Human"),
  BP = getGMT("https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025"),
  GTEx_Tissues = getGMT("https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GTEx_Tissues_V8_2023"),
  CellMarker = getGMT("https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=CellMarker_2024")

)

# prefix each gene‐set name with its library to guarantee uniqueness
for(lib in names(gtex_gmtList)) {
  names(gtex_gmtList[[lib]]) <- paste0(lib, "_", names(gtex_gmtList[[lib]]))
}

gtex_pathMat <- gmtListToSparseMat(gtex_gmtList)
gtex_matched <- getMatchedPathwayMat(gtex_pathMat, gtex_genes)

# CLAMPfull
gtex_fullRes <- CLAMPfull(
  Y                 = gtex_fbm_filt,
  priorMat          = as.matrix(gtex_matched),
  svdres            = gtex_svdRes,
  clamp.base.result = gtex_baseRes,
  clamp_k           = CLAMP_K_gtex,
  doCrossval        = TRUE,
  trace             = TRUE,
  use_cpp           = TRUE
)

# Fix colnames and rownames
colnames(gtex_fullRes$B) <- samples
colnames(gtex_fullRes$Z) <- paste0('LV', seq_len(ncol(gtex_fullRes$Z)))
gtex_fullRes$summary <- gtex_fullRes$summary %>%
    dplyr::rename(LV = LV_index)  %>% 
    dplyr::mutate(LV = paste0('LV', LV))

# save
saveRDS(gtex_fullRes, file = file.path(output_data_dir, "gtex_all_CLAMP.rds"))
# Out:
# Auto-detected name: KEGG_2021_Human
#
# Using cached file for KEGG_2021_Human
#
# Auto-detected name: GO_Biological_Process_2025
#
# Using cached file for GO_Biological_Process_2025
#
# Auto-detected name: GTEx_Tissues_V8_2023
#
# Using cached file for GTEx_Tissues_V8_2023
#
# Auto-detected name: CellMarker_2024
#
# Using cached file for CellMarker_2024
#
# There are 14533 genes in the intersection between data and prior
#
# Removing 2995 pathways
#
# ** CLAMPfull **
#
# using provided CLAMPbase result
#
# CLAMP k is set to 412
#
# L1=45.2778145717356; L2=135.833443715207
#
# Progress 1 / 30 | Bdiff=0.000454
#
# Progress 2 / 30 | Bdiff=0.038158
#
# Progress 3 / 30 | Bdiff=0.015244
#
# Estimated total runtime: ~22.7 min
#
# Progress 4 / 30 | Bdiff=0.012969
#
# Progress 5 / 30 | Bdiff=0.008988
#
# Progress 6 / 30 | Bdiff=0.006554
#
# Progress 7 / 30 | Bdiff=0.005401
#
# Progress 8 / 30 | Bdiff=0.005061
#
# Progress 9 / 30 | Bdiff=0.005105
#
# Progress 10 / 30 | Bdiff=0.004800
#
# Progress 11 / 30 | Bdiff=0.004759
#
# Progress 12 / 30 | Bdiff=0.004352
#
# Progress 13 / 30 | Bdiff=0.003883
#
# Progress 14 / 30 | Bdiff=0.003886
#
# Progress 15 / 30 | Bdiff=0.003615
#
# Progress 16 / 30 | Bdiff=0.003440
#
# Progress 17 / 30 | Bdiff=0.003524
#
# Progress 18 / 30 | Bdiff=0.003000
#
# Progress 19 / 30 | Bdiff=0.003084
#
# Progress 20 / 30 | Bdiff=0.002989
#
# Progress 21 / 30 | Bdiff=0.002853
#
# Progress 22 / 30 | Bdiff=0.002912
#
# Progress 23 / 30 | Bdiff=0.002944
#
# Progress 24 / 30 | Bdiff=0.002904
#
# Progress 25 / 30 | Bdiff=0.003020
#
# Progress 26 / 30 | Bdiff=0.002980
#
# Progress 27 / 30 | Bdiff=0.002772
#
# Progress 28 / 30 | Bdiff=0.002908
#
# Progress 29 / 30 | Bdiff=0.003129
#
# Progress 30 / 30 | Bdiff=0.003091
#
# Updating Z for CV
#
# crossValidation
#
# There are 352 LVs with AUC>0.70
#
# There are 229 LVs with AUC>0.90
