# %% [markdown]
# # ARCHS4 reconstruction error — saturation models, study subsamples (plots)

# %% [markdown]
# **Environment:** `clamp-analyses`
#
# Loads pre-computed reconstruction error results from `06_study_saturation_reconstruction_error_compute.ipynb` and generates plots showing how reconstruction quality changes with the number of latent variables (k) at each study-subsample coverage level.
#
# Inputs: `output/01_model_building/06_reconstruction_error/reconstruction_error_study_saturation_results.rds`
#
# Outputs: `output/01_model_building/06_reconstruction_error/`

# %%
library(data.table)
library(dplyr)
library(ggplot2)
library(here)
# Out:
# Attaching package: ‘dplyr’
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses

# %% [markdown]
# ## Parameters

# %%
output_dir <- here("output", "01_model_building", "06_reconstruction_error")
message("Output dir: ", output_dir)
# Out:
# Output dir: /home/msubirana/Documents/pivlab/clamp-analyses/output/01_model_building/06_reconstruction_error

# %% [markdown]
# ## Load results

# %%
results_list <- readRDS(file.path(output_dir, "reconstruction_error_study_saturation_results.rds"))
results_df   <- data.table::fread(file.path(output_dir, "reconstruction_error_study_saturation_summary.csv"))

message("Loaded ", length(results_list), " result entries")
print(results_df)
# Out:
# Loaded 83 result entries
#     coverage_pct  seed   run          model         sampling k_target n_lvs
#            <int> <int> <int>         <char>           <char>    <int> <int>
#  1:            1   123     1 CLAMPfull_hall study_saturation     1296  1296
#  2:            1   124     2 CLAMPfull_hall study_saturation     1296  1296
#  3:            1   125     3 CLAMPfull_hall study_saturation     1296  1296
#  4:            1   124     2 CLAMPfull_hall study_saturation     1728  1728
#  5:            1   125     3 CLAMPfull_hall study_saturation     1728  1728
#  6:            1   123     1 CLAMPfull_hall study_saturation      173   173
#  7:            1   124     2 CLAMPfull_hall study_saturation      173   173
#  8:            1   125     3 CLAMPfull_hall study_saturation      173   173
#  9:            1   123     1 CLAMPfull_hall study_saturation      432   432
# 10:            1   124     2 CLAMPfull_hall study_saturation      432   432
# 11:            1   125     3 CLAMPfull_hall study_saturation      432   432
# 12:            1   123     1 CLAMPfull_hall study_saturation       86    86
# 13:            1   124     2 CLAMPfull_hall study_saturation       86    86
# 14:            1   125     3 CLAMPfull_hall study_saturation       86    86
# 15:            1   123     1 CLAMPfull_hall study_saturation      864   864
# 16:            1   124     2 CLAMPfull_hall study_saturation      864   864
# 17:            1   125     3 CLAMPfull_hall study_saturation      864   864
# 18:           10   123     1 CLAMPfull_hall study_saturation     1296  1296
# 19:           10   124     2 CLAMPfull_hall study_saturation     1296  1296
# 20:           10   125     3 CLAMPfull_hall study_saturation     1296  1296
# 21:           10   123     1 CLAMPfull_hall study_saturation     1728  1728
# 22:           10   124     2 CLAMPfull_hall study_saturation     1728  1728
# 23:           10   125     3 CLAMPfull_hall study_saturation     1728  1728
# 24:           10   123     1 CLAMPfull_hall study_saturation      173   173
# 25:           10   124     2 CLAMPfull_hall study_saturation      173   173
# 26:           10   125     3 CLAMPfull_hall study_saturation      173   173
# 27:           10   123     1 CLAMPfull_hall study_saturation      432   432
# 28:           10   124     2 CLAMPfull_hall study_saturation      432   432
# 29:           10   125     3 CLAMPfull_hall study_saturation      432   432
# 30:           10   123     1 CLAMPfull_hall study_saturation       86    86
# 31:           10   124     2 CLAMPfull_hall study_saturation       86    86
# 32:           10   125     3 CLAMPfull_hall study_saturation       86    86
# 33:           10   123     1 CLAMPfull_hall study_saturation      864   864
# 34:           10   124     2 CLAMPfull_hall study_saturation      864   864
# 35:           10   125     3 CLAMPfull_hall study_saturation      864   864
# 36:           25   123     1 CLAMPfull_hall study_saturation     1296  1296
# 37:           25   124     2 CLAMPfull_hall study_saturation     1296  1296
# 38:           25   125     3 CLAMPfull_hall study_saturation     1296  1296
# 39:           25   123     1 CLAMPfull_hall study_saturation     1728  1728
# 40:           25   124     2 CLAMPfull_hall study_saturation     1728  1728
# 41:           25   125     3 CLAMPfull_hall study_saturation     1728  1728
# 42:           25   123     1 CLAMPfull_hall study_saturation      173   173
# 43:           25   124     2 CLAMPfull_hall study_saturation      173   173
# 44:           25   125     3 CLAMPfull_hall study_saturation      173   173
# 45:           25   123     1 CLAMPfull_hall study_saturation      432   432
# 46:           25   124     2 CLAMPfull_hall study_saturation      432   432
# 47:           25   125     3 CLAMPfull_hall study_saturation      432   432
# 48:           25   123     1 CLAMPfull_hall study_saturation       86    86
# 49:           25   124     2 CLAMPfull_hall study_saturation       86    86
# 50:           25   125     3 CLAMPfull_hall study_saturation       86    86
# 51:           25   123     1 CLAMPfull_hall study_saturation      864   864
# 52:           25   124     2 CLAMPfull_hall study_saturation      864   864
# 53:           25   125     3 CLAMPfull_hall study_saturation      864   864
# 54:            5   123     1 CLAMPfull_hall study_saturation     1296  1296
# 55:            5   124     2 CLAMPfull_hall study_saturation     1296  1296
# 56:            5   125     3 CLAMPfull_hall study_saturation     1296  1296
# 57:            5   123     1 CLAMPfull_hall study_saturation     1728  1728
# 58:            5   124     2 CLAMPfull_hall study_saturation     1728  1728
# 59:            5   125     3 CLAMPfull_hall study_saturation     1728  1728
# 60:            5   123     1 CLAMPfull_hall study_saturation      173   173
# 61:            5   124     2 CLAMPfull_hall study_saturation      173   173
# 62:            5   125     3 CLAMPfull_hall study_saturation      173   173
# 63:            5   123     1 CLAMPfull_hall study_saturation      432   432
# 64:            5   124     2 CLAMPfull_hall study_saturation      432   432
# 65:            5   125     3 CLAMPfull_hall study_saturation      432   432
# 66:            5   123     1 CLAMPfull_hall study_saturation       86    86
# 67:            5   124     2 CLAMPfull_hall study_saturation       86    86
# 68:            5   125     3 CLAMPfull_hall study_saturation       86    86
# 69:            5   123     1 CLAMPfull_hall study_saturation      864   864
# 70:            5   124     2 CLAMPfull_hall study_saturation      864   864
# 71:            5   125     3 CLAMPfull_hall study_saturation      864   864
# 72:           50   123     1 CLAMPfull_hall study_saturation     1296  1296
# 73:           50   124     2 CLAMPfull_hall study_saturation     1296  1296
# 74:           50   123     1 CLAMPfull_hall study_saturation     1728  1728
# 75:           50   124     2 CLAMPfull_hall study_saturation     1728  1728
# 76:           50   123     1 CLAMPfull_hall study_saturation      173   173
# 77:           50   124     2 CLAMPfull_hall study_saturation      173   173
# 78:           50   123     1 CLAMPfull_hall study_saturation      432   432
# 79:           50   124     2 CLAMPfull_hall study_saturation      432   432
# 80:           50   123     1 CLAMPfull_hall study_saturation       86    86
# 81:           50   124     2 CLAMPfull_hall study_saturation       86    86
# 82:           50   123     1 CLAMPfull_hall study_saturation      864   864
# 83:           50   124     2 CLAMPfull_hall study_saturation      864   864
#     coverage_pct  seed   run          model         sampling k_target n_lvs
#     n_samples median_cor  mean_cor
#         <int>      <num>     <num>
#  1:      6109  0.8395369 0.8227825
#  2:      7084  0.8544284 0.8447889
#  3:      7858  0.8275934 0.8166380
#  4:      7084  0.8532372 0.8489355
#  5:      7858  0.8528591 0.8427618
#  6:      6109  0.7727628 0.7501091
#  7:      7084  0.7977473 0.7742245
#  8:      7858  0.7940958 0.7699124
#  9:      6109  0.8064229 0.7803054
# 10:      7084  0.8120138 0.7894158
# 11:      7858  0.8179245 0.7940816
# 12:      6109  0.7430388 0.7292235
# 13:      7084  0.7594236 0.7388811
# 14:      7858  0.7585780 0.7373149
# 15:      6109  0.8267657 0.8052351
# 16:      7084  0.8336900 0.8148812
# 17:      7858  0.8131584 0.7936423
# 18:     60645  0.8478152 0.8163952
# 19:     60678  0.8503860 0.8211844
# 20:     60662  0.8489513 0.8187210
# 21:     60645  0.8558226 0.8247210
# 22:     60678  0.8532190 0.8249653
# 23:     60662  0.8573145 0.8254827
# 24:     60645  0.7835216 0.7639144
# 25:     60678  0.7750094 0.7580275
# 26:     60662  0.7862517 0.7633146
# 27:     60645  0.8127235 0.7875288
# 28:     60678  0.8153024 0.7915172
# 29:     60662  0.8125119 0.7854631
# 30:     60645  0.7451628 0.7305430
# 31:     60678  0.7499994 0.7322204
# 32:     60662  0.7572855 0.7360530
# 33:     60645  0.8390785 0.8110329
# 34:     60678  0.8373892 0.8099751
# 35:     60662  0.8392409 0.8106991
# 36:    152860  0.8471402 0.8190293
# 37:    151532  0.8448514 0.8192591
# 38:    151424  0.8502506 0.8255028
# 39:    152860  0.8622901 0.8328584
# 40:    151532  0.8546028 0.8249385
# 41:    151424  0.8592791 0.8325056
# 42:    152860  0.7849498 0.7634736
# 43:    151532  0.7761873 0.7592106
# 44:    151424  0.7843709 0.7653096
# 45:    152860  0.8170561 0.7938434
# 46:    151532  0.8077366 0.7875736
# 47:    151424  0.8073487 0.7867078
# 48:    152860  0.7518490 0.7319189
# 49:    151532  0.7506710 0.7338418
# 50:    151424  0.7514557 0.7355592
# 51:    152860  0.8410905 0.8149467
# 52:    151532  0.8385755 0.8119808
# 53:    151424  0.8395431 0.8154991
# 54:     30308  0.8401541 0.8116462
# 55:     30290  0.8255750 0.8076078
# 56:     30281  0.8407508 0.8139136
# 57:     30308  0.8540959 0.8242902
# 58:     30290  0.8439279 0.8236776
# 59:     30281  0.8583048 0.8299741
# 60:     30308  0.7906957 0.7704717
# 61:     30290  0.7792777 0.7638062
# 62:     30281  0.7905682 0.7680019
# 63:     30308  0.8093418 0.7877320
# 64:     30290  0.8133362 0.7938727
# 65:     30281  0.8167950 0.7917290
# 66:     30308  0.7512809 0.7370836
# 67:     30290  0.7494158 0.7360772
# 68:     30281  0.7549805 0.7332677
# 69:     30308  0.8397233 0.8113706
# 70:     30290  0.8240796 0.8070068
# 71:     30281  0.8392970 0.8116807
# 72:    303309  0.8522067 0.8226775
# 73:    303930  0.8461231 0.8174348
# 74:    303309  0.8586460 0.8288066
# 75:    303930  0.8600701 0.8320866
# 76:    303309  0.7834269 0.7640707
# 77:    303930  0.7799667 0.7594436
# 78:    303309  0.8186768 0.7922197
# 79:    303930  0.8074474 0.7840061
# 80:    303309  0.7525963 0.7357352
# 81:    303930  0.7503472 0.7311655
# 82:    303309  0.8389500 0.8122868
# 83:    303930  0.8397768 0.8136169
#     n_samples median_cor  mean_cor

# %% [markdown]
# ## Plots

# %%
canonical_k <- c(86, 173, 432, 864, 1296, 1728)
snap_k <- function(k) canonical_k[which.min(abs(canonical_k - k))]

coverage_order <- sort(unique(results_df$coverage_pct))
results_df$coverage_label <- factor(
  paste0(results_df$coverage_pct, "%"),
  levels = paste0(coverage_order, "%")
)
results_df$k_canonical <- sapply(results_df$k_target, snap_k)

summary_stats <- results_df %>%
  dplyr::group_by(coverage_pct, coverage_label, k_canonical) %>%
  dplyr::summarise(
    mean_median_cor = mean(median_cor),
    sd_median_cor   = sd(median_cor),
    n_runs          = dplyr::n(),
    .groups = "drop"
  )

# %%
# Plot 1: median correlation vs k_canonical, coloured by coverage %, boxplot across seeds
box_width <- min(diff(sort(log10(canonical_k)))) * 0.5

p_line <- ggplot2::ggplot(
    results_df,
    ggplot2::aes(x = k_canonical, y = median_cor,
                 colour = coverage_label, fill = coverage_label)) +
  ggplot2::geom_boxplot(
    ggplot2::aes(group = interaction(coverage_label, k_canonical)),
    alpha = 0.2, outlier.shape = NA, width = box_width, position = "identity"
  ) +
  ggplot2::geom_line(
    data = summary_stats,
    ggplot2::aes(x = k_canonical, y = mean_median_cor, group = coverage_label)
  ) +
  ggplot2::geom_point(
    data = summary_stats,
    ggplot2::aes(x = k_canonical, y = mean_median_cor)
  ) +
  ggplot2::scale_x_continuous(
    breaks = canonical_k,
    trans  = "log10",
    labels = scales::comma
  ) +
  ggplot2::theme_bw() +
  ggplot2::labs(
    x      = "Number of latent variables (k, log scale)",
    y      = "Median Spearman correlation",
    colour = "Coverage",
    fill   = "Coverage",
    title  = "Reconstruction error vs. k: saturation models, study subsamples"
  ) +
  ggplot2::theme(plot.title = ggplot2::element_text(hjust = 0.5, face = "bold"))

p_line
# Out:
# plot without title

# %%
# Plot 2: density of per-sample Spearman cors, faceted by coverage %, coloured by k
cor_long <- dplyr::bind_rows(
  lapply(results_list, function(x) {
    data.frame(
      coverage_pct = x$coverage_pct,
      k_target     = x$k_target,
      run          = x$run,
      cor          = x$cor_vector[[1]],
      stringsAsFactors = FALSE
    )
  })
)

cor_long$coverage_label <- factor(
  paste0(cor_long$coverage_pct, "%"),
  levels = paste0(coverage_order, "%")
)
cor_long$k_canonical <- sapply(cor_long$k_target, snap_k)
cor_long$k_label <- factor(
  paste0("k=", cor_long$k_canonical),
  levels = paste0("k=", canonical_k)
)

p_density <- ggplot2::ggplot(
    cor_long,
    ggplot2::aes(x = cor, colour = k_label,
                 group = interaction(k_label, run))) +
  ggplot2::geom_density(alpha = 0.3) +
  ggplot2::facet_wrap(~ coverage_label, ncol = 2) +
  ggplot2::theme_bw() +
  ggplot2::labs(
    x      = "Spearman correlation (input vs reconstructed, per sample)",
    y      = "Density",
    colour = "k",
    title  = "Reconstruction quality by k: saturation models, study subsamples"
  ) +
  ggplot2::theme(
    plot.title      = ggplot2::element_text(hjust = 0.5, face = "bold"),
    legend.position = "bottom"
  )

p_density
# Out:
# plot without title
