# %% [markdown]
# # GTEx model building with flashier

# %% [markdown]
# Empirical Bayes non-negative matrix factorization for single-cell RNA-seq data

# %% [markdown]
# ## Libraries

# %%
if (!requireNamespace("flashier", quietly = TRUE)) {
  install.packages(
  "fastTopics",
  repos = c("https://stephenslab.r-universe.dev", "https://cloud.r-project.org")
  )
  remotes::install_github("willwerscheid/flashier", dependencies = c("Depends","Imports"))
}

# %%
library(flashier)
library(here)
library(flashier)
library(Matrix)
library(fastTopics)
library(ggplot2)
set.seed(3)
# Out:
# Loading required package: ebnm
#
# here() starts at /home/msubirana/Documents/pivlab/clamp-analyses

# %% [markdown]
# ## Input

# %%
gtex_data <- readRDS(here('output/gtex/df_gtex_fbm_filt.rds'))
head(gtex_data)
# Out:
#               GTEX-1117F-0226-SM-5GZZ7 GTEX-1117F-0426-SM-5EGHI
# WASH7P         1.44614308               0.1466590
# RP11-34P13.15 -0.21703290              -1.2491072
# RP11-34P13.16  0.05000362              -1.2529810
# RP11-34P13.18  0.80964288              -0.4648762
# AP006222.2     0.60340589              -0.6590192
# MTND1P23      -0.28701222               0.4584699
#               GTEX-1117F-0526-SM-5EGHJ GTEX-1117F-0626-SM-5N9CS
# WASH7P         1.15444418               1.8411744
# RP11-34P13.15 -0.71067536              -0.5458638
# RP11-34P13.16 -1.26148519              -0.7514709
# RP11-34P13.18  0.60984294               0.6852051
# AP006222.2    -0.22788724              -0.3186479
# MTND1P23      -0.04655404              -0.6834497
#               GTEX-1117F-0726-SM-5GIEN GTEX-1117F-1326-SM-5EGHH
# WASH7P        -0.07922225               0.6559264
# RP11-34P13.15 -0.88156172              -0.4026354
# RP11-34P13.16 -0.77242737              -0.3766090
# ...

# %%
K <- 412

# %% [markdown]
# # Run Flashier

# %%
flash_gtex <- flash(gtex_data,
    ebnm_fn = ebnm_normal,
    backfit = TRUE,
    greedy_Kmax = K      
)
# Out:
# Adding factor 1 to flash object...

# %%
plot(flash_gtex, pm_which = "factors", pm_colors = gtex_colors, plot_type = "bar")
