# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('output/03_model_biology/00_pseudobulk/00_benchmark/benchmark_long.csv', 'output/01_model_building/00_pseudobulk/grouped_cv_analysis/oof_predictions.csv', 'output/01_model_building/00_pseudobulk/grouped_cv_analysis/thresholded_metrics.csv', 'output/01_model_building/00_pseudobulk/grouped_cv_analysis/thresholded_summary.csv', 'output/03_model_biology/00_pseudobulk/02_disentangle/module_panel_ready.csv', 'output/03_model_biology/00_pseudobulk/04_hard_cell_types/hard_group_dot_ready.csv', 'output/03_model_biology/00_pseudobulk/04_hard_cell_types/related_lv_correlations.csv', 'output/03_model_biology/00_pseudobulk/05_hard_pair_loadings/hard_pair_loadings_panel_ready.csv', 'output/03_model_biology/00_pseudobulk/05_hard_pair_loadings/hard_pair_loading_stats.csv', 'output/03_model_biology/01_gtex/04_subtissues/subtissue_confusion_matrices.tsv', 'output/03_model_biology/01_gtex/04_subtissues/anatomical_subtissue_results.tsv', 'output/03_model_biology/01_gtex/04_liver_disentangle_xcell_rf_true_labels/liver_xcell_scatter.csv', 'output/03_model_biology/01_gtex/04_liver_disentangle_xcell_rf_true_labels/liver_lv_pathways.csv', 'output/03_model_biology/01_gtex/06_multitissue_xcell_recovery/multitissue_recovery_panel_ready.csv', 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_oof_predictions.csv', 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_oof_statistics.csv', 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_perez_annotation.csv', 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_perez_activity.csv', 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_perez_summary.csv', '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/99_panels/fig2.ipynb', "benchmark_long" = 'output/03_model_biology/00_pseudobulk/00_benchmark/benchmark_long.csv', "holdout_predictions" = 'output/01_model_building/00_pseudobulk/grouped_cv_analysis/oof_predictions.csv', "holdout_thresholded_metrics" = 'output/01_model_building/00_pseudobulk/grouped_cv_analysis/thresholded_metrics.csv', "holdout_thresholded_summary" = 'output/01_model_building/00_pseudobulk/grouped_cv_analysis/thresholded_summary.csv', "marker" = 'output/03_model_biology/00_pseudobulk/02_disentangle/module_panel_ready.csv', "hard" = 'output/03_model_biology/00_pseudobulk/04_hard_cell_types/hard_group_dot_ready.csv', "related_corr" = 'output/03_model_biology/00_pseudobulk/04_hard_cell_types/related_lv_correlations.csv', "hard_pair_loading_ready" = 'output/03_model_biology/00_pseudobulk/05_hard_pair_loadings/hard_pair_loadings_panel_ready.csv', "hard_pair_loading_stats" = 'output/03_model_biology/00_pseudobulk/05_hard_pair_loadings/hard_pair_loading_stats.csv', "subtissue_confusion" = 'output/03_model_biology/01_gtex/04_subtissues/subtissue_confusion_matrices.tsv', "subtissue_anatomical" = 'output/03_model_biology/01_gtex/04_subtissues/anatomical_subtissue_results.tsv', "liver_xcell_scatter" = 'output/03_model_biology/01_gtex/04_liver_disentangle_xcell_rf_true_labels/liver_xcell_scatter.csv', "liver_lv_pathways" = 'output/03_model_biology/01_gtex/04_liver_disentangle_xcell_rf_true_labels/liver_lv_pathways.csv', "multitissue_panel_ready" = 'output/03_model_biology/01_gtex/06_multitissue_xcell_recovery/multitissue_recovery_panel_ready.csv', "donor_bulk_predictions" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_oof_predictions.csv', "donor_bulk_statistics" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_oof_statistics.csv', "donor_bulk_perez_annotation" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_perez_annotation.csv', "donor_bulk_perez_activity" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_perez_activity.csv', "donor_bulk_perez_summary" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery/fig2_perez_summary.csv', "notebook" = '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/99_panels/fig2.ipynb'),
    output = list('output/99_panels/fig2/fig2.png', 'output/99_panels/fig2/fig2.pdf', 'output/99_panels/fig2/fig2.svg', 'output/99_panels/fig2/notebook.complete', "png" = 'output/99_panels/fig2/fig2.png', "pdf" = 'output/99_panels/fig2/fig2.pdf', "svg" = 'output/99_panels/fig2/fig2.svg', "complete" = 'output/99_panels/fig2/notebook.complete'),
    params = list(),
    wildcards = list(),
    threads = 1,
    log = list('/home/msubirana/Documents/pivlab/clamp-analyses/nbs/99_panels/fig2.executed.ipynb', "notebook" = '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/99_panels/fig2.executed.ipynb'),
    resources = list('tmpdir', "tmpdir" = '/tmp'),
    config = list("datasets" = list("Brain_Mathys2023" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/Brain_Mathys2023', "kind" = 'matrix_market', "raw" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_matrix.mtx.gz', "features" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_features.tsv.gz', "barcodes" = 'data/pseudobulk/raw/Brain_Mathys2023/ad430_barcodes.tsv.gz', "metadata" = 'data/pseudobulk/raw/Brain_Mathys2023/meta.tsv', "cell_id_col" = 'cellName', "sample_col" = 'Individual', "sample_transform" = 'identity', "truth_v0_col" = 'Major_Cell_Type', "truth_v1_col" = 'Cell_Type', "raw_cell_type_col" = 'Major_Cell_Type', "projection_label_col" = 'Major_Cell_Type', "cohort_manifest" = 'data/pseudobulk/Brain_Mathys2023/patient_info.csv'), "Brain_Xiong2023" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/Brain_Xiong2023', "kind" = 'matrix_market', "raw" = 'data/pseudobulk/raw/Brain_Xiong2023/matrix.mtx.gz', "features" = 'data/pseudobulk/raw/Brain_Xiong2023/features.tsv.gz', "barcodes" = 'data/pseudobulk/raw/Brain_Xiong2023/barcodes.tsv.gz', "metadata" = 'data/pseudobulk/raw/Brain_Xiong2023/meta.tsv', "cell_id_col" = 'cellId', "sample_col" = 'Individual', "sample_transform" = 'hyphen_to_underscore', "truth_v0_col" = 'Celltype', "truth_v1_col" = 'Subcelltype', "raw_cell_type_col" = 'Celltype', "projection_label_col" = 'Celltype', "cohort_manifest" = 'data/pseudobulk/Brain_Xiong2023/patient_info.csv'), "Heart_Datar2026" = list("build_pseudobulk" = TRUE, "kind" = 'h5ad', "raw" = 'data/pseudobulk/Heart_Datar2026/HeartMap_V1.0_raw_counts.h5ad', "matrix" = 'X', "sample_col" = 'donor_id', "sample_transform" = 'identity', "truth_v0_col" = 'cell_type__ontology_label', "raw_cell_type_col" = 'cell_type__ontology_label', "projection_label_col" = 'cell_type__ontology_label', "min_cells" = 400, "exclude" = list("cell_type__ontology_label" = c('cell')), "truth_v0_map" = list("adipocyte" = 'Adipocyte', "regular atrial cardiac myocyte" = 'AtrialCM', "endocardial cell" = 'Endocardial', "cardiac endothelial cell" = 'Endothelial', "mesothelial cell of epicardium" = 'Epicardial', "fibroblast of cardiac tissue" = 'Fibroblast', "endothelial cell of lymphatic vessel" = 'LymphaticEndothelial', "lymphocyte" = 'Lymphocyte', "macrophage" = 'Macrophage', "mast cell" = 'Mast', "cardiac neuron" = 'Neuronal', "pericyte" = 'Pericyte', "vascular associated smooth muscle cell" = 'VSMC', "regular ventricular cardiac myocyte" = 'VentricularCM'), "projection_label_map" = list("adipocyte" = 'Adipocyte', "regular atrial cardiac myocyte" = 'AtrialCM', "endocardial cell" = 'Endocardial', "cardiac endothelial cell" = 'Endothelial', "mesothelial cell of epicardium" = 'Epicardial', "fibroblast of cardiac tissue" = 'Fibroblast', "endothelial cell of lymphatic vessel" = 'LymphaticEndothelial', "lymphocyte" = 'Lymphocyte', "macrophage" = 'Macrophage', "mast cell" = 'Mast', "cardiac neuron" = 'Neuronal', "pericyte" = 'Pericyte', "vascular associated smooth muscle cell" = 'VSMC', "regular ventricular cardiac myocyte" = 'VentricularCM')), "PBMC_1k1k" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/PBMC_1k1k', "kind" = 'h5ad', "raw" = 'data/pseudobulk/raw/PBMC_1k1k/PBMC_1k1k_raw.h5ad', "matrix" = 'X', "sample_col" = 'donor_id', "sample_transform" = 'sample_prefix_hyphen_to_underscore', "truth_v0_col" = 'predicted.celltype.l2', "raw_cell_type_col" = 'predicted.celltype.l2', "projection_label_col" = 'predicted.celltype.l2', "cohort_manifest" = 'data/pseudobulk/PBMC_1k1k/patient_info.csv', "truth_v0_map" = list("CD4 CTL" = 'CD4_T', "CD4 Naive" = 'CD4_T', "CD4 Proliferating" = 'CD4_T', "CD4 TCM" = 'CD4_T', "CD4 TEM" = 'CD4_T', "Treg" = 'CD4_T', "CD8 Naive" = 'CD8_T', "CD8 Proliferating" = 'CD8_T', "CD8 TCM" = 'CD8_T', "CD8 TEM" = 'CD8_T', "gdT" = 'gd_T', "B intermediate" = 'B_cell', "B memory" = 'B_cell', "B naive" = 'B_cell', "Plasmablast" = 'Plasma_B', "CD14 Mono" = 'CD14_Mono', "CD16 Mono" = 'CD16_Mono', "cDC1" = 'DC', "cDC2" = 'DC', "ASDC" = 'DC', "NK" = 'NK', "NK Proliferating" = 'NK', "NK_CD56bright" = 'NK'), "projection_label_map" = list("CD4 CTL" = 'CD4_T', "CD4 Naive" = 'CD4_T', "CD4 Proliferating" = 'CD4_T', "CD4 TCM" = 'CD4_T', "CD4 TEM" = 'CD4_T', "Treg" = 'CD4_T', "CD8 Naive" = 'CD8_T', "CD8 Proliferating" = 'CD8_T', "CD8 TCM" = 'CD8_T', "CD8 TEM" = 'CD8_T', "gdT" = 'gd_T', "B intermediate" = 'B_cell', "B memory" = 'B_cell', "B naive" = 'B_cell', "Plasmablast" = 'Plasma_B', "CD14 Mono" = 'CD14_Mono', "CD16 Mono" = 'CD16_Mono', "cDC1" = 'DC', "cDC2" = 'DC', "ASDC" = 'DC', "NK" = 'NK', "NK Proliferating" = 'NK', "NK_CD56bright" = 'NK')), "PBMC_Perez2022" = list("build_pseudobulk" = FALSE, "pseudobulk_dir" = 'data/pseudobulk/PBMC_Perez2022', "kind" = 'h5ad', "raw" = 'data/pseudobulk/raw/PBMC_Perez2022/PBMC_Perez2022_raw.h5ad', "matrix" = 'raw.X', "sample_col" = 'ind_cov', "sample_transform" = 'sample_prefix_hyphen_to_underscore', "truth_v0_col" = 'cell_type', "raw_cell_type_col" = 'cell_type', "projection_label_col" = 'cell_type', "cohort_manifest" = 'data/pseudobulk/PBMC_Perez2022/patient_info.csv', "truth_v0_map" = list("B cell" = 'B_cell', "plasmablast" = 'B_cell', "classical monocyte" = 'Myeloid', "non-classical monocyte" = 'Myeloid', "conventional dendritic cell" = 'Myeloid', "plasmacytoid dendritic cell" = 'Myeloid', "progenitor cell" = 'Myeloid', "natural killer cell" = 'NK', "CD4-positive, alpha-beta T cell" = 'T_cell', "CD8-positive, alpha-beta T cell" = 'T_cell', "lymphocyte" = 'T_cell'), "projection_label_map" = list("B cell" = 'B_cell', "plasmablast" = 'B_cell', "classical monocyte" = 'Myeloid', "non-classical monocyte" = 'Myeloid', "conventional dendritic cell" = 'Myeloid', "plasmacytoid dendritic cell" = 'Myeloid', "progenitor cell" = 'Myeloid', "natural killer cell" = 'NK', "CD4-positive, alpha-beta T cell" = 'T_cell', "CD8-positive, alpha-beta T cell" = 'T_cell', "lymphocyte" = 'T_cell')), "Lung_Sikkema2023" = list("build_pseudobulk" = TRUE, "kind" = 'h5ad', "raw" = 'data/pseudobulk/Lung_Sikkema2023/lung_HLCA.h5ad', "matrix" = 'raw.X', "sample_col" = 'donor_id', "sample_transform" = 'identity', "truth_v0_col" = 'ann_level_2', "truth_v1_col" = 'ann_finest_level', "raw_cell_type_col" = 'ann_level_3', "projection_label_col" = 'ann_level_2', "min_cells" = 400)), "methods" = list("CLAMPbase" = 'CLAMPbase/B.csv', "CLAMPfull" = 'CLAMPfull/B.csv', "PLIER" = 'PLIER/B.csv', "PCA" = 'PCA/B.csv', "NMF" = 'NMF/B.csv', "ICA" = 'ICA/B.csv', "Flashier" = 'flashier/B.csv', "MOFA-FLEX" = 'MOFA_FLEX_PRIOR/B.csv', "GSSig" = 'GSS/B.csv', "CoGAPS" = 'CoGAPS/B.csv'), "paths" = list("production" = 'output/01_model_building/00_pseudobulk', "biology" = 'output/03_model_biology/00_pseudobulk', "model_notebooks" = 'nbs/01_model_building/00_pseudobulk', "biology_notebooks" = 'nbs/03_model_biology/00_pseudobulk', "panels" = 'output/99_panels', "panels_notebooks" = 'nbs/99_panels'), "references" = list("go_bp_url" = 'https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName=GO_Biological_Process_2025', "go_bp_file" = 'data/pathways/GO_Biological_Process_2025.gmt', "go_bp_sha256" = '0fc02458765cfce6c9348dce9f7a9397c6caf7c09ba318f468135d7ac60342ee', "cell_marker_file" = 'data/pathways/Cell_marker_Human.xlsx', "allen_brain_gmt_file" = 'data/pathways/Allen_Brain_Atlas_10x_scRNA_2021.gmt', "azimuth_file" = 'data/pathways/Azimuth_2023.txt', "gtex_tissues_pathmat" = 'data/archs4/GTEx_Tissues_pathMat.rds', "brain_datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023')), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "seed" = 123), "module_recovery" = list("top_gene_fraction" = 0.01, "retry_gene_fraction" = 0.03, "fdr_threshold" = 0.05, "top_terms" = 3), "clamp" = list("max_iter" = 500, "seed" = 123), "grouped_cv" = list("n_folds" = 5, "group_col" = 'sample', "split_seed" = 42, "min_train_lv_cor" = 0.5, "bootstrap_seed" = 123, "bootstrap_replicates" = 10000), "flashier" = list("backfit_maxiter" = 20), "cogaps" = list("n_iterations" = 5000, "n_threads" = 4, "seed" = 123), "mofa_flex" = list("max_epochs" = 1000, "seed" = 123), "projection" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "top_fraction" = 0.01), "cell_type_analysis" = list("excluded_targets" = list("Brain_Mathys2023" = c('Vas'), "Brain_Xiong2023" = c('Vas'), "Lung_Sikkema2023" = c('Hematopoietic stem cells', 'Mesothelium', 'Smooth muscle'))), "gtex" = list("raw_url" = 'https://storage.googleapis.com/adult-gtex/bulk-gex/v8/rna-seq/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', "raw_gz" = 'data/gtex/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz', "metadata" = 'data/gtex/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt', "xcell_scores" = 'data/gtex/GTEx_Analysis_v8_xCell_scores_7_celltypes.txt', "paths" = list("production" = 'output/01_model_building/01_gtex', "biology" = 'output/03_model_biology/01_gtex', "model_notebooks" = 'nbs/01_model_building/01_gtex', "biology_notebooks" = 'nbs/03_model_biology/01_gtex'), "raw_data" = list("chunk_size" = 100, "n_cores" = 1), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "seed" = 123), "clamp" = list("max_iter" = 500, "seed" = 123), "flashier" = list("backfit_maxiter" = 20), "mofa_flex_prior" = list("min_fraction" = 0.4, "min_count" = 40, "max_count" = 200, "similarity_threshold" = 0.8, "max_epochs" = 1000, "seed" = 123), "cogaps" = list("n_iterations" = 5000, "n_threads" = 4, "seed" = 123, "timeout_days" = 7), "gss" = list("d_cluster" = 4, "seed" = 123), "kmeans_clustering" = list("min_samples" = 50, "ari_min_samples" = 1, "n_clusters" = 54, "base_seed" = 10000, "n_reps_per_k" = 50, "gene_fractions" = c(1.0, 0.75, 0.5, 0.25, 0.1, 0.05, 0.01)), "lv_importance" = list("global_seed" = 42, "min_rf_accuracy" = 0.9), "subtissue_inference" = list("n_folds" = 5, "global_seed" = 42, "min_rf_accuracy" = 0.85, "min_subtissue_samples" = 20, "n_jobs_per_fold" = 8, "anatomical_spec" = 'workflow/config/gtex_anatomical_subtissues.tsv', "permutation_repeats" = 1000, "bootstrap_repeats" = 1000, "evaluation_jobs" = 8, "tissues" = c('Adipose Tissue', 'Blood', 'Blood Vessel', 'Brain', 'Colon', 'Esophagus', 'Heart', 'Kidney', 'Skin'))), "runtime_benchmark" = list("seeds" = c(123, 456, 789), "threads" = 4, "methods" = c('CLAMPfull', 'CLAMPbase', 'PLIER', 'CoGAPS', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), "output_root" = 'output/02_model_performance/00_pseudobulk/00_computational_timing', "notebook" = 'nbs/02_model_performance/00_pseudobulk/00_computational_timing.ipynb'), "runtime_benchmark_gtex" = list("dataset" = 'GTEx', "seeds" = c(123, 456, 789), "threads" = 4, "methods" = c('CLAMPfull', 'CLAMPbase', 'PLIER', 'Flashier', 'NMF', 'PCA', 'ICA', 'GSSig', 'MOFA-FLEX'), "excluded_methods" = list("CoGAPS" = 'rule cogaps_gtex was run to the end of its hard wall-clock budget (gtex.cogaps.timeout_days = 7) and killed without converging; the evidence is on disk at output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt. CoGAPS therefore has no finite GTEx runtime to report\n'), "cogaps_evidence" = 'output/01_model_building/01_gtex/CoGAPS/NOT_CONVERGED.txt', "output_root" = 'output/02_model_performance/01_gtex/00_computational_timing', "notebook" = 'nbs/02_model_performance/01_gtex/00_computational_timing.ipynb'), "donor_bulk" = list("datasets" = c('Brain_Mathys2023', 'Brain_Xiong2023', 'Heart_Datar2026', 'PBMC_1k1k', 'PBMC_Perez2022', 'Lung_Sikkema2023'), "paths" = list("production" = 'output/01_model_building/00_pseudobulk/donor_bulk', "biology" = 'output/03_model_biology/00_pseudobulk/06_donor_bulk_recovery', "model_notebooks" = 'nbs/01_model_building/00_pseudobulk', "biology_notebooks" = 'nbs/03_model_biology/00_pseudobulk'), "aggregation" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "sample_cells" = 60000, "minimum_per_type" = 250, "seed" = 123), "umap" = list("target_sum" = 10000, "n_hvg" = 2000, "n_pcs" = 50, "n_neighbors" = 30, "min_dist" = 0.3, "seed" = 123), "projection" = list("chunk_cells" = 20000, "chunk_nnz" = 20000000, "duplicate_gene_policy" = 'sum')), "archs4" = list("raw_url" = 'https://s3.dev.maayanlab.cloud/archs4/files/human_gene_v2.5.h5', "raw_h5" = 'data/archs4/human_gene_v2.5.h5', "gene_lengths" = 'data/archs4/gene_lengths.rds', "ensembl_version" = 107, "paths" = list("production" = 'output/01_model_building/02_archs4', "biology" = 'output/03_model_biology/02_archs4', "model_notebooks" = 'nbs/01_model_building/02_archs4', "biology_notebooks" = 'nbs/03_model_biology/02_archs4'), "raw_data" = list("block_size" = 100, "n_cores" = 10), "preprocess" = list("mean_cutoff" = 0.5, "var_cutoff" = 0.1, "single_cell_probability_max" = 0.5, "seed" = 123), "svd" = list("n_cores" = 30, "seed" = 123), "clamp" = list("k_multiplier" = 2, "multiplier" = 100, "max_iter" = 5000, "seed" = 123), "prior" = list("gmts" = list("HALL" = 'data/pathways/h.all.v2026.1.Hs.symbols.gmt', "REACTOME" = 'data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt', "GOCC" = 'data/pathways/c5.go.cc.v2026.1.Hs.symbols.gmt', "C8" = 'data/pathways/c8.all.v2026.1.Hs.symbols.gmt')), "final_model" = list("dir" = 'output/01_model_building/02_archs4/01_final_model', "seeds" = c(1, 2, 3), "reference_seed" = 1, "leaf" = 'seed{seed}', "model_name" = 'CLAMPfull'), "coverage" = list("prior_gmt" = 'data/pathways/go_bp.Hs.symbols.gmt', "model_root" = 'output/01_model_building/02_archs4/02_coverage_study/models', "ora_root" = 'output/01_model_building/02_archs4/02_coverage_study/ora', "assignments" = 'output/03_model_biology/02_archs4/00_coverage/assignments', "seeds" = c(1, 2, 3), "rng_seeds" = c(123, 124, 125), "levels" = list("1" = '00_bp_coverage_study_01', "5" = '01_bp_coverage_study_05', "10" = '02_bp_coverage_study_10', "25" = '03_bp_coverage_study_25', "50" = '04_bp_coverage_study_50', "75" = '05_bp_coverage_study_75', "100" = '06_bp_coverage_study_100'), "input_root" = 'output/01_model_building/02_archs4/02_coverage_study', "model_name" = 'CLAMPfull_bp', "resources" = list("1" = list("mem_mb" = 32000, "runtime" = 5760), "5" = list("mem_mb" = 64000, "runtime" = 8640), "10" = list("mem_mb" = 96000, "runtime" = 14400), "25" = list("mem_mb" = 224000, "runtime" = 24000), "50" = list("mem_mb" = 192000, "runtime" = 36000), "75" = list("mem_mb" = 288000, "runtime" = 48000), "100" = list("mem_mb" = 320000, "runtime" = 54000)), "comparators" = list("gtex" = list("label" = 'GTEx', "fbm_rds" = 'output/01_model_building/01_gtex/gtex_fbm_filt.rds', "genes_rds" = 'output/01_model_building/01_gtex/gtex_genes.rds', "samples_rds" = 'output/01_model_building/01_gtex/gtex_samples.rds', "svd" = 'output/01_model_building/01_gtex/gtex_svdRes.rds', "k" = 'output/01_model_building/01_gtex/CLAMP_K_gtex.rds', "base" = 'output/01_model_building/01_gtex/CLAMPbase.rds', "base_z" = 'output/01_model_building/01_gtex/CLAMPbase/Z.csv', "max_iter" = 500), "recount2" = list("label" = 'recount2', "fbm_rds" = 'output/01_model_building/03_recount2/00_recount2/recount2_fbm_filt.rds', "genes_rds" = 'output/01_model_building/03_recount2/00_recount2/recount2_genes.rds', "samples_rds" = 'output/01_model_building/03_recount2/00_recount2/recount2_samples.rds', "svd" = 'output/01_model_building/03_recount2/00_recount2/recount2_svdRes.rds', "k" = 'output/01_model_building/03_recount2/00_recount2/CLAMP_K_recount2.rds', "base" = 'output/01_model_building/03_recount2/00_recount2/CLAMPbase.rds', "base_z" = 'output/01_model_building/03_recount2/00_recount2/CLAMPbase/Z.csv', "max_iter" = 500)), "colors" = list("model" = list("CLAMPfull" = '#0072B2', "CLAMPbase" = '#777777'), "dataset" = list("ARCHS4" = '#0072B2', "GTEx" = '#E69F00', "recount2" = '#009E73')), "routing" = list("remote_min_free_cpus" = 2, "remote_min_free_mem_mb" = 16000, "remote_max_ora_jobs" = 8, "local_total_mem_mb" = 96000, "retries" = 2, "retry_mem_factors" = c(1.0, 1.5, 2.0), "retry_mem_cap_mb" = 800000)), "ora" = list("databases" = list("reactome" = list("type" = 'gmt', "path" = 'data/pathways/c2.cp.reactome.v2026.1.Hs.symbols.gmt', "label" = 'Reactome'), "canonical" = list("type" = 'gmt', "path" = 'data/pathways/c2.cp.v2026.1.Hs.symbols.gmt', "exclude_term_regex" = '^REACTOME_', "label" = 'Canonical non-Reactome'), "cellmarker" = list("type" = 'cellmarker_xlsx', "path" = 'data/pathways/Cell_marker_Human.xlsx', "sheet" = 'human', "term_column" = 'cell_name', "gene_column" = 'Symbol', "label" = 'CellMarker')), "top_pct" = 0.01, "min_size" = 10, "max_size" = 500, "pvalue_cutoff" = 0.05, "qvalue_cutoff" = 0.2, "fdr" = c(0.05), "resources" = list("mem_mb" = 8000, "runtime" = 5760)))),
    rule = 'fig2_panel',
    bench_iteration = as.numeric(NA),
    scriptdir = '/home/msubirana/Documents/pivlab/clamp-analyses/nbs/99_panels',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
setwd('/home/msubirana/Documents/pivlab/clamp-analyses');

######## snakemake preamble end #########

# %% [markdown]
# 💡 **Environment:** `clamp-analyses`

# %%
suppressPackageStartupMessages({
  library(data.table)
  library(ggplot2)
  library(patchwork)
  library(cowplot)
  library(ggrastr)
  library(yaml)
  library(here)
})

# %%
cfg <- yaml::read_yaml(here("config.yaml"))

AXIS_TITLE_SIZE  <- 10.5
AXIS_LABEL_SIZE  <- 8
PLOT_TITLE_SIZE  <- 9
LEGEND_TEXT_SIZE <- 7
LEGEND_TITLE_SIZE <- 8

LABEL_SIZE <- 10
LABEL_FONTFACE <- "bold"
LABEL_FONTFAMILY <- "Helvetica"
CLAMP_COLOR <- "#0072B2"

DATASET_LABELS <- c(
  Brain_Mathys2023 = "Brain Mathys",
  Brain_Xiong2023  = "Brain Xiong",
  Heart_Datar2026  = "Heart Datar",
  PBMC_1k1k        = "PBMC 1k1k",
  PBMC_Perez2022   = "PBMC Perez",
  Lung_Sikkema2023 = "Lung Sikkema"
)

DATASET_COLORS <- unlist(cfg$DATASET_COLORS)

abbreviate_ct <- function(x) {
  x <- gsub("Oligodendrocyte [Pp]rogenitor [Cc]ells?", "OPC", x)
  x <- gsub("Oligodendrocyte [Pp]recursor [Cc]ells?", "OPC", x)
  x
}

wrap_label <- function(x, width = 14) {
  vapply(x, function(s) paste(strwrap(s, width = width), collapse = "\n"),
         character(1), USE.NAMES = FALSE)
}
shorten_label <- function(x, width = 18) {
  ifelse(nchar(x) > width, paste0(substr(x, 1, width - 1), "…"), x)
}

theme_pub <- function(base_size = 7, base_line_size = 0.3) {
    theme_classic(base_size = base_size, base_family = "Helvetica") %+replace%
    theme(
        plot.title        = element_text(size = PLOT_TITLE_SIZE, face = "plain", hjust = 0.5,
                                          margin = margin(b = 2)),
        axis.line         = element_line(linewidth = base_line_size),
        axis.ticks        = element_line(linewidth = base_line_size),
        axis.text         = element_text(size = AXIS_LABEL_SIZE),
        axis.title        = element_text(size = AXIS_TITLE_SIZE, face = "plain"),
        legend.text       = element_text(size = LEGEND_TEXT_SIZE),
        legend.title      = element_text(size = LEGEND_TITLE_SIZE, face = "plain"),
        legend.key.size   = unit(3, "mm"),
        legend.background = element_blank(),
        legend.key        = element_blank(),
        panel.grid        = element_blank(),
        strip.text        = element_text(size = PLOT_TITLE_SIZE, face = "plain"),
        strip.background  = element_blank(),
        plot.margin       = unit(c(1, 2, 1, 1), "mm")
    )
}

MODEL_COLORS_RAW <- unlist(cfg$MODEL_COLORS)
names(MODEL_COLORS_RAW)[names(MODEL_COLORS_RAW) == "GenomicSuperSignature"] <- "GSSig"

# %% [markdown]
# ## Panel A: pooled benchmark boxplot

# %%
long     <- fread(snakemake@input[["benchmark_long"]])
long_box <- long[truth == "v0" & !is.na(cor)]

mean_order <- long_box[, .(m = mean(cor, na.rm = TRUE)), by = method]
setorder(mean_order, -m)
method_order <- as.character(mean_order$method)
long_box[, method := factor(method, levels = method_order)]

METHOD_COLORS <- MODEL_COLORS_RAW[method_order]
METHOD_COLORS[is.na(METHOD_COLORS)] <- "grey70"
names(METHOD_COLORS) <- method_order

mean_df <- long_box[, .(mean_cor = mean(cor, na.rm = TRUE),
                        max_cor  = max(cor, na.rm = TRUE)), by = method]
mean_df[, method := factor(method, levels = method_order)]

xpos <- setNames(seq_along(method_order), method_order)
other_methods <- setdiff(method_order, "CLAMPfull")

fmt_q <- function(q) {
  if (q >= 0.001) {
    sprintf('"%.3f"', q)
  } else {
    e_str    <- formatC(q, format = "e", digits = 1)
    parts    <- strsplit(e_str, "e")[[1]]
    mantissa <- trimws(parts[1])
    exp_val  <- as.integer(parts[2])
    sprintf('%s%%*%%10^{%d}', mantissa, exp_val)
  }
}

wide_ct_box <- dcast(long_box, dataset + cell_type ~ method, value.var = "cor")

comp_df_paired <- rbind(
  data.table(a = "CLAMPfull", b = other_methods[1:3]),
  data.table(a = "CLAMPbase", b = "PLIER")
)
comp_df_paired[, p_raw := mapply(function(a, b) {
  d <- wide_ct_box[!is.na(get(a)) & !is.na(get(b))]
  wilcox.test(d[[a]], d[[b]], paired = TRUE, alternative = "two.sided", exact = FALSE)$p.value
}, a, b)]
comp_df_paired[, q := p.adjust(p_raw, method = "BH")]

comp_df_paired[, p_one := mapply(function(a, b) {
  d <- wide_ct_box[!is.na(get(a)) & !is.na(get(b))]
  wilcox.test(d[[a]], d[[b]], paired = TRUE, alternative = "greater", exact = FALSE)$p.value
}, a, b)]
comp_df_paired[, q_one := p.adjust(p_one, method = "BH")]

assign_bracket_tiers <- function(comp_df, xpos) {
  comp_ord <- copy(comp_df)
  comp_ord[, x1 := xpos[a]]
  comp_ord[, x2 := xpos[b]]
  comp_ord[, left  := pmin(x1, x2)]
  comp_ord[, right := pmax(x1, x2)]
  comp_ord[, span  := right - left]
  setorder(comp_ord, span, q)

  levels_used <- list()
  comp_ord[, tier := 0L]

  for (i in seq_len(nrow(comp_ord))) {
    left  <- comp_ord$left[i]
    right <- comp_ord$right[i]
    tier  <- 1

    repeat {
      current <- if (tier <= length(levels_used)) levels_used[[tier]] else NULL
      overlaps <- FALSE

      if (!is.null(current)) {
        overlaps <- any(vapply(current, function(interval) {
          !(right < interval[1] || left > interval[2])
        }, logical(1)))
      }

      if (!overlaps) break
      tier <- tier + 1
    }

    comp_ord$tier[i] <- tier
    prior <- if (tier <= length(levels_used)) levels_used[[tier]] else list()
    levels_used[[tier]] <- c(prior, list(c(left, right)))
  }

  comp_ord
}

comp_ord <- assign_bracket_tiers(comp_df_paired, xpos)
n_tiers <- max(comp_ord$tier)
y_base  <- 1.08
y_step  <- 0.17
h       <- 0.02
y_max   <- y_base + (n_tiers - 1) * y_step + 0.14

plot_A <- ggplot(long_box, aes(method, cor, fill = method)) +
  geom_boxplot(width = 0.5, outlier.shape = NA, color = "black",
               linewidth = 0.25, alpha = 0.85) +
  geom_jitter(width = 0.10, size = 0.35, shape = 21, fill = "white",
              color = "#333333", stroke = 0.15, alpha = 0.75) +
  geom_point(data = mean_df, aes(x = method, y = mean_cor), shape = 23,
             size = 1.4, fill = "white", color = "black", stroke = 0.4,
             inherit.aes = FALSE) +
  geom_text(data = mean_df,
            aes(x = method, y = max_cor + 0.05, label = sprintf("%.3f", mean_cor)),
            size = 3.2, fontface = "bold", inherit.aes = FALSE) +
  scale_fill_manual(values = METHOD_COLORS, na.value = "grey70") +
  scale_y_continuous(breaks = seq(0, 1, 0.25), expand = expansion(mult = c(0.02, 0.02))) +
  coord_cartesian(ylim = c(0, y_max), clip = "on") +
  labs(x = NULL, y = "Max Pearson r per cell type") +
  theme_pub() +
  theme(legend.position = "none",
        axis.text.x = element_text(angle = 35, hjust = 1, size = AXIS_LABEL_SIZE),
        panel.grid.major = element_line(color = "grey88", linewidth = 0.25),
        panel.grid.minor = element_blank())

for (i in seq_len(nrow(comp_ord))) {
  row <- comp_ord[i, ]
  y   <- y_base + (row$tier - 1) * y_step

  if (
    (row$a == "CLAMPfull" & row$b == "CLAMPbase") |
    (row$a == "CLAMPbase" & row$b == "CLAMPfull")
  ) {
    y <- y + 0.02
  }

  lbl <- fmt_q(row$q)

  plot_A <- plot_A +
    annotate("segment", x = row$left,  xend = row$left,  y = y,       yend = y + h, linewidth = 0.25) +
    annotate("segment", x = row$left,  xend = row$right, y = y + h, yend = y + h, linewidth = 0.25) +
    annotate("segment", x = row$right, xend = row$right, y = y,       yend = y + h, linewidth = 0.25) +
    annotate("text",
             x = (row$left + row$right) / 2,
             y = y + h + 0.015,
             label = lbl,
             size = 3.0,
             vjust = 0,
             parse = TRUE,
             family = "sans")
}

options(repr.plot.width = 10, repr.plot.height = 3.2)
print(plot_A)
# Out:
# plot without title

# %% [markdown]
# ## Panel C: held-out test-prediction scatter, by dataset

# %%
predictions          <- fread(snakemake@input[["holdout_predictions"]])
thresholded_metrics  <- fread(snakemake@input[["holdout_thresholded_metrics"]])

valid_keys <- thresholded_metrics[
  valid_all_folds == TRUE,
  .(dataset, method, cell_type)
]
scatter_data <- merge(predictions, valid_keys, by = c("dataset", "method", "cell_type"))
scatter_data[, panel_label := DATASET_LABELS[dataset]]

plot_statistics <- scatter_data[, {
  fit <- lm(predicted ~ observed)
  fit_summary <- summary(fit)
  t_val <- fit_summary$coefficients["observed", "t value"]
  df_resid <- fit_summary$df[2]
  log10_p <- (log(2) + pt(-abs(t_val), df_resid, log.p = TRUE)) / log(10)
  list(
    pooled_r2 = fit_summary$r.squared,
    log10_p = log10_p
  )
}, by = panel_label]
setorder(plot_statistics, -pooled_r2)
panel_levels <- plot_statistics$panel_label
scatter_data[, panel_label := factor(panel_label, levels = panel_levels)]
plot_statistics[, panel_label := factor(panel_label, levels = panel_levels)]
log10_eps <- log10(2.2e-16)
plot_statistics[, r2_label := sprintf('R^2 == %.2f', pooled_r2)]
plot_statistics[, p_label := fifelse(
  log10_p < log10_eps,
  'italic(p) < 2.2 %*% 10^{-16}',
  sprintf('italic(p) == %.3f', 10^log10_p)
)]

plot_B <- ggplot(scatter_data, aes(x = observed, y = predicted)) +
  geom_abline(slope = 1, intercept = 0, color = "black", linetype = "dashed", linewidth = 0.35) +
  geom_point(aes(color = panel_label), alpha = 0.28, size = 0.22, show.legend = FALSE) +
  geom_text(
    data = plot_statistics,
    aes(x = 0.02, y = 0.98, label = r2_label),
    inherit.aes = FALSE, hjust = 0, vjust = 1, size = 2.2, parse = TRUE
  ) +
  geom_text(
    data = plot_statistics,
    aes(x = 0.02, y = 0.88, label = p_label),
    inherit.aes = FALSE, hjust = 0, vjust = 1, size = 2.2, parse = TRUE
  ) +
  facet_wrap(~panel_label, ncol = 3, scales = "free_x") +
  coord_cartesian(xlim = c(0, 1), ylim = c(0, 1), expand = FALSE) +
  scale_x_continuous(
    breaks = seq(0, 1, 0.25),
    labels = c("0", "0.25", "0.50", "0.75", "1.00")
  ) +
  scale_y_continuous(breaks = seq(0, 1, 0.25),
                     labels = c("0", "0.25", "0.50", "0.75", "1.00")) +
  scale_color_manual(values = DATASET_COLORS) +
  labs(
    x = "True cell proportion in test sample",
    y = "Predicted cell proportion in test sample"
  ) +
  theme_pub() +
  theme(
    aspect.ratio = 1,
    strip.background = element_rect(fill = "grey94", color = "black", linewidth = 0.3),
    panel.spacing.x = grid::unit(1.4, "lines"),
    panel.spacing.y = grid::unit(0.6, "lines")
  )

options(repr.plot.width = 6, repr.plot.height = 8)
print(plot_B)
# Out:
# plot without title

# %% [markdown]
# ## Panel D: marker-recovery dot grid, by dataset

# %%
module_ready <- fread(snakemake@input[["marker"]])
stopifnot(unique(module_ready$marker_source) == "CellMarker + Allen + Azimuth")

GRID_COLORS <- unlist(cfg$GRID_COLORS)
GRID_VALUES <- as.numeric(cfg$GRID_VALUES)

module_blocks <- lapply(split(module_ready, module_ready$dataset), function(d) {
  ds <- d$dataset[1]
  ds_label <- if (ds %in% names(DATASET_LABELS)) DATASET_LABELS[ds] else ds
  d[, marker_row_label := abbreviate_ct(marker_row_label)]
  d[, marker_row_label := wrap_label(marker_row_label, width = 18)]
  d[, lv_col_label     := abbreviate_ct(lv_col_label)]
  d[, lv_col_label     := vapply(strsplit(lv_col_label, " - "), function(p) {
    if (length(p) >= 3) paste(p[1], p[length(p)], sep = " - ") else paste(p, collapse = " - ")
  }, character(1))]
  d[, lv_col_label     := wrap_label(lv_col_label, width = 14)]
  row_levels <- unique(d[order(marker_row_rank), marker_row_label])
  col_levels <- unique(d[order(lv_col_rank), lv_col_label])
  d[, marker_row_label := factor(marker_row_label, levels = row_levels)]
  d[, lv_col_label     := factor(lv_col_label, levels = col_levels)]
  diag_recovered <- d[diag_recovered == TRUE]
  Z_LIM     <- d$Z_LIM[1]
  Q_LIM     <- d$Q_LIM[1]
  n_samples <- d$n_samples[1]

  p <- ggplot(d, aes(x = lv_col_label, y = marker_row_label)) +
    geom_point(aes(size = neg_log10_fdr, color = row_effect)) +
    { if (nrow(diag_recovered) > 0)
        geom_point(data = diag_recovered, aes(size = neg_log10_fdr),
                   shape = 1, color = "black", stroke = 0.8) } +
    scale_size_continuous(limits = c(0, Q_LIM), range = c(0.4, 3.2),
                          name = expression("Combined ORA " * -log[10] ~ "(FDR)")) +
    scale_color_gradientn(colors = GRID_COLORS, values = GRID_VALUES,
                          limits = c(-Z_LIM, Z_LIM), name = "LV effect") +
    coord_fixed() +
    scale_x_discrete(drop = FALSE) +
    scale_y_discrete(drop = FALSE) +
    theme_bw(base_size = 7.5) +
    theme(axis.text.x = element_text(angle = 45, hjust = 1, vjust = 1, size = 6),
          axis.text.y = element_text(size = 6.5),
          plot.title  = element_text(face = "bold", size = 8, hjust = 0.5)) +
    labs(x = NULL, y = NULL, title = paste0(ds_label, " (n = ", n_samples, ")"))

  list(plot = p, n_cat = length(row_levels))
})

module_order  <- order(-vapply(module_blocks, `[[`, "n_cat", FUN.VALUE = numeric(1)))
module_blocks <- module_blocks[module_order]
module_panels <- lapply(module_blocks, `[[`, "plot")
module_n_cat  <- vapply(module_blocks, `[[`, "n_cat", FUN.VALUE = numeric(1))
names(module_n_cat) <- names(module_blocks)
module_widths <- sqrt(module_n_cat)

C_row1_idx <- seq_len(min(3, length(module_widths)))
C_row2_idx <- setdiff(seq_along(module_widths), C_row1_idx)

options(repr.plot.width = 20, repr.plot.height = 4)
print(wrap_plots(module_panels, ncol = 6, guides = "collect", widths = module_widths))
# Out:
# plot without title

# %% [markdown]
# ## Panel E: hard-to-distinguish cell-type dot grid

# %%
hard_ready <- fread(snakemake@input[["hard"]])
stopifnot(unique(hard_ready$marker_source) == "CellMarker + Allen + Azimuth")

group_dot_panels <- lapply(split(hard_ready, hard_ready$group_id), function(d) {
  d[, marker_row_label := abbreviate_ct(marker_row_label)]
  d[, marker_row_label := wrap_label(marker_row_label, width = 14)]
  d[, lv_col_label     := abbreviate_ct(lv_col_label)]
  d[, lv_col_label     := wrap_label(lv_col_label, width = 14)]
  row_levels <- unique(d[order(marker_row_rank), marker_row_label])
  col_levels <- unique(d[order(lv_col_rank), lv_col_label])
  d[, marker_row_label := factor(marker_row_label, levels = row_levels)]
  d[, lv_col_label     := factor(lv_col_label, levels = col_levels)]
  Z_LIM       <- d$Z_LIM[1]
  Q_LIM       <- d$Q_LIM[1]
  panel_title <- abbreviate_ct(d$panel_title[1])

  ggplot(d, aes(x = lv_col_label, y = marker_row_label)) +
    geom_point(aes(size = neg_log10_fdr, color = row_effect)) +
    coord_fixed() +
    scale_size_continuous(limits = c(0, Q_LIM), range = c(0.4, 3.2),
                          name = expression("Combined ORA " * -log[10] ~ "(FDR)")) +
    scale_color_gradientn(colors = GRID_COLORS, values = GRID_VALUES,
                          limits = c(-Z_LIM, Z_LIM), name = "LV effect") +
    theme_bw(base_size = 7.5) +
    theme(axis.text.x = element_text(angle = 45, hjust = 1, size = 6.5),
          axis.text.y = element_text(size = 6.5),
          axis.title  = element_blank(),
          plot.title  = element_text(face = "bold", size = 7, hjust = 0.5,
                                      lineheight = 0.95, margin = margin(b = 2)),
          plot.margin = margin(1, 1, 1, 1)) +
    labs(x = NULL, y = NULL, title = panel_title)
})

options(repr.plot.width = 20, repr.plot.height = 6)
print(wrap_plots(group_dot_panels, ncol = 2, guides = "collect"))
# Out:
# plot without title

# %% [markdown]
# ## Panel F: GTEx subtissue confusion matrices (full CLAMP latent space)

# %%
subtissue_confusion  <- fread(snakemake@input[["subtissue_confusion"]])
subtissue_confusion  <- subtissue_confusion[Analysis == "anatomical" & Representation == "FullLV"]
subtissue_anatomical <- fread(snakemake@input[["subtissue_anatomical"]])

CONFUSION_COLORS <- unlist(cfg$CONFUSION_COLORS)

strip_parens <- function(x) trimws(sub("\\s*\\([^)]*\\)\\s*$", "", x))

build_confusion_tile <- function(tissue_name, compact = FALSE) {
  d <- subtissue_confusion[Tissue == tissue_name]
  order_dt <- unique(d[, .(True_SMTSD, True_Display)])
  lvls     <- order_dt$True_SMTSD
  display  <- setNames(strip_parens(order_dt$True_Display), order_dt$True_SMTSD)

  d[, True_SMTSD      := factor(True_SMTSD, levels = rev(lvls))]
  d[, Predicted_SMTSD := factor(Predicted_SMTSD, levels = lvls)]
  n_classes <- length(lvls)
  d[, show_label := (n_classes <= 3) | (True_SMTSD == Predicted_SMTSD) | (Row_Proportion >= 0.10)]

  res <- subtissue_anatomical[Tissue == tissue_name]
  title      <- strip_parens(res$Tissue_Display)
  title_size <- if (compact) 6 else 7.5
  label_size <- if (compact) 1.7 else 2.0
  axis_size  <- if (compact) 5 else 6

  ggplot(d, aes(x = Predicted_SMTSD, y = True_SMTSD, fill = Row_Proportion)) +
    geom_tile(color = "white", linewidth = 0.4) +
    geom_text(data = d[show_label == TRUE],
              aes(label = sprintf("%.0f%%", Row_Proportion * 100),
                  color = Row_Proportion > 0.5),
              size = label_size, show.legend = FALSE) +
    scale_fill_gradientn(colours = CONFUSION_COLORS, limits = c(0, 1),
                         name = "Fraction of\ntrue subtissue") +
    scale_color_manual(values = c(`TRUE` = "white", `FALSE` = "black")) +
    scale_x_discrete(labels = display) +
    scale_y_discrete(labels = display) +
    coord_fixed() +
    labs(x = NULL, y = NULL, title = title) +
    theme_bw(base_size = 6.5) +
    theme(axis.text.x = element_text(angle = 45, hjust = 1, size = axis_size),
          axis.text.y = element_text(size = axis_size),
          plot.title  = element_text(size = title_size, hjust = 0.5, margin = margin(b = 2)),
          plot.margin = margin(1, 1, 1, 1))
}

CONFUSION_AXIS_TITLE_SIZE <- AXIS_TITLE_SIZE - 2

brain_tile <- build_confusion_tile("Brain") +
  labs(x = "Predicted region", y = "True region") +
  theme(axis.title = element_text(size = CONFUSION_AXIS_TITLE_SIZE))

SMALL_TISSUE_ORDER <- c("Adipose Tissue", "Blood Vessel", "Colon",
                        "Esophagus", "Heart", "Skin")
small_tiles <- lapply(SMALL_TISSUE_ORDER, build_confusion_tile, compact = TRUE)

confusion_legend <- cowplot::get_legend(
  brain_tile +
    theme(legend.position = "right",
          legend.key.size = unit(3, "mm"),
          legend.text  = element_text(size = LEGEND_TEXT_SIZE),
          legend.title = element_text(size = LEGEND_TITLE_SIZE, hjust = 0.5))
)

small_tiles_grid <- wrap_plots(
  lapply(small_tiles, function(p) p + theme(legend.position = "none")),
  ncol = 3
)

shared_x_title <- ggdraw() +
  draw_label("Predicted region", size = CONFUSION_AXIS_TITLE_SIZE, fontface = "plain")
shared_y_title <- ggdraw() +
  draw_label("True region", size = CONFUSION_AXIS_TITLE_SIZE, fontface = "plain", angle = 90)

small_tiles_block <- plot_grid(small_tiles_grid, shared_x_title,
                               ncol = 1, rel_heights = c(1, 0.08))
small_tiles_block <- plot_grid(shared_y_title, small_tiles_block,
                               ncol = 2, rel_widths = c(0.05, 1))

plot_E <- plot_grid(
  brain_tile + theme(legend.position = "none"),
  small_tiles_block,
  confusion_legend,
  ncol = 3, rel_widths = c(1, 1.35, 0.32)
)

options(repr.plot.width = 9, repr.plot.height = 5)
print(plot_E)
# Out:
# plot without title

# %% [markdown]
# ## Panel G: xCell hepatocyte enrichment vs. liver SHAP importance

# %%
liver_xcell <- fread(snakemake@input[["liver_xcell_scatter"]])

CT_COLORS_LIVER <- unlist(cfg$CT_COLORS_LIVER)
CT_LABELS_LIVER <- unlist(cfg$CT_LABELS_LIVER)

ct_test_liver <- cor.test(liver_xcell$shap_pct, liver_xcell$top1pct, method = "pearson")
r_val_liver <- unname(ct_test_liver$estimate)
p_val_liver <- ct_test_liver$p.value
fmt_p_liver <- if (p_val_liver < 0.001) {
  e_str <- formatC(p_val_liver, format = "e", digits = 1)
  parts <- strsplit(e_str, "e")[[1]]
  sprintf("italic(P) == %s %%*%% 10^{%d}", trimws(parts[1]), as.integer(parts[2]))
} else {
  sprintf("italic(P) == %.3f", p_val_liver)
}
r_label_liver <- sprintf('italic(r) == %.3f', r_val_liver)
p_label_liver <- fmt_p_liver

plot_F_xcell <- ggplot(liver_xcell, aes(x = top1pct, y = shap_pct)) +
  geom_smooth(method = "lm", se = FALSE, colour = "grey55",
              linetype = "dashed", linewidth = 0.5) +
  geom_point(aes(fill = dominant_ct), size = 1.7, shape = 21,
             colour = "grey25", stroke = 0.3) +
  ggrepel::geom_text_repel(
    aes(label = LV), size = 2.2, max.overlaps = 20,
    segment.size = 0.25, segment.color = "grey60"
  ) +
  geom_text(
    data = data.table(x = -Inf, y = Inf, label = r_label_liver),
    aes(x = x, y = y, label = label), inherit.aes = FALSE,
    hjust = -0.1, vjust = 1.3, size = 2.2, parse = TRUE
  ) +
  geom_text(
    data = data.table(x = -Inf, y = Inf, label = p_label_liver),
    aes(x = x, y = y, label = label), inherit.aes = FALSE,
    hjust = -0.1, vjust = 2.45, size = 2.2, parse = TRUE
  ) +
  scale_fill_manual(values = CT_COLORS_LIVER, labels = CT_LABELS_LIVER,
                    name = "Dominant\ncell type") +
  labs(x = "Mean hepatocyte xCell score in top-1% GTEx samples",
       y = "Individual SHAP importance (%)") +
  coord_fixed(ratio = diff(range(liver_xcell$top1pct)) / diff(range(liver_xcell$shap_pct))) +
  theme_pub() +
  theme(legend.position = "right",
        axis.title   = element_text(size = AXIS_TITLE_SIZE),
        axis.text    = element_text(size = AXIS_LABEL_SIZE),
        legend.text  = element_text(size = LEGEND_TEXT_SIZE),
        legend.title = element_text(size = LEGEND_TITLE_SIZE))

liver_lv_pathways <- fread(snakemake@input[["liver_lv_pathways"]])
PATHWAY_LVS <- c("LV21", "LV471")
pathway_sel <- liver_lv_pathways[LV %in% PATHWAY_LVS]
pathway_sel <- pathway_sel[order(-AUC), head(.SD, 3), by = LV]
pathway_sel[, LV := factor(LV, levels = PATHWAY_LVS)]

setorder(pathway_sel, LV, AUC)
pathway_sel[, row_key := factor(paste0(pathway_clean, "___", LV),
                                levels = unique(paste0(pathway_clean, "___", LV)))]
strip_lv_suffix <- function(x) sub("___LV[0-9]+$", "", x)

GREEN_PATHWAY <- unlist(cfg$GREEN_PATHWAY)

plot_F_pathways <- ggplot(pathway_sel, aes(x = AUC, y = row_key)) +
  geom_segment(aes(x = 0.45, xend = AUC, yend = row_key),
               color = "#cccccc", linewidth = 0.4, linetype = "dotted") +
  geom_point(aes(color = neg_log_fdr, size = AUC)) +
  scale_color_gradientn(colors = GREEN_PATHWAY, limits = c(0, 3),
                        name = expression("-" * log[10] ~ "FDR")) +
  scale_size_continuous(range = c(1, 3), guide = "none") +
  scale_x_continuous(limits = c(0.45, 1.0), breaks = seq(0.5, 1.0, 0.25)) +
  scale_y_discrete(labels = strip_lv_suffix) +
  facet_wrap(~LV, ncol = 1, scales = "free_y") +
  labs(x = "AUC", y = "GO:BP") +
  theme_pub() +
  theme(legend.position = "right",
        strip.background   = element_rect(fill = "grey94", color = "black", linewidth = 0.3),
        strip.text         = element_text(size = PLOT_TITLE_SIZE, face = "bold"),
        panel.grid.major.y = element_blank(),
        axis.text.y        = element_text(size = AXIS_LABEL_SIZE),
        axis.title         = element_text(size = AXIS_TITLE_SIZE),
        legend.text        = element_text(size = LEGEND_TEXT_SIZE),
        legend.title       = element_text(size = LEGEND_TITLE_SIZE))

plot_F_xcell_centered <- plot_grid(NULL, plot_F_xcell, NULL,
                                   nrow = 1, rel_widths = c(0.12, 1, 0.12))
plot_F <- plot_grid(plot_F_xcell_centered, plot_F_pathways,
                    ncol = 1, rel_heights = c(1, 0.6))

options(repr.plot.width = 4, repr.plot.height = 5)
print(plot_F)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
FIG_W <- 180
FIG_H <- 170
stopifnot(FIG_W == 180, FIG_H == 170)

FS_TAG <- 9
FS_TITLE <- 6.5
FS_AXIS_TITLE <- 6.5
FS_AXIS_TEXT <- 5
FS_LEGEND <- 5
FS_LEGEND_TITLE <- 5.5
MIN_FONT_PT <- 5
MIN_GEOM_TEXT <- MIN_FONT_PT / .pt
DIVERGING_COLORS <- unlist(cfg$DIVERGING_COLORS)
DIVERGING_VALUES <- as.numeric(cfg$DIVERGING_VALUES)

theme_nm <- function(base_size = FS_AXIS_TEXT, base_line_size = 0.25) {
  theme_classic(base_size = base_size, base_family = "Helvetica") %+replace%
    theme(
      plot.title = element_text(size = FS_TITLE, face = "bold", hjust = 0.5,
                                margin = margin(b = 1.2)),
      axis.line = element_line(linewidth = base_line_size, colour = "black"),
      axis.ticks = element_line(linewidth = base_line_size, colour = "black"),
      axis.ticks.length = unit(1.1, "mm"),
      axis.text = element_text(size = FS_AXIS_TEXT, colour = "black"),
      axis.title = element_text(size = FS_AXIS_TITLE, face = "plain", colour = "black"),
      legend.text = element_text(size = FS_LEGEND),
      legend.title = element_text(size = FS_LEGEND_TITLE, face = "plain"),
      legend.key = element_blank(),
      legend.background = element_blank(),
      strip.background = element_blank(),
      strip.text = element_text(size = FS_TITLE, face = "bold", margin = margin(b = 0.7)),
      panel.grid = element_blank(),
      plot.margin = margin(1.3, 1.3, 1.3, 1.3)
    )
}

compact_ct <- function(x) {
  x <- abbreviate_ct(x)
  x <- gsub("Endothelial cells", "Endothelial", x, ignore.case = TRUE)
  x <- gsub("LymphaticEndothelial", "Lymphatic endothelial", x, fixed = TRUE)
  x <- gsub("Alveolar epithelium", "Alveolar epi.", x, ignore.case = TRUE)
  x <- gsub("Airway epithelium", "Airway epi.", x, ignore.case = TRUE)
  x <- gsub("Submucosal Gland", "Submucosal gland", x, ignore.case = TRUE)
  x <- gsub("Cardiomyocyte", "CM", x, ignore.case = TRUE)
  x
}

compact_axis_ct <- function(x) {
  x <- compact_ct(x)
  x <- gsub("Human ", "", x, fixed = TRUE)
  x <- gsub("Astrocyte", "Astro.", x, ignore.case = TRUE)
  x <- gsub("Microglial cell", "Microglia", x, ignore.case = TRUE)
  x <- gsub("Oligodendrocytes", "Oligodend.", x, ignore.case = TRUE)
  x <- gsub("Inhibitory neuron", "Inhibitory", x, ignore.case = TRUE)
  x <- gsub("Excitatory neuron", "Excitatory", x, ignore.case = TRUE)
  x <- gsub("Lymphatic endothelial", "Lymphatic EC", x, ignore.case = TRUE)
  x <- gsub("Endothelial cell", "Endothelial", x, ignore.case = TRUE)
  x <- gsub("Cardiomyocyte", "CM", x, ignore.case = TRUE)
  x <- gsub("Monocyte", "Mono.", x, ignore.case = TRUE)
  x <- gsub("Natural killer", "NK", x, ignore.case = TRUE)
  x <- gsub("Mesothelial cell", "Mesothelial", x, ignore.case = TRUE)
  trimws(x)
}

compact_lv_label <- function(x) {
  vapply(strsplit(x, " - ", fixed = TRUE), function(parts) {
    lv <- tail(parts, 1)
    lv <- if (grepl("LV[0-9]+", lv)) sub(".*(LV[0-9]+).*", "\\1", lv) else lv
    ct <- compact_axis_ct(parts[1])
    if (length(parts) == 1 || identical(ct, lv)) lv else paste(ct, lv, sep = "\n")
  }, character(1), USE.NAMES = FALSE)
}

compact_lv_label_vertical <- function(x) {
  vapply(strsplit(x, " - ", fixed = TRUE), function(parts) {
    lv <- tail(parts, 1)
    lv <- if (grepl("LV[0-9]+", lv)) sub(".*(LV[0-9]+).*", "\\1", lv) else lv
    gene_set <- if (length(parts) >= 3) parts[length(parts) - 1] else parts[1]
    gene_set <- compact_axis_ct(gene_set)
    gene_set <- gsub("^Astro.*L1.*$", "Astro. L1", gene_set)
    gene_set <- gsub("^Micro.*L1-6.*$", "Microglia L1-6", gene_set)
    gene_set <- gsub("Central memory CD4\\+ T cell", "Central mem. CD4", gene_set)
    gene_set <- gsub("Memory CD8\\+ T cell", "Memory CD8", gene_set)
    gene_set <- gsub("Type 3 dendritic cell \\(DC3\\)", "DC3", gene_set)
    gene_set <- gsub("Cytotoxic CD4\\+ T cell", "Cytotoxic CD4", gene_set)
    gene_set <- gsub("Natural killer T ?\\(NKT\\) cell", "NKT cell", gene_set)
    gene_set <- gsub("Natural killer cell", "NK cell", gene_set)
    gene_set <- gsub("GABAergic neuron", "GABAergic", gene_set)
    gene_set <- gsub("Cardiac progenitor cell", "Cardiac prog.", gene_set)
    gene_set <- gsub("Ciliated epithelial cell", "Ciliated epi.", gene_set)
    gene_set <- gsub("Gonadal endothelial", "Gonadal EC", gene_set)
    gene_set <- gsub("Pan-endothelial", "Pan-EC", gene_set)
    gene_set <- gsub("Type II pneumocyte", "Type II pneumo.", gene_set)
    gene_set <- gsub("Leydig precursor cell", "Leydig prec.", gene_set)
    if (identical(gene_set, lv)) lv else paste(gene_set, lv)
  }, character(1), USE.NAMES = FALSE)
}

lv_only_label <- function(x) {
  ifelse(grepl("LV[0-9]+", x), sub(".*(LV[0-9]+).*", "\\1", x),
         compact_lv_label(x))
}

compact_hard_title <- function(x) {
  x <- gsub("_", " ", x, fixed = TRUE)
  x <- gsub("B cells vs\\. T cells", "B vs. T cells", x)
  x <- gsub("CD4\\+ T cells vs\\. CD8\\+ T\n?cells", "CD4+ vs. CD8+ T", x)
  x <- gsub("Oligodendrocyte\nPrecursor Cells vs\\.\nOligodendrocytes",
            "OPC vs. oligodendrocytes", x)
  x <- gsub("Astrocytes vs\\. Microglia", "Astrocytes vs.\nmicroglia", x)
  x <- gsub("Inhibitory neurons vs\\.\nExcitatory neurons",
            "Inhibitory vs. excitatory", x)
  x <- gsub("AtrialCM vs\\.\nVentricularCM", "Atrial vs.\nventricular CM", x)
  x
}

compact_region <- function(x) {
  x <- gsub("Cervical spinal cord", "Cervical cord", x, ignore.case = TRUE)
  x <- gsub("Gastroesophageal junction", "GE junction", x, ignore.case = TRUE)
  x <- gsub("Substantia nigra", "Substantia nigra", x, ignore.case = TRUE)
  x <- gsub("Nucleus accumbens", "N. accumbens", x, ignore.case = TRUE)
  x <- gsub("Cerebellar hemisphere", "Cerebellar hemi.", x, ignore.case = TRUE)
  x <- gsub("Subcutaneous", "Subcut.", x, ignore.case = TRUE)
  x <- gsub("Visceral", "Visc.", x, ignore.case = TRUE)
  x <- gsub("Coronary", "Coron.", x, ignore.case = TRUE)
  x <- gsub("Transverse", "Transv.", x, ignore.case = TRUE)
  x <- gsub("Muscularis", "Muscul.", x, ignore.case = TRUE)
  x <- gsub("Left ventricle", "Left ventr.", x, ignore.case = TRUE)
  x <- gsub("Atrial appendage", "Atrial app.", x, ignore.case = TRUE)
  x
}

add_tag <- function(p, label, x = 0.002, y = 0.998) {
  ggdraw() +
    draw_plot(p, x = 0, y = 0, width = 1, height = 1) +
    draw_label(label, x = x, y = y, hjust = 0, vjust = 1,
               size = FS_TAG, fontface = "bold", fontfamily = "Helvetica")
}

# Four biologically difficult pairs retained in the main figure.
PAIR_GROUPS <- c(1, 2, 4, 6)
PAIR_LEGEND_ORDER <- c(
  "B cell", "T cell", "CD4+ T cell", "CD8+ T cell",
  "Astrocyte", "Microglia", "Atrial CM", "Ventricular CM",
  "Shared marker"
)
PAIR_SET_COLORS <- c(
  "B cell" = "#0072B2",
  "T cell" = "#D55E00",
  "CD4+ T cell" = "#009E73",
  "CD8+ T cell" = "#CC79A7",
  "Astrocyte" = "#56B4E9",
  "Microglia" = "#E69F00",
  "Atrial CM" = "#6A3D9A",
  "Ventricular CM" = "#B15928",
  "Shared marker" = "#555555"
)
PAIR_DISPLAY_TITLES <- c(
  "1" = "B vs. T cells",
  "2" = "CD4+ vs. CD8+ T cells",
  "4" = "Astrocyte vs. microglia",
  "6" = "Atrial vs. ventricular CM"
)
PAIR_DISPLAY_TITLES_SMALL <- c(
  "1" = "B vs.\nT cells",
  "2" = "CD4+ vs.\nCD8+ T cells",
  "4" = "Astrocyte vs.\nmicroglia",
  "6" = "Atrial vs.\nventricular CM"
)

canonical_pair_set <- function(x) {
  x <- gsub("_", " ", as.character(x), fixed = TRUE)
  x <- trimws(x)
  x <- sub("^B( cells?)?$", "B cell", x)
  x <- sub("^T( cells?)?$", "T cell", x)
  x <- sub("^CD4\\+?( T)?( cells?)?$", "CD4+ T cell", x)
  x <- sub("^CD8\\+?( T)?( cells?)?$", "CD8+ T cell", x)
  x <- sub("^(Ast|Astro\\.?s?|Astrocytes?)$", "Astrocyte", x)
  x <- sub("^(Mic|Microglia)$", "Microglia", x)
  x <- sub("^Atrial ?CM$", "Atrial CM", x)
  x <- sub("^Ventricular ?CM$", "Ventricular CM", x)
  x
}
related_corr_pub <- fread(snakemake@input[["related_corr"]])

pair_axis_label <- function(x) {
  x <- compact_axis_ct(x)
  x <- sub(" cells$", "", x)
  x <- sub("^VentricularCM$", "Ventric. CM", x)
  x <- sub("^AtrialCM$", "Atrial CM", x)
  x
}

pair_y_axis_label <- function(x) {
  x <- pair_axis_label(x)
  x[x == "B"] <- "B cell"
  x[x == "T"] <- "T cell"
  x
}

make_pair_pub <- function(gid) {
  d <- copy(related_corr_pub[group_id == gid])
  members <- unique(d$assigned_cell_type)
  member_lv <- d$LV[match(members, d$assigned_cell_type)]
  d <- d[cell_type %in% members]
  axis_lab <- pair_axis_label(members)
  row_levels <- pair_y_axis_label(members)
  col_levels <- paste0(axis_lab, "\n", member_lv)
  d[, row_label := factor(pair_y_axis_label(cell_type), levels = row_levels)]
  d[, col_label := factor(paste0(pair_axis_label(assigned_cell_type), "\n", LV),
                          levels = col_levels)]
  title_lab <- PAIR_DISPLAY_TITLES_SMALL[[as.character(gid)]]

  ggplot(d, aes(col_label, row_label, fill = cor)) +
    geom_tile(colour = "white", linewidth = 0.25) +
    scale_fill_gradientn(colours = DIVERGING_COLORS, values = DIVERGING_VALUES,
                         limits = c(-1, 1), name = "Pearson r") +
    scale_colour_manual(values = setNames(c("white", "black"), c("TRUE", "FALSE")),
                        guide = "none") +
    scale_x_discrete(expand = c(0, 0)) +
    scale_y_discrete(expand = c(0, 0)) +
    coord_fixed() +
    labs(x = NULL, y = NULL, title = title_lab) +
    theme_nm() +
    theme(axis.line = element_blank(), axis.ticks = element_blank(),
          axis.text.x = element_text(size = MIN_FONT_PT, lineheight = 0.9),
          axis.text.y = element_text(size = MIN_FONT_PT, margin = margin(r = 0.5)),
          plot.title = element_text(size = 5.4, face = "bold", hjust = 0.5,
                                    lineheight = 0.9, margin = margin(b = 0.5)),
          plot.margin = margin(0.5, 0.6, 0.5, 0.6))
}

pair_pub_panels <- lapply(PAIR_GROUPS, make_pair_pub)
pair_corr_legend <- get_legend(
  pair_pub_panels[[1]] +
    guides(fill = guide_colourbar(title.position = "top", title.hjust = 0.5,
                                  barwidth = unit(13, "mm"),
                                  barheight = unit(1.4, "mm"))) +
    theme(legend.position = "bottom", legend.direction = "horizontal",
          legend.title = element_text(size = 5),
          legend.text = element_text(size = MIN_FONT_PT),
          legend.margin = margin(0, 0, 0, 0))
)
pair_pub_body <- wrap_plots(lapply(pair_pub_panels, function(p)
  p + theme(legend.position = "none")), ncol = 2)
plot_D_pair_pub <- ggdraw() +
  draw_plot(pair_pub_body, x = 0, y = 0.24, width = 1, height = 0.76) +
  draw_grob(pair_corr_legend, x = 0.18, y = 0.19,
            width = 0.64, height = 0.10)

y_base_pub <- 1.055
y_step_pub <- 0.115
h_pub <- 0.014
y_max_pub <- y_base_pub + (max(comp_ord$tier) - 1) * y_step_pub + 0.105

plot_A_pub <- ggplot(long_box, aes(method, cor, fill = method)) +
  geom_boxplot(width = 0.52, outlier.shape = NA, color = "black",
               linewidth = 0.22, alpha = 0.85) +
  geom_jitter(width = 0.09, size = 0.24, shape = 21, fill = "white",
              color = "#333333", stroke = 0.1, alpha = 0.65) +
  geom_point(data = mean_df, aes(x = method, y = mean_cor), shape = 23,
             size = 1.05, fill = "white", color = "black", stroke = 0.28,
             inherit.aes = FALSE) +
  geom_text(data = mean_df,
            aes(x = method, y = max_cor + 0.035, label = sprintf("%.2f", mean_cor)),
            size = MIN_GEOM_TEXT, fontface = "bold", family = "Helvetica",
            inherit.aes = FALSE) +
  scale_fill_manual(values = METHOD_COLORS, na.value = "grey70") +
  scale_y_continuous(breaks = seq(0, 1, 0.25),
                     labels = c("0", "0.25", "0.50", "0.75", "1.00"),
                     expand = expansion(mult = c(0.01, 0.01))) +
  coord_cartesian(ylim = c(0, y_max_pub), clip = "on") +
  labs(x = NULL, y = "Max Pearson r") +
  theme_nm() +
  theme(legend.position = "none",
        axis.text.x = element_text(angle = 45, hjust = 1, vjust = 1, size = MIN_FONT_PT),
        axis.title.y = element_text(size = 5.7),
        plot.margin = margin(4.5, 0.8, 0.6, 2.5))

for (i in seq_len(nrow(comp_ord))) {
  stat_row <- comp_ord[i]
  y <- y_base_pub + (stat_row$tier - 1) * y_step_pub
  if (setequal(c(stat_row$a, stat_row$b), c("CLAMPfull", "CLAMPbase"))) y <- y + 0.012
  plot_A_pub <- plot_A_pub +
    annotate("segment", x = stat_row$left, xend = stat_row$left,
             y = y, yend = y + h_pub, linewidth = 0.22) +
    annotate("segment", x = stat_row$left, xend = stat_row$right,
             y = y + h_pub, yend = y + h_pub, linewidth = 0.22) +
    annotate("segment", x = stat_row$right, xend = stat_row$right,
             y = y, yend = y + h_pub, linewidth = 0.22) +
    annotate("text", x = (stat_row$left + stat_row$right) / 2,
             y = y + h_pub + 0.01, label = fmt_q(stat_row$q),
             size = MIN_GEOM_TEXT, vjust = 0, parse = TRUE, family = "Helvetica")
}

plot_C_pub <- ggplot(scatter_data, aes(x = observed, y = predicted)) +
  geom_abline(slope = 1, intercept = 0, color = "grey25",
              linetype = "dashed", linewidth = 0.25) +
  geom_point(aes(color = panel_label), alpha = 0.28, size = 0.16,
             show.legend = FALSE) +
  geom_text(data = plot_statistics, aes(x = 0.025, y = 0.975, label = r2_label),
            inherit.aes = FALSE, hjust = 0, vjust = 1, size = MIN_GEOM_TEXT, parse = TRUE) +
  facet_wrap(~panel_label, ncol = 3) +
  coord_cartesian(xlim = c(0, 1), ylim = c(0, 1), expand = FALSE) +
  scale_x_continuous(breaks = seq(0, 1, 0.25),
                     labels = c("0", "0.25", "0.50", "0.75", "1.00")) +
  scale_y_continuous(breaks = seq(0, 1, 0.25),
                     labels = c("0", "0.25", "0.50", "0.75", "1.00")) +
  scale_color_manual(values = DATASET_COLORS) +
  labs(x = "True cell proportion", y = "Predicted cell proportion") +
  theme_nm() +
  theme(aspect.ratio = 1,
        axis.text = element_text(size = MIN_FONT_PT),
        axis.title = element_text(size = 6),
        panel.spacing.x = unit(2.0, "mm"),
        panel.spacing.y = unit(1.7, "mm"),
        strip.text = element_text(size = 5.2, face = "bold", margin = margin(b = 0.5)),
        plot.margin = margin(3.4, 1.2, 0.8, 1.3))

build_module_pub <- function(d) {
  ds <- d$dataset[1]
  ds_label <- if (ds %in% names(DATASET_LABELS)) DATASET_LABELS[ds] else ds
  d[, marker_row_label := compact_axis_ct(marker_row_label)]
  d[, lv_col_label := compact_lv_label_vertical(lv_col_label)]
  row_levels <- unique(d[order(marker_row_rank), marker_row_label])
  col_levels <- unique(d[order(lv_col_rank), lv_col_label])
  d[, marker_row_label := factor(marker_row_label, levels = row_levels)]
  d[, lv_col_label := factor(lv_col_label, levels = col_levels)]
  diagonal <- d[diag_recovered == TRUE]
  z_lim <- d$Z_LIM[1]
  q_lim <- d$Q_LIM[1]
  n_samples <- d$n_samples[1]

  p <- ggplot(d, aes(lv_col_label, marker_row_label)) +
    geom_point(aes(size = neg_log10_fdr, color = row_effect)) +
    {if (nrow(diagonal)) geom_point(data = diagonal, aes(size = neg_log10_fdr),
                                    shape = 1, color = "black", stroke = 0.55)} +
    scale_size_continuous(limits = c(0, q_lim), range = c(0.25, 2.15),
                          name = expression("Combined ORA " * -log[10] ~ "(FDR)")) +
    scale_color_gradientn(colors = GRID_COLORS, values = GRID_VALUES,
                          limits = c(-z_lim, z_lim), name = "LV effect") +
    scale_x_discrete(drop = FALSE) +
    scale_y_discrete(drop = FALSE) +
    coord_fixed() +
    labs(x = NULL, y = NULL, title = paste0(ds_label, " (n = ", n_samples, ")")) +
    theme_nm() +
    theme(panel.grid.major = element_line(color = "grey90", linewidth = 0.18),
          axis.line = element_blank(), axis.ticks = element_blank(),
          axis.text.x = element_text(angle = 45, hjust = 1, vjust = 1,
                                     size = MIN_FONT_PT, lineheight = 0.88),
          axis.text.y = element_text(size = MIN_FONT_PT),
          plot.title = element_text(size = 5.7, face = "bold", hjust = 0.5,
                                    margin = margin(b = 0.5)),
          plot.margin = margin(0.5, 0.7, 0.5, 0.7))
  list(plot = p, n_cat = length(row_levels))
}

module_pub_blocks <- lapply(split(copy(module_ready), module_ready$dataset), build_module_pub)
module_pub_order <- order(-vapply(module_pub_blocks, `[[`, "n_cat", FUN.VALUE = numeric(1)))
module_pub_blocks <- module_pub_blocks[module_pub_order]
module_pub_panels <- lapply(module_pub_blocks, `[[`, "plot")
module_pub_widths <- sqrt(vapply(module_pub_blocks, `[[`, "n_cat", FUN.VALUE = numeric(1)))

top_idx <- 1:3
bottom_idx <- 4:6
top_sum <- sum(module_pub_widths[top_idx])
bottom_sum <- sum(module_pub_widths[bottom_idx])
legend_pad <- max(0.8, top_sum - bottom_sum)

module_legend <- get_legend(
  module_pub_panels[[1]] +
    guides(color = guide_colorbar(order = 1, title.position = "top",
                                  barwidth = unit(16, "mm"),
                                  barheight = unit(1.5, "mm")),
           size = guide_legend(order = 2, title.position = "top", nrow = 1)) +
    theme(legend.position = "bottom", legend.direction = "horizontal",
          legend.box = "vertical", legend.box.just = "center",
          legend.spacing.y = unit(0.5, "mm"),
          legend.box.margin = margin(0, 0, 0, 0),
          legend.key.width = unit(2.1, "mm"), legend.key.height = unit(1.8, "mm"),
          legend.text = element_text(size = MIN_FONT_PT),
          legend.title = element_text(size = 5))
)

C_top <- plot_grid(plotlist = lapply(module_pub_panels[top_idx],
                                     function(p) p + theme(legend.position = "none")),
                   nrow = 1, rel_widths = module_pub_widths[top_idx])
C_bottom <- plot_grid(
  plotlist = c(lapply(module_pub_panels[bottom_idx],
                      function(p) p + theme(legend.position = "none")),
               list(ggdraw() + draw_grob(module_legend, x = 0.08, y = 0.02,
                                         width = 0.84, height = 0.96))),
  nrow = 1, rel_widths = c(module_pub_widths[bottom_idx], legend_pad)
)
C_main <- plot_grid(C_top, C_bottom, ncol = 1,
                    rel_heights = c(max(module_pub_widths[top_idx]),
                                    max(module_pub_widths[bottom_idx])))

HARD_EFFECT_LIM <- ceiling(
  max(abs(hard_ready[group_id %in% PAIR_GROUPS, row_effect])) * 10
) / 10

build_hard_pub <- function(d) {
  d[, marker_row_label := compact_axis_ct(marker_row_label)]
  d[, lv_col_label := gsub("\n", " ", compact_lv_label(lv_col_label),
                            fixed = TRUE)]
  d[, lv_col_label := sub(".*(LV[0-9]+).*", "\\1", lv_col_label)]
  row_levels <- unique(d[order(marker_row_rank), marker_row_label])
  col_levels <- unique(d[order(lv_col_rank), lv_col_label])
  d[, marker_row_label := factor(marker_row_label, levels = row_levels)]
  d[, lv_col_label := factor(lv_col_label, levels = col_levels)]
  z_lim <- HARD_EFFECT_LIM
  q_lim <- d$Q_LIM[1]
  ggplot(d, aes(lv_col_label, marker_row_label)) +
    geom_point(aes(size = neg_log10_fdr, fill = row_effect),
               shape = 21, colour = "grey30", stroke = 0.35) +
    scale_size_continuous(limits = c(0, q_lim), range = c(0.35, 1.9),
                          name = expression("Azimuth ORA " * -log[10](FDR)),
                          breaks = c(20, 40, 60)) +
    scale_fill_gradientn(colors = GRID_COLORS, values = GRID_VALUES,
                         limits = c(-z_lim, z_lim),
                         breaks = seq(-z_lim, z_lim, length.out = 5),
                         name = "LV effect") +
    coord_fixed() +
    labs(x = NULL, y = NULL,
         title = PAIR_DISPLAY_TITLES_SMALL[[as.character(d$group_id[1])]]) +
    theme_nm() +
    theme(panel.grid.major = element_line(color = "grey90", linewidth = 0.18),
          axis.line = element_blank(), axis.ticks = element_blank(),
          axis.text.x = element_text(angle = 45, hjust = 1, size = MIN_FONT_PT,
                                     lineheight = 0.88),
          axis.text.y = element_text(size = MIN_FONT_PT),
          plot.title = element_text(size = 5.1, face = "bold", hjust = 0.5,
                                    lineheight = 0.9, margin = margin(b = 0.4)),
          plot.margin = margin(0.4, 0.5, 0.4, 0.5))
}

hard_pub_selected <- copy(hard_ready[group_id %in% PAIR_GROUPS])
hard_pub_panels <- lapply(PAIR_GROUPS, function(gid)
  build_hard_pub(copy(hard_pub_selected[group_id == gid])))
plot_D_pub <- C_main
hard_pub_legend <- get_legend(
  hard_pub_panels[[1]] +
    guides(fill = guide_colourbar(order = 1, title.position = "top",
                                  title.hjust = 0.5,
                                  barwidth = unit(13, "mm"),
                                  barheight = unit(1.4, "mm")),
           size = guide_legend(order = 2, title.position = "top",
                               title.hjust = 0.5, nrow = 1,
                               override.aes = list(fill = "grey55",
                                                   colour = "grey20"))) +
    theme(legend.position = "bottom", legend.box = "vertical",
          legend.box.just = "center", legend.spacing.y = unit(0.2, "mm"),
          legend.title = element_text(size = 5),
          legend.text = element_text(size = MIN_FONT_PT),
          legend.key.width = unit(2.8, "mm"),
          legend.key.height = unit(1.8, "mm"),
          legend.margin = margin(0, 0, 0, 0))
)
hard_pub_body <- wrap_plots(lapply(hard_pub_panels, function(p)
  p + theme(legend.position = "none")), ncol = 2)
plot_E_pub <- ggdraw() +
  draw_plot(hard_pub_body, x = 0, y = 0.24, width = 1, height = 0.76) +
  draw_grob(hard_pub_legend, x = 0.12, y = 0.13,
            width = 0.76, height = 0.16)

build_confusion_pub <- function(tissue_name, compact = FALSE) {
  d <- copy(subtissue_confusion[Tissue == tissue_name])
  order_dt <- unique(d[, .(True_SMTSD, True_Display)])
  lvls <- order_dt$True_SMTSD
  display <- setNames(compact_region(strip_parens(order_dt$True_Display)),
                      order_dt$True_SMTSD)
  d[, True_SMTSD := factor(True_SMTSD, levels = rev(lvls))]
  d[, Predicted_SMTSD := factor(Predicted_SMTSD, levels = lvls)]
  n_classes <- length(lvls)
  d[, show_label := (n_classes <= 3) | (True_SMTSD == Predicted_SMTSD) |
                      (Row_Proportion >= 0.10)]
  title <- strip_parens(subtissue_anatomical[Tissue == tissue_name]$Tissue_Display)

  ggplot(d, aes(Predicted_SMTSD, True_SMTSD, fill = Row_Proportion)) +
    geom_tile(color = "white", linewidth = 0.25) +
    scale_fill_gradientn(colours = CONFUSION_COLORS, limits = c(0, 1),
                         name = "True\nfraction") +
    scale_color_manual(values = c(`TRUE` = "white", `FALSE` = "black")) +
    scale_x_discrete(labels = display, expand = expansion(add = 0)) +
    scale_y_discrete(labels = display, expand = expansion(add = 0)) +
    coord_fixed() +
    labs(x = NULL, y = NULL, title = title) +
    theme_nm() +
    theme(panel.border = element_rect(fill = NA, color = "grey25", linewidth = 0.22),
          axis.line = element_blank(), axis.ticks = element_blank(),
          axis.text.x = element_text(angle = 45, hjust = 1,
                                     size = MIN_FONT_PT,
                                     margin = margin(t = if (compact) -1 else 0)),
          axis.text.y = element_text(size = MIN_FONT_PT,
                                     margin = margin(r = if (compact) -1 else 0)),
          plot.title = element_text(size = if (compact) 5.1 else 5.8,
                                    face = "plain", hjust = 0.5,
                                    margin = margin(b = 0.5)),
          plot.margin = if (compact) margin(0.2, 0.2, 0.2, 0.2)
                        else margin(0.5, 0.5, 0.5, 0.5))
}

brain_pub <- build_confusion_pub("Brain") +
  labs(x = "Predicted region", y = "True region") +
  theme(axis.title = element_text(size = 5.8))
small_pub <- lapply(SMALL_TISSUE_ORDER, build_confusion_pub, compact = TRUE)
confusion_legend_pub <- get_legend(
  brain_pub +
    guides(fill = guide_colorbar(title.position = "top",
                                 barheight = unit(14, "mm"),
                                 barwidth = unit(1.8, "mm"))) +
    theme(legend.position = "right", legend.text = element_text(size = MIN_FONT_PT),
          legend.title = element_text(size = 5, hjust = 0.5),
          legend.key.height = unit(2.3, "mm"))
)
small_grid_pub <- wrap_plots(lapply(small_pub, function(p) p + theme(legend.position = "none")),
                             ncol = 2)
small_x_pub <- ggdraw() + draw_label("Predicted region", size = 5.8,
                                     fontfamily = "Helvetica")
small_block_inner_pub <- plot_grid(small_grid_pub, small_x_pub,
                             ncol = 1, rel_heights = c(1, 0.07))
small_block_pub <- ggdraw() +
  draw_plot(small_block_inner_pub, x = 0.052, y = 0, width = 0.948, height = 1) +
  draw_label("True region", x = 0.17, y = 0.53, size = 5.8, angle = 90,
             fontfamily = "Helvetica")
plot_F_pub <- plot_grid(brain_pub + theme(legend.position = "none"),
                        small_block_pub, confusion_legend_pub,
                        nrow = 1, rel_widths = c(1.0, 1.42, 0.17))

liver_label_data <- copy(liver_xcell)[order(-shap_pct)][seq_len(min(9, .N))]

plot_E_scatter <- ggplot(liver_xcell, aes(top1pct, shap_pct)) +
  geom_smooth(method = "lm", se = FALSE, colour = "grey55",
              linetype = "dashed", linewidth = 0.35) +
  geom_point(aes(fill = dominant_ct), size = 1.0, shape = 21,
             colour = "grey25", stroke = 0.2) +
  ggrepel::geom_text_repel(data = liver_label_data, aes(label = LV),
                           size = MIN_GEOM_TEXT, max.overlaps = Inf,
                           min.segment.length = 0, segment.size = 0.18,
                           segment.color = "grey65", box.padding = 0.15) +
  annotate("text", x = -Inf, y = Inf, label = r_label_liver,
           hjust = -0.05, vjust = 1.2, size = MIN_GEOM_TEXT, parse = TRUE) +
  annotate("text", x = -Inf, y = Inf, label = p_label_liver,
           hjust = -0.05, vjust = 2.4, size = MIN_GEOM_TEXT, parse = TRUE) +
  scale_fill_manual(values = CT_COLORS_LIVER, labels = CT_LABELS_LIVER,
                    name = "Dominant\ncell type") +
  labs(x = "Mean hepatocyte xCell score in top-1% GTEx samples",
       y = "Individual SHAP importance (%)") +
  theme_nm() +
  guides(fill = guide_legend(ncol = 1, byrow = TRUE, title.position = "top",
                             title.hjust = 0.5,
                             override.aes = list(size = 1.8))) +
  theme(axis.text = element_text(size = MIN_FONT_PT),
        axis.title = element_text(size = 5.8),
        legend.position = "right", legend.direction = "vertical",
        legend.text = element_text(size = MIN_FONT_PT),
        legend.title = element_text(size = MIN_FONT_PT, hjust = 0.5),
        legend.key.width = unit(2.4, "mm"),
        legend.key.height = unit(2.0, "mm"),
        legend.spacing.x = unit(0.5, "mm"),
        plot.margin = margin(1, 0.3, 0.5, 1.5))

scatter_legend_pub <- get_legend(plot_E_scatter)
plot_F_scatter <- plot_grid(
  plot_E_scatter + theme(legend.position = "none"),
  scatter_legend_pub,
  nrow = 1, rel_widths = c(1, 0.29)
)

pathway_pub <- copy(pathway_sel)
pathway_pub[, pathway_display := pathway_clean]
pathway_pub[grepl("acyl-CoA Oxidase", pathway_display, ignore.case = TRUE),
            pathway_display := "FA beta-oxidation (acyl-CoA oxidase)"]
pathway_pub[grepl("acyl-CoA Dehydrog", pathway_display, ignore.case = TRUE),
            pathway_display := "FA beta-oxidation (acyl-CoA dehydrog.)"]
pathway_pub[, pathway_display := shorten_label(pathway_display, width = 43)]
pathway_pub[, row_key_pub := factor(paste0(pathway_display, "___", LV),
                                    levels = unique(paste0(pathway_display, "___", LV)))]

plot_E_pathways <- ggplot(pathway_pub, aes(AUC, row_key_pub)) +
  geom_segment(aes(x = 0.45, xend = AUC, yend = row_key_pub),
               color = "grey78", linewidth = 0.25, linetype = "dotted") +
  geom_point(aes(color = neg_log_fdr, size = AUC)) +
  scale_color_gradientn(colors = GREEN_PATHWAY, limits = c(0, 3),
                        name = expression("-" * log[10] ~ "FDR")) +
  guides(color = guide_colorbar(title.position = "top",
                                 barheight = unit(10, "mm"),
                                 barwidth = unit(1.6, "mm"))) +
  scale_size_continuous(range = c(0.6, 1.8), guide = "none") +
  scale_x_continuous(limits = c(0.45, 1), breaks = seq(0.5, 1, 0.25)) +
  scale_y_discrete(labels = strip_lv_suffix) +
  facet_wrap(~LV, ncol = 1, scales = "free_y") +
  labs(x = "AUC", y = "GO:BP") +
  theme_nm() +
  theme(panel.grid.major.y = element_line(color = "grey88", linewidth = 0.18,
                                          linetype = "dotted"),
        strip.background = element_blank(),
        strip.text = element_text(size = 5.3, face = "bold", margin = margin(0.4, 0, 0.4, 0)),
        axis.text.x = element_text(size = MIN_FONT_PT),
        axis.text.y = element_text(size = MIN_FONT_PT),
        axis.title = element_text(size = 5.8),
        legend.position = "right", legend.text = element_text(size = MIN_FONT_PT),
        legend.title = element_text(size = 5),
        plot.margin = margin(0.5, 0.5, 0.8, 1.5))

plot_G_pub <- plot_grid(plot_F_scatter, NULL, plot_E_pathways, ncol = 1,
                        rel_heights = c(1.52, 0.10, 0.68))

# Additional Figure 2 panels assembled from canonical workflow exports.

FONT_FAMILY <- "Helvetica"

# E: ranked CLAMPfull gene loadings for the four displayed hard cell-type pairs.
loading_ready <- fread(snakemake@input[["hard_pair_loading_ready"]])
loading_stats <- fread(snakemake@input[["hard_pair_loading_stats"]])
loading_stats <- loading_stats[shown == TRUE]
stopifnot(unique(loading_stats$marker_source) == "Azimuth 2023",
          unique(loading_ready$marker_source) == "Azimuth 2023")
loading_ready <- loading_ready[pair_id %in% loading_stats$pair_id]

LOADING_OTHER <- "#D0D0D0"

compact_pair_title <- function(x) {
  if (grepl("^01_", x)) return(PAIR_DISPLAY_TITLES[["1"]])
  if (grepl("^02_", x)) return(PAIR_DISPLAY_TITLES[["2"]])
  if (grepl("^04_", x)) return(PAIR_DISPLAY_TITLES[["4"]])
  if (grepl("^06_", x)) return(PAIR_DISPLAY_TITLES[["6"]])
  x <- sub("^[0-9]+_", "", x)
  x <- gsub("_vs_", " vs. ", x)
  x <- gsub("Atrial vs. Ventricular", "Atrial vs. ventricular CM", x)
  x <- gsub("Ast vs. Mic", "Astrocyte vs. microglia", x)
  x <- gsub("CD4 vs. CD8", "CD4+ vs. CD8+ T cells", x)
  x <- gsub("B vs. T", "B vs. T cells", x)
  x
}

compact_loading_ct <- function(x) {
  x <- gsub("_", " ", x, fixed = TRUE)
  x <- gsub("VentricularCM", "Ventricular CM", x, fixed = TRUE)
  x <- gsub("AtrialCM", "Atrial CM", x, fixed = TRUE)
  x <- gsub("B cell", "B cell", x, fixed = TRUE)
  x
}

format_loading_p <- function(p) {
  if (is.na(p)) return("P n.a.")
  if (p < 1e-3) {
    exponent <- floor(log10(p))
    mantissa <- p / 10^exponent
    superscript <- chartr("-0123456789", "⁻⁰¹²³⁴⁵⁶⁷⁸⁹",
                         as.character(exponent))
    return(sprintf("P=%.1f×10%s", mantissa, superscript))
  }
  sprintf("P=%.3f", p)
}

make_loading_side <- function(pid, side) {
  d <- copy(loading_ready[pair_id == pid & panel_side == side])
  s <- loading_stats[pair_id == pid & panel_side == side]
  stopifnot(nrow(s) == 1L)
  first_set <- canonical_pair_set(s$set_A_label)
  second_set <- canonical_pair_set(s$set_B_label)
  d[, set_name := fifelse(grp == "A", first_set,
                   fifelse(grp == "B", second_set,
                     fifelse(grp == "shared", "Shared marker", "Other")))]
  d[, set_name := factor(set_name, levels = c("Other", PAIR_LEGEND_ORDER))]
  recovered_set <- if (side == "A") first_set else second_set
  n_recovered <- d[as.character(set_name) == recovered_set, .N]
  n_available <- if (side == "A") s$n_A_excl else s$n_B_excl
  label_d <- d[is_label == TRUE][order(rank)][seq_len(min(.N, 5L))]

  ggplot(d, aes(rank, loading)) +
    geom_point(data = d[set_name == "Other"], colour = LOADING_OTHER,
               size = 0.12, alpha = 0.65) +
    geom_point(data = d[set_name != "Other"], aes(colour = set_name),
               size = 0.48, alpha = 0.9) +
    ggrepel::geom_text_repel(
      data = label_d, aes(label = gene, colour = set_name),
      size = MIN_GEOM_TEXT, fontface = "italic", seed = 42, max.overlaps = Inf,
      min.segment.length = 0, segment.size = 0.14, segment.alpha = 0.38,
      box.padding = 0.12,
      point.padding = 0.08, show.legend = FALSE
    ) +
    annotate("text", x = Inf, y = Inf,
             label = sprintf("%d/%d", n_recovered, n_available),
             colour = PAIR_SET_COLORS[[recovered_set]],
             hjust = 1.05, vjust = 1.25, size = MIN_GEOM_TEXT,
             fontface = "bold", family = FONT_FAMILY) +
    scale_colour_manual(
      values = PAIR_SET_COLORS,
      breaks = PAIR_LEGEND_ORDER,
      drop = FALSE, name = "Azimuth gene set"
    ) +
    scale_x_continuous(expand = expansion(mult = c(0.015, 0.08))) +
    labs(
      x = NULL, y = NULL,
      title = sprintf("%s %s", compact_loading_ct(s$cell_type), s$LV),
      subtitle = sprintf("%.2f/%.2f; %s",
                         s$auc_own, s$auc_other, format_loading_p(s$wilcox_p))
    ) +
    theme_nm() +
    theme(
      axis.text = element_text(size = MIN_FONT_PT),
      axis.title = element_blank(),
      plot.title = element_text(size = MIN_FONT_PT, face = "bold", hjust = 0.5,
                                margin = margin(b = 0.1)),
      plot.subtitle = element_text(size = MIN_FONT_PT, colour = "grey25", hjust = 0.5,
                                   margin = margin(b = 0.3)),
      legend.position = "none",
      plot.margin = margin(0.6, 0.7, 0.7, 0.7, "mm")
    )
}

loading_pair_ids <- intersect(
  c("01_B_vs_T", "02_CD4_vs_CD8", "04_Ast_vs_Mic",
    "06_Atrial_vs_Ventricular"),
  unique(loading_stats$pair_id)
)
stopifnot(length(loading_pair_ids) == 4L)
loading_pair_blocks <- lapply(loading_pair_ids, function(pid) {
  pair_body <- plot_grid(make_loading_side(pid, "A"), make_loading_side(pid, "B"),
                         nrow = 1, align = "h", axis = "tb")
  pair_title <- ggdraw() + draw_label(compact_pair_title(pid), x = 0.5, y = 0.5,
                                      size = 5.6, fontface = "bold",
                                      fontfamily = FONT_FAMILY)
  plot_grid(pair_title, pair_body, ncol = 1, rel_heights = c(0.12, 0.88))
})

loading_legend_data <- data.table(
  set_name = factor(PAIR_LEGEND_ORDER, levels = PAIR_LEGEND_ORDER),
  x = 1, y = 1
)
loading_legend <- get_legend(
  ggplot(loading_legend_data, aes(x, y, colour = set_name)) +
    geom_point(size = 1.5) +
    scale_colour_manual(values = PAIR_SET_COLORS, breaks = PAIR_LEGEND_ORDER,
                        labels = c("B cell", "T cell", "CD4+ T", "CD8+ T",
                                   "Astrocyte", "Microglia", "Atrial CM",
                                   "Ventric. CM", "Shared"),
                        drop = FALSE, name = "Azimuth gene set") +
    guides(colour = guide_legend(ncol = 1, byrow = TRUE,
                                 title.position = "top", title.hjust = 0.5,
                                 override.aes = list(size = 1.5))) +
    theme_void(base_family = FONT_FAMILY) +
    theme(legend.position = "right", legend.direction = "vertical",
          legend.text = element_text(size = MIN_FONT_PT),
          legend.title = element_text(size = 5),
          legend.key.width = unit(1.8, "mm"), legend.key.height = unit(1.4, "mm"),
          legend.spacing.x = unit(0.5, "mm"),
          legend.spacing.y = unit(0, "mm"),
          legend.margin = margin(0, 0, 0, 0))
)
loading_grid <- plot_grid(plotlist = loading_pair_blocks, ncol = 2)
loading_grid_labeled <- ggdraw() +
  draw_plot(loading_grid, x = 0.04, y = 0.075, width = 0.96, height = 0.925) +
  draw_label("Genes ranked by loading", x = 0.51, y = 0.060,
             hjust = 0.5, vjust = 0, size = 5.2, fontfamily = FONT_FAMILY) +
  draw_label("CLAMPfull gene loading", x = 0.012, y = 0.54, angle = 90,
             hjust = 0.5, vjust = 0.5, size = 5.2, fontfamily = FONT_FAMILY)
plot_E_loading <- plot_grid(loading_grid_labeled, loading_legend,
                            nrow = 1, rel_widths = c(0.82, 0.18))

# G: multitissue xCell/CellMarker recovery from notebook 06's panel-ready export.
multi <- fread(snakemake@input[["multitissue_panel_ready"]])
multi[, short := factor(short, levels = unique(short))]
multi[, cell_type := factor(cell_type, levels = unique(cell_type))]
multi_lv <- unique(multi[, .(tissue, short, LV, shap_pct, rank, ora_term, ora_fold,
                              ora_genes, ora_neg_log10_fdr)])
setorder(multi_lv, short, rank)
multi_lv[, term_clean := fifelse(is.na(ora_term) | !nzchar(ora_term), "n.s.",
                          fifelse(nchar(ora_term) > 18,
                                  paste0(substr(ora_term, 1, 17), "…"), ora_term))]
multi_lv[, key := paste(tissue, LV)]
multi_row_labels <- rev(sprintf("%s (%.1f%%) · %s", multi_lv$LV, multi_lv$shap_pct,
                                multi_lv$term_clean))
multi_lv[, row_id := factor(key, levels = rev(key), labels = multi_row_labels)]
multi[, row_id := factor(paste(tissue, LV), levels = rev(multi_lv$key),
                         labels = multi_row_labels)]

multi_ora <- ggplot(multi_lv, aes(ora_fold, row_id)) +
  geom_hline(yintercept = 0.5, colour = "grey65", linewidth = 0.28) +
  geom_segment(aes(x = 0, xend = ora_fold, yend = row_id), colour = "grey78",
               linewidth = 0.25, linetype = "dotted", na.rm = TRUE) +
  geom_point(aes(colour = ora_neg_log10_fdr, size = ora_genes), na.rm = TRUE) +
  facet_grid(short ~ ., scales = "free_y", space = "free_y", switch = "y",
             labeller = labeller(short = function(x)
               gsub(" ", "\n", x, fixed = TRUE))) +
  scale_colour_gradientn(colours = GREEN_PATHWAY,
                         name = expression("-" * log[10] ~ "FDR")) +
  scale_size_continuous(range = c(0.7, 2.8), name = "Genes", breaks = c(5, 15, 25)) +
  guides(
    colour = guide_colourbar(order = 1, title.position = "top", title.hjust = 0.5,
                             barwidth = unit(10, "mm"),
                             barheight = unit(1.0, "mm")),
    size = guide_legend(order = 2, title.position = "top", nrow = 1,
                        override.aes = list(size = c(0.8, 1.2, 1.7)))
  ) +
  scale_x_continuous(expand = expansion(mult = c(0, 0.10))) +
  labs(x = "CellMarker fold enrichment", y = NULL) +
  theme_nm() +
  theme(strip.placement = "outside", strip.background = element_blank(),
        strip.text.y.left = element_text(angle = 0, face = "bold", size = MIN_FONT_PT,
                                         hjust = 1),
        axis.text.y = element_text(size = MIN_FONT_PT, lineheight = 0.88),
        axis.text.x = element_text(size = MIN_FONT_PT), axis.title.x = element_text(size = MIN_FONT_PT),
        legend.position = "bottom", legend.box = "horizontal",
        legend.box.just = "center", legend.spacing.x = unit(0.6, "mm"),
        legend.spacing.y = unit(0, "mm"),
        legend.text = element_text(size = MIN_FONT_PT), legend.title = element_text(size = MIN_FONT_PT),
        legend.key.width = unit(1.8, "mm"), legend.key.height = unit(1.35, "mm"),
        legend.margin = margin(0, 0, 0, 0),
        panel.spacing.y = unit(0.2, "mm"),
        plot.margin = margin(0.5, 0.5, 0.5, 0.5))

multi_fill_vals <- c(0, .20, .375, .4583, .4584, .5416, .5417, .625, .80, 1)
multi_fill_cols <- c("#67001f", "#b2182b", "#d6604d", "#f4a582", "white", "white",
                     "#a1d9b6", "#57b37e", "#007a33", "#00431e")
multi_xcell <- ggplot(multi, aes(cell_type, row_id)) +
  geom_hline(yintercept = 0.5, colour = "grey65", linewidth = 0.28) +
  geom_tile(data = multi[is_dominant == TRUE], fill = NA, colour = "grey20",
            linewidth = 0.35, width = 0.98, height = 0.98) +
  geom_point(aes(size = top1pct, fill = l2fc_shap), shape = 21, stroke = 0.12,
             colour = "grey40") +
  facet_grid(short ~ ., scales = "free_y", space = "free_y",
             labeller = labeller(short = function(x)
               gsub(" ", "\n", x, fixed = TRUE))) +
  scale_size_binned(name = "xCell score", breaks = c(.1, .25, .5, .9),
                    limits = c(0, max(multi$top1pct)), range = c(.45, 3.8)) +
  scale_fill_gradientn(colours = multi_fill_cols, values = multi_fill_vals,
                       limits = c(-6, 6), oob = scales::squish,
                       breaks = c(-6, -3, 0, 3, 6),
                       labels = c("≤-6", "-3", "0", "3", "≥6"),
                       name = expression(log[2] ~ "FC SHAP")) +
  guides(
    size = guide_legend(order = 1, title.position = "top", nrow = 1,
                        override.aes = list(size = c(0.7, 1.0, 1.4, 1.8))),
    fill = guide_colourbar(order = 2, title.position = "top", title.hjust = 0.5,
                           barwidth = unit(11.5, "mm"),
                           barheight = unit(1.0, "mm"))
  ) +
  labs(x = NULL, y = NULL) +
  theme_nm() +
  theme(axis.text.x = element_text(angle = 40, hjust = 1, size = MIN_FONT_PT),
        axis.text.y = element_blank(), axis.ticks.y = element_blank(),
        strip.background = element_blank(), strip.text.y = element_blank(),
        legend.position = "bottom", legend.box = "horizontal",
        legend.box.just = "center", legend.spacing.x = unit(0.6, "mm"),
        legend.spacing.y = unit(0, "mm"),
        legend.text = element_text(size = MIN_FONT_PT), legend.title = element_text(size = MIN_FONT_PT),
        legend.key.width = unit(1.8, "mm"), legend.key.height = unit(1.35, "mm"),
        legend.margin = margin(0, 0, 0, 0),
        panel.spacing.y = unit(0.2, "mm"),
        plot.margin = margin(0.5, 0.5, 0.5, 0.5))

multi_legends <- plot_grid(get_plot_component(multi_ora, "guide-box-bottom"),
                           get_plot_component(multi_xcell, "guide-box-bottom"),
                           nrow = 1, rel_widths = c(1.3, 1.4))
multi_body <- plot_grid(multi_ora + theme(legend.position = "none"),
                        multi_xcell + theme(legend.position = "none"),
                        nrow = 1, rel_widths = c(1.35, 1.45), align = "h", axis = "tb")
plot_G_xcell <- plot_grid(multi_body, multi_legends, ncol = 1,
                          rel_heights = c(1, 0.17))


# G/H: donor-bulk held-out recovery and projection back to PBMC Perez cells.
donor_predictions <- fread(snakemake@input[["donor_bulk_predictions"]])
donor_statistics <- fread(snakemake@input[["donor_bulk_statistics"]])
perez_annotation <- fread(snakemake@input[["donor_bulk_perez_annotation"]])
perez_activity <- fread(snakemake@input[["donor_bulk_perez_activity"]])
perez_summary <- fread(snakemake@input[["donor_bulk_perez_summary"]])

donor_predictions[, panel_label := DATASET_LABELS[dataset]]
donor_plot_statistics <- copy(donor_statistics)
stopifnot(all(is.finite(donor_plot_statistics$mean_predictive_r2)))
donor_plot_statistics[, panel_label := DATASET_LABELS[dataset]]
donor_predictions[, panel_label := factor(panel_label, levels=panel_levels)]
donor_plot_statistics[, panel_label := factor(panel_label, levels=panel_levels)]
donor_plot_statistics[, r2_label := sprintf('R^2 == %.2f', mean_predictive_r2)]
plot_G_scatter <- ggplot(donor_predictions, aes(observed, predicted)) +
  geom_abline(slope=1, intercept=0, color="grey25",
              linetype="dashed", linewidth=0.25) +
  geom_point(aes(color=panel_label), alpha=0.28, size=0.16,
             show.legend=FALSE) +
  geom_text(data=donor_plot_statistics,
            aes(x=0.025, y=0.975, label=r2_label), inherit.aes=FALSE,
            hjust=0, vjust=1, size=MIN_GEOM_TEXT, parse=TRUE) +
  facet_wrap(~panel_label, ncol=3) +
  coord_cartesian(xlim=c(0,1), ylim=c(0,1), expand=FALSE) +
  scale_x_continuous(breaks=seq(0,1,0.25),
    labels=c("0","0.25","0.50","0.75","1.00")) +
  scale_y_continuous(breaks=seq(0,1,0.25),
    labels=c("0","0.25","0.50","0.75","1.00")) +
  scale_color_manual(values=DATASET_COLORS) +
  labs(x="True donor cell proportion", y="Predicted donor cell proportion") +
  theme_nm() +
  theme(aspect.ratio=1, axis.text=element_text(size=MIN_FONT_PT),
        axis.title=element_text(size=6),
        panel.spacing.x=unit(2.0, "mm"),
        panel.spacing.y=unit(1.7, "mm"),
        strip.text=element_text(size=5.2, face="bold", margin=margin(b=0.5)),
        plot.margin=margin(3.4, 1.2, 0.8, 1.3))

PEREZ_COLORS <- c(B_cell = "#4477AA", Myeloid = "#EE6677",
                  NK = "#228833", T_cell = "#CCBB44")
PEREZ_LABELS <- c(B_cell = "B cell", Myeloid = "Myeloid",
                  NK = "NK", T_cell = "T cell")
perez_annotation[, mapped_cell_type := factor(mapped_cell_type, levels = names(PEREZ_COLORS))]
perez_centroids <- perez_annotation[, .(umap1 = median(umap1), umap2 = median(umap2)),
                                     by = mapped_cell_type]
perez_xr <- range(perez_annotation$umap1, finite = TRUE)
perez_yr <- range(perez_annotation$umap2, finite = TRUE)
perez_span <- max(diff(perez_xr), diff(perez_yr)) * 1.08
perez_xlim <- mean(perez_xr) + c(-0.5, 0.5) * perez_span
perez_ylim <- mean(perez_yr) + c(-0.5, 0.5) * perez_span
map_theme_H <- theme_void(base_family = FONT_FAMILY, base_size = MIN_FONT_PT) +
  theme(panel.border = element_rect(colour = "black", fill = NA, linewidth = 0.25),
    plot.title = element_text(size = MIN_FONT_PT, hjust = 0.5, lineheight = 0.95,
                              margin = margin(0, 0, 0.4, 0, "mm")),
    plot.margin = margin(0.5, 0.4, 0.4, 0.4, "mm"))
plot_H_annotation <- ggplot(perez_annotation, aes(umap1, umap2, colour = mapped_cell_type)) +
  ggrastr::rasterise(geom_point(size = 0.18, alpha = 0.80), dpi = 300) +
  geom_text(data = perez_centroids, aes(label = mapped_cell_type), colour = "black",
            size = MIN_GEOM_TEXT, fontface = "bold", family = FONT_FAMILY, check_overlap = TRUE) +
  scale_colour_manual(values = PEREZ_COLORS) +
  coord_equal(xlim = perez_xlim, ylim = perez_ylim, expand = FALSE) +
  labs(title = "Cell-type annotation") +
  map_theme_H + theme(legend.position = "none",
                      plot.title = element_text(size = MIN_FONT_PT, face = "bold"))
perez_types_H <- names(PEREZ_COLORS)
plot_H_features <- lapply(perez_types_H, function(ct) {
  dat <- perez_activity[cell_type == ct]
  stopifnot(nrow(dat) > 0L, uniqueN(dat$LV) == 1L)
  ggplot(dat, aes(umap1, umap2, colour = activity)) +
    ggrastr::rasterise(geom_point(size = 0.18), dpi = 300) +
    scale_colour_gradientn(colours = c("#D8E2EF", "white", PEREZ_COLORS[[ct]])) +
    coord_equal(xlim = perez_xlim, ylim = perez_ylim, expand = FALSE) +
    labs(title = sprintf("%s · %s", PEREZ_LABELS[[ct]], unique(dat$LV))) +
    map_theme_H + theme(legend.position = "none")
})
perez_features_H <- plot_grid(plotlist = plot_H_features, ncol = 2, align = "hv")
perez_maps_core_H <- plot_grid(plot_H_annotation, perez_features_H, nrow = 1,
                               rel_widths = c(0.42, 0.58))
perez_maps_H <- plot_grid(NULL, perez_maps_core_H, NULL, nrow = 1,
                          rel_widths = c(0.015, 0.97, 0.015))
perez_auc_H <- perez_summary$median_auroc[[1]]
perez_r_H <- perez_summary$median_bulk_r[[1]]
perez_header_H <- ggdraw() +
  draw_label(sprintf("PBMC: Perez     AUROC = %.2f     r = %.2f",
                     perez_auc_H, perez_r_H),
             x = 0.5, y = 0.5, hjust = 0.5, size = MIN_FONT_PT,
             fontface = "bold", fontfamily = FONT_FAMILY)
perez_block_H <- plot_grid(perez_header_H, perez_maps_H, ncol = 1,
                           rel_heights = c(0.16, 0.84))

row_AB_pub <- plot_grid(add_tag(plot_A_pub, "A"),
                        add_tag(plot_C_pub, "B"),
                        nrow = 1, rel_widths = c(0.44, 0.56))
module_compact_panels <- lapply(module_pub_panels, function(p)
  p + theme(legend.position = "none",
            axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5, size = MIN_FONT_PT),
            axis.text.y = element_text(size = MIN_FONT_PT),
            plot.title = element_text(size = MIN_FONT_PT)))
plot_E_marker_compact <- plot_grid(
  plot_grid(plotlist = module_compact_panels, ncol = 2),
  module_legend, ncol = 1, rel_heights = c(1, 0.075)
)
brain_core_G <- brain_pub +
  coord_fixed(ratio = 1.28) +
  labs(x = NULL, y = NULL) +
  theme(legend.position = "none", plot.margin = margin(0.2, 0.2, 0.2, 0.2))
small_grid_G <- wrap_plots(lapply(small_pub, function(p)
  p + coord_fixed(ratio = 1.22) +
    theme(legend.position = "none", axis.text = element_text(size = MIN_FONT_PT),
            plot.margin = margin(0.1, 0.1, 0.1, 0.1))), ncol = 2)
brain_legend_bottom_G <- get_legend(
  brain_pub +
    guides(fill = guide_colourbar(title = "True fraction",
                                  title.position = "top", title.hjust = 0.5,
                                  direction = "horizontal",
                                  barwidth = unit(15, "mm"),
                                  barheight = unit(1.2, "mm"))) +
    theme(legend.position = "bottom", legend.direction = "horizontal",
          legend.title = element_text(size = MIN_FONT_PT, hjust = 0.5),
          legend.text = element_text(size = MIN_FONT_PT),
          legend.margin = margin(0, 0, 0, 0))
)
G_matrix_body <- plot_grid(brain_core_G, small_grid_G, nrow = 1,
                           rel_widths = c(1.10, 0.90))
plot_G_confusion <- ggdraw() +
  draw_plot(G_matrix_body, x = 0.025, y = 0.10, width = 0.975, height = 0.90) +
  draw_label("Predicted region", x = 0.52, y = 0.125,
             size = MIN_FONT_PT, fontfamily = FONT_FAMILY) +
  draw_grob(brain_legend_bottom_G, x = 0.37, y = 0.005,
            width = 0.30, height = 0.085) +
  draw_label("True region", x = 0.012, y = 0.56, angle = 90,
             size = MIN_FONT_PT, fontfamily = FONT_FAMILY)
multi_ora_legend_H <- get_plot_component(multi_ora, "guide-box-bottom")
multi_xcell_legend_H <- get_plot_component(multi_xcell, "guide-box-bottom")
multi_ora_legend_aligned_H <- ggdraw() +
  draw_grob(multi_ora_legend_H, x = 0.34, y = 0.18,
            width = 0.66, height = 0.82)
multi_legends_H <- plot_grid(
  multi_ora_legend_aligned_H,
  multi_xcell_legend_H,
  nrow = 1, rel_widths = c(1.35, 1.45), align = "h"
)
plot_H_xcell <- plot_grid(multi_body, multi_legends_H, ncol = 1,
                          rel_heights = c(1, 0.10))
row_CDE_pub <- plot_grid(add_tag(plot_D_pair_pub, "C"),
                         add_tag(plot_E_pub, "D"),
                         add_tag(plot_E_loading, "E"),
                         nrow = 1, rel_widths = c(0.20, 0.20, 0.60))
row_FG_pub <- plot_grid(add_tag(plot_G_scatter, "F"), NULL,
                        add_tag(perez_block_H, "G"),
                        nrow = 1, rel_widths = c(0.49, 0.015, 0.495))
row_HI_pub <- plot_grid(add_tag(plot_G_confusion, "H"),
                        add_tag(plot_H_xcell, "I"),
                        nrow = 1, rel_widths = c(1, 1))
fig2 <- plot_grid(row_AB_pub, row_CDE_pub, row_FG_pub, NULL, row_HI_pub,
                  ncol = 1, rel_heights = c(0.22, 0.27, 0.22, 0.01, 0.28))

raw_pdf <- tempfile(fileext = ".pdf")
exact_pdf <- tempfile(fileext = ".pdf")
ggsave(raw_pdf, fig2,
       width = FIG_W, height = FIG_H, units = "mm",
       device = cairo_pdf, bg = "white", limitsize = FALSE)
pdf_w_pt <- FIG_W / 25.4 * 72
pdf_h_pt <- FIG_H / 25.4 * 72
gs_status <- system2("gs", c(
  "-q", "-dNOPAUSE", "-dBATCH", "-sDEVICE=pdfwrite",
  sprintf("-dDEVICEWIDTHPOINTS=%.6f", pdf_w_pt),
  sprintf("-dDEVICEHEIGHTPOINTS=%.6f", pdf_h_pt),
  "-dFIXEDMEDIA", "-dPDFFitPage",
  paste0("-sOutputFile=", exact_pdf), raw_pdf
))
stopifnot(gs_status == 0L, file.copy(exact_pdf, snakemake@output[["pdf"]],
                                      overwrite = TRUE))
unlink(c(raw_pdf, exact_pdf))
ggsave(snakemake@output[["svg"]], fig2,
       width = FIG_W, height = FIG_H, units = "mm",
       device = svglite::svglite, bg = "white", limitsize = FALSE)
ggsave(snakemake@output[["png"]], fig2,
       width = FIG_W, height = FIG_H, units = "mm", dpi = 600,
       device = ragg::agg_png, bg = "white", limitsize = FALSE)

cat(sprintf("fig2: %.0f x %.0f mm, one-page Nature Methods main figure\n", FIG_W, FIG_H))
cat("output directory:", dirname(snakemake@output[["pdf"]]), "\n")
options(repr.plot.width = FIG_W / 25.4, repr.plot.height = FIG_H / 25.4)
fig2
# Out:
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# ...
